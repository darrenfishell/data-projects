# %% [markdown]
# ## Maine Senate overview script
#
# This file pulls in individual contributions to all Senate committees as well as independent expenditures to support or oppose the candidates _and_ party-coordinated expenditures to support or oppose the candidates.
#
# The data fuels a dashboard that contains an overview of the race so far. It also provides the information to reconcile itemized contribution data with campaign totals available from the FEC.
#
# All of the files are written to a repository at data.world, where they are combined together in SQL scripts to fuel Tableau Public dashboards.

# %%
import numpy as np
import pandas as pd
import requests
import config
import os
import datadotworld as dw
from pandas.io.json import json_normalize

##Schedule_a API guide: https://api.open.fec.gov/developers/#/receipts/get_schedules_schedule_a_˜

# %%
### INDIVIDUAL DONATIONS TO MAINE SENATE CAMPAIGNS ###
## SENATE COMMITTEE SEARCH ##
#Set search for all 2020 (two-year transaction period) Maine Senate candidates
cand_state = 'ME'
cycle='2020'
parameters = {'election_year':cycle
            ,'state':cand_state
#             ,'office':'S'
            ,'api_key':config.api_key}

#Requests candidate info
r_cands = requests.get('https://api.open.fec.gov/v1/candidates/search',params=parameters).json()

#Locates and sets Committee ID from 'principal_committees' sub-array
#Output list of IDs
comm_ids=json_normalize(data=r_cands['results'],record_path='principal_committees')['committee_id'].tolist()

# %%
replace_dict = {
    '<td>':''
    ,'</td>':''
   ,r'\[|\]':''
   ,r'\\n|\\t':''
   ,r"\'":''
}
## Create and publish candidate id - committee id table
lkup = json_normalize(data=r_cands['results'])[['candidate_id'
                                                ,'name'
                                                ,'party_full'
                                                ,'incumbent_challenge_full'
                                                ,'office_full'
                                                ,'first_file_date']]
lkup2 = json_normalize(data=r_cands['results'],record_path='principal_committees')[['candidate_ids','committee_id','name']].astype(str)
#Eliminate <td> tags
lkup2.replace(replace_dict,regex=True,inplace=True)
lkup = lkup.merge(lkup2,left_on='candidate_id',right_on='candidate_ids')

colnm = {
    'name_x':'candidate_name'
    ,'name_y':'committee_name'
}
lkup.rename(columns=colnm,inplace=True)
lkup.drop(columns='candidate_ids',inplace=True)

#Write out files to data.world
with dw.open_remote_file('darrenfishell/2020-election-repo','candidate_committee_lookup.csv') as w:
    lkup.to_csv(w,index=False)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-2-6ef3320f7816> in <module>
#       7 }
#       8 ## Create and publish candidate id - committee id table
# ----> 9 lkup = json_normalize(data=r_cands['results'])[['candidate_id'
#      10                                                 ,'name'
#      11                                                 ,'party_full'
#
# NameError: name 'r_cands' is not defined

# %%
r_cands['results']
# Out:
# [{'inactive_election_years': None,
#   'party': 'REP',
#   'candidate_inactive': False,
#   'election_districts': ['01'],
#   'active_through': 2020,
#   'last_file_date': '2019-08-18',
#   'federal_funds_flag': False,
#   'incumbent_challenge_full': 'Challenger',
#   'incumbent_challenge': 'C',
#   'last_f2_date': '2019-08-18',
#   'district_number': 1,
#   'office_full': 'House',
#   'load_date': '2019-08-23T22:05:29+00:00',
#   'candidate_status': 'N',
#   'has_raised_funds': False,
#   'first_file_date': '2019-08-10',
#   'district': '01',
#   'cycles': [2020],
#   'party_full': 'REPUBLICAN PARTY',
#   'candidate_id': 'H0ME01119',
#   'state': 'ME',
#   'name': 'ALLEN, JAY THOMAS',
#   'office': 'H',
#   'election_years': [2020],
#   'principal_committees': [{'party': 'REP',
#     'candidate_ids': ['H0ME01119'],
#     'designation': 'P',
#     'last_f1_date': '2019-12-14',
#     'last_file_date': '2019-12-14',
#     'organization_type_full': None,
#     'affiliated_committee_name': 'NONE',
#     'committee_type_full': 'House',
#     'designation_full': 'Principal campaign committee',
#     'organization_type': None,
#     'filing_frequency': 'Q',
#     'first_file_date': '2019-08-12',
#     'cycles': [2020],
#     'treasurer_name': 'ALLEN, JAY ALLEN',
#     'committee_type': 'H',
#     'party_full': 'REPUBLICAN PARTY',
#     'name': 'JAY ALLEN FOR MAINE',
#     'committee_id': 'C00715532',
#     'state': 'ME'}]},
#  {'inactive_election_years': None,
#   'party': 'REP',
#   'candidate_inactive': False,
#   'election_districts': ['02'],
#   'active_through': 2020,
#   'last_file_date': '2019-10-08',
#   'federal_funds_flag': False,
#   'incumbent_challenge_full': 'Challenger',
#   'incumbent_challenge': 'C',
#   'last_f2_date': '2019-10-08',
#   'district_number': 2,
#   'office_full': 'House',
#   'load_date': '2019-10-18T21:29:17+00:00',
#   'candidate_status': 'N',
#   'has_raised_funds': False,
#   'first_file_date': '2019-10-08',
#   'district': '02',
#   'cycles': [2020],
#   'party_full': 'REPUBLICAN PARTY',
#   'candidate_id': 'H0ME02075',
#   'state': 'ME',
#   'name': 'BENNETT, ADRIENNE',
#   'office': 'H',
#   'election_years': [2020],
#   'principal_committees': [{'party': 'REP',
#     'candidate_ids': ['H0ME02075'],
#     'designation': 'P',
#     'last_f1_date': '2019-10-10',
#     'last_file_date': '2019-10-10',
#     'organization_type_full': None,
#     'affiliated_committee_name': 'NONE',
#     'committee_type_full': 'House',
#     'designation_full': 'Principal campaign committee',
#     'organization_type': None,
#     'filing_frequency': 'Q',
#     'first_file_date': '2019-10-08',
#     'cycles': [2020],
#     'treasurer_name': 'DALE, MICHELLE',
#     'committee_type': 'H',
#     'party_full': 'REPUBLICAN PARTY',
#     'name': 'ADRIENNE FOR CONGRESS',
#     'committee_id': 'C00722108',
#     'state': 'ME'}]},
#  {'inactive_election_years': None,
#   'party': 'REP',
#   'candidate_inactive': False,
#   'election_districts': ['02'],
#   'active_through': 2020,
#   'last_file_date': '2019-07-29',
#   'federal_funds_flag': False,
#   'incumbent_challenge_full': 'Challenger',
#   'incumbent_challenge': 'C',
#   'last_f2_date': '2019-07-29',
#   'district_number': 2,
#   'office_full': 'House',
#   'load_date': '2019-10-25T21:28:14+00:00',
#   'candidate_status': 'C',
#   'has_raised_funds': True,
#   'first_file_date': '2019-07-29',
#   'district': '02',
#   'cycles': [2020],
#   'party_full': 'REPUBLICAN PARTY',
#   'candidate_id': 'H0ME02067',
#   'state': 'ME',
#   'name': 'BRAKEY, ERIC',
#   'office': 'H',
#   'election_years': [2020],
#   'principal_committees': [{'party': 'REP',
#     'candidate_ids': ['H0ME02067'],
#     'designation': 'P',
#     'last_f1_date': '2019-07-29',
#     'last_file_date': '2019-10-15',
#     'organization_type_full': None,
#     'affiliated_committee_name': 'NONE',
#     'committee_type_full': 'House',
#     'designation_full': 'Principal campaign committee',
#     'organization_type': None,
#     'filing_frequency': 'Q',
#     'first_file_date': '2019-07-29',
#     'cycles': [2020],
#     'treasurer_name': 'PHILLIPS, ROBERT III',
#     'committee_type': 'H',
#     'party_full': 'REPUBLICAN PARTY',
#     'name': 'BRAKEY FOR CONGRESS',
#     'committee_id': 'C00713958',
#     'state': 'ME'}]},
#  {'inactive_election_years': None,
#   'party': 'DEM',
#   'candidate_inactive': False,
#   'election_districts': ['00'],
#   'active_through': 2020,
#   'last_file_date': '2018-11-12',
#   'federal_funds_flag': False,
#   'incumbent_challenge_full': 'Challenger',
#   'incumbent_challenge': 'C',
#   'last_f2_date': '2018-11-12',
#   'district_number': 0,
#   'office_full': 'Senate',
#   'load_date': '2019-01-28T21:05:11+00:00',
#   'candidate_status': 'N',
#   'has_raised_funds': False,
#   'first_file_date': '2018-11-12',
#   'district': '00',
#   'cycles': [2018, 2020],
#   'party_full': 'DEMOCRATIC PARTY',
#   'candidate_id': 'S0ME00061',
#   'state': 'ME',
#   'name': 'BUNKER, MICHAEL P MR',
#   'office': 'S',
#   'election_years': [2020],
#   'principal_committees': [{'party': 'DEM',
#     'candidate_ids': ['S0ME00061'],
#     'designation': 'P',
#     'last_f1_date': '2019-07-02',
#     'last_file_date': '2019-07-03',
#     'organization_type_full': None,
#     'affiliated_committee_name': 'NONE',
#     'committee_type_full': 'Senate',
#     'designation_full': 'Principal campaign committee',
#     'organization_type': None,
#     'filing_frequency': 'T',
#     'first_file_date': '2019-06-25',
#     'cycles': [2020],
#     'treasurer_name': 'BUNKER, MICHAEL PHILLIP MR',
#     'committee_type': 'S',
#     'party_full': 'DEMOCRATIC PARTY',
#     'name': 'MICHAEL BUNKER FOR MAINE',
#     'committee_id': 'C00710087',
#     'state': 'ME'}]},
#  {'inactive_election_years': None,
#   'party': 'REP',
#   'candidate_inactive': False,
#   'election_districts': ['00', '00', '00', '00', '00'],
#   'active_through': 2020,
#   'last_file_date': '2019-10-09',
#   'federal_funds_flag': False,
#   'incumbent_challenge_full': 'Incumbent',
#   'incumbent_challenge': 'I',
#   'last_f2_date': '2019-10-09',
#   'district_number': 0,
#   'office_full': 'Senate',
#   'load_date': '2019-10-09T21:11:04+00:00',
#   'candidate_status': 'C',
#   'has_raised_funds': True,
#   'first_file_date': '1996-02-22',
#   'district': '00',
#   'cycles': [1996,
#    1998,
#    2000,
#    2002,
#    2004,
#    2006,
#    2008,
#    2010,
#    2012,
#    2014,
#    2016,
#    2018,
#    2020],
#   'party_full': 'REPUBLICAN PARTY',
#   'candidate_id': 'S6ME00159',
#   'state': 'ME',
#   'name': 'COLLINS, SUSAN M.',
#   'office': 'S',
#   'election_years': [1996, 2002, 2008, 2014, 2020],
#   'principal_committees': [{'party': 'REP',
#     'candidate_ids': ['S6ME00159'],
#     'designation': 'P',
#     'last_f1_date': '2019-10-09',
#     'last_file_date': '2019-10-15',
#     'organization_type_full': None,
#     'affiliated_committee_name': 'COLLINS VICTORY COMMITEE',
#     'committee_type_full': 'Senate',
#     'designation_full': 'Principal campaign committee',
#     'organization_type': None,
#     'filing_frequency': 'Q',
#     'first_file_date': '1996-02-23',
#     'cycles': [1996,
#      1998,
#      2000,
#      2002,
#      2004,
#      2006,
#      2008,
#      2010,
#      2012,
#      2014,
#      2016,
#      2018,
#      2020],
#     'treasurer_name': 'MCCANDLESS, ELIZABETH T.',
#     'committee_type': 'S',
#     'party_full': 'REPUBLICAN PARTY',
#     'name': 'COLLINS FOR SENATOR',
#     'committee_id': 'C00314575',
#     'state': 'ME'}]},
#  {'inactive_election_years': None,
#   'party': 'REP',
#   'candidate_inactive': False,
#   'election_districts': ['02'],
#   'active_through': 2020,
#   'last_file_date': '2019-10-10',
#   'federal_funds_flag': False,
#   'incumbent_challenge_full': 'Challenger',
#   'incumbent_challenge': 'C',
#   'last_f2_date': '2019-10-10',
#   'district_number': 2,
#   'office_full': 'House',
#   'load_date': '2019-10-18T21:29:17+00:00',
#   'candidate_status': 'N',
#   'has_raised_funds': False,
#   'first_file_date': '2019-10-10',
#   'district': '02',
#   'cycles': [2020],
#   'party_full': 'REPUBLICAN PARTY',
#   'candidate_id': 'H0ME02083',
#   'state': 'ME',
#   'name': 'CRAFTS, DALE',
#   'office': 'H',
#   'election_years': [2020],
#   'principal_committees': [{'party': 'REP',
#     'candidate_ids': ['H0ME02083'],
#     'designation': 'P',
#     'last_f1_date': '2019-10-10',
#     'last_file_date': '2019-10-10',
#     'organization_type_full': None,
#     'affiliated_committee_name': 'NONE',
#     'committee_type_full': 'House',
#     'designation_full': 'Principal campaign committee',
#     'organization_type': None,
#     'filing_frequency': 'Q',
#     'first_file_date': '2019-10-10',
#     'cycles': [2020],
#     'treasurer_name': 'TIMBERLAKE, JEFFREY L',
#     'committee_type': 'H',
#     'party_full': 'REPUBLICAN PARTY',
#     'name': 'DALE CRAFTS FOR CONGRESS',
#     'committee_id': 'C00722454',
#     'state': 'ME'}]},
#  {'inactive_election_years': None,
#   'party': 'DEM',
#   'candidate_inactive': False,
#   'election_districts': ['00'],
#   'active_through': 2020,
#   'last_file_date': '2019-09-30',
#   'federal_funds_flag': False,
#   'incumbent_challenge_full': 'Challenger',
#   'incumbent_challenge': 'C',
#   'last_f2_date': '2019-09-30',
#   'district_number': 0,
#   'office_full': 'Senate',
#   'load_date': '2019-10-01T21:13:53+00:00',
#   'candidate_status': 'C',
#   'has_raised_funds': True,
#   'first_file_date': '2019-06-24',
#   'district': '00',
#   'cycles': [2020],
#   'party_full': 'DEMOCRATIC PARTY',
#   'candidate_id': 'S0ME00111',
#   'state': 'ME',
#   'name': 'GIDEON, SARA',
#   'office': 'S',
#   'election_years': [2020],
#   'principal_committees': [{'party': 'DEM',
#     'candidate_ids': ['S0ME00111'],
#     'designation': 'P',
#     'last_f1_date': '2019-09-30',
#     'last_file_date': '2019-10-15',
#     'organization_type_full': None,
#     'affiliated_committee_name': 'VAN HOLLEN/GIDEON JOINT FUND 2020',
#     'committee_type_full': 'Senate',
#     'designation_full': 'Principal campaign committee',
#     'organization_type': None,
#     'filing_frequency': 'Q',
#     'first_file_date': '2019-06-24',
#     'cycles': [2020],
#     'treasurer_name': 'LUNN, LISA MS.',
#     'committee_type': 'S',
#     'party_full': 'DEMOCRATIC PARTY',
#     'name': 'SARA GIDEON FOR MAINE',
#     'committee_id': 'C00709899',
#     'state': 'ME'}]},
#  {'inactive_election_years': None,
#   'party': 'DEM',
#   'candidate_inactive': False,
#   'election_districts': ['02', '02'],
#   'active_through': 2020,
#   'last_file_date': '2019-12-16',
#   'federal_funds_flag': False,
#   'incumbent_challenge_full': 'Incumbent',
#   'incumbent_challenge': 'I',
#   'last_f2_date': '2019-12-16',
#   'district_number': 2,
#   'office_full': 'House',
#   'load_date': '2019-12-16T21:09:32+00:00',
#   'candidate_status': 'C',
#   'has_raised_funds': True,
#   'first_file_date': '2017-08-24',
#   'district': '02',
#   'cycles': [2018, 2020],
#   'party_full': 'DEMOCRATIC PARTY',
#   'candidate_id': 'H8ME02185',
#   'state': 'ME',
#   'name': 'GOLDEN, JARED',
#   'office': 'H',
#   'election_years': [2018, 2020],
#   'principal_committees': [{'party': 'DEM',
#     'candidate_ids': ['H8ME02185'],
#     'designation': 'P',
#     'last_f1_date': '2019-12-16',
#     'last_file_date': '2019-12-16',
#     'organization_type_full': None,
#     'affiliated_committee_name': 'SERVE AMERICA VICTORY FUND',
#     'committee_type_full': 'House',
#     'designation_full': 'Principal campaign committee',
#     'organization_type': None,
#     'filing_frequency': 'Q',
#     'first_file_date': '2017-08-24',
#     'cycles': [2018, 2020],
#     'treasurer_name': 'CARPENTER, MICHAEL',
#     'committee_type': 'H',
#     'party_full': 'DEMOCRATIC PARTY',
#     'name': 'COMMITTEE TO ELECT JARED GOLDEN',
#     'committee_id': 'C00653816',
#     'state': 'ME'}]},
#  {'inactive_election_years': None,
#   'party': 'REP',
#   'candidate_inactive': False,
#   'election_districts': ['02'],
#   'active_through': 2020,
#   'last_file_date': '2019-12-02',
#   'federal_funds_flag': False,
#   'incumbent_challenge_full': None,
#   'incumbent_challenge': None,
#   'last_f2_date': '2019-12-02',
#   'district_number': 2,
#   'office_full': 'House',
#   'load_date': '2019-12-02T21:10:14+00:00',
#   'candidate_status': 'N',
#   'has_raised_funds': False,
#   'first_file_date': '2019-12-02',
#   'district': '02',
#   'cycles': [2020],
#   'party_full': 'REPUBLICAN PARTY',
#   'candidate_id': 'H0ME02091',
#   'state': 'ME',
#   'name': 'HIATT, JOHN DAVID',
#   'office': 'H',
#   'election_years': [2020],
#   'principal_committees': [{'party': 'REP',
#     'candidate_ids': ['H0ME02091'],
#     'designation': 'P',
#     'last_f1_date': '2019-12-02',
#     'last_file_date': '2019-12-02',
#     'organization_type_full': None,
#     'affiliated_committee_name': 'NONE',
#     'committee_type_full': 'House',
#     'designation_full': 'Principal campaign committee',
#     'organization_type': None,
#     'filing_frequency': 'Q',
#     'first_file_date': '2019-12-02',
#     'cycles': [2020],
#     'treasurer_name': 'HIATT, JOHN DAVID',
#     'committee_type': 'H',
#     'party_full': 'REPUBLICAN PARTY',
#     'name': 'JOHN HIATT FOR CONGRESS',
#     'committee_id': 'C00729251',
#     'state': 'ME'}]},
#  {'inactive_election_years': None,
#   'party': 'DEM',
#   'candidate_inactive': False,
#   'election_districts': ['00'],
#   'active_through': 2020,
#   'last_file_date': '2019-04-20',
#   'federal_funds_flag': False,
#   'incumbent_challenge_full': 'Challenger',
#   'incumbent_challenge': 'C',
#   'last_f2_date': '2019-04-20',
#   'district_number': 0,
#   'office_full': 'Senate',
#   'load_date': '2019-07-22T21:11:27+00:00',
#   'candidate_status': 'C',
#   'has_raised_funds': True,
#   'first_file_date': '2019-04-20',
#   'district': '00',
#   'cycles': [2020],
#   'party_full': 'DEMOCRATIC PARTY',
#   'candidate_id': 'S0ME00087',
#   'state': 'ME',
#   'name': 'KIDMAN, BRE MX.',
#   'office': 'S',
#   'election_years': [2020],
#   'principal_committees': [{'party': 'DEM',
#     'candidate_ids': ['S0ME00087'],
#     'designation': 'P',
#     'last_f1_date': '2019-04-20',
#     'last_file_date': '2019-10-14',
#     'organization_type_full': None,
#     'affiliated_committee_name': 'NONE',
#     'committee_type_full': 'Senate',
#     'designation_full': 'Principal campaign committee',
#     'organization_type': None,
#     'filing_frequency': 'Q',
#     'first_file_date': '2019-04-20',
#     'cycles': [2020],
#     'treasurer_name': 'KIDMAN, BRE MX.',
#     'committee_type': 'S',
#     'party_full': 'DEMOCRATIC PARTY',
#     'name': 'FRIENDS OF BRE KIDMAN',
#     'committee_id': 'C00703413',
#     'state': 'ME'}]},
#  {'inactive_election_years': None,
#   'party': 'DEM',
#   'candidate_inactive': False,
#   'election_districts': ['00'],
#   'active_through': 2020,
#   'last_file_date': '2019-11-06',
#   'federal_funds_flag': False,
#   'incumbent_challenge_full': 'Challenger',
#   'incumbent_challenge': 'C',
#   'last_f2_date': '2019-11-06',
#   'district_number': 0,
#   'office_full': 'Senate',
#   'load_date': '2019-11-13T21:09:51+00:00',
#   'candidate_status': 'N',
#   'has_raised_funds': False,
#   'first_file_date': '2019-11-06',
#   'district': '00',
#   'cycles': [2020],
#   'party_full': 'DEMOCRATIC PARTY',
#   'candidate_id': 'S0ME00145',
#   'state': 'ME',
#   'name': 'LAJEUNESSE, ROSS',
#   'office': 'S',
#   'election_years': [2020],
#   'principal_committees': [{'party': 'DEM',
#     'candidate_ids': ['S0ME00145'],
#     'designation': 'P',
#     'last_f1_date': '2019-11-06',
#     'last_file_date': '2019-11-06',
#     'organization_type_full': None,
#     'affiliated_committee_name': 'NONE',
#     'committee_type_full': 'Senate',
#     'designation_full': 'Principal campaign committee',
#     'organization_type': None,
#     'filing_frequency': 'Q',
#     'first_file_date': '2019-11-06',
#     'cycles': [2020],
#     'treasurer_name': 'MAY, JENNIFER',
#     'committee_type': 'S',
#     'party_full': 'DEMOCRATIC PARTY',
#     'name': 'ROSS FOR MAINE',
#     'committee_id': 'C00726182',
#     'state': 'ME'}]},
#  {'inactive_election_years': None,
#   'party': 'REP',
#   'candidate_inactive': False,
#   'election_districts': ['00'],
#   'active_through': 2020,
#   'last_file_date': '2019-05-06',
#   'federal_funds_flag': False,
#   'incumbent_challenge_full': 'Challenger',
#   'incumbent_challenge': 'C',
#   'last_f2_date': '2019-05-06',
#   'district_number': 0,
#   'office_full': 'Senate',
#   'load_date': '2019-07-22T21:11:27+00:00',
#   'candidate_status': 'C',
#   'has_raised_funds': True,
#   'first_file_date': '2019-05-06',
#   'district': '00',
#   'cycles': [2020],
#   'party_full': 'REPUBLICAN PARTY',
#   'candidate_id': 'S0ME00095',
#   'state': 'ME',
#   'name': 'LEVASSEUR, DEREK ALLEN',
#   'office': 'S',
#   'election_years': [2020],
#   'principal_committees': [{'party': 'REP',
#     'candidate_ids': ['S0ME00095'],
#     'designation': 'P',
#     'last_f1_date': '2019-05-16',
#     'last_file_date': '2019-10-15',
#     'organization_type_full': None,
#     'affiliated_committee_name': 'NONE',
#     'committee_type_full': 'Senate',
#     'designation_full': 'Principal campaign committee',
#     'organization_type': None,
#     'filing_frequency': 'Q',
#     'first_file_date': '2019-05-16',
#     'cycles': [2020],
#     'treasurer_name': 'LEVASSEUR, DEREK A',
#     'committee_type': 'S',
#     'party_full': 'REPUBLICAN PARTY',
#     'name': 'DEREK FOR U.S. SENATE',
#     'committee_id': 'C00706739',
#     'state': 'ME'}]},
#  {'inactive_election_years': None,
#   'party': 'DEM',
#   'candidate_inactive': False,
#   'election_districts': ['00'],
#   'active_through': 2020,
#   'last_file_date': '2018-07-13',
#   'federal_funds_flag': False,
#   'incumbent_challenge_full': 'Challenger',
#   'incumbent_challenge': 'C',
#   'last_f2_date': '2018-07-13',
#   'district_number': 0,
#   'office_full': 'Senate',
#   'load_date': '2019-03-27T21:06:35+00:00',
#   'candidate_status': 'C',
#   'has_raised_funds': True,
#   'first_file_date': '2018-07-13',
#   'district': '00',
#   'cycles': [2018, 2020],
#   'party_full': 'DEMOCRATIC PARTY',
#   'candidate_id': 'S0ME00053',
#   'state': 'ME',
#   'name': 'LONDON, CATHLEEN GREENBERG DR',
#   'office': 'S',
#   'election_years': [2020],
#   'principal_committees': [{'party': 'DEM',
#     'candidate_ids': ['S0ME00053'],
#     'designation': 'P',
#     'last_f1_date': '2018-07-31',
#     'last_file_date': '2019-10-30',
#     'organization_type_full': None,
#     'affiliated_committee_name': 'NONE',
#     'committee_type_full': 'Senate',
#     'designation_full': 'Principal campaign committee',
#     'organization_type': None,
#     'filing_frequency': 'Q',
#     'first_file_date': '2018-07-13',
#     'cycles': [2018, 2020],
#     'treasurer_name': 'PRATT, ANDREW',
#     'committee_type': 'S',
#     'party_full': 'DEMOCRATIC PARTY',
#     'name': 'DR CAT LONDON FOR US SENATE',
#     'committee_id': 'C00683193',
#     'state': 'ME'}]},
#  {'inactive_election_years': None,
#   'party': 'DEM',
#   'candidate_inactive': False,
#   'election_districts': ['01', '01', '01', '01', '01', '01', '01'],
#   'active_through': 2020,
#   'last_file_date': '2018-12-05',
#   'federal_funds_flag': False,
#   'incumbent_challenge_full': 'Incumbent',
#   'incumbent_challenge': 'I',
#   'last_f2_date': '2018-12-05',
#   'district_number': 1,
#   'office_full': 'House',
#   'load_date': '2019-03-27T21:06:35+00:00',
#   'candidate_status': 'C',
#   'has_raised_funds': True,
#   'first_file_date': '2007-03-30',
#   'district': '01',
#   'cycles': [2008, 2010, 2012, 2014, 2016, 2018, 2020],
#   'party_full': 'DEMOCRATIC PARTY',
#   'candidate_id': 'H8ME01120',
#   'state': 'ME',
#   'name': 'PINGREE, CHELLIE M',
#   'office': 'H',
#   'election_years': [2008, 2010, 2012, 2014, 2016, 2018, 2020],
#   'principal_committees': [{'party': 'DEM',
#     'candidate_ids': ['H8ME01120'],
#     'designation': 'P',
#     'last_f1_date': '2015-02-27',
#     'last_file_date': '2019-10-15',
#     'organization_type_full': None,
#     'affiliated_committee_name': 'NONE',
#     'committee_type_full': 'House',
#     'designation_full': 'Principal campaign committee',
#     'organization_type': None,
#     'filing_frequency': 'Q',
#     'first_file_date': '2007-03-29',
#     'cycles': [2008, 2010, 2012, 2014, 2016, 2018, 2020],
#     'treasurer_name': 'RAND, ANNE',
#     'committee_type': 'H',
#     'party_full': 'DEMOCRATIC PARTY',
#     'name': 'PINGREE FOR CONGRESS',
#     'committee_id': 'C00433391',
#     'state': 'ME'}]},
#  {'inactive_election_years': None,
#   'party': 'UNK',
#   'candidate_inactive': False,
#   'election_districts': ['00'],
#   'active_through': 2020,
#   'last_file_date': '2019-10-10',
#   'federal_funds_flag': False,
#   'incumbent_challenge_full': 'Challenger',
#   'incumbent_challenge': 'C',
#   'last_f2_date': '2019-10-10',
#   'district_number': 0,
#   'office_full': 'Senate',
#   'load_date': '2019-10-18T21:29:17+00:00',
#   'candidate_status': 'N',
#   'has_raised_funds': False,
#   'first_file_date': '2019-10-10',
#   'district': '00',
#   'cycles': [2020],
#   'party_full': 'UNKNOWN',
#   'candidate_id': 'S0ME00137',
#   'state': 'ME',
#   'name': 'SAVAGE, LISA JILL',
#   'office': 'S',
#   'election_years': [2020],
#   'principal_committees': [{'party': 'UNK',
#     'candidate_ids': ['S0ME00137'],
#     'designation': 'P',
#     'last_f1_date': '2019-10-10',
#     'last_file_date': '2019-11-24',
#     'organization_type_full': None,
#     'affiliated_committee_name': None,
#     'committee_type_full': 'Senate',
#     'designation_full': 'Principal campaign committee',
#     'organization_type': None,
#     'filing_frequency': 'Q',
#     'first_file_date': '2019-10-10',
#     'cycles': [2020],
#     'treasurer_name': 'JOHN MORRIS',
#     'committee_type': 'S',
#     'party_full': 'UNKNOWN',
#     'name': 'LISAFORMAINE',
#     'committee_id': 'C00723411',
#     'state': 'ME'}]},
#  {'inactive_election_years': None,
#   'party': 'DEM',
#   'candidate_inactive': False,
#   'election_districts': ['00'],
#   'active_through': 2020,
#   'last_file_date': '2019-06-14',
#   'federal_funds_flag': False,
#   'incumbent_challenge_full': 'Challenger',
#   'incumbent_challenge': 'C',
#   'last_f2_date': '2019-06-14',
#   'district_number': 0,
#   'office_full': 'Senate',
#   'load_date': '2019-07-22T21:11:27+00:00',
#   'candidate_status': 'C',
#   'has_raised_funds': True,
#   'first_file_date': '2019-06-14',
#   'district': '00',
#   'cycles': [2020],
#   'party_full': 'DEMOCRATIC PARTY',
#   'candidate_id': 'S0ME00103',
#   'state': 'ME',
#   'name': 'SWEET, BETSY',
#   'office': 'S',
#   'election_years': [2020],
#   'principal_committees': [{'party': 'DEM',
#     'candidate_ids': ['S0ME00103'],
#     'designation': 'P',
#     'last_f1_date': '2019-10-15',
#     'last_file_date': '2019-10-15',
#     'organization_type_full': None,
#     'affiliated_committee_name': 'NONE',
#     'committee_type_full': 'Senate',
#     'designation_full': 'Principal campaign committee',
#     'organization_type': None,
#     'filing_frequency': 'Q',
#     'first_file_date': '2019-06-14',
#     'cycles': [2020],
#     'treasurer_name': 'JACKSON, SUE',
#     'committee_type': 'S',
#     'party_full': 'DEMOCRATIC PARTY',
#     'name': 'SWEET FOR SENATE',
#     'committee_id': 'C00709279',
#     'state': 'ME'}]},
#  {'inactive_election_years': None,
#   'party': 'DEM',
#   'candidate_inactive': False,
#   'election_districts': ['00'],
#   'active_through': 2020,
#   'last_file_date': '2019-11-07',
#   'federal_funds_flag': False,
#   'incumbent_challenge_full': 'Challenger',
#   'incumbent_challenge': 'C',
#   'last_f2_date': '2019-11-07',
#   'district_number': 0,
#   'office_full': 'Senate',
#   'load_date': '2019-11-07T21:13:56+00:00',
#   'candidate_status': 'C',
#   'has_raised_funds': True,
#   'first_file_date': '2019-07-15',
#   'district': '00',
#   'cycles': [2020],
#   'party_full': 'DEMOCRATIC PARTY',
#   'candidate_id': 'S0ME00129',
#   'state': 'ME',
#   'name': 'TREACY, JONATHAN',
#   'office': 'S',
#   'election_years': [2020],
#   'principal_committees': [{'party': 'DEM',
#     'candidate_ids': ['S0ME00129'],
#     'designation': 'P',
#     'last_f1_date': '2019-11-07',
#     'last_file_date': '2019-11-25',
#     'organization_type_full': None,
#     'affiliated_committee_name': 'NONE',
#     'committee_type_full': 'Senate',
#     'designation_full': 'Principal campaign committee',
#     'organization_type': None,
#     'filing_frequency': 'T',
#     'first_file_date': '2019-07-15',
#     'cycles': [2020],
#     'treasurer_name': 'TREACY, DEBRA',
#     'committee_type': 'S',
#     'party_full': 'DEMOCRATIC PARTY',
#     'name': 'JON TREACY FOR SENATE',
#     'committee_id': 'C00712323',
#     'state': 'ME'}]},
#  {'inactive_election_years': None,
#   'party': 'IND',
#   'candidate_inactive': False,
#   'election_districts': ['00'],
#   'active_through': 2020,
#   'last_file_date': '2019-01-19',
#   'federal_funds_flag': False,
#   'incumbent_challenge_full': 'Challenger',
#   'incumbent_challenge': 'C',
#   'last_f2_date': '2019-01-19',
#   'district_number': 0,
#   'office_full': 'Senate',
#   'load_date': '2019-01-28T21:05:11+00:00',
#   'candidate_status': 'N',
#   'has_raised_funds': False,
#   'first_file_date': '2019-01-19',
#   'district': '00',
#   'cycles': [2020],
#   'party_full': 'INDEPENDENT',
#   'candidate_id': 'S0ME00079',
#   'state': 'ME',
#   'name': 'VANHELSING, DANIELLE RAVYN',
#   'office': 'S',
#   'election_years': [2020],
#   'principal_committees': [{'party': 'IND',
#     'candidate_ids': ['S0ME00079'],
#     'designation': 'P',
#     'last_f1_date': '2019-01-19',
#     'last_file_date': '2019-04-12',
#     'organization_type_full': None,
#     'affiliated_committee_name': 'NONE',
#     'committee_type_full': 'Senate',
#     'designation_full': 'Principal campaign committee',
#     'organization_type': None,
#     'filing_frequency': 'Q',
#     'first_file_date': '2019-01-19',
#     'cycles': [2020],
#     'treasurer_name': 'MERRITHEW, ELLA BELLE',
#     'committee_type': 'S',
#     'party_full': 'INDEPENDENT',
#     'name': 'DANIELLE VANHELSING FOR SENATE',
#     'committee_id': 'C00694364',
#     'state': 'ME'}]}]

# %%
## FOR LOOP TO COLLECT CONTRIBUTION RECORDS ##
#Initialize dataframe collector for itemized contribs
idfs=[]
udfs=[]
commid=0

#Initialize query dictionary
itemdict = {
    'per_page':'100'
    ,'sort':'contribution_receipt_date'
    ,'api_key':config.api_key
    ,'is_individual':'true'
    ,'two_year_transaction_period':cycle
    ,'last_index':[]
    ,'last_contribution_receipt_date':[]
    ,'committee_id':comm_ids[commid]
}

#Dict for unitemized contributions
unitemdict = {
'api_key':config.api_key
,'cycle':cycle
,'per_page':'100'
,'committee_id':comm_ids[commid]
}

#Page through results for each committee id
for x in range(0,len(comm_ids)-1):
    
    u_r = requests.get('https://api.open.fec.gov/v1/committee/'+comm_ids[commid]+'/totals',params=unitemdict).json()
    udf = json_normalize(u_r['results'])
    udfs.append(udf)
    
    #Get first itemized payload for a candidate
    r = requests.get('https://api.open.fec.gov/v1/schedules/schedule_a/',params=itemdict).json()
    
    #Print itemdict to validate
    print(itemdict)
    
    #Last page variables
    while r['pagination']['last_indexes'] is not None:
        
        #Store results of payload
        idf = json_normalize(r['results'])
        idfs.append(idf)
                
        #Assign last_index and date values, update itemdict
        last_index=pd.to_numeric(r['pagination']['last_indexes']['last_index'])
        last_date=r['pagination']['last_indexes']['last_contribution_receipt_date']
        #Update dictionary with new indices
        itemdict.update([('last_index',last_index)
                        ,('last_contribution_receipt_date',last_date)])

        #Get next payload with updated dict
        r = requests.get('https://api.open.fec.gov/v1/schedules/schedule_a/',params=itemdict).json()
    
    commid+=1
    
    #Update dictionary with next candidate in list and reset last indices
    itemdict.update([('committee_id',comm_ids[commid])
                     ,('last_index',[])
                     ,('last_contribution_receipt_date',[])])
    
    unitemdict.update([('committee_id',comm_ids[commid])])

# Concatenate all dfs
itemdf=pd.concat(idfs,sort=False,ignore_index=True)
itemdf=itemdf.drop_duplicates(subset='transaction_id')

udf=pd.concat(udfs,sort=False,ignore_index=True)
udf=udf.drop_duplicates()
# Out:
# {'per_page': '100', 'sort': 'contribution_receipt_date', 'api_key': 'egxSs7endLz5xMuoprm5zfVZCeoyeZbO5D6HFzJz', 'is_individual': 'true', 'two_year_transaction_period': '2020', 'last_index': [], 'last_contribution_receipt_date': [], 'committee_id': 'C00715532'}
# {'per_page': '100', 'sort': 'contribution_receipt_date', 'api_key': 'egxSs7endLz5xMuoprm5zfVZCeoyeZbO5D6HFzJz', 'is_individual': 'true', 'two_year_transaction_period': '2020', 'last_index': [], 'last_contribution_receipt_date': [], 'committee_id': 'C00722108'}
# {'per_page': '100', 'sort': 'contribution_receipt_date', 'api_key': 'egxSs7endLz5xMuoprm5zfVZCeoyeZbO5D6HFzJz', 'is_individual': 'true', 'two_year_transaction_period': '2020', 'last_index': [], 'last_contribution_receipt_date': [], 'committee_id': 'C00713958'}
# {'per_page': '100', 'sort': 'contribution_receipt_date', 'api_key': 'egxSs7endLz5xMuoprm5zfVZCeoyeZbO5D6HFzJz', 'is_individual': 'true', 'two_year_transaction_period': '2020', 'last_index': [], 'last_contribution_receipt_date': [], 'committee_id': 'C00710087'}
# {'per_page': '100', 'sort': 'contribution_receipt_date', 'api_key': 'egxSs7endLz5xMuoprm5zfVZCeoyeZbO5D6HFzJz', 'is_individual': 'true', 'two_year_transaction_period': '2020', 'last_index': [], 'last_contribution_receipt_date': [], 'committee_id': 'C00314575'}
# {'per_page': '100', 'sort': 'contribution_receipt_date', 'api_key': 'egxSs7endLz5xMuoprm5zfVZCeoyeZbO5D6HFzJz', 'is_individual': 'true', 'two_year_transaction_period': '2020', 'last_index': [], 'last_contribution_receipt_date': [], 'committee_id': 'C00722454'}
# {'per_page': '100', 'sort': 'contribution_receipt_date', 'api_key': 'egxSs7endLz5xMuoprm5zfVZCeoyeZbO5D6HFzJz', 'is_individual': 'true', 'two_year_transaction_period': '2020', 'last_index': [], 'last_contribution_receipt_date': [], 'committee_id': 'C00709899'}
# {'per_page': '100', 'sort': 'contribution_receipt_date', 'api_key': 'egxSs7endLz5xMuoprm5zfVZCeoyeZbO5D6HFzJz', 'is_individual': 'true', 'two_year_transaction_period': '2020', 'last_index': [], 'last_contribution_receipt_date': [], 'committee_id': 'C00653816'}
# {'per_page': '100', 'sort': 'contribution_receipt_date', 'api_key': 'egxSs7endLz5xMuoprm5zfVZCeoyeZbO5D6HFzJz', 'is_individual': 'true', 'two_year_transaction_period': '2020', 'last_index': [], 'last_contribution_receipt_date': [], 'committee_id': 'C00729251'}
# {'per_page': '100', 'sort': 'contribution_receipt_date', 'api_key': 'egxSs7endLz5xMuoprm5zfVZCeoyeZbO5D6HFzJz', 'is_individual': 'true', 'two_year_transaction_period': '2020', 'last_index': [], 'last_contribution_receipt_date': [], 'committee_id': 'C00703413'}
# {'per_page': '100', 'sort': 'contribution_receipt_date', 'api_key': 'egxSs7endLz5xMuoprm5zfVZCeoyeZbO5D6HFzJz', 'is_individual': 'true', 'two_year_transaction_period': '2020', 'last_index': [], 'last_contribution_receipt_date': [], 'committee_id': 'C00726182'}
# {'per_page': '100', 'sort': 'contribution_receipt_date', 'api_key': 'egxSs7endLz5xMuoprm5zfVZCeoyeZbO5D6HFzJz', 'is_individual': 'true', 'two_year_transaction_period': '2020', 'last_index': [], 'last_contribution_receipt_date': [], 'committee_id': 'C00706739'}
# {'per_page': '100', 'sort': 'contribution_receipt_date', 'api_key': 'egxSs7endLz5xMuoprm5zfVZCeoyeZbO5D6HFzJz', 'is_individual': 'true', 'two_year_transaction_period': '2020', 'last_index': [], 'last_contribution_receipt_date': [], 'committee_id': 'C00683193'}
# {'per_page': '100', 'sort': 'contribution_receipt_date', 'api_key': 'egxSs7endLz5xMuoprm5zfVZCeoyeZbO5D6HFzJz', 'is_individual': 'true', 'two_year_transaction_period': '2020', 'last_index': [], 'last_contribution_receipt_date': [], 'committee_id': 'C00433391'}
# {'per_page': '100', 'sort': 'contribution_receipt_date', 'api_key': 'egxSs7endLz5xMuoprm5zfVZCeoyeZbO5D6HFzJz', 'is_individual': 'true', 'two_year_transaction_period': '2020', 'last_index': [], 'last_contribution_receipt_date': [], 'committee_id': 'C00723411'}
# {'per_page': '100', 'sort': 'contribution_receipt_date', 'api_key': 'egxSs7endLz5xMuoprm5zfVZCeoyeZbO5D6HFzJz', 'is_individual': 'true', 'two_year_transaction_period': '2020', 'last_index': [], 'last_contribution_receipt_date': [], 'committee_id': 'C00709279'}
# {'per_page': '100', 'sort': 'contribution_receipt_date', 'api_key': 'egxSs7endLz5xMuoprm5zfVZCeoyeZbO5D6HFzJz', 'is_individual': 'true', 'two_year_transaction_period': '2020', 'last_index': [], 'last_contribution_receipt_date': [], 'committee_id': 'C00712323'}

# %%
## FOR LOOP TO COLLECT COMMITTEE RECORDS ##
#Initialize dataframe collector for itemized contribs
idfs=[]
commid=0

#Initialize query dictionary
itemdict = {
    'per_page':'100'
    ,'sort':'contribution_receipt_date'
    ,'api_key':config.api_key
    #Committees and is_individual:false
    ,'contributor_type':'committee'
    ,'is_individual':'false'
    ,'two_year_transaction_period':cycle
    ,'last_index':[]
    ,'last_contribution_receipt_date':[]
    ,'committee_id':comm_ids[commid]
}

#Page through results for each committee id
for x in range(0,len(comm_ids)-1):
    
    #Get first itemized payload for a candidate
    r = requests.get('https://api.open.fec.gov/v1/schedules/schedule_a/',params=itemdict).json()
    
    #Print itemdict to validate
    print(itemdict)
    
    #Last page variables
    while r['pagination']['last_indexes'] is not None:
        
        #Store results of payload
        idf = json_normalize(r['results'])
        idfs.append(idf)
                
        #Assign last_index and date values, update itemdict
        last_index=pd.to_numeric(r['pagination']['last_indexes']['last_index'])
        last_date=r['pagination']['last_indexes']['last_contribution_receipt_date']
        #Update dictionary with new indices
        itemdict.update([('last_index',last_index)
                        ,('last_contribution_receipt_date',last_date)])

        #Get next payload with updated dict
        r = requests.get('https://api.open.fec.gov/v1/schedules/schedule_a/',params=itemdict).json()
    
    commid+=1
    
    #Update dictionary with next candidate in list and reset last indices
    itemdict.update([('committee_id',comm_ids[commid])
                     ,('last_index',[])
                     ,('last_contribution_receipt_date',[])])
    
comm_df=pd.concat(idfs,sort=False,ignore_index=True)
comm_df=comm_df.drop_duplicates(subset='transaction_id')
# Out:
# {'per_page': '100', 'sort': 'contribution_receipt_date', 'api_key': 'egxSs7endLz5xMuoprm5zfVZCeoyeZbO5D6HFzJz', 'contributor_type': 'committee', 'is_individual': 'false', 'two_year_transaction_period': '2020', 'last_index': [], 'last_contribution_receipt_date': [], 'committee_id': 'C00715532'}
# {'per_page': '100', 'sort': 'contribution_receipt_date', 'api_key': 'egxSs7endLz5xMuoprm5zfVZCeoyeZbO5D6HFzJz', 'contributor_type': 'committee', 'is_individual': 'false', 'two_year_transaction_period': '2020', 'last_index': [], 'last_contribution_receipt_date': [], 'committee_id': 'C00722108'}
# {'per_page': '100', 'sort': 'contribution_receipt_date', 'api_key': 'egxSs7endLz5xMuoprm5zfVZCeoyeZbO5D6HFzJz', 'contributor_type': 'committee', 'is_individual': 'false', 'two_year_transaction_period': '2020', 'last_index': [], 'last_contribution_receipt_date': [], 'committee_id': 'C00713958'}
# {'per_page': '100', 'sort': 'contribution_receipt_date', 'api_key': 'egxSs7endLz5xMuoprm5zfVZCeoyeZbO5D6HFzJz', 'contributor_type': 'committee', 'is_individual': 'false', 'two_year_transaction_period': '2020', 'last_index': [], 'last_contribution_receipt_date': [], 'committee_id': 'C00710087'}
# {'per_page': '100', 'sort': 'contribution_receipt_date', 'api_key': 'egxSs7endLz5xMuoprm5zfVZCeoyeZbO5D6HFzJz', 'contributor_type': 'committee', 'is_individual': 'false', 'two_year_transaction_period': '2020', 'last_index': [], 'last_contribution_receipt_date': [], 'committee_id': 'C00314575'}
# {'per_page': '100', 'sort': 'contribution_receipt_date', 'api_key': 'egxSs7endLz5xMuoprm5zfVZCeoyeZbO5D6HFzJz', 'contributor_type': 'committee', 'is_individual': 'false', 'two_year_transaction_period': '2020', 'last_index': [], 'last_contribution_receipt_date': [], 'committee_id': 'C00722454'}
# {'per_page': '100', 'sort': 'contribution_receipt_date', 'api_key': 'egxSs7endLz5xMuoprm5zfVZCeoyeZbO5D6HFzJz', 'contributor_type': 'committee', 'is_individual': 'false', 'two_year_transaction_period': '2020', 'last_index': [], 'last_contribution_receipt_date': [], 'committee_id': 'C00709899'}
# {'per_page': '100', 'sort': 'contribution_receipt_date', 'api_key': 'egxSs7endLz5xMuoprm5zfVZCeoyeZbO5D6HFzJz', 'contributor_type': 'committee', 'is_individual': 'false', 'two_year_transaction_period': '2020', 'last_index': [], 'last_contribution_receipt_date': [], 'committee_id': 'C00653816'}
# {'per_page': '100', 'sort': 'contribution_receipt_date', 'api_key': 'egxSs7endLz5xMuoprm5zfVZCeoyeZbO5D6HFzJz', 'contributor_type': 'committee', 'is_individual': 'false', 'two_year_transaction_period': '2020', 'last_index': [], 'last_contribution_receipt_date': [], 'committee_id': 'C00729251'}
# {'per_page': '100', 'sort': 'contribution_receipt_date', 'api_key': 'egxSs7endLz5xMuoprm5zfVZCeoyeZbO5D6HFzJz', 'contributor_type': 'committee', 'is_individual': 'false', 'two_year_transaction_period': '2020', 'last_index': [], 'last_contribution_receipt_date': [], 'committee_id': 'C00703413'}
# {'per_page': '100', 'sort': 'contribution_receipt_date', 'api_key': 'egxSs7endLz5xMuoprm5zfVZCeoyeZbO5D6HFzJz', 'contributor_type': 'committee', 'is_individual': 'false', 'two_year_transaction_period': '2020', 'last_index': [], 'last_contribution_receipt_date': [], 'committee_id': 'C00726182'}
# {'per_page': '100', 'sort': 'contribution_receipt_date', 'api_key': 'egxSs7endLz5xMuoprm5zfVZCeoyeZbO5D6HFzJz', 'contributor_type': 'committee', 'is_individual': 'false', 'two_year_transaction_period': '2020', 'last_index': [], 'last_contribution_receipt_date': [], 'committee_id': 'C00706739'}
# {'per_page': '100', 'sort': 'contribution_receipt_date', 'api_key': 'egxSs7endLz5xMuoprm5zfVZCeoyeZbO5D6HFzJz', 'contributor_type': 'committee', 'is_individual': 'false', 'two_year_transaction_period': '2020', 'last_index': [], 'last_contribution_receipt_date': [], 'committee_id': 'C00683193'}
# {'per_page': '100', 'sort': 'contribution_receipt_date', 'api_key': 'egxSs7endLz5xMuoprm5zfVZCeoyeZbO5D6HFzJz', 'contributor_type': 'committee', 'is_individual': 'false', 'two_year_transaction_period': '2020', 'last_index': [], 'last_contribution_receipt_date': [], 'committee_id': 'C00433391'}
# {'per_page': '100', 'sort': 'contribution_receipt_date', 'api_key': 'egxSs7endLz5xMuoprm5zfVZCeoyeZbO5D6HFzJz', 'contributor_type': 'committee', 'is_individual': 'false', 'two_year_transaction_period': '2020', 'last_index': [], 'last_contribution_receipt_date': [], 'committee_id': 'C00723411'}
# {'per_page': '100', 'sort': 'contribution_receipt_date', 'api_key': 'egxSs7endLz5xMuoprm5zfVZCeoyeZbO5D6HFzJz', 'contributor_type': 'committee', 'is_individual': 'false', 'two_year_transaction_period': '2020', 'last_index': [], 'last_contribution_receipt_date': [], 'committee_id': 'C00709279'}
# {'per_page': '100', 'sort': 'contribution_receipt_date', 'api_key': 'egxSs7endLz5xMuoprm5zfVZCeoyeZbO5D6HFzJz', 'contributor_type': 'committee', 'is_individual': 'false', 'two_year_transaction_period': '2020', 'last_index': [], 'last_contribution_receipt_date': [], 'committee_id': 'C00712323'}

# %%
#ITEMIZED DATA CLEANING#
itemdf['contributor_zip'] = itemdf['contributor_zip'].str[:5]
# comm_df['contributor_zip'] = comm_df['contributor_zip'].str[5]

#Create DataFrame with columns to match itemized table
cols=itemdf.columns.values.tolist()
unitemdf=[]
unitemdf = pd.DataFrame(columns=cols)

## Select data for unitemized df ##
unitemdf[['committee.name'
        ,'committee.party_full'
        ,'committee_id'
        ,'contribution_receipt_amount'
        ,'contribution_receipt_date'
        ,'fec_election_type_desc']] = udf[['committee_name'
                                        ,'party_full'
                                        ,'committee_id'
                                        ,'individual_unitemized_contributions'
                                        ,'coverage_end_date'
                                        ,'last_report_type_full']]

#Label as unitemized
unitemdf['contributor_name'] = 'Unitemized individual contributions'
unitemdf['entity_type'] = 'IND'

#Union Itemized and Unitemized contributions
ind_df = pd.concat([itemdf,unitemdf,comm_df],sort=False,ignore_index=True)
ind_df['contribution_receipt_date'] = ind_df['contribution_receipt_date'].str.split('T', expand=True)[0]

# %%
## WRITE OUT INDIVIDUAL DONATION FILES ##
#Write full files out to data.world project

##Test if results are longer than current file. If so, write.
results = dw.query('darrenfishell/2020-election-repo', 'SELECT * FROM individual_congressional_contributions')
if len(results.dataframe) < len(ind_df):
    with dw.open_remote_file('darrenfishell/2020-election-repo','individual-congressional-contributions.csv') as w:
        ind_df.to_csv(w,index=False)

##Tests if contribution sum is greater than old file. If so, write.        
results = dw.query('darrenfishell/2020-election-repo', 'SELECT * FROM congress_financial_summaries')
if sum(results.dataframe['receipts']) < len(udf['receipts']):
    with dw.open_remote_file('darrenfishell/2020-election-repo','congress_financial_summaries.csv') as w:
        udf.to_csv(w,index=False)

# %%
### INDEPENDENT EXPENDITURE RETRIEVAL ###
## SENATE CANDIDATE ID SEARCH ##
cand_ids=json_normalize(data=r_cands['results'])['candidate_id'].tolist()

#Declare loop variables
candid=0
iedict = {
    'per_page':'100'
    ,'api_key':config.api_key
    ,'cycle':cycle
    ,'last_index':[]
    ,'last_expenditure_date':[]
    ,'candidate_id':cand_ids[candid]
}
edfs = []

#Page through results for each committee id
for x in range(0,len(cand_ids)-1):
    
    #Get first itemized payload for a candidate
    ier = requests.get('https://api.open.fec.gov/v1/schedules/schedule_e/',params=iedict).json()
    
    #Last page variables
    while ier['pagination']['last_indexes'] is not None:
        
        #Store results of payload
        edf = json_normalize(ier['results'])
        edfs.append(edf)
                
        #Assign last_index and date values, update itemdict
        last_index=ier['pagination']['last_indexes']['last_index']
        last_date=ier['pagination']['last_indexes']['last_expenditure_date']
        #Update dictionary with new indices
        iedict.update([('last_index',last_index)
                        ,('last_expenditure_date',last_date)])

        #Get next payload with updated dict
        ier = requests.get('https://api.open.fec.gov/v1/schedules/schedule_e/',params=iedict).json()
    
    candid+=1
    
    #Update dictionary with next candidate in list and reset last indices
    iedict.update([('candidate_id',cand_ids[candid])
                    ,('last_index',[])
                    ,('last_expenditure_date',[])])

edf=pd.concat(edfs,sort=False,ignore_index=True)
edf=edf.drop_duplicates(subset='transaction_id')

#Clean up ZIP codes
edf['committee.zip'] = edf['committee.zip'].str[:5]
edf['expenditure_date'] = edf['expenditure_date'].str.split('T', expand=True)[0]

#Write out files to data.world
results = dw.query('darrenfishell/2020-election-repo', 'SELECT * FROM congress_independent_expenditures')
if len(results.dataframe) < len(edf):
    with dw.open_remote_file('darrenfishell/2020-election-repo','congress-independent-expenditures.csv') as w:
        edf.to_csv(w,index=False)

# %%
with dw.open_remote_file('darrenfishell/2020-election-repo','congress-independent-expenditures.csv') as w:
    edf.to_csv(w,index=False)

# %%
## COORDINATED POLITICAL SPENDING RETRIEVAL ## 
#Declare loop variables
candid=0
i=1
pdict = {
    'per_page':'100'
    ,'api_key':config.api_key
    ,'two_year_transaction_period':cycle
    ,'page':i
    ,'candidate_id':cand_ids[candid]
}
pdfs = []

#Page through results for each committee id
for x in range(0,len(cand_ids)-1):
    
    #Get first itemized payload for a candidate
    p_r = requests.get('https://api.open.fec.gov/v1/schedules/schedule_f/',params=pdict).json()
    
    #Last page variables
    while p_r['pagination']['page']<=p_r['pagination']['pages']:
        
        #Store results of payload
        pdf = json_normalize(p_r['results'])
        pdfs.append(pdf)
                
        #Increment and update page
        i+=1
        pdict.update([('page',i)])

        #Get next payload with updated dict
        p_r = requests.get('https://api.open.fec.gov/v1/schedules/schedule_f/',params=pdict).json()
    
    candid+=1
    
    #Update dictionary with next candidate in list and reset last indices
    pdict.update([('candidate_id',cand_ids[candid])
                    ,('page',1)])

pdf=pd.concat(pdfs,sort=False,ignore_index=True)
pdf=pdf.drop_duplicates(subset='transaction_id')
pdf['committee.zip'] = pdf['committee.zip'].str[:5]

#Write out file to data.world
results = dw.query('darrenfishell/2020-election-repo', 'SELECT * FROM congress_party_coordinated_expenditures')

if len(results.dataframe) < len(pdf):
    with dw.open_remote_file('darrenfishell/2020-election-repo','congress-party-coordinated-expenditures.csv') as w:
        pdf.to_csv(w,index=False)
# Out:
# {'per_page': '100', 'api_key': 'egxSs7endLz5xMuoprm5zfVZCeoyeZbO5D6HFzJz', 'two_year_transaction_period': '2020', 'page': 1, 'candidate_id': 'H0ME01119'}
# {'per_page': '100', 'api_key': 'egxSs7endLz5xMuoprm5zfVZCeoyeZbO5D6HFzJz', 'two_year_transaction_period': '2020', 'page': 1, 'candidate_id': 'H0ME02075'}
# {'per_page': '100', 'api_key': 'egxSs7endLz5xMuoprm5zfVZCeoyeZbO5D6HFzJz', 'two_year_transaction_period': '2020', 'page': 1, 'candidate_id': 'H0ME02067'}
# {'per_page': '100', 'api_key': 'egxSs7endLz5xMuoprm5zfVZCeoyeZbO5D6HFzJz', 'two_year_transaction_period': '2020', 'page': 1, 'candidate_id': 'S0ME00061'}
# {'per_page': '100', 'api_key': 'egxSs7endLz5xMuoprm5zfVZCeoyeZbO5D6HFzJz', 'two_year_transaction_period': '2020', 'page': 1, 'candidate_id': 'S6ME00159'}
# {'per_page': '100', 'api_key': 'egxSs7endLz5xMuoprm5zfVZCeoyeZbO5D6HFzJz', 'two_year_transaction_period': '2020', 'page': 1, 'candidate_id': 'H0ME02083'}
# {'per_page': '100', 'api_key': 'egxSs7endLz5xMuoprm5zfVZCeoyeZbO5D6HFzJz', 'two_year_transaction_period': '2020', 'page': 1, 'candidate_id': 'S0ME00111'}
# {'per_page': '100', 'api_key': 'egxSs7endLz5xMuoprm5zfVZCeoyeZbO5D6HFzJz', 'two_year_transaction_period': '2020', 'page': 1, 'candidate_id': 'H8ME02185'}
# {'per_page': '100', 'api_key': 'egxSs7endLz5xMuoprm5zfVZCeoyeZbO5D6HFzJz', 'two_year_transaction_period': '2020', 'page': 1, 'candidate_id': 'H0ME02091'}
# {'per_page': '100', 'api_key': 'egxSs7endLz5xMuoprm5zfVZCeoyeZbO5D6HFzJz', 'two_year_transaction_period': '2020', 'page': 1, 'candidate_id': 'S0ME00087'}
# {'per_page': '100', 'api_key': 'egxSs7endLz5xMuoprm5zfVZCeoyeZbO5D6HFzJz', 'two_year_transaction_period': '2020', 'page': 1, 'candidate_id': 'S0ME00145'}
# {'per_page': '100', 'api_key': 'egxSs7endLz5xMuoprm5zfVZCeoyeZbO5D6HFzJz', 'two_year_transaction_period': '2020', 'page': 1, 'candidate_id': 'S0ME00095'}
# {'per_page': '100', 'api_key': 'egxSs7endLz5xMuoprm5zfVZCeoyeZbO5D6HFzJz', 'two_year_transaction_period': '2020', 'page': 1, 'candidate_id': 'S0ME00053'}
# {'per_page': '100', 'api_key': 'egxSs7endLz5xMuoprm5zfVZCeoyeZbO5D6HFzJz', 'two_year_transaction_period': '2020', 'page': 1, 'candidate_id': 'H8ME01120'}
# {'per_page': '100', 'api_key': 'egxSs7endLz5xMuoprm5zfVZCeoyeZbO5D6HFzJz', 'two_year_transaction_period': '2020', 'page': 1, 'candidate_id': 'S0ME00137'}
# {'per_page': '100', 'api_key': 'egxSs7endLz5xMuoprm5zfVZCeoyeZbO5D6HFzJz', 'two_year_transaction_period': '2020', 'page': 1, 'candidate_id': 'S0ME00103'}
# {'per_page': '100', 'api_key': 'egxSs7endLz5xMuoprm5zfVZCeoyeZbO5D6HFzJz', 'two_year_transaction_period': '2020', 'page': 1, 'candidate_id': 'S0ME00129'}

# %%
import numpy as np
import pandas as pd
import requests
import config
import os
import json
import time
from pandas.io.json import json_normalize
from copy import deepcopy

##Schedule_a API guide: https://api.open.fec.gov/developers/#/receipts/get_schedules_schedule_a_

# %%
# ### MULTI-CANDIDATE SEARCH ###
# # DEVELOPING LOOP FOR CANDIDATE IDS #

# #Set search for all 2020 (two-year transaction period) Maine candidates
# cand_state = 'ME'
# period='2020'
# parameters = {'election_year':period
#             ,'state':cand_state
#             ,'api_key':config.api_key}
# #Requests candidate info
# r_cands = requests.get('https://api.open.fec.gov/v1/candidates/search',params=parameters).json()
# r_cands

# #Locates and sets Committee ID from 'principal_committees' sub-array
# comm_ids=json_normalize(data=r_cands['results'],record_path='principal_committees')[['committee_id','name','party']]
# comm_ids
# Out:
# {'api_version': '1.0',
#  'results': [{'active_through': 2020,
#    'incumbent_challenge_full': 'Challenger',
#    'first_file_date': '2018-11-12',
#    'office_full': 'Senate',
#    'district_number': 0,
#    'candidate_inactive': False,
#    'election_districts': ['00'],
#    'last_file_date': '2018-11-12',
#    'candidate_id': 'S0ME00061',
#    'name': 'BUNKER, MICHAEL P MR',
#    'state': 'ME',
#    'incumbent_challenge': 'C',
#    'election_years': [2020],
#    'federal_funds_flag': False,
#    'principal_committees': [{'filing_frequency': 'T',
#      'committee_type': 'S',
#      'first_file_date': '2019-06-25',
#      'organization_type': None,
#      'organization_type_full': None,
#      'designation': 'P',
#      'committee_id': 'C00710087',
#      'last_file_date': '2019-07-03',
#      'name': 'MICHAEL BUNKER FOR MAINE',
#      'state': 'ME',
#      'last_f1_date': '2019-07-02',
#      'designation_full': 'Principal campaign committee',
#      'party_full': 'DEMOCRATIC PARTY',
#      'treasurer_name': 'BUNKER, MICHAEL PHILLIP MR',
#      'cycles': [2020],
#      'candidate_ids': ['S0ME00061'],
#      'committee_type_full': 'Senate',
#      'party': 'DEM'}],
#    'party_full': 'DEMOCRATIC PARTY',
#    'load_date': '2019-01-28T21:05:11+00:00',
#    'party': 'DEM',
#    'last_f2_date': '2018-11-12',
#    'cycles': [2018, 2020],
#    'candidate_status': 'N',
#    'has_raised_funds': False,
#    'district': '00',
#    'office': 'S'},
#   {'active_through': 2020,
#    'incumbent_challenge_full': 'Incumbent',
#    'first_file_date': '1996-02-22',
#    'office_full': 'Senate',
#    'district_number': 0,
#    'candidate_inactive': False,
#    'election_districts': ['00', '00', '00', '00', '00'],
#    'last_file_date': '2015-09-15',
#    'candidate_id': 'S6ME00159',
#    'name': 'COLLINS, SUSAN M',
#    'state': 'ME',
#    'incumbent_challenge': 'I',
#    'election_years': [1996, 2002, 2008, 2014, 2020],
#    'federal_funds_flag': False,
#    'principal_committees': [{'filing_frequency': 'Q',
#      'committee_type': 'S',
#      'first_file_date': '1996-02-23',
#      'organization_type': None,
#      'organization_type_full': None,
#      'designation': 'P',
#      'committee_id': 'C00314575',
#      'last_file_date': '2019-05-21',
#      'name': 'COLLINS FOR SENATOR',
#      'state': 'ME',
#      'last_f1_date': '2019-05-21',
#      'designation_full': 'Principal campaign committee',
#      'party_full': 'REPUBLICAN PARTY',
#      'treasurer_name': 'MCCANDLESS, ELIZABETH T.',
#      'cycles': [1996,
#       1998,
#       2000,
#       2002,
#       2004,
#       2006,
#       2008,
#       2010,
#       2012,
#       2014,
#       2016,
#       2018,
#       2020],
#      'candidate_ids': ['S6ME00159'],
#      'committee_type_full': 'Senate',
#      'party': 'REP'}],
#    'party_full': 'REPUBLICAN PARTY',
#    'load_date': '2019-03-27T21:06:35+00:00',
#    'party': 'REP',
#    'last_f2_date': '2015-09-15',
#    'cycles': [1996,
#     1998,
#     2000,
#     2002,
#     2004,
#     2006,
#     2008,
#     2010,
#     2012,
#     2014,
#     2016,
#     2018,
#     2020],
#    'candidate_status': 'C',
#    'has_raised_funds': True,
#    'district': '00',
#    'office': 'S'},
#   {'active_through': 2020,
#    'incumbent_challenge_full': 'Challenger',
#    'first_file_date': '2019-06-24',
#    'office_full': 'Senate',
#    'district_number': 0,
#    'candidate_inactive': False,
#    'election_districts': ['00'],
#    'last_file_date': '2019-06-24',
#    'candidate_id': 'S0ME00111',
#    'name': 'GIDEON, SARA',
#    'state': 'ME',
#    'incumbent_challenge': 'C',
#    'election_years': [2020],
#    'federal_funds_flag': False,
#    'principal_committees': [{'filing_frequency': 'Q',
#      'committee_type': 'S',
#      'first_file_date': '2019-06-24',
#      'organization_type': None,
#      'organization_type_full': None,
#      'designation': 'P',
#      'committee_id': 'C00709899',
#      'last_file_date': '2019-06-24',
#      'name': 'SARA GIDEON FOR MAINE',
#      'state': 'ME',
#      'last_f1_date': '2019-06-24',
#      'designation_full': 'Principal campaign committee',
#      'party_full': 'DEMOCRATIC PARTY',
#      'treasurer_name': 'LUNN, LISA',
#      'cycles': [2020],
#      'candidate_ids': ['S0ME00111'],
#      'committee_type_full': 'Senate',
#      'party': 'DEM'}],
#    'party_full': 'DEMOCRATIC PARTY',
#    'load_date': '2019-07-02T21:09:57+00:00',
#    'party': 'DEM',
#    'last_f2_date': '2019-06-24',
#    'cycles': [2020],
#    'candidate_status': 'N',
#    'has_raised_funds': False,
#    'district': '00',
#    'office': 'S'},
#   {'active_through': 2020,
#    'incumbent_challenge_full': 'Incumbent',
#    'first_file_date': '2017-08-24',
#    'office_full': 'House',
#    'district_number': 2,
#    'candidate_inactive': False,
#    'election_districts': ['02', '02'],
#    'last_file_date': '2019-06-13',
#    'candidate_id': 'H8ME02185',
#    'name': 'GOLDEN, JARED',
#    'state': 'ME',
#    'incumbent_challenge': 'I',
#    'election_years': [2018, 2020],
#    'federal_funds_flag': False,
#    'principal_committees': [{'filing_frequency': 'Q',
#      'committee_type': 'H',
#      'first_file_date': '2017-08-24',
#      'organization_type': None,
#      'organization_type_full': None,
#      'designation': 'P',
#      'committee_id': 'C00653816',
#      'last_file_date': '2019-06-27',
#      'name': 'COMMITTEE TO ELECT JARED GOLDEN',
#      'state': 'ME',
#      'last_f1_date': '2019-06-13',
#      'designation_full': 'Principal campaign committee',
#      'party_full': 'DEMOCRATIC PARTY',
#      'treasurer_name': 'CARPENTER, MICHAEL',
#      'cycles': [2018, 2020],
#      'candidate_ids': ['H8ME02185'],
#      'committee_type_full': 'House',
#      'party': 'DEM'}],
#    'party_full': 'DEMOCRATIC PARTY',
#    'load_date': '2019-06-13T21:07:01+00:00',
#    'party': 'DEM',
#    'last_f2_date': '2019-06-13',
#    'cycles': [2018, 2020],
#    'candidate_status': 'C',
#    'has_raised_funds': True,
#    'district': '02',
#    'office': 'H'},
#   {'active_through': 2020,
#    'incumbent_challenge_full': 'Challenger',
#    'first_file_date': '2019-04-20',
#    'office_full': 'Senate',
#    'district_number': 0,
#    'candidate_inactive': False,
#    'election_districts': ['00'],
#    'last_file_date': '2019-04-20',
#    'candidate_id': 'S0ME00087',
#    'name': 'KIDMAN, BRE MX.',
#    'state': 'ME',
#    'incumbent_challenge': 'C',
#    'election_years': [2020],
#    'federal_funds_flag': False,
#    'principal_committees': [{'filing_frequency': 'Q',
#      'committee_type': 'S',
#      'first_file_date': '2019-04-20',
#      'organization_type': None,
#      'organization_type_full': None,
#      'designation': 'P',
#      'committee_id': 'C00703413',
#      'last_file_date': '2019-04-20',
#      'name': 'FRIENDS OF BRE KIDMAN',
#      'state': 'ME',
#      'last_f1_date': '2019-04-20',
#      'designation_full': 'Principal campaign committee',
#      'party_full': 'DEMOCRATIC PARTY',
#      'treasurer_name': 'KIDMAN, BRE MX.',
#      'cycles': [2020],
#      'candidate_ids': ['S0ME00087'],
#      'committee_type_full': 'Senate',
#      'party': 'DEM'}],
#    'party_full': 'DEMOCRATIC PARTY',
#    'load_date': '2019-06-10T21:08:12+00:00',
#    'party': 'DEM',
#    'last_f2_date': '2019-04-20',
#    'cycles': [2020],
#    'candidate_status': 'N',
#    'has_raised_funds': False,
#    'district': '00',
#    'office': 'S'},
#   {'active_through': 2020,
#    'incumbent_challenge_full': 'Challenger',
#    'first_file_date': '2019-05-06',
#    'office_full': 'Senate',
#    'district_number': 0,
#    'candidate_inactive': False,
#    'election_districts': ['00'],
#    'last_file_date': '2019-05-06',
#    'candidate_id': 'S0ME00095',
#    'name': 'LEVASSEUR, DEREK ALLEN',
#    'state': 'ME',
#    'incumbent_challenge': 'C',
#    'election_years': [2020],
#    'federal_funds_flag': False,
#    'principal_committees': [{'filing_frequency': 'Q',
#      'committee_type': 'S',
#      'first_file_date': '2019-05-16',
#      'organization_type': None,
#      'organization_type_full': None,
#      'designation': 'P',
#      'committee_id': 'C00706739',
#      'last_file_date': '2019-05-16',
#      'name': 'DEREK FOR U.S. SENATE',
#      'state': 'ME',
#      'last_f1_date': '2019-05-16',
#      'designation_full': 'Principal campaign committee',
#      'party_full': 'REPUBLICAN PARTY',
#      'treasurer_name': 'LEVASSEUR, DEREK A',
#      'cycles': [2020],
#      'candidate_ids': ['S0ME00095'],
#      'committee_type_full': 'Senate',
#      'party': 'REP'}],
#    'party_full': 'REPUBLICAN PARTY',
#    'load_date': '2019-06-10T21:08:12+00:00',
#    'party': 'REP',
#    'last_f2_date': '2019-05-06',
#    'cycles': [2020],
#    'candidate_status': 'N',
#    'has_raised_funds': False,
#    'district': '00',
#    'office': 'S'},
#   {'active_through': 2020,
#    'incumbent_challenge_full': 'Challenger',
#    'first_file_date': '2018-07-13',
#    'office_full': 'Senate',
#    'district_number': 0,
#    'candidate_inactive': False,
#    'election_districts': ['00'],
#    'last_file_date': '2018-07-13',
#    'candidate_id': 'S0ME00053',
#    'name': 'LONDON, CATHLEEN GREENBERG DR',
#    'state': 'ME',
#    'incumbent_challenge': 'C',
#    'election_years': [2020],
#    'federal_funds_flag': False,
#    'principal_committees': [{'filing_frequency': 'Q',
#      'committee_type': 'S',
#      'first_file_date': '2018-07-13',
#      'organization_type': None,
#      'organization_type_full': None,
#      'designation': 'P',
#      'committee_id': 'C00683193',
#      'last_file_date': '2019-04-17',
#      'name': 'DR CAT LONDON FOR US SENATE',
#      'state': 'ME',
#      'last_f1_date': '2018-07-31',
#      'designation_full': 'Principal campaign committee',
#      'party_full': 'DEMOCRATIC PARTY',
#      'treasurer_name': 'PRATT, ANDREW',
#      'cycles': [2018, 2020],
#      'candidate_ids': ['S0ME00053'],
#      'committee_type_full': 'Senate',
#      'party': 'DEM'}],
#    'party_full': 'DEMOCRATIC PARTY',
#    'load_date': '2019-03-27T21:06:35+00:00',
#    'party': 'DEM',
#    'last_f2_date': '2018-07-13',
#    'cycles': [2018, 2020],
#    'candidate_status': 'C',
#    'has_raised_funds': True,
#    'district': '00',
#    'office': 'S'},
#   {'active_through': 2020,
#    'incumbent_challenge_full': 'Incumbent',
#    'first_file_date': '2007-03-30',
#    'office_full': 'House',
#    'district_number': 1,
#    'candidate_inactive': False,
#    'election_districts': ['01', '01', '01', '01', '01', '01', '01'],
#    'last_file_date': '2018-12-05',
#    'candidate_id': 'H8ME01120',
#    'name': 'PINGREE, CHELLIE M',
#    'state': 'ME',
#    'incumbent_challenge': 'I',
#    'election_years': [2008, 2010, 2012, 2014, 2016, 2018, 2020],
#    'federal_funds_flag': False,
#    'principal_committees': [{'filing_frequency': 'Q',
#      'committee_type': 'H',
#      'first_file_date': '2007-03-29',
#      'organization_type': None,
#      'organization_type_full': None,
#      'designation': 'P',
#      'committee_id': 'C00433391',
#      'last_file_date': '2019-04-15',
#      'name': 'PINGREE FOR CONGRESS',
#      'state': 'ME',
#      'last_f1_date': '2015-02-27',
#      'designation_full': 'Principal campaign committee',
#      'party_full': 'DEMOCRATIC PARTY',
#      'treasurer_name': 'RAND, ANNE',
#      'cycles': [2008, 2010, 2012, 2014, 2016, 2018, 2020],
#      'candidate_ids': ['H8ME01120'],
#      'committee_type_full': 'House',
#      'party': 'DEM'}],
#    'party_full': 'DEMOCRATIC PARTY',
#    'load_date': '2019-03-27T21:06:35+00:00',
#    'party': 'DEM',
#    'last_f2_date': '2018-12-05',
#    'cycles': [2008, 2010, 2012, 2014, 2016, 2018, 2020],
#    'candidate_status': 'C',
#    'has_raised_funds': True,
#    'district': '01',
#    'office': 'H'},
#   {'active_through': 2020,
#    'incumbent_challenge_full': 'Challenger',
#    'first_file_date': '2019-06-14',
#    'office_full': 'Senate',
#    'district_number': 0,
#    'candidate_inactive': False,
#    'election_districts': ['00'],
#    'last_file_date': '2019-06-14',
#    'candidate_id': 'S0ME00103',
#    'name': 'SWEET, BETSY',
#    'state': 'ME',
#    'incumbent_challenge': 'C',
#    'election_years': [2020],
#    'federal_funds_flag': False,
#    'principal_committees': [{'filing_frequency': 'Q',
#      'committee_type': 'S',
#      'first_file_date': '2019-06-14',
#      'organization_type': None,
#      'organization_type_full': None,
#      'designation': 'P',
#      'committee_id': 'C00709279',
#      'last_file_date': '2019-06-14',
#      'name': 'SWEET FOR SENATE',
#      'state': 'ME',
#      'last_f1_date': '2019-06-14',
#      'designation_full': 'Principal campaign committee',
#      'party_full': 'DEMOCRATIC PARTY',
#      'treasurer_name': 'JACKSON, SUE',
#      'cycles': [2020],
#      'candidate_ids': ['S0ME00103'],
#      'committee_type_full': 'Senate',
#      'party': 'DEM'}],
#    'party_full': 'DEMOCRATIC PARTY',
#    'load_date': '2019-07-02T21:09:57+00:00',
#    'party': 'DEM',
#    'last_f2_date': '2019-06-14',
#    'cycles': [2020],
#    'candidate_status': 'N',
#    'has_raised_funds': False,
#    'district': '00',
#    'office': 'S'},
#   {'active_through': 2020,
#    'incumbent_challenge_full': 'Challenger',
#    'first_file_date': '2019-01-19',
#    'office_full': 'Senate',
#    'district_number': 0,
#    'candidate_inactive': False,
#    'election_districts': ['00'],
#    'last_file_date': '2019-01-19',
#    'candidate_id': 'S0ME00079',
#    'name': 'VANHELSING, DANIELLE RAVYN',
#    'state': 'ME',
#    'incumbent_challenge': 'C',
#    'election_years': [2020],
#    'federal_funds_flag': False,
#    'principal_committees': [{'filing_frequency': 'Q',
#      'committee_type': 'S',
#      'first_file_date': '2019-01-19',
#      'organization_type': None,
#      'organization_type_full': None,
#      'designation': 'P',
#      'committee_id': 'C00694364',
#      'last_file_date': '2019-04-12',
#      'name': 'DANIELLE VANHELSING FOR SENATE',
#      'state': 'ME',
#      'last_f1_date': '2019-01-19',
#      'designation_full': 'Principal campaign committee',
#      'party_full': 'INDEPENDENT',
#      'treasurer_name': 'MERRITHEW, ELLA BELLE',
#      'cycles': [2020],
#      'candidate_ids': ['S0ME00079'],
#      'committee_type_full': 'Senate',
#      'party': 'IND'}],
#    'party_full': 'INDEPENDENT',
#    'load_date': '2019-01-28T21:05:11+00:00',
#    'party': 'IND',
#    'last_f2_date': '2019-01-19',
#    'cycles': [2020],
#    'candidate_status': 'N',
#    'has_raised_funds': False,
#    'district': '00',
#    'office': 'S'}],
#  'pagination': {'count': 10, 'page': 1, 'pages': 1, 'per_page': 20}}

# %%
### SINGLE-CANDIDATE SEARCH ###

#Set search for all 2020 (two-year transaction period) Maine candidates
cand_name = 'COLLINS, SUSAN M'
period='2020'
parameters = {'q':cand_name
            ,'api_key':config.api_key}
#Requests candidate info
r_cand = requests.get('https://api.open.fec.gov/v1/candidates/search',params=parameters).json()
r

#Locates and sets Committee ID from 'principal_committees' sub-array
comm_id=json_normalize(data=r_cand['results'],record_path='principal_committees')[['committee_id','name','party']]
comm_id
# Out:
#   committee_id                 name party
# 0    C00314575  COLLINS FOR SENATOR   REP

# %%
# Out:
# {'api_version': '1.0',
#  'results': [{'fec_election_year': '2020',
#    'load_date': '2019-04-09T02:42:36.656000+00:00',
#    'contributor_employer': 'RETIRED',
#    'contributor': None,
#    'line_number': '11AI',
#    'candidate_prefix': None,
#    'contributor_state': 'FL',
#    'contributor_last_name': 'BENTLEY',
#    'two_year_transaction_period': 2020,
#    'candidate_office_full': None,
#    'committee': {'designation': 'P',
#     'party_full': 'REPUBLICAN PARTY',
#     'zip': '04402',
#     'committee_id': 'C00314575',
#     'state': 'ME',
#     'cycles': [1996,
#      1998,
#      2000,
#      2002,
#      2004,
#      2006,
#      2008,
#      2010,
#      2012,
#      2014,
#      2016,
#      2018,
#      2020],
#     'designation_full': 'Principal campaign committee',
#     'organization_type': None,
#     'street_1': 'PO BOX 1096',
#     'name': 'COLLINS FOR SENATOR',
#     'organization_type_full': None,
#     'filing_frequency': 'Q',
#     'committee_type': 'S',
#     'committee_type_full': 'Senate',
#     'candidate_ids': ['S6ME00159'],
#     'city': 'BANGOR',
#     'treasurer_name': 'MCCANDLESS, ELIZABETH T.',
#     'street_2': None,
#     'state_full': 'Maine',
#     'cycle': 2020,
#     'party': 'REP'},
#    'conduit_committee_street1': None,
#    'recipient_committee_type': 'S',
#    'receipt_type_desc': 'CONTRIBUTION',
#    'conduit_committee_name': None,
#    'line_number_label': 'Contributions From Individuals/Persons Other Than Political Committees',
#    'contributor_first_name': 'HENRY',
#    'schedule_type_full': 'ITEMIZED RECEIPTS',
#    'memo_text': None,
#    'candidate_suffix': None,
#    'entity_type_desc': 'INDIVIDUAL',
#    'candidate_id': None,
#    'image_number': '201904079146046969',
#    'candidate_office_state': None,
#    'candidate_last_name': None,
#    'receipt_type_full': None,
#    'contributor_city': 'SAINT PETERSBURG',
#    'increased_limit': None,
#    'entity_type': 'IND',
#    'candidate_office': None,
#    'contributor_zip': '337387060',
#    'candidate_middle_name': None,
#    'fec_election_type_desc': 'PRIMARY',
#    'candidate_office_state_full': None,
#    'conduit_committee_state': None,
#    'original_sub_id': None,
#    'contributor_prefix': None,
#    'memo_code': None,
#    'contributor_street_2': 'UNIT 86459',
#    'committee_id': 'C00314575',
#    'file_number': 1322783,
#    'receipt_type': '15',
#    'candidate_office_district': None,
#    'contributor_id': None,
#    'transaction_id': 'A1F99550E176249C7AFC',
#    'contribution_receipt_amount': 250.0,
#    'report_type': 'Q1',
#    'filing_form': 'F3',
#    'report_year': 2019,
#    'contributor_aggregate_ytd': 750.0,
#    'candidate_name': None,
#    'committee_name': None,
#    'conduit_committee_id': None,
#    'memoed_subtotal': False,
#    'candidate_first_name': None,
#    'election_type': 'P2020',
#    'national_committee_nonfederal_account': None,
#    'contribution_receipt_date': '2019-01-01T00:00:00',
#    'back_reference_schedule_name': None,
#    'contributor_middle_name': None,
#    'unused_contbr_id': None,
#    'contributor_suffix': None,
#    'election_type_full': None,
#    'memo_code_full': None,
#    'amendment_indicator_desc': 'ADD',
#    'amendment_indicator': 'A',
#    'pdf_url': 'http://docquery.fec.gov/cgi-bin/fecimg/?201904079146046969',
#    'link_id': 4040720191646004836,
#    'is_individual': True,
#    'conduit_committee_street2': None,
#    'sub_id': '4040820191646012926',
#    'contributor_name': 'BENTLEY, HENRY',
#    'contributor_occupation': 'RETIRED',
#    'back_reference_transaction_id': None,
#    'schedule_type': 'SA',
#    'donor_committee_name': None,
#    'contributor_street_1': '15019 MADEIRA WAY',
#    'conduit_committee_city': None,
#    'conduit_committee_zip': None},
#   {'fec_election_year': '2020',
#    'load_date': '2019-04-09T02:42:36.677000+00:00',
#    'contributor_employer': 'SELF',
#    'contributor': None,
#    'line_number': '11AI',
#    'candidate_prefix': None,
#    'contributor_state': 'AL',
#    'contributor_last_name': 'BRECKINRIDGE',
#    'two_year_transaction_period': 2020,
#    'candidate_office_full': None,
#    'committee': {'designation': 'P',
#     'party_full': 'REPUBLICAN PARTY',
#     'zip': '04402',
#     'committee_id': 'C00314575',
#     'state': 'ME',
#     'cycles': [1996,
#      1998,
#      2000,
#      2002,
#      2004,
#      2006,
#      2008,
#      2010,
#      2012,
#      2014,
#      2016,
#      2018,
#      2020],
#     'designation_full': 'Principal campaign committee',
#     'organization_type': None,
#     'street_1': 'PO BOX 1096',
#     'name': 'COLLINS FOR SENATOR',
#     'organization_type_full': None,
#     'filing_frequency': 'Q',
#     'committee_type': 'S',
#     'committee_type_full': 'Senate',
#     'candidate_ids': ['S6ME00159'],
#     'city': 'BANGOR',
#     'treasurer_name': 'MCCANDLESS, ELIZABETH T.',
#     'street_2': None,
#     'state_full': 'Maine',
#     'cycle': 2020,
#     'party': 'REP'},
#    'conduit_committee_street1': None,
#    'recipient_committee_type': 'S',
#    'receipt_type_desc': 'CONTRIBUTION',
#    'conduit_committee_name': None,
#    'line_number_label': 'Contributions From Individuals/Persons Other Than Political Committees',
#    'contributor_first_name': 'FLINT',
#    'schedule_type_full': 'ITEMIZED RECEIPTS',
#    'memo_text': None,
#    'candidate_suffix': None,
#    'entity_type_desc': 'INDIVIDUAL',
#    'candidate_id': None,
#    'image_number': '201904079146046980',
#    'candidate_office_state': None,
#    'candidate_last_name': None,
#    'receipt_type_full': None,
#    'contributor_city': 'TUSCALOOSA',
#    'increased_limit': None,
#    'entity_type': 'IND',
#    'candidate_office': None,
#    'contributor_zip': '354062944',
#    'candidate_middle_name': None,
#    'fec_election_type_desc': 'PRIMARY',
#    'candidate_office_state_full': None,
#    'conduit_committee_state': None,
#    'original_sub_id': None,
#    'contributor_prefix': None,
#    'memo_code': None,
#    'contributor_street_2': None,
#    'committee_id': 'C00314575',
#    'file_number': 1322783,
#    'receipt_type': '15',
#    'candidate_office_district': None,
#    'contributor_id': None,
#    'transaction_id': 'A66BF5ABC54F943FA94E',
#    'contribution_receipt_amount': 100.0,
#    'report_type': 'Q1',
#    'filing_form': 'F3',
#    'report_year': 2019,
#    'contributor_aggregate_ytd': 500.0,
#    'candidate_name': None,
#    'committee_name': None,
#    'conduit_committee_id': None,
#    'memoed_subtotal': False,
#    'candidate_first_name': None,
#    'election_type': 'P2020',
#    'national_committee_nonfederal_account': None,
#    'contribution_receipt_date': '2019-01-01T00:00:00',
#    'back_reference_schedule_name': None,
#    'contributor_middle_name': None,
#    'unused_contbr_id': None,
#    'contributor_suffix': None,
#    'election_type_full': None,
#    'memo_code_full': None,
#    'amendment_indicator_desc': 'ADD',
#    'amendment_indicator': 'A',
#    'pdf_url': 'http://docquery.fec.gov/cgi-bin/fecimg/?201904079146046980',
#    'link_id': 4040720191646004836,
#    'is_individual': True,
#    'conduit_committee_street2': None,
#    'sub_id': '4040820191646012959',
#    'contributor_name': 'BRECKINRIDGE, FLINT',
#    'contributor_occupation': 'CONSULTANT',
#    'back_reference_transaction_id': None,
#    'schedule_type': 'SA',
#    'donor_committee_name': None,
#    'contributor_street_1': '4114 CITATION CIR',
#    'conduit_committee_city': None,
#    'conduit_committee_zip': None},
#   {'fec_election_year': '2020',
#    'load_date': '2019-04-09T02:42:36.764000+00:00',
#    'contributor_employer': 'ARVEST BANK',
#    'contributor': None,
#    'line_number': '11AI',
#    'candidate_prefix': None,
#    'contributor_state': 'AR',
#    'contributor_last_name': 'GIBBS',
#    'two_year_transaction_period': 2020,
#    'candidate_office_full': None,
#    'committee': {'designation': 'P',
#     'party_full': 'REPUBLICAN PARTY',
#     'zip': '04402',
#     'committee_id': 'C00314575',
#     'state': 'ME',
#     'cycles': [1996,
#      1998,
#      2000,
#      2002,
#      2004,
#      2006,
#      2008,
#      2010,
#      2012,
#      2014,
#      2016,
#      2018,
#      2020],
#     'designation_full': 'Principal campaign committee',
#     'organization_type': None,
#     'street_1': 'PO BOX 1096',
#     'name': 'COLLINS FOR SENATOR',
#     'organization_type_full': None,
#     'filing_frequency': 'Q',
#     'committee_type': 'S',
#     'committee_type_full': 'Senate',
#     'candidate_ids': ['S6ME00159'],
#     'city': 'BANGOR',
#     'treasurer_name': 'MCCANDLESS, ELIZABETH T.',
#     'street_2': None,
#     'state_full': 'Maine',
#     'cycle': 2020,
#     'party': 'REP'},
#    'conduit_committee_street1': None,
#    'recipient_committee_type': 'S',
#    'receipt_type_desc': 'CONTRIBUTION',
#    'conduit_committee_name': None,
#    'line_number_label': 'Contributions From Individuals/Persons Other Than Political Committees',
#    'contributor_first_name': 'CLIFFORD',
#    'schedule_type_full': 'ITEMIZED RECEIPTS',
#    'memo_text': None,
#    'candidate_suffix': None,
#    'entity_type_desc': 'INDIVIDUAL',
#    'candidate_id': None,
#    'image_number': '201904079146047043',
#    'candidate_office_state': None,
#    'candidate_last_name': None,
#    'receipt_type_full': None,
#    'contributor_city': 'SILOAM SPRINGS',
#    'increased_limit': None,
#    'entity_type': 'IND',
#    'candidate_office': None,
#    'contributor_zip': '727618641',
#    'candidate_middle_name': None,
#    'fec_election_type_desc': 'PRIMARY',
#    'candidate_office_state_full': None,
#    'conduit_committee_state': None,
#    'original_sub_id': None,
#    'contributor_prefix': None,
#    'memo_code': None,
#    'contributor_street_2': None,
#    'committee_id': 'C00314575',
#    'file_number': 1322783,
#    'receipt_type': '15',
#    'candidate_office_district': None,
#    'contributor_id': None,
#    'transaction_id': 'AE9C7DC4C7855441A843',
#    'contribution_receipt_amount': 100.0,
#    'report_type': 'Q1',
#    'filing_form': 'F3',
#    'report_year': 2019,
#    'contributor_aggregate_ytd': 400.0,
#    'candidate_name': None,
#    'committee_name': None,
#    'conduit_committee_id': None,
#    'memoed_subtotal': False,
#    'candidate_first_name': None,
#    'election_type': 'P2020',
#    'national_committee_nonfederal_account': None,
#    'contribution_receipt_date': '2019-01-01T00:00:00',
#    'back_reference_schedule_name': None,
#    'contributor_middle_name': None,
#    'unused_contbr_id': None,
#    'contributor_suffix': None,
#    'election_type_full': None,
#    'memo_code_full': None,
#    'amendment_indicator_desc': 'ADD',
#    'amendment_indicator': 'A',
#    'pdf_url': 'http://docquery.fec.gov/cgi-bin/fecimg/?201904079146047043',
#    'link_id': 4040720191646004836,
#    'is_individual': True,
#    'conduit_committee_street2': None,
#    'sub_id': '4040820191646013149',
#    'contributor_name': 'GIBBS, CLIFFORD',
#    'contributor_occupation': 'MANAGEMENT',
#    'back_reference_transaction_id': None,
#    'schedule_type': 'SA',
#    'donor_committee_name': None,
#    'contributor_street_1': '16735 OLD HIGHWAY 68',
#    'conduit_committee_city': None,
#    'conduit_committee_zip': None},
#   {'fec_election_year': '2020',
#    'load_date': '2019-04-09T02:42:36.843000+00:00',
#    'contributor_employer': 'RETIRED',
#    'contributor': None,
#    'line_number': '11AI',
#    'candidate_prefix': None,
#    'contributor_state': 'FL',
#    'contributor_last_name': 'PARELL',
#    'two_year_transaction_period': 2020,
#    'candidate_office_full': None,
#    'committee': {'designation': 'P',
#     'party_full': 'REPUBLICAN PARTY',
#     'zip': '04402',
#     'committee_id': 'C00314575',
#     'state': 'ME',
#     'cycles': [1996,
#      1998,
#      2000,
#      2002,
#      2004,
#      2006,
#      2008,
#      2010,
#      2012,
#      2014,
#      2016,
#      2018,
#      2020],
#     'designation_full': 'Principal campaign committee',
#     'organization_type': None,
#     'street_1': 'PO BOX 1096',
#     'name': 'COLLINS FOR SENATOR',
#     'organization_type_full': None,
#     'filing_frequency': 'Q',
#     'committee_type': 'S',
#     'committee_type_full': 'Senate',
#     'candidate_ids': ['S6ME00159'],
#     'city': 'BANGOR',
#     'treasurer_name': 'MCCANDLESS, ELIZABETH T.',
#     'street_2': None,
#     'state_full': 'Maine',
#     'cycle': 2020,
#     'party': 'REP'},
#    'conduit_committee_street1': None,
#    'recipient_committee_type': 'S',
#    'receipt_type_desc': 'CONTRIBUTION',
#    'conduit_committee_name': None,
#    'line_number_label': 'Contributions From Individuals/Persons Other Than Political Committees',
#    'contributor_first_name': 'JOHN',
#    'schedule_type_full': 'ITEMIZED RECEIPTS',
#    'memo_text': None,
#    'candidate_suffix': None,
#    'entity_type_desc': 'INDIVIDUAL',
#    'candidate_id': None,
#    'image_number': '201904079146047149',
#    'candidate_office_state': None,
#    'candidate_last_name': None,
#    'receipt_type_full': None,
#    'contributor_city': 'HILLSBORO BEACH',
#    'increased_limit': None,
#    'entity_type': 'IND',
#    'candidate_office': None,
#    'contributor_zip': '330622501',
#    'candidate_middle_name': None,
#    'fec_election_type_desc': 'PRIMARY',
#    'candidate_office_state_full': None,
#    'conduit_committee_state': None,
#    'original_sub_id': None,
#    'contributor_prefix': None,
#    'memo_code': None,
#    'contributor_street_2': None,
#    'committee_id': 'C00314575',
#    'file_number': 1322783,
#    'receipt_type': '15',
#    'candidate_office_district': None,
#    'contributor_id': None,
#    'transaction_id': 'AB3531B9E6A664583BE4',
#    'contribution_receipt_amount': 100.0,
#    'report_type': 'Q1',
#    'filing_form': 'F3',
#    'report_year': 2019,
#    'contributor_aggregate_ytd': 300.0,
#    'candidate_name': None,
#    'committee_name': None,
#    'conduit_committee_id': None,
#    'memoed_subtotal': False,
#    'candidate_first_name': None,
#    'election_type': 'P2020',
#    'national_committee_nonfederal_account': None,
#    'contribution_receipt_date': '2019-01-01T00:00:00',
#    'back_reference_schedule_name': None,
#    'contributor_middle_name': None,
#    'unused_contbr_id': None,
#    'contributor_suffix': None,
#    'election_type_full': None,
#    'memo_code_full': None,
#    'amendment_indicator_desc': 'ADD',
#    'amendment_indicator': 'A',
#    'pdf_url': 'http://docquery.fec.gov/cgi-bin/fecimg/?201904079146047149',
#    'link_id': 4040720191646004836,
#    'is_individual': True,
#    'conduit_committee_street2': None,
#    'sub_id': '4040820191646013465',
#    'contributor_name': 'PARELL, JOHN',
#    'contributor_occupation': 'RETIRED',
#    'back_reference_transaction_id': None,
#    'schedule_type': 'SA',
#    'donor_committee_name': None,
#    'contributor_street_1': '953 HILLSBORO MILE',
#    'conduit_committee_city': None,
#    'conduit_committee_zip': None},
#   {'fec_election_year': '2020',
#    'load_date': '2019-04-09T02:42:36.852000+00:00',
#    'contributor_employer': 'RETIRED',
#    'contributor': None,
#    'line_number': '11AI',
#    'candidate_prefix': None,
#    'contributor_state': 'WA',
#    'contributor_last_name': 'REED',
#    'two_year_transaction_period': 2020,
#    'candidate_office_full': None,
#    'committee': {'designation': 'P',
#     'party_full': 'REPUBLICAN PARTY',
#     'zip': '04402',
#     'committee_id': 'C00314575',
#     'state': 'ME',
#     'cycles': [1996,
#      1998,
#      2000,
#      2002,
#      2004,
#      2006,
#      2008,
#      2010,
#      2012,
#      2014,
#      2016,
#      2018,
#      2020],
#     'designation_full': 'Principal campaign committee',
#     'organization_type': None,
#     'street_1': 'PO BOX 1096',
#     'name': 'COLLINS FOR SENATOR',
#     'organization_type_full': None,
#     'filing_frequency': 'Q',
#     'committee_type': 'S',
#     'committee_type_full': 'Senate',
#     'candidate_ids': ['S6ME00159'],
#     'city': 'BANGOR',
#     'treasurer_name': 'MCCANDLESS, ELIZABETH T.',
#     'street_2': None,
#     'state_full': 'Maine',
#     'cycle': 2020,
#     'party': 'REP'},
#    'conduit_committee_street1': None,
#    'recipient_committee_type': 'S',
#    'receipt_type_desc': None,
#    'conduit_committee_name': None,
#    'line_number_label': 'Contributions From Individuals/Persons Other Than Political Committees',
#    'contributor_first_name': 'FRANK',
#    'schedule_type_full': 'ITEMIZED RECEIPTS',
#    'memo_text': None,
#    'candidate_suffix': None,
#    'entity_type_desc': 'INDIVIDUAL',
#    'candidate_id': None,
#    'image_number': '201904079146047163',
#    'candidate_office_state': None,
#    'candidate_last_name': None,
#    'receipt_type_full': None,
#    'contributor_city': 'POULSBO',
#    'increased_limit': None,
#    'entity_type': 'IND',
#    'candidate_office': None,
#    'contributor_zip': '983706907',
#    'candidate_middle_name': None,
#    'fec_election_type_desc': 'PRIMARY',
#    'candidate_office_state_full': None,
#    'conduit_committee_state': None,
#    'original_sub_id': None,
#    'contributor_prefix': None,
#    'memo_code': None,
#    'contributor_street_2': None,
#    'committee_id': 'C00314575',
#    'file_number': 1322783,
#    'receipt_type': None,
#    'candidate_office_district': None,
#    'contributor_id': None,
#    'transaction_id': 'A8BDD8FFE4FE34C7DAA7',
#    'contribution_receipt_amount': 100.0,
#    'report_type': 'Q1',
#    'filing_form': 'F3',
#    'report_year': 2019,
#    'contributor_aggregate_ytd': 200.0,
#    'candidate_name': None,
#    'committee_name': None,
#    'conduit_committee_id': None,
#    'memoed_subtotal': False,
#    'candidate_first_name': None,
#    'election_type': 'P2020',
#    'national_committee_nonfederal_account': None,
#    'contribution_receipt_date': '2019-01-01T00:00:00',
#    'back_reference_schedule_name': None,
#    'contributor_middle_name': None,
#    'unused_contbr_id': None,
#    'contributor_suffix': None,
#    'election_type_full': None,
#    'memo_code_full': None,
#    'amendment_indicator_desc': 'ADD',
#    'amendment_indicator': 'A',
#    'pdf_url': 'http://docquery.fec.gov/cgi-bin/fecimg/?201904079146047163',
#    'link_id': 4040720191646004836,
#    'is_individual': True,
#    'conduit_committee_street2': None,
#    'sub_id': '4040820191646013507',
#    'contributor_name': 'REED, FRANK',
#    'contributor_occupation': 'RETIRED',
#    'back_reference_transaction_id': None,
#    'schedule_type': 'SA',
#    'donor_committee_name': None,
#    'contributor_street_1': '10750 OGLE RD NE',
#    'conduit_committee_city': None,
#    'conduit_committee_zip': None},
#   {'fec_election_year': '2020',
#    'load_date': '2019-04-09T02:42:36.852000+00:00',
#    'contributor_employer': 'RETIRED',
#    'contributor': None,
#    'line_number': '11AI',
#    'candidate_prefix': None,
#    'contributor_state': 'WA',
#    'contributor_last_name': 'REED',
#    'two_year_transaction_period': 2020,
#    'candidate_office_full': None,
#    'committee': {'designation': 'P',
#     'party_full': 'REPUBLICAN PARTY',
#     'zip': '04402',
#     'committee_id': 'C00314575',
#     'state': 'ME',
#     'cycles': [1996,
#      1998,
#      2000,
#      2002,
#      2004,
#      2006,
#      2008,
#      2010,
#      2012,
#      2014,
#      2016,
#      2018,
#      2020],
#     'designation_full': 'Principal campaign committee',
#     'organization_type': None,
#     'street_1': 'PO BOX 1096',
#     'name': 'COLLINS FOR SENATOR',
#     'organization_type_full': None,
#     'filing_frequency': 'Q',
#     'committee_type': 'S',
#     'committee_type_full': 'Senate',
#     'candidate_ids': ['S6ME00159'],
#     'city': 'BANGOR',
#     'treasurer_name': 'MCCANDLESS, ELIZABETH T.',
#     'street_2': None,
#     'state_full': 'Maine',
#     'cycle': 2020,
#     'party': 'REP'},
#    'conduit_committee_street1': None,
#    'recipient_committee_type': 'S',
#    'receipt_type_desc': None,
#    'conduit_committee_name': None,
#    'line_number_label': 'Contributions From Individuals/Persons Other Than Political Committees',
#    'contributor_first_name': 'FRANK',
#    'schedule_type_full': 'ITEMIZED RECEIPTS',
#    'memo_text': None,
#    'candidate_suffix': None,
#    'entity_type_desc': 'INDIVIDUAL',
#    'candidate_id': None,
#    'image_number': '201904079146047163',
#    'candidate_office_state': None,
#    'candidate_last_name': None,
#    'receipt_type_full': None,
#    'contributor_city': 'POULSBO',
#    'increased_limit': None,
#    'entity_type': 'IND',
#    'candidate_office': None,
#    'contributor_zip': '983706907',
#    'candidate_middle_name': None,
#    'fec_election_type_desc': 'PRIMARY',
#    'candidate_office_state_full': None,
#    'conduit_committee_state': None,
#    'original_sub_id': None,
#    'contributor_prefix': None,
#    'memo_code': None,
#    'contributor_street_2': None,
#    'committee_id': 'C00314575',
#    'file_number': 1322783,
#    'receipt_type': None,
#    'candidate_office_district': None,
#    'contributor_id': None,
#    'transaction_id': 'AA2E9430417814DCAB3B',
#    'contribution_receipt_amount': 100.0,
#    'report_type': 'Q1',
#    'filing_form': 'F3',
#    'report_year': 2019,
#    'contributor_aggregate_ytd': 200.0,
#    'candidate_name': None,
#    'committee_name': None,
#    'conduit_committee_id': None,
#    'memoed_subtotal': False,
#    'candidate_first_name': None,
#    'election_type': 'P2020',
#    'national_committee_nonfederal_account': None,
#    'contribution_receipt_date': '2019-01-01T00:00:00',
#    'back_reference_schedule_name': None,
#    'contributor_middle_name': None,
#    'unused_contbr_id': None,
#    'contributor_suffix': None,
#    'election_type_full': None,
#    'memo_code_full': None,
#    'amendment_indicator_desc': 'ADD',
#    'amendment_indicator': 'A',
#    'pdf_url': 'http://docquery.fec.gov/cgi-bin/fecimg/?201904079146047163',
#    'link_id': 4040720191646004836,
#    'is_individual': True,
#    'conduit_committee_street2': None,
#    'sub_id': '4040820191646013508',
#    'contributor_name': 'REED, FRANK',
#    'contributor_occupation': 'RETIRED',
#    'back_reference_transaction_id': None,
#    'schedule_type': 'SA',
#    'donor_committee_name': None,
#    'contributor_street_1': '10750 OGLE RD NE',
#    'conduit_committee_city': None,
#    'conduit_committee_zip': None},
#   {'fec_election_year': '2020',
#    'load_date': '2019-04-09T02:42:36.867000+00:00',
#    'contributor_employer': 'HTPN',
#    'contributor': None,
#    'line_number': '11AI',
#    'candidate_prefix': None,
#    'contributor_state': 'TX',
#    'contributor_last_name': 'SCHUMACHER',
#    'two_year_transaction_period': 2020,
#    'candidate_office_full': None,
#    'committee': {'designation': 'P',
#     'party_full': 'REPUBLICAN PARTY',
#     'zip': '04402',
#     'committee_id': 'C00314575',
#     'state': 'ME',
#     'cycles': [1996,
#      1998,
#      2000,
#      2002,
#      2004,
#      2006,
#      2008,
#      2010,
#      2012,
#      2014,
#      2016,
#      2018,
#      2020],
#     'designation_full': 'Principal campaign committee',
#     'organization_type': None,
#     'street_1': 'PO BOX 1096',
#     'name': 'COLLINS FOR SENATOR',
#     'organization_type_full': None,
#     'filing_frequency': 'Q',
#     'committee_type': 'S',
#     'committee_type_full': 'Senate',
#     'candidate_ids': ['S6ME00159'],
#     'city': 'BANGOR',
#     'treasurer_name': 'MCCANDLESS, ELIZABETH T.',
#     'street_2': None,
#     'state_full': 'Maine',
#     'cycle': 2020,
#     'party': 'REP'},
#    'conduit_committee_street1': None,
#    'recipient_committee_type': 'S',
#    'receipt_type_desc': 'CONTRIBUTION',
#    'conduit_committee_name': None,
#    'line_number_label': 'Contributions From Individuals/Persons Other Than Political Committees',
#    'contributor_first_name': 'JOHN',
#    'schedule_type_full': 'ITEMIZED RECEIPTS',
#    'memo_text': None,
#    'candidate_suffix': None,
#    'entity_type_desc': 'INDIVIDUAL',
#    'candidate_id': None,
#    'image_number': '201904079146047184',
#    'candidate_office_state': None,
#    'candidate_last_name': None,
#    'receipt_type_full': None,
#    'contributor_city': 'DALLAS',
#    'increased_limit': None,
#    'entity_type': 'IND',
#    'candidate_office': None,
#    'contributor_zip': '752051621',
#    'candidate_middle_name': None,
#    'fec_election_type_desc': 'PRIMARY',
#    'candidate_office_state_full': None,
#    'conduit_committee_state': None,
#    'original_sub_id': None,
#    'contributor_prefix': None,
#    'memo_code': None,
#    'contributor_street_2': None,
#    'committee_id': 'C00314575',
#    'file_number': 1322783,
#    'receipt_type': '15',
#    'candidate_office_district': None,
#    'contributor_id': None,
#    'transaction_id': 'A0950552B2BCE4148A89',
#    'contribution_receipt_amount': 100.0,
#    'report_type': 'Q1',
#    'filing_form': 'F3',
#    'report_year': 2019,
#    'contributor_aggregate_ytd': 400.0,
#    'candidate_name': None,
#    'committee_name': None,
#    'conduit_committee_id': None,
#    'memoed_subtotal': False,
#    'candidate_first_name': None,
#    'election_type': 'P2020',
#    'national_committee_nonfederal_account': None,
#    'contribution_receipt_date': '2019-01-01T00:00:00',
#    'back_reference_schedule_name': None,
#    'contributor_middle_name': None,
#    'unused_contbr_id': None,
#    'contributor_suffix': None,
#    'election_type_full': None,
#    'memo_code_full': None,
#    'amendment_indicator_desc': 'ADD',
#    'amendment_indicator': 'A',
#    'pdf_url': 'http://docquery.fec.gov/cgi-bin/fecimg/?201904079146047184',
#    'link_id': 4040720191646004836,
#    'is_individual': True,
#    'conduit_committee_street2': None,
#    'sub_id': '4040820191646013572',
#    'contributor_name': 'SCHUMACHER, JOHN',
#    'contributor_occupation': 'PHYSICIAN',
#    'back_reference_transaction_id': None,
#    'schedule_type': 'SA',
#    'donor_committee_name': None,
#    'contributor_street_1': '4412 LARCHMONT ST',
#    'conduit_committee_city': None,
#    'conduit_committee_zip': None},
#   {'fec_election_year': '2020',
#    'load_date': '2019-04-09T02:42:36.769000+00:00',
#    'contributor_employer': 'ALL SEASONS ROOFING',
#    'contributor': None,
#    'line_number': '11AI',
#    'candidate_prefix': None,
#    'contributor_state': 'CA',
#    'contributor_last_name': 'GORSHTEYN',
#    'two_year_transaction_period': 2020,
#    'candidate_office_full': None,
#    'committee': {'designation': 'P',
#     'party_full': 'REPUBLICAN PARTY',
#     'zip': '04402',
#     'committee_id': 'C00314575',
#     'state': 'ME',
#     'cycles': [1996,
#      1998,
#      2000,
#      2002,
#      2004,
#      2006,
#      2008,
#      2010,
#      2012,
#      2014,
#      2016,
#      2018,
#      2020],
#     'designation_full': 'Principal campaign committee',
#     'organization_type': None,
#     'street_1': 'PO BOX 1096',
#     'name': 'COLLINS FOR SENATOR',
#     'organization_type_full': None,
#     'filing_frequency': 'Q',
#     'committee_type': 'S',
#     'committee_type_full': 'Senate',
#     'candidate_ids': ['S6ME00159'],
#     'city': 'BANGOR',
#     'treasurer_name': 'MCCANDLESS, ELIZABETH T.',
#     'street_2': None,
#     'state_full': 'Maine',
#     'cycle': 2020,
#     'party': 'REP'},
#    'conduit_committee_street1': None,
#    'recipient_committee_type': 'S',
#    'receipt_type_desc': 'CONTRIBUTION',
#    'conduit_committee_name': None,
#    'line_number_label': 'Contributions From Individuals/Persons Other Than Political Committees',
#    'contributor_first_name': 'VLAD',
#    'schedule_type_full': 'ITEMIZED RECEIPTS',
#    'memo_text': None,
#    'candidate_suffix': None,
#    'entity_type_desc': 'INDIVIDUAL',
#    'candidate_id': None,
#    'image_number': '201904079146047048',
#    'candidate_office_state': None,
#    'candidate_last_name': None,
#    'receipt_type_full': None,
#    'contributor_city': 'LOS GATOS',
#    'increased_limit': None,
#    'entity_type': 'IND',
#    'candidate_office': None,
#    'contributor_zip': '950303085',
#    'candidate_middle_name': None,
#    'fec_election_type_desc': 'PRIMARY',
#    'candidate_office_state_full': None,
#    'conduit_committee_state': None,
#    'original_sub_id': None,
#    'contributor_prefix': None,
#    'memo_code': None,
#    'contributor_street_2': None,
#    'committee_id': 'C00314575',
#    'file_number': 1322783,
#    'receipt_type': '15',
#    'candidate_office_district': None,
#    'contributor_id': None,
#    'transaction_id': 'AB2FD1F7334D440D0917',
#    'contribution_receipt_amount': 100.0,
#    'report_type': 'Q1',
#    'filing_form': 'F3',
#    'report_year': 2019,
#    'contributor_aggregate_ytd': 300.0,
#    'candidate_name': None,
#    'committee_name': None,
#    'conduit_committee_id': None,
#    'memoed_subtotal': False,
#    'candidate_first_name': None,
#    'election_type': 'P2020',
#    'national_committee_nonfederal_account': None,
#    'contribution_receipt_date': '2019-01-02T00:00:00',
#    'back_reference_schedule_name': None,
#    'contributor_middle_name': None,
#    'unused_contbr_id': None,
#    'contributor_suffix': None,
#    'election_type_full': None,
#    'memo_code_full': None,
#    'amendment_indicator_desc': 'ADD',
#    'amendment_indicator': 'A',
#    'pdf_url': 'http://docquery.fec.gov/cgi-bin/fecimg/?201904079146047048',
#    'link_id': 4040720191646004836,
#    'is_individual': True,
#    'conduit_committee_street2': None,
#    'sub_id': '4040820191646013163',
#    'contributor_name': 'GORSHTEYN, VLAD',
#    'contributor_occupation': 'CONSTRUCTION EXECUTIVE',
#    'back_reference_transaction_id': None,
#    'schedule_type': 'SA',
#    'donor_committee_name': None,
#    'contributor_street_1': '15965 LANCASTER RD',
#    'conduit_committee_city': None,
#    'conduit_committee_zip': None},
#   {'fec_election_year': '2020',
#    'load_date': '2019-04-09T02:42:36.838000+00:00',
#    'contributor_employer': 'INDEPENDENT CONTRACTOR',
#    'contributor': None,
#    'line_number': '11AI',
#    'candidate_prefix': None,
#    'contributor_state': 'MS',
#    'contributor_last_name': "O'CONNOR",
#    'two_year_transaction_period': 2020,
#    'candidate_office_full': None,
#    'committee': {'designation': 'P',
#     'party_full': 'REPUBLICAN PARTY',
#     'zip': '04402',
#     'committee_id': 'C00314575',
#     'state': 'ME',
#     'cycles': [1996,
#      1998,
#      2000,
#      2002,
#      2004,
#      2006,
#      2008,
#      2010,
#      2012,
#      2014,
#      2016,
#      2018,
#      2020],
#     'designation_full': 'Principal campaign committee',
#     'organization_type': None,
#     'street_1': 'PO BOX 1096',
#     'name': 'COLLINS FOR SENATOR',
#     'organization_type_full': None,
#     'filing_frequency': 'Q',
#     'committee_type': 'S',
#     'committee_type_full': 'Senate',
#     'candidate_ids': ['S6ME00159'],
#     'city': 'BANGOR',
#     'treasurer_name': 'MCCANDLESS, ELIZABETH T.',
#     'street_2': None,
#     'state_full': 'Maine',
#     'cycle': 2020,
#     'party': 'REP'},
#    'conduit_committee_street1': None,
#    'recipient_committee_type': 'S',
#    'receipt_type_desc': 'CONTRIBUTION',
#    'conduit_committee_name': None,
#    'line_number_label': 'Contributions From Individuals/Persons Other Than Political Committees',
#    'contributor_first_name': 'RICHARD',
#    'schedule_type_full': 'ITEMIZED RECEIPTS',
#    'memo_text': None,
#    'candidate_suffix': None,
#    'entity_type_desc': 'INDIVIDUAL',
#    'candidate_id': None,
#    'image_number': '201904079146047144',
#    'candidate_office_state': None,
#    'candidate_last_name': None,
#    'receipt_type_full': None,
#    'contributor_city': 'BILOXI',
#    'increased_limit': None,
#    'entity_type': 'IND',
#    'candidate_office': None,
#    'contributor_zip': '395328383',
#    'candidate_middle_name': None,
#    'fec_election_type_desc': 'PRIMARY',
#    'candidate_office_state_full': None,
#    'conduit_committee_state': None,
#    'original_sub_id': None,
#    'contributor_prefix': None,
#    'memo_code': None,
#    'contributor_street_2': None,
#    'committee_id': 'C00314575',
#    'file_number': 1322783,
#    'receipt_type': '15',
#    'candidate_office_district': None,
#    'contributor_id': None,
#    'transaction_id': 'ADFE3250EAA894F028D3',
#    'contribution_receipt_amount': 250.0,
#    'report_type': 'Q1',
#    'filing_form': 'F3',
#    'report_year': 2019,
#    'contributor_aggregate_ytd': 250.0,
#    'candidate_name': None,
#    'committee_name': None,
#    'conduit_committee_id': None,
#    'memoed_subtotal': False,
#    'candidate_first_name': None,
#    'election_type': 'P2020',
#    'national_committee_nonfederal_account': None,
#    'contribution_receipt_date': '2019-01-02T00:00:00',
#    'back_reference_schedule_name': None,
#    'contributor_middle_name': None,
#    'unused_contbr_id': None,
#    'contributor_suffix': None,
#    'election_type_full': None,
#    'memo_code_full': None,
#    'amendment_indicator_desc': 'ADD',
#    'amendment_indicator': 'A',
#    'pdf_url': 'http://docquery.fec.gov/cgi-bin/fecimg/?201904079146047144',
#    'link_id': 4040720191646004836,
#    'is_individual': True,
#    'conduit_committee_street2': None,
#    'sub_id': '4040820191646013450',
#    'contributor_name': "O'CONNOR, RICHARD",
#    'contributor_occupation': 'IT SECURITY MGR',
#    'back_reference_transaction_id': None,
#    'schedule_type': 'SA',
#    'donor_committee_name': None,
#    'contributor_street_1': '8051 CRESTWOOD CV',
#    'conduit_committee_city': None,
#    'conduit_committee_zip': None},
#   {'fec_election_year': '2020',
#    'load_date': '2019-04-09T02:42:36.744000+00:00',
#    'contributor_employer': 'RETIRED',
#    'contributor': None,
#    'line_number': '11AI',
#    'candidate_prefix': None,
#    'contributor_state': 'FL',
#    'contributor_last_name': 'FOX',
#    'two_year_transaction_period': 2020,
#    'candidate_office_full': None,
#    'committee': {'designation': 'P',
#     'party_full': 'REPUBLICAN PARTY',
#     'zip': '04402',
#     'committee_id': 'C00314575',
#     'state': 'ME',
#     'cycles': [1996,
#      1998,
#      2000,
#      2002,
#      2004,
#      2006,
#      2008,
#      2010,
#      2012,
#      2014,
#      2016,
#      2018,
#      2020],
#     'designation_full': 'Principal campaign committee',
#     'organization_type': None,
#     'street_1': 'PO BOX 1096',
#     'name': 'COLLINS FOR SENATOR',
#     'organization_type_full': None,
#     'filing_frequency': 'Q',
#     'committee_type': 'S',
#     'committee_type_full': 'Senate',
#     'candidate_ids': ['S6ME00159'],
#     'city': 'BANGOR',
#     'treasurer_name': 'MCCANDLESS, ELIZABETH T.',
#     'street_2': None,
#     'state_full': 'Maine',
#     'cycle': 2020,
#     'party': 'REP'},
#    'conduit_committee_street1': None,
#    'recipient_committee_type': 'S',
#    'receipt_type_desc': 'CONTRIBUTION',
#    'conduit_committee_name': None,
#    'line_number_label': 'Contributions From Individuals/Persons Other Than Political Committees',
#    'contributor_first_name': 'JOHN',
#    'schedule_type_full': 'ITEMIZED RECEIPTS',
#    'memo_text': None,
#    'candidate_suffix': None,
#    'entity_type_desc': 'INDIVIDUAL',
#    'candidate_id': None,
#    'image_number': '201904079146047027',
#    'candidate_office_state': None,
#    'candidate_last_name': None,
#    'receipt_type_full': None,
#    'contributor_city': 'GAINESVILLE',
#    'increased_limit': None,
#    'entity_type': 'IND',
#    'candidate_office': None,
#    'contributor_zip': '326072693',
#    'candidate_middle_name': None,
#    'fec_election_type_desc': 'PRIMARY',
#    'candidate_office_state_full': None,
#    'conduit_committee_state': None,
#    'original_sub_id': None,
#    'contributor_prefix': None,
#    'memo_code': None,
#    'contributor_street_2': None,
#    'committee_id': 'C00314575',
#    'file_number': 1322783,
#    'receipt_type': '15',
#    'candidate_office_district': None,
#    'contributor_id': None,
#    'transaction_id': 'AC9527181AD7C477EB4D',
#    'contribution_receipt_amount': 50.0,
#    'report_type': 'Q1',
#    'filing_form': 'F3',
#    'report_year': 2019,
#    'contributor_aggregate_ytd': 250.0,
#    'candidate_name': None,
#    'committee_name': None,
#    'conduit_committee_id': None,
#    'memoed_subtotal': False,
#    'candidate_first_name': None,
#    'election_type': 'P2020',
#    'national_committee_nonfederal_account': None,
#    'contribution_receipt_date': '2019-01-03T00:00:00',
#    'back_reference_schedule_name': None,
#    'contributor_middle_name': None,
#    'unused_contbr_id': None,
#    'contributor_suffix': None,
#    'election_type_full': None,
#    'memo_code_full': None,
#    'amendment_indicator_desc': 'ADD',
#    'amendment_indicator': 'A',
#    'pdf_url': 'http://docquery.fec.gov/cgi-bin/fecimg/?201904079146047027',
#    'link_id': 4040720191646004836,
#    'is_individual': True,
#    'conduit_committee_street2': None,
#    'sub_id': '4040820191646013099',
#    'contributor_name': 'FOX, JOHN',
#    'contributor_occupation': 'RETIRED',
#    'back_reference_transaction_id': None,
#    'schedule_type': 'SA',
#    'donor_committee_name': None,
#    'contributor_street_1': '309 NW 24TH ST',
#    'conduit_committee_city': None,
#    'conduit_committee_zip': None},
#   {'fec_election_year': '2020',
#    'load_date': '2019-04-09T02:42:36.773000+00:00',
#    'contributor_employer': 'GIBSONBURG HEALTH',
#    'contributor': None,
#    'line_number': '11AI',
#    'candidate_prefix': None,
#    'contributor_state': 'GA',
#    'contributor_last_name': 'HERETH',
#    'two_year_transaction_period': 2020,
#    'candidate_office_full': None,
#    'committee': {'designation': 'P',
#     'party_full': 'REPUBLICAN PARTY',
#     'zip': '04402',
#     'committee_id': 'C00314575',
#     'state': 'ME',
#     'cycles': [1996,
#      1998,
#      2000,
#      2002,
#      2004,
#      2006,
#      2008,
#      2010,
#      2012,
#      2014,
#      2016,
#      2018,
#      2020],
#     'designation_full': 'Principal campaign committee',
#     'organization_type': None,
#     'street_1': 'PO BOX 1096',
#     'name': 'COLLINS FOR SENATOR',
#     'organization_type_full': None,
#     'filing_frequency': 'Q',
#     'committee_type': 'S',
#     'committee_type_full': 'Senate',
#     'candidate_ids': ['S6ME00159'],
#     'city': 'BANGOR',
#     'treasurer_name': 'MCCANDLESS, ELIZABETH T.',
#     'street_2': None,
#     'state_full': 'Maine',
#     'cycle': 2020,
#     'party': 'REP'},
#    'conduit_committee_street1': None,
#    'recipient_committee_type': 'S',
#    'receipt_type_desc': 'CONTRIBUTION',
#    'conduit_committee_name': None,
#    'line_number_label': 'Contributions From Individuals/Persons Other Than Political Committees',
#    'contributor_first_name': 'JACK',
#    'schedule_type_full': 'ITEMIZED RECEIPTS',
#    'memo_text': None,
#    'candidate_suffix': None,
#    'entity_type_desc': 'INDIVIDUAL',
#    'candidate_id': None,
#    'image_number': '201904079146047058',
#    'candidate_office_state': None,
#    'candidate_last_name': None,
#    'receipt_type_full': None,
#    'contributor_city': 'WOODSTOCK',
#    'increased_limit': None,
#    'entity_type': 'IND',
#    'candidate_office': None,
#    'contributor_zip': '301885218',
#    'candidate_middle_name': None,
#    'fec_election_type_desc': 'PRIMARY',
#    'candidate_office_state_full': None,
#    'conduit_committee_state': None,
#    'original_sub_id': None,
#    'contributor_prefix': None,
#    'memo_code': None,
#    'contributor_street_2': None,
#    'committee_id': 'C00314575',
#    'file_number': 1322783,
#    'receipt_type': '15',
#    'candidate_office_district': None,
#    'contributor_id': None,
#    'transaction_id': 'A17BBA885375946F7AD0',
#    'contribution_receipt_amount': 250.0,
#    'report_type': 'Q1',
#    'filing_form': 'F3',
#    'report_year': 2019,
#    'contributor_aggregate_ytd': 1000.0,
#    'candidate_name': None,
#    'committee_name': None,
#    'conduit_committee_id': None,
#    'memoed_subtotal': False,
#    'candidate_first_name': None,
#    'election_type': 'P2020',
#    'national_committee_nonfederal_account': None,
#    'contribution_receipt_date': '2019-01-04T00:00:00',
#    'back_reference_schedule_name': None,
#    'contributor_middle_name': None,
#    'unused_contbr_id': None,
#    'contributor_suffix': None,
#    'election_type_full': None,
#    'memo_code_full': None,
#    'amendment_indicator_desc': 'ADD',
#    'amendment_indicator': 'A',
#    'pdf_url': 'http://docquery.fec.gov/cgi-bin/fecimg/?201904079146047058',
#    'link_id': 4040720191646004836,
#    'is_individual': True,
#    'conduit_committee_street2': None,
#    'sub_id': '4040820191646013192',
#    'contributor_name': 'HERETH, JACK',
#    'contributor_occupation': 'EXECUTIVE',
#    'back_reference_transaction_id': None,
#    'schedule_type': 'SA',
#    'donor_committee_name': None,
#    'contributor_street_1': '4066 EARNEY RD',
#    'conduit_committee_city': None,
#    'conduit_committee_zip': None},
#   {'fec_election_year': '2020',
#    'load_date': '2019-04-09T02:42:36.778000+00:00',
#    'contributor_employer': 'RETIRED',
#    'contributor': None,
#    'line_number': '11AI',
#    'candidate_prefix': None,
#    'contributor_state': 'NY',
#    'contributor_last_name': 'HOULIHAN',
#    'two_year_transaction_period': 2020,
#    'candidate_office_full': None,
#    'committee': {'designation': 'P',
#     'party_full': 'REPUBLICAN PARTY',
#     'zip': '04402',
#     'committee_id': 'C00314575',
#     'state': 'ME',
#     'cycles': [1996,
#      1998,
#      2000,
#      2002,
#      2004,
#      2006,
#      2008,
#      2010,
#      2012,
#      2014,
#      2016,
#      2018,
#      2020],
#     'designation_full': 'Principal campaign committee',
#     'organization_type': None,
#     'street_1': 'PO BOX 1096',
#     'name': 'COLLINS FOR SENATOR',
#     'organization_type_full': None,
#     'filing_frequency': 'Q',
#     'committee_type': 'S',
#     'committee_type_full': 'Senate',
#     'candidate_ids': ['S6ME00159'],
#     'city': 'BANGOR',
#     'treasurer_name': 'MCCANDLESS, ELIZABETH T.',
#     'street_2': None,
#     'state_full': 'Maine',
#     'cycle': 2020,
#     'party': 'REP'},
#    'conduit_committee_street1': None,
#    'recipient_committee_type': 'S',
#    'receipt_type_desc': 'CONTRIBUTION',
#    'conduit_committee_name': None,
#    'line_number_label': 'Contributions From Individuals/Persons Other Than Political Committees',
#    'contributor_first_name': 'MARK',
#    'schedule_type_full': 'ITEMIZED RECEIPTS',
#    'memo_text': None,
#    'candidate_suffix': None,
#    'entity_type_desc': 'INDIVIDUAL',
#    'candidate_id': None,
#    'image_number': '201904079146047067',
#    'candidate_office_state': None,
#    'candidate_last_name': None,
#    'receipt_type_full': None,
#    'contributor_city': 'WHITE PLAINS',
#    'increased_limit': None,
#    'entity_type': 'IND',
#    'candidate_office': None,
#    'contributor_zip': '106028236',
#    'candidate_middle_name': None,
#    'fec_election_type_desc': 'PRIMARY',
#    'candidate_office_state_full': None,
#    'conduit_committee_state': None,
#    'original_sub_id': None,
#    'contributor_prefix': None,
#    'memo_code': None,
#    'contributor_street_2': None,
#    'committee_id': 'C00314575',
#    'file_number': 1322783,
#    'receipt_type': '15',
#    'candidate_office_district': None,
#    'contributor_id': None,
#    'transaction_id': 'AADE9F7F67E9141DDA1E',
#    'contribution_receipt_amount': 250.0,
#    'report_type': 'Q1',
#    'filing_form': 'F3',
#    'report_year': 2019,
#    'contributor_aggregate_ytd': 750.0,
#    'candidate_name': None,
#    'committee_name': None,
#    'conduit_committee_id': None,
#    'memoed_subtotal': False,
#    'candidate_first_name': None,
#    'election_type': 'P2020',
#    'national_committee_nonfederal_account': None,
#    'contribution_receipt_date': '2019-01-04T00:00:00',
#    'back_reference_schedule_name': None,
#    'contributor_middle_name': None,
#    'unused_contbr_id': None,
#    'contributor_suffix': None,
#    'election_type_full': None,
#    'memo_code_full': None,
#    'amendment_indicator_desc': 'ADD',
#    'amendment_indicator': 'A',
#    'pdf_url': 'http://docquery.fec.gov/cgi-bin/fecimg/?201904079146047067',
#    'link_id': 4040720191646004836,
#    'is_individual': True,
#    'conduit_committee_street2': None,
#    'sub_id': '4040820191646013220',
#    'contributor_name': 'HOULIHAN, MARK',
#    'contributor_occupation': 'RETIRED',
#    'back_reference_transaction_id': None,
#    'schedule_type': 'SA',
#    'donor_committee_name': None,
#    'contributor_street_1': 'PO BOX 8236',
#    'conduit_committee_city': None,
#    'conduit_committee_zip': None},
#   {'fec_election_year': '2020',
#    'load_date': '2019-04-09T02:42:36.782000+00:00',
#    'contributor_employer': 'STATE OF MD',
#    'contributor': None,
#    'line_number': '11AI',
#    'candidate_prefix': None,
#    'contributor_state': 'MD',
#    'contributor_last_name': 'HUT',
#    'two_year_transaction_period': 2020,
#    'candidate_office_full': None,
#    'committee': {'designation': 'P',
#     'party_full': 'REPUBLICAN PARTY',
#     'zip': '04402',
#     'committee_id': 'C00314575',
#     'state': 'ME',
#     'cycles': [1996,
#      1998,
#      2000,
#      2002,
#      2004,
#      2006,
#      2008,
#      2010,
#      2012,
#      2014,
#      2016,
#      2018,
#      2020],
#     'designation_full': 'Principal campaign committee',
#     'organization_type': None,
#     'street_1': 'PO BOX 1096',
#     'name': 'COLLINS FOR SENATOR',
#     'organization_type_full': None,
#     'filing_frequency': 'Q',
#     'committee_type': 'S',
#     'committee_type_full': 'Senate',
#     'candidate_ids': ['S6ME00159'],
#     'city': 'BANGOR',
#     'treasurer_name': 'MCCANDLESS, ELIZABETH T.',
#     'street_2': None,
#     'state_full': 'Maine',
#     'cycle': 2020,
#     'party': 'REP'},
#    'conduit_committee_street1': None,
#    'recipient_committee_type': 'S',
#    'receipt_type_desc': 'CONTRIBUTION',
#    'conduit_committee_name': None,
#    'line_number_label': 'Contributions From Individuals/Persons Other Than Political Committees',
#    'contributor_first_name': 'STEPHEN',
#    'schedule_type_full': 'ITEMIZED RECEIPTS',
#    'memo_text': None,
#    'candidate_suffix': None,
#    'entity_type_desc': 'INDIVIDUAL',
#    'candidate_id': None,
#    'image_number': '201904079146047074',
#    'candidate_office_state': None,
#    'candidate_last_name': None,
#    'receipt_type_full': None,
#    'contributor_city': 'CHEVY CHASE',
#    'increased_limit': None,
#    'entity_type': 'IND',
#    'candidate_office': None,
#    'contributor_zip': '208155030',
#    'candidate_middle_name': None,
#    'fec_election_type_desc': 'PRIMARY',
#    'candidate_office_state_full': None,
#    'conduit_committee_state': None,
#    'original_sub_id': None,
#    'contributor_prefix': None,
#    'memo_code': None,
#    'contributor_street_2': None,
#    'committee_id': 'C00314575',
#    'file_number': 1322783,
#    'receipt_type': '15',
#    'candidate_office_district': None,
#    'contributor_id': None,
#    'transaction_id': 'ACF36C6799A074832BA4',
#    'contribution_receipt_amount': 100.0,
#    'report_type': 'Q1',
#    'filing_form': 'F3',
#    'report_year': 2019,
#    'contributor_aggregate_ytd': 300.0,
#    'candidate_name': None,
#    'committee_name': None,
#    'conduit_committee_id': None,
#    'memoed_subtotal': False,
#    'candidate_first_name': None,
#    'election_type': 'P2020',
#    'national_committee_nonfederal_account': None,
#    'contribution_receipt_date': '2019-01-04T00:00:00',
#    'back_reference_schedule_name': None,
#    'contributor_middle_name': None,
#    'unused_contbr_id': None,
#    'contributor_suffix': None,
#    'election_type_full': None,
#    'memo_code_full': None,
#    'amendment_indicator_desc': 'ADD',
#    'amendment_indicator': 'A',
#    'pdf_url': 'http://docquery.fec.gov/cgi-bin/fecimg/?201904079146047074',
#    'link_id': 4040720191646004836,
#    'is_individual': True,
#    'conduit_committee_street2': None,
#    'sub_id': '4040820191646013241',
#    'contributor_name': 'HUT, STEPHEN',
#    'contributor_occupation': 'LAWYER',
#    'back_reference_transaction_id': None,
#    'schedule_type': 'SA',
#    'donor_committee_name': None,
#    'contributor_street_1': '3908 UNDERWOOD ST',
#    'conduit_committee_city': None,
#    'conduit_committee_zip': None},
#   {'fec_election_year': '2020',
#    'load_date': '2019-04-09T02:42:36.802000+00:00',
#    'contributor_employer': 'SELF',
#    'contributor': None,
#    'line_number': '11AI',
#    'candidate_prefix': None,
#    'contributor_state': 'CA',
#    'contributor_last_name': 'LOWE',
#    'two_year_transaction_period': 2020,
#    'candidate_office_full': None,
#    'committee': {'designation': 'P',
#     'party_full': 'REPUBLICAN PARTY',
#     'zip': '04402',
#     'committee_id': 'C00314575',
#     'state': 'ME',
#     'cycles': [1996,
#      1998,
#      2000,
#      2002,
#      2004,
#      2006,
#      2008,
#      2010,
#      2012,
#      2014,
#      2016,
#      2018,
#      2020],
#     'designation_full': 'Principal campaign committee',
#     'organization_type': None,
#     'street_1': 'PO BOX 1096',
#     'name': 'COLLINS FOR SENATOR',
#     'organization_type_full': None,
#     'filing_frequency': 'Q',
#     'committee_type': 'S',
#     'committee_type_full': 'Senate',
#     'candidate_ids': ['S6ME00159'],
#     'city': 'BANGOR',
#     'treasurer_name': 'MCCANDLESS, ELIZABETH T.',
#     'street_2': None,
#     'state_full': 'Maine',
#     'cycle': 2020,
#     'party': 'REP'},
#    'conduit_committee_street1': None,
#    'recipient_committee_type': 'S',
#    'receipt_type_desc': 'CONTRIBUTION',
#    'conduit_committee_name': None,
#    'line_number_label': 'Contributions From Individuals/Persons Other Than Political Committees',
#    'contributor_first_name': 'KENNETH',
#    'schedule_type_full': 'ITEMIZED RECEIPTS',
#    'memo_text': None,
#    'candidate_suffix': None,
#    'entity_type_desc': 'INDIVIDUAL',
#    'candidate_id': None,
#    'image_number': '201904079146047100',
#    'candidate_office_state': None,
#    'candidate_last_name': None,
#    'receipt_type_full': None,
#    'contributor_city': 'VISTA',
#    'increased_limit': None,
#    'entity_type': 'IND',
#    'candidate_office': None,
#    'contributor_zip': '920835502',
#    'candidate_middle_name': None,
#    'fec_election_type_desc': 'PRIMARY',
#    'candidate_office_state_full': None,
#    'conduit_committee_state': None,
#    'original_sub_id': None,
# ...
#    'fec_election_type_desc': 'PRIMARY',
#    'candidate_office_state_full': None,
#    'conduit_committee_state': None,
#    'original_sub_id': None,
#    'contributor_prefix': None,
#    'memo_code': None,
#    'contributor_street_2': None,
#    'committee_id': 'C00314575',
#    'file_number': 1322783,
#    'receipt_type': '15',
#    'candidate_office_district': None,
#    'contributor_id': None,
#    'transaction_id': 'A3621EB0DFE0843ABAB1',
#    'contribution_receipt_amount': 100.0,
#    'report_type': 'Q1',
#    'filing_form': 'F3',
#    'report_year': 2019,
#    'contributor_aggregate_ytd': 400.0,
#    'candidate_name': None,
#    'committee_name': None,
#    'conduit_committee_id': None,
#    'memoed_subtotal': False,
#    'candidate_first_name': None,
#    'election_type': 'P2020',
#    'national_committee_nonfederal_account': None,
#    'contribution_receipt_date': '2019-01-25T00:00:00',
#    'back_reference_schedule_name': None,
#    'contributor_middle_name': 'F.',
#    'unused_contbr_id': None,
#    'contributor_suffix': None,
#    'election_type_full': None,
#    'memo_code_full': None,
#    'amendment_indicator_desc': 'ADD',
#    'amendment_indicator': 'A',
#    'pdf_url': 'http://docquery.fec.gov/cgi-bin/fecimg/?201904079146046967',
#    'link_id': 4040720191646004836,
#    'is_individual': True,
#    'conduit_committee_street2': None,
#    'sub_id': '4040820191646012921',
#    'contributor_name': 'BARROSO, LUIS F.',
#    'contributor_occupation': 'RETIRED',
#    'back_reference_transaction_id': None,
#    'schedule_type': 'SA',
#    'donor_committee_name': None,
#    'contributor_street_1': '1928 GREEN MEADOW LN',
#    'conduit_committee_city': None,
#    'conduit_committee_zip': None},
#   {'fec_election_year': '2020',
#    'load_date': '2019-04-09T02:42:36.669000+00:00',
#    'contributor_employer': 'SELF',
#    'contributor': None,
#    'line_number': '11AI',
#    'candidate_prefix': None,
#    'contributor_state': 'DC',
#    'contributor_last_name': 'BOESCH',
#    'two_year_transaction_period': 2020,
#    'candidate_office_full': None,
#    'committee': {'designation': 'P',
#     'party_full': 'REPUBLICAN PARTY',
#     'zip': '04402',
#     'committee_id': 'C00314575',
#     'state': 'ME',
#     'cycles': [1996,
#      1998,
#      2000,
#      2002,
#      2004,
#      2006,
#      2008,
#      2010,
#      2012,
#      2014,
#      2016,
#      2018,
#      2020],
#     'designation_full': 'Principal campaign committee',
#     'organization_type': None,
#     'street_1': 'PO BOX 1096',
#     'name': 'COLLINS FOR SENATOR',
#     'organization_type_full': None,
#     'filing_frequency': 'Q',
#     'committee_type': 'S',
#     'committee_type_full': 'Senate',
#     'candidate_ids': ['S6ME00159'],
#     'city': 'BANGOR',
#     'treasurer_name': 'MCCANDLESS, ELIZABETH T.',
#     'street_2': None,
#     'state_full': 'Maine',
#     'cycle': 2020,
#     'party': 'REP'},
#    'conduit_committee_street1': None,
#    'recipient_committee_type': 'S',
#    'receipt_type_desc': 'CONTRIBUTION',
#    'conduit_committee_name': None,
#    'line_number_label': 'Contributions From Individuals/Persons Other Than Political Committees',
#    'contributor_first_name': 'DOYCE',
#    'schedule_type_full': 'ITEMIZED RECEIPTS',
#    'memo_text': None,
#    'candidate_suffix': None,
#    'entity_type_desc': 'INDIVIDUAL',
#    'candidate_id': None,
#    'image_number': '201904079146046976',
#    'candidate_office_state': None,
#    'candidate_last_name': None,
#    'receipt_type_full': None,
#    'contributor_city': 'WASHINGTON',
#    'increased_limit': None,
#    'entity_type': 'IND',
#    'candidate_office': None,
#    'contributor_zip': '200071513',
#    'candidate_middle_name': None,
#    'fec_election_type_desc': 'PRIMARY',
#    'candidate_office_state_full': None,
#    'conduit_committee_state': None,
#    'original_sub_id': None,
#    'contributor_prefix': None,
#    'memo_code': None,
#    'contributor_street_2': None,
#    'committee_id': 'C00314575',
#    'file_number': 1322783,
#    'receipt_type': '15',
#    'candidate_office_district': None,
#    'contributor_id': None,
#    'transaction_id': 'A6AF3C902551C4DC7AF6',
#    'contribution_receipt_amount': 500.0,
#    'report_type': 'Q1',
#    'filing_form': 'F3',
#    'report_year': 2019,
#    'contributor_aggregate_ytd': 5000.0,
#    'candidate_name': None,
#    'committee_name': None,
#    'conduit_committee_id': None,
#    'memoed_subtotal': False,
#    'candidate_first_name': None,
#    'election_type': 'P2020',
#    'national_committee_nonfederal_account': None,
#    'contribution_receipt_date': '2019-01-25T00:00:00',
#    'back_reference_schedule_name': None,
#    'contributor_middle_name': None,
#    'unused_contbr_id': None,
#    'contributor_suffix': None,
#    'election_type_full': None,
#    'memo_code_full': None,
#    'amendment_indicator_desc': 'ADD',
#    'amendment_indicator': 'A',
#    'pdf_url': 'http://docquery.fec.gov/cgi-bin/fecimg/?201904079146046976',
#    'link_id': 4040720191646004836,
#    'is_individual': True,
#    'conduit_committee_street2': None,
#    'sub_id': '4040820191646012946',
#    'contributor_name': 'BOESCH, DOYCE',
#    'contributor_occupation': 'GOVT RELATIONS',
#    'back_reference_transaction_id': None,
#    'schedule_type': 'SA',
#    'donor_committee_name': None,
#    'contributor_street_1': '4515 W ST NW',
#    'conduit_committee_city': None,
#    'conduit_committee_zip': None},
#   {'fec_election_year': '2020',
#    'load_date': '2019-04-09T02:42:36.676000+00:00',
#    'contributor_employer': 'HOMELAND VINYL PRODUCTS',
#    'contributor': None,
#    'line_number': '11AI',
#    'candidate_prefix': None,
#    'contributor_state': 'AL',
#    'contributor_last_name': 'BRADLEY',
#    'two_year_transaction_period': 2020,
#    'candidate_office_full': None,
#    'committee': {'designation': 'P',
#     'party_full': 'REPUBLICAN PARTY',
#     'zip': '04402',
#     'committee_id': 'C00314575',
#     'state': 'ME',
#     'cycles': [1996,
#      1998,
#      2000,
#      2002,
#      2004,
#      2006,
#      2008,
#      2010,
#      2012,
#      2014,
#      2016,
#      2018,
#      2020],
#     'designation_full': 'Principal campaign committee',
#     'organization_type': None,
#     'street_1': 'PO BOX 1096',
#     'name': 'COLLINS FOR SENATOR',
#     'organization_type_full': None,
#     'filing_frequency': 'Q',
#     'committee_type': 'S',
#     'committee_type_full': 'Senate',
#     'candidate_ids': ['S6ME00159'],
#     'city': 'BANGOR',
#     'treasurer_name': 'MCCANDLESS, ELIZABETH T.',
#     'street_2': None,
#     'state_full': 'Maine',
#     'cycle': 2020,
#     'party': 'REP'},
#    'conduit_committee_street1': None,
#    'recipient_committee_type': 'S',
#    'receipt_type_desc': None,
#    'conduit_committee_name': None,
#    'line_number_label': 'Contributions From Individuals/Persons Other Than Political Committees',
#    'contributor_first_name': 'WILLIAM',
#    'schedule_type_full': 'ITEMIZED RECEIPTS',
#    'memo_text': None,
#    'candidate_suffix': None,
#    'entity_type_desc': 'INDIVIDUAL',
#    'candidate_id': None,
#    'image_number': '201904079146046979',
#    'candidate_office_state': None,
#    'candidate_last_name': None,
#    'receipt_type_full': None,
#    'contributor_city': 'HOOVER',
#    'increased_limit': None,
#    'entity_type': 'IND',
#    'candidate_office': None,
#    'contributor_zip': '352444512',
#    'candidate_middle_name': None,
#    'fec_election_type_desc': 'PRIMARY',
#    'candidate_office_state_full': None,
#    'conduit_committee_state': None,
#    'original_sub_id': None,
#    'contributor_prefix': None,
#    'memo_code': None,
#    'contributor_street_2': None,
#    'committee_id': 'C00314575',
#    'file_number': 1322783,
#    'receipt_type': None,
#    'candidate_office_district': None,
#    'contributor_id': None,
#    'transaction_id': 'A1C7606C4EB9C4234A59',
#    'contribution_receipt_amount': 50.0,
#    'report_type': 'Q1',
#    'filing_form': 'F3',
#    'report_year': 2019,
#    'contributor_aggregate_ytd': 200.0,
#    'candidate_name': None,
#    'committee_name': None,
#    'conduit_committee_id': None,
#    'memoed_subtotal': False,
#    'candidate_first_name': None,
#    'election_type': 'P2020',
#    'national_committee_nonfederal_account': None,
#    'contribution_receipt_date': '2019-01-25T00:00:00',
#    'back_reference_schedule_name': None,
#    'contributor_middle_name': None,
#    'unused_contbr_id': None,
#    'contributor_suffix': None,
#    'election_type_full': None,
#    'memo_code_full': None,
#    'amendment_indicator_desc': 'ADD',
#    'amendment_indicator': 'A',
#    'pdf_url': 'http://docquery.fec.gov/cgi-bin/fecimg/?201904079146046979',
#    'link_id': 4040720191646004836,
#    'is_individual': True,
#    'conduit_committee_street2': None,
#    'sub_id': '4040820191646012955',
#    'contributor_name': 'BRADLEY, WILLIAM',
#    'contributor_occupation': 'PURCHASING MANAGER',
#    'back_reference_transaction_id': None,
#    'schedule_type': 'SA',
#    'donor_committee_name': None,
#    'contributor_street_1': '143 MAPLE TRCE',
#    'conduit_committee_city': None,
#    'conduit_committee_zip': None},
#   {'fec_election_year': '2020',
#    'load_date': '2019-04-09T02:42:36.701000+00:00',
#    'contributor_employer': 'CORNERSTONE DEVELOPMENT CO',
#    'contributor': None,
#    'line_number': '11AI',
#    'candidate_prefix': None,
#    'contributor_state': 'OH',
#    'contributor_last_name': 'CHARLTON',
#    'two_year_transaction_period': 2020,
#    'candidate_office_full': None,
#    'committee': {'designation': 'P',
#     'party_full': 'REPUBLICAN PARTY',
#     'zip': '04402',
#     'committee_id': 'C00314575',
#     'state': 'ME',
#     'cycles': [1996,
#      1998,
#      2000,
#      2002,
#      2004,
#      2006,
#      2008,
#      2010,
#      2012,
#      2014,
#      2016,
#      2018,
#      2020],
#     'designation_full': 'Principal campaign committee',
#     'organization_type': None,
#     'street_1': 'PO BOX 1096',
#     'name': 'COLLINS FOR SENATOR',
#     'organization_type_full': None,
#     'filing_frequency': 'Q',
#     'committee_type': 'S',
#     'committee_type_full': 'Senate',
#     'candidate_ids': ['S6ME00159'],
#     'city': 'BANGOR',
#     'treasurer_name': 'MCCANDLESS, ELIZABETH T.',
#     'street_2': None,
#     'state_full': 'Maine',
#     'cycle': 2020,
#     'party': 'REP'},
#    'conduit_committee_street1': None,
#    'recipient_committee_type': 'S',
#    'receipt_type_desc': 'CONTRIBUTION',
#    'conduit_committee_name': None,
#    'line_number_label': 'Contributions From Individuals/Persons Other Than Political Committees',
#    'contributor_first_name': 'STEVEN',
#    'schedule_type_full': 'ITEMIZED RECEIPTS',
#    'memo_text': None,
#    'candidate_suffix': None,
#    'entity_type_desc': 'INDIVIDUAL',
#    'candidate_id': None,
#    'image_number': '201904079146046992',
#    'candidate_office_state': None,
#    'candidate_last_name': None,
#    'receipt_type_full': None,
#    'contributor_city': 'SOLON',
#    'increased_limit': None,
#    'entity_type': 'IND',
#    'candidate_office': None,
#    'contributor_zip': '441393881',
#    'candidate_middle_name': None,
#    'fec_election_type_desc': 'PRIMARY',
#    'candidate_office_state_full': None,
#    'conduit_committee_state': None,
#    'original_sub_id': None,
#    'contributor_prefix': None,
#    'memo_code': None,
#    'contributor_street_2': 'APT 416',
#    'committee_id': 'C00314575',
#    'file_number': 1322783,
#    'receipt_type': '15',
#    'candidate_office_district': None,
#    'contributor_id': None,
#    'transaction_id': 'AFDB49FD9CAFF4E7CAAC',
#    'contribution_receipt_amount': 100.0,
#    'report_type': 'Q1',
#    'filing_form': 'F3',
#    'report_year': 2019,
#    'contributor_aggregate_ytd': 400.0,
#    'candidate_name': None,
#    'committee_name': None,
#    'conduit_committee_id': None,
#    'memoed_subtotal': False,
#    'candidate_first_name': None,
#    'election_type': 'P2020',
#    'national_committee_nonfederal_account': None,
#    'contribution_receipt_date': '2019-01-25T00:00:00',
#    'back_reference_schedule_name': None,
#    'contributor_middle_name': None,
#    'unused_contbr_id': None,
#    'contributor_suffix': None,
#    'election_type_full': None,
#    'memo_code_full': None,
#    'amendment_indicator_desc': 'ADD',
#    'amendment_indicator': 'A',
#    'pdf_url': 'http://docquery.fec.gov/cgi-bin/fecimg/?201904079146046992',
#    'link_id': 4040720191646004836,
#    'is_individual': True,
#    'conduit_committee_street2': None,
#    'sub_id': '4040820191646012995',
#    'contributor_name': 'CHARLTON, STEVEN',
#    'contributor_occupation': 'REAL ESTATE INVESTMENT',
#    'back_reference_transaction_id': None,
#    'schedule_type': 'SA',
#    'donor_committee_name': None,
#    'contributor_street_1': '34200 BROOKMEADE CT',
#    'conduit_committee_city': None,
#    'conduit_committee_zip': None},
#   {'fec_election_year': '2020',
#    'load_date': '2019-04-09T02:42:36.713000+00:00',
#    'contributor_employer': 'RETIRED',
#    'contributor': None,
#    'line_number': '11AI',
#    'candidate_prefix': None,
#    'contributor_state': 'NV',
#    'contributor_last_name': 'CORDERO',
#    'two_year_transaction_period': 2020,
#    'candidate_office_full': None,
#    'committee': {'designation': 'P',
#     'party_full': 'REPUBLICAN PARTY',
#     'zip': '04402',
#     'committee_id': 'C00314575',
#     'state': 'ME',
#     'cycles': [1996,
#      1998,
#      2000,
#      2002,
#      2004,
#      2006,
#      2008,
#      2010,
#      2012,
#      2014,
#      2016,
#      2018,
#      2020],
#     'designation_full': 'Principal campaign committee',
#     'organization_type': None,
#     'street_1': 'PO BOX 1096',
#     'name': 'COLLINS FOR SENATOR',
#     'organization_type_full': None,
#     'filing_frequency': 'Q',
#     'committee_type': 'S',
#     'committee_type_full': 'Senate',
#     'candidate_ids': ['S6ME00159'],
#     'city': 'BANGOR',
#     'treasurer_name': 'MCCANDLESS, ELIZABETH T.',
#     'street_2': None,
#     'state_full': 'Maine',
#     'cycle': 2020,
#     'party': 'REP'},
#    'conduit_committee_street1': None,
#    'recipient_committee_type': 'S',
#    'receipt_type_desc': 'CONTRIBUTION',
#    'conduit_committee_name': None,
#    'line_number_label': 'Contributions From Individuals/Persons Other Than Political Committees',
#    'contributor_first_name': 'ALFONSO',
#    'schedule_type_full': 'ITEMIZED RECEIPTS',
#    'memo_text': None,
#    'candidate_suffix': None,
#    'entity_type_desc': 'INDIVIDUAL',
#    'candidate_id': None,
#    'image_number': '201904079146047001',
#    'candidate_office_state': None,
#    'candidate_last_name': None,
#    'receipt_type_full': None,
#    'contributor_city': 'ZEPHYR COVE',
#    'increased_limit': None,
#    'entity_type': 'IND',
#    'candidate_office': None,
#    'contributor_zip': '894480546',
#    'candidate_middle_name': None,
#    'fec_election_type_desc': 'PRIMARY',
#    'candidate_office_state_full': None,
#    'conduit_committee_state': None,
#    'original_sub_id': None,
#    'contributor_prefix': None,
#    'memo_code': None,
#    'contributor_street_2': None,
#    'committee_id': 'C00314575',
#    'file_number': 1322783,
#    'receipt_type': '15',
#    'candidate_office_district': None,
#    'contributor_id': None,
#    'transaction_id': 'ABCA00568C4B841BEB92',
#    'contribution_receipt_amount': 500.0,
#    'report_type': 'Q1',
#    'filing_form': 'F3',
#    'report_year': 2019,
#    'contributor_aggregate_ytd': 2000.0,
#    'candidate_name': None,
#    'committee_name': None,
#    'conduit_committee_id': None,
#    'memoed_subtotal': False,
#    'candidate_first_name': None,
#    'election_type': 'P2020',
#    'national_committee_nonfederal_account': None,
#    'contribution_receipt_date': '2019-01-25T00:00:00',
#    'back_reference_schedule_name': None,
#    'contributor_middle_name': None,
#    'unused_contbr_id': None,
#    'contributor_suffix': None,
#    'election_type_full': None,
#    'memo_code_full': None,
#    'amendment_indicator_desc': 'ADD',
#    'amendment_indicator': 'A',
#    'pdf_url': 'http://docquery.fec.gov/cgi-bin/fecimg/?201904079146047001',
#    'link_id': 4040720191646004836,
#    'is_individual': True,
#    'conduit_committee_street2': None,
#    'sub_id': '4040820191646013022',
#    'contributor_name': 'CORDERO, ALFONSO',
#    'contributor_occupation': 'RETIRED',
#    'back_reference_transaction_id': None,
#    'schedule_type': 'SA',
#    'donor_committee_name': None,
#    'contributor_street_1': 'PO BOX 546',
#    'conduit_committee_city': None,
#    'conduit_committee_zip': None}],
#  'pagination': {'count': 859,
#   'last_indexes': {'last_index': '4040820191646013022',
#    'last_contribution_receipt_date': '2019-01-25T00:00:00'},
#   'pages': 9,
#   'per_page': 100}}

# %%
#Initialize dataframe collector
dfs=[]

# #Initialize last_index and last_date
# querydict = {'per_page':'100'
#              ,'committee_id':comm_id['committee_id']
#              ,'sort':'contribution_receipt_date'
#              ,'api_key':config.api_key
#              ,'is_individual':'true'
#              ,'two_year_transaction_period':period
# #              ,'last_index':last_index
# #              ,'last_contribution_receipt_date':last_date
#       }

# r = requests.get('https://api.open.fec.gov/v1/schedules/schedule_a/',params=querydict).json()

# #Pagination variables
# pg = json_normalize(r['pagination'])
# pg_cols=['count','last_contribution_date','last_index','pages','per_page']
# pg.columns = pg_cols

# last_index=pg['last_index']
# last_date=pg['last_contribution_date']

# #Results rows
# df = json_normalize(r['results'])
# dfs.append(df)

# #Pagination variables
# pg = json_normalize(r['pagination'])

# last_index=pg['last_indexes.last_index']
# last_date=pg['last_indexes.last_contribution_receipt_date']


#Loop through pages
for x in range(2):
    
    #Add last_index and date to query
    querydict = {'per_page':'100'
                 ,'committee_id':comm_id['committee_id']
                 ,'sort':'contribution_receipt_date'
                 ,'api_key':config.api_key
                 ,'is_individual':'true'
                 ,'two_year_transaction_period':period
                 ,'last_index':last_index
#                  ,'last_contribution_receipt_date':last_date
          }

    r = requests.get('https://api.open.fec.gov/v1/schedules/schedule_a/',params=querydict).json()

    #Results rows
    df = json_normalize(r['results'])
    dfs.append(df)
    
    #Pagination variables
    last_index=r['pagination']['last_indexes']['last_index']
    last_date=r['pagination']['last_indexes']['last_contribution_receipt_date']

    dfs.append(df)


#Concatenate all dfs
contribs=pd.concat(dfs)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-355-f32dcb344ef5> in <module>
#      51
#      52     #Results rows
# ---> 53     df = json_normalize(r['results'])
#      54     dfs.append(df)
#      55
#
# KeyError: 'results'

# %%
last_index
# Out:
# {'last_index': '4040820191646013022',
#  'last_contribution_receipt_date': '2019-01-25T00:00:00'}

# %%
r
# Out:
# {'api_version': '1.0',
#  'results': [{'committee': {'committee_type': 'S',
#     'filing_frequency': 'Q',
#     'street_2': None,
#     'treasurer_name': 'MCCANDLESS, ELIZABETH T.',
#     'organization_type': None,
#     'city': 'BANGOR',
#     'name': 'COLLINS FOR SENATOR',
#     'party': 'REP',
#     'party_full': 'REPUBLICAN PARTY',
#     'designation': 'P',
#     'zip': '04402',
#     'state_full': 'Maine',
#     'cycle': 2020,
#     'committee_type_full': 'Senate',
#     'designation_full': 'Principal campaign committee',
#     'committee_id': 'C00314575',
#     'street_1': 'PO BOX 1096',
#     'organization_type_full': None,
#     'candidate_ids': ['S6ME00159'],
#     'state': 'ME',
#     'cycles': [1996,
#      1998,
#      2000,
#      2002,
#      2004,
#      2006,
#      2008,
#      2010,
#      2012,
#      2014,
#      2016,
#      2018,
#      2020]},
#    'fec_election_type_desc': 'PRIMARY',
#    'memo_code': None,
#    'memo_text': None,
#    'contributor_employer': 'RETIRED',
#    'candidate_prefix': None,
#    'amendment_indicator_desc': 'ADD',
#    'load_date': '2019-04-09T02:42:36.656000+00:00',
#    'contributor_zip': '337387060',
#    'schedule_type_full': 'ITEMIZED RECEIPTS',
#    'contributor_prefix': None,
#    'contributor_aggregate_ytd': 750.0,
#    'contributor_street_1': '15019 MADEIRA WAY',
#    'amendment_indicator': 'A',
#    'contributor_street_2': 'UNIT 86459',
#    'committee_name': None,
#    'candidate_middle_name': None,
#    'contributor_first_name': 'HENRY',
#    'memoed_subtotal': False,
#    'committee_id': 'C00314575',
#    'filing_form': 'F3',
#    'unused_contbr_id': None,
#    'entity_type': 'IND',
#    'schedule_type': 'SA',
#    'is_individual': True,
#    'line_number': '11AI',
#    'increased_limit': None,
#    'election_type': 'P2020',
#    'receipt_type_desc': 'CONTRIBUTION',
#    'contributor_city': 'SAINT PETERSBURG',
#    'entity_type_desc': 'INDIVIDUAL',
#    'election_type_full': None,
#    'candidate_suffix': None,
#    'original_sub_id': None,
#    'conduit_committee_state': None,
#    'contributor_id': None,
#    'candidate_first_name': None,
#    'conduit_committee_street2': None,
#    'memo_code_full': None,
#    'candidate_last_name': None,
#    'contributor_name': 'BENTLEY, HENRY',
#    'candidate_name': None,
#    'contributor_suffix': None,
#    'contributor_last_name': 'BENTLEY',
#    'receipt_type_full': None,
#    'candidate_id': None,
#    'candidate_office_state': None,
#    'two_year_transaction_period': 2020,
#    'transaction_id': 'A1F99550E176249C7AFC',
#    'candidate_office': None,
#    'candidate_office_state_full': None,
#    'donor_committee_name': None,
#    'contributor': None,
#    'receipt_type': '15',
#    'candidate_office_district': None,
#    'conduit_committee_zip': None,
#    'candidate_office_full': None,
#    'conduit_committee_city': None,
#    'back_reference_transaction_id': None,
#    'contribution_receipt_amount': 250.0,
#    'back_reference_schedule_name': None,
#    'image_number': '201904079146046969',
#    'conduit_committee_id': None,
#    'report_type': 'Q1',
#    'conduit_committee_name': None,
#    'file_number': 1322783,
#    'contribution_receipt_date': '2019-01-01T00:00:00',
#    'national_committee_nonfederal_account': None,
#    'contributor_state': 'FL',
#    'conduit_committee_street1': None,
#    'sub_id': '4040820191646012926',
#    'pdf_url': 'http://docquery.fec.gov/cgi-bin/fecimg/?201904079146046969',
#    'recipient_committee_type': 'S',
#    'fec_election_year': '2020',
#    'contributor_middle_name': None,
#    'report_year': 2019,
#    'line_number_label': 'Contributions From Individuals/Persons Other Than Political Committees',
#    'contributor_occupation': 'RETIRED',
#    'link_id': 4040720191646004836},
#   {'committee': {'committee_type': 'S',
#     'filing_frequency': 'Q',
#     'street_2': None,
#     'treasurer_name': 'MCCANDLESS, ELIZABETH T.',
#     'organization_type': None,
#     'city': 'BANGOR',
#     'name': 'COLLINS FOR SENATOR',
#     'party': 'REP',
#     'party_full': 'REPUBLICAN PARTY',
#     'designation': 'P',
#     'zip': '04402',
#     'state_full': 'Maine',
#     'cycle': 2020,
#     'committee_type_full': 'Senate',
#     'designation_full': 'Principal campaign committee',
#     'committee_id': 'C00314575',
#     'street_1': 'PO BOX 1096',
#     'organization_type_full': None,
#     'candidate_ids': ['S6ME00159'],
#     'state': 'ME',
#     'cycles': [1996,
#      1998,
#      2000,
#      2002,
#      2004,
#      2006,
#      2008,
#      2010,
#      2012,
#      2014,
#      2016,
#      2018,
#      2020]},
#    'fec_election_type_desc': 'PRIMARY',
#    'memo_code': None,
#    'memo_text': None,
#    'contributor_employer': 'SELF',
#    'candidate_prefix': None,
#    'amendment_indicator_desc': 'ADD',
#    'load_date': '2019-04-09T02:42:36.677000+00:00',
#    'contributor_zip': '354062944',
#    'schedule_type_full': 'ITEMIZED RECEIPTS',
#    'contributor_prefix': None,
#    'contributor_aggregate_ytd': 500.0,
#    'contributor_street_1': '4114 CITATION CIR',
#    'amendment_indicator': 'A',
#    'contributor_street_2': None,
#    'committee_name': None,
#    'candidate_middle_name': None,
#    'contributor_first_name': 'FLINT',
#    'memoed_subtotal': False,
#    'committee_id': 'C00314575',
#    'filing_form': 'F3',
#    'unused_contbr_id': None,
#    'entity_type': 'IND',
#    'schedule_type': 'SA',
#    'is_individual': True,
#    'line_number': '11AI',
#    'increased_limit': None,
#    'election_type': 'P2020',
#    'receipt_type_desc': 'CONTRIBUTION',
#    'contributor_city': 'TUSCALOOSA',
#    'entity_type_desc': 'INDIVIDUAL',
#    'election_type_full': None,
#    'candidate_suffix': None,
#    'original_sub_id': None,
#    'conduit_committee_state': None,
#    'contributor_id': None,
#    'candidate_first_name': None,
#    'conduit_committee_street2': None,
#    'memo_code_full': None,
#    'candidate_last_name': None,
#    'contributor_name': 'BRECKINRIDGE, FLINT',
#    'candidate_name': None,
#    'contributor_suffix': None,
#    'contributor_last_name': 'BRECKINRIDGE',
#    'receipt_type_full': None,
#    'candidate_id': None,
#    'candidate_office_state': None,
#    'two_year_transaction_period': 2020,
#    'transaction_id': 'A66BF5ABC54F943FA94E',
#    'candidate_office': None,
#    'candidate_office_state_full': None,
#    'donor_committee_name': None,
#    'contributor': None,
#    'receipt_type': '15',
#    'candidate_office_district': None,
#    'conduit_committee_zip': None,
#    'candidate_office_full': None,
#    'conduit_committee_city': None,
#    'back_reference_transaction_id': None,
#    'contribution_receipt_amount': 100.0,
#    'back_reference_schedule_name': None,
#    'image_number': '201904079146046980',
#    'conduit_committee_id': None,
#    'report_type': 'Q1',
#    'conduit_committee_name': None,
#    'file_number': 1322783,
#    'contribution_receipt_date': '2019-01-01T00:00:00',
#    'national_committee_nonfederal_account': None,
#    'contributor_state': 'AL',
#    'conduit_committee_street1': None,
#    'sub_id': '4040820191646012959',
#    'pdf_url': 'http://docquery.fec.gov/cgi-bin/fecimg/?201904079146046980',
#    'recipient_committee_type': 'S',
#    'fec_election_year': '2020',
#    'contributor_middle_name': None,
#    'report_year': 2019,
#    'line_number_label': 'Contributions From Individuals/Persons Other Than Political Committees',
#    'contributor_occupation': 'CONSULTANT',
#    'link_id': 4040720191646004836},
#   {'committee': {'committee_type': 'S',
#     'filing_frequency': 'Q',
#     'street_2': None,
#     'treasurer_name': 'MCCANDLESS, ELIZABETH T.',
#     'organization_type': None,
#     'city': 'BANGOR',
#     'name': 'COLLINS FOR SENATOR',
#     'party': 'REP',
#     'party_full': 'REPUBLICAN PARTY',
#     'designation': 'P',
#     'zip': '04402',
#     'state_full': 'Maine',
#     'cycle': 2020,
#     'committee_type_full': 'Senate',
#     'designation_full': 'Principal campaign committee',
#     'committee_id': 'C00314575',
#     'street_1': 'PO BOX 1096',
#     'organization_type_full': None,
#     'candidate_ids': ['S6ME00159'],
#     'state': 'ME',
#     'cycles': [1996,
#      1998,
#      2000,
#      2002,
#      2004,
#      2006,
#      2008,
#      2010,
#      2012,
#      2014,
#      2016,
#      2018,
#      2020]},
#    'fec_election_type_desc': 'PRIMARY',
#    'memo_code': None,
#    'memo_text': None,
#    'contributor_employer': 'ARVEST BANK',
#    'candidate_prefix': None,
#    'amendment_indicator_desc': 'ADD',
#    'load_date': '2019-04-09T02:42:36.764000+00:00',
#    'contributor_zip': '727618641',
#    'schedule_type_full': 'ITEMIZED RECEIPTS',
#    'contributor_prefix': None,
#    'contributor_aggregate_ytd': 400.0,
#    'contributor_street_1': '16735 OLD HIGHWAY 68',
#    'amendment_indicator': 'A',
#    'contributor_street_2': None,
#    'committee_name': None,
#    'candidate_middle_name': None,
#    'contributor_first_name': 'CLIFFORD',
#    'memoed_subtotal': False,
#    'committee_id': 'C00314575',
#    'filing_form': 'F3',
#    'unused_contbr_id': None,
#    'entity_type': 'IND',
#    'schedule_type': 'SA',
#    'is_individual': True,
#    'line_number': '11AI',
#    'increased_limit': None,
#    'election_type': 'P2020',
#    'receipt_type_desc': 'CONTRIBUTION',
#    'contributor_city': 'SILOAM SPRINGS',
#    'entity_type_desc': 'INDIVIDUAL',
#    'election_type_full': None,
#    'candidate_suffix': None,
#    'original_sub_id': None,
#    'conduit_committee_state': None,
#    'contributor_id': None,
#    'candidate_first_name': None,
#    'conduit_committee_street2': None,
#    'memo_code_full': None,
#    'candidate_last_name': None,
#    'contributor_name': 'GIBBS, CLIFFORD',
#    'candidate_name': None,
#    'contributor_suffix': None,
#    'contributor_last_name': 'GIBBS',
#    'receipt_type_full': None,
#    'candidate_id': None,
#    'candidate_office_state': None,
#    'two_year_transaction_period': 2020,
#    'transaction_id': 'AE9C7DC4C7855441A843',
#    'candidate_office': None,
#    'candidate_office_state_full': None,
#    'donor_committee_name': None,
#    'contributor': None,
#    'receipt_type': '15',
#    'candidate_office_district': None,
#    'conduit_committee_zip': None,
#    'candidate_office_full': None,
#    'conduit_committee_city': None,
#    'back_reference_transaction_id': None,
#    'contribution_receipt_amount': 100.0,
#    'back_reference_schedule_name': None,
#    'image_number': '201904079146047043',
#    'conduit_committee_id': None,
#    'report_type': 'Q1',
#    'conduit_committee_name': None,
#    'file_number': 1322783,
#    'contribution_receipt_date': '2019-01-01T00:00:00',
#    'national_committee_nonfederal_account': None,
#    'contributor_state': 'AR',
#    'conduit_committee_street1': None,
#    'sub_id': '4040820191646013149',
#    'pdf_url': 'http://docquery.fec.gov/cgi-bin/fecimg/?201904079146047043',
#    'recipient_committee_type': 'S',
#    'fec_election_year': '2020',
#    'contributor_middle_name': None,
#    'report_year': 2019,
#    'line_number_label': 'Contributions From Individuals/Persons Other Than Political Committees',
#    'contributor_occupation': 'MANAGEMENT',
#    'link_id': 4040720191646004836},
#   {'committee': {'committee_type': 'S',
#     'filing_frequency': 'Q',
#     'street_2': None,
#     'treasurer_name': 'MCCANDLESS, ELIZABETH T.',
#     'organization_type': None,
#     'city': 'BANGOR',
#     'name': 'COLLINS FOR SENATOR',
#     'party': 'REP',
#     'party_full': 'REPUBLICAN PARTY',
#     'designation': 'P',
#     'zip': '04402',
#     'state_full': 'Maine',
#     'cycle': 2020,
#     'committee_type_full': 'Senate',
#     'designation_full': 'Principal campaign committee',
#     'committee_id': 'C00314575',
#     'street_1': 'PO BOX 1096',
#     'organization_type_full': None,
#     'candidate_ids': ['S6ME00159'],
#     'state': 'ME',
#     'cycles': [1996,
#      1998,
#      2000,
#      2002,
#      2004,
#      2006,
#      2008,
#      2010,
#      2012,
#      2014,
#      2016,
#      2018,
#      2020]},
#    'fec_election_type_desc': 'PRIMARY',
#    'memo_code': None,
#    'memo_text': None,
#    'contributor_employer': 'RETIRED',
#    'candidate_prefix': None,
#    'amendment_indicator_desc': 'ADD',
#    'load_date': '2019-04-09T02:42:36.843000+00:00',
#    'contributor_zip': '330622501',
#    'schedule_type_full': 'ITEMIZED RECEIPTS',
#    'contributor_prefix': None,
#    'contributor_aggregate_ytd': 300.0,
#    'contributor_street_1': '953 HILLSBORO MILE',
#    'amendment_indicator': 'A',
#    'contributor_street_2': None,
#    'committee_name': None,
#    'candidate_middle_name': None,
#    'contributor_first_name': 'JOHN',
#    'memoed_subtotal': False,
#    'committee_id': 'C00314575',
#    'filing_form': 'F3',
#    'unused_contbr_id': None,
#    'entity_type': 'IND',
#    'schedule_type': 'SA',
#    'is_individual': True,
#    'line_number': '11AI',
#    'increased_limit': None,
#    'election_type': 'P2020',
#    'receipt_type_desc': 'CONTRIBUTION',
#    'contributor_city': 'HILLSBORO BEACH',
#    'entity_type_desc': 'INDIVIDUAL',
#    'election_type_full': None,
#    'candidate_suffix': None,
#    'original_sub_id': None,
#    'conduit_committee_state': None,
#    'contributor_id': None,
#    'candidate_first_name': None,
#    'conduit_committee_street2': None,
#    'memo_code_full': None,
#    'candidate_last_name': None,
#    'contributor_name': 'PARELL, JOHN',
#    'candidate_name': None,
#    'contributor_suffix': None,
#    'contributor_last_name': 'PARELL',
#    'receipt_type_full': None,
#    'candidate_id': None,
#    'candidate_office_state': None,
#    'two_year_transaction_period': 2020,
#    'transaction_id': 'AB3531B9E6A664583BE4',
#    'candidate_office': None,
#    'candidate_office_state_full': None,
#    'donor_committee_name': None,
#    'contributor': None,
#    'receipt_type': '15',
#    'candidate_office_district': None,
#    'conduit_committee_zip': None,
#    'candidate_office_full': None,
#    'conduit_committee_city': None,
#    'back_reference_transaction_id': None,
#    'contribution_receipt_amount': 100.0,
#    'back_reference_schedule_name': None,
#    'image_number': '201904079146047149',
#    'conduit_committee_id': None,
#    'report_type': 'Q1',
#    'conduit_committee_name': None,
#    'file_number': 1322783,
#    'contribution_receipt_date': '2019-01-01T00:00:00',
#    'national_committee_nonfederal_account': None,
#    'contributor_state': 'FL',
#    'conduit_committee_street1': None,
#    'sub_id': '4040820191646013465',
#    'pdf_url': 'http://docquery.fec.gov/cgi-bin/fecimg/?201904079146047149',
#    'recipient_committee_type': 'S',
#    'fec_election_year': '2020',
#    'contributor_middle_name': None,
#    'report_year': 2019,
#    'line_number_label': 'Contributions From Individuals/Persons Other Than Political Committees',
#    'contributor_occupation': 'RETIRED',
#    'link_id': 4040720191646004836},
#   {'committee': {'committee_type': 'S',
#     'filing_frequency': 'Q',
#     'street_2': None,
#     'treasurer_name': 'MCCANDLESS, ELIZABETH T.',
#     'organization_type': None,
#     'city': 'BANGOR',
#     'name': 'COLLINS FOR SENATOR',
#     'party': 'REP',
#     'party_full': 'REPUBLICAN PARTY',
#     'designation': 'P',
#     'zip': '04402',
#     'state_full': 'Maine',
#     'cycle': 2020,
#     'committee_type_full': 'Senate',
#     'designation_full': 'Principal campaign committee',
#     'committee_id': 'C00314575',
#     'street_1': 'PO BOX 1096',
#     'organization_type_full': None,
#     'candidate_ids': ['S6ME00159'],
#     'state': 'ME',
#     'cycles': [1996,
#      1998,
#      2000,
#      2002,
#      2004,
#      2006,
#      2008,
#      2010,
#      2012,
#      2014,
#      2016,
#      2018,
#      2020]},
#    'fec_election_type_desc': 'PRIMARY',
#    'memo_code': None,
#    'memo_text': None,
#    'contributor_employer': 'RETIRED',
#    'candidate_prefix': None,
#    'amendment_indicator_desc': 'ADD',
#    'load_date': '2019-04-09T02:42:36.852000+00:00',
#    'contributor_zip': '983706907',
#    'schedule_type_full': 'ITEMIZED RECEIPTS',
#    'contributor_prefix': None,
#    'contributor_aggregate_ytd': 200.0,
#    'contributor_street_1': '10750 OGLE RD NE',
#    'amendment_indicator': 'A',
#    'contributor_street_2': None,
#    'committee_name': None,
#    'candidate_middle_name': None,
#    'contributor_first_name': 'FRANK',
#    'memoed_subtotal': False,
#    'committee_id': 'C00314575',
#    'filing_form': 'F3',
#    'unused_contbr_id': None,
#    'entity_type': 'IND',
#    'schedule_type': 'SA',
#    'is_individual': True,
#    'line_number': '11AI',
#    'increased_limit': None,
#    'election_type': 'P2020',
#    'receipt_type_desc': None,
#    'contributor_city': 'POULSBO',
#    'entity_type_desc': 'INDIVIDUAL',
#    'election_type_full': None,
#    'candidate_suffix': None,
#    'original_sub_id': None,
#    'conduit_committee_state': None,
#    'contributor_id': None,
#    'candidate_first_name': None,
#    'conduit_committee_street2': None,
#    'memo_code_full': None,
#    'candidate_last_name': None,
#    'contributor_name': 'REED, FRANK',
#    'candidate_name': None,
#    'contributor_suffix': None,
#    'contributor_last_name': 'REED',
#    'receipt_type_full': None,
#    'candidate_id': None,
#    'candidate_office_state': None,
#    'two_year_transaction_period': 2020,
#    'transaction_id': 'A8BDD8FFE4FE34C7DAA7',
#    'candidate_office': None,
#    'candidate_office_state_full': None,
#    'donor_committee_name': None,
#    'contributor': None,
#    'receipt_type': None,
#    'candidate_office_district': None,
#    'conduit_committee_zip': None,
#    'candidate_office_full': None,
#    'conduit_committee_city': None,
#    'back_reference_transaction_id': None,
#    'contribution_receipt_amount': 100.0,
#    'back_reference_schedule_name': None,
#    'image_number': '201904079146047163',
#    'conduit_committee_id': None,
#    'report_type': 'Q1',
#    'conduit_committee_name': None,
#    'file_number': 1322783,
#    'contribution_receipt_date': '2019-01-01T00:00:00',
#    'national_committee_nonfederal_account': None,
#    'contributor_state': 'WA',
#    'conduit_committee_street1': None,
#    'sub_id': '4040820191646013507',
#    'pdf_url': 'http://docquery.fec.gov/cgi-bin/fecimg/?201904079146047163',
#    'recipient_committee_type': 'S',
#    'fec_election_year': '2020',
#    'contributor_middle_name': None,
#    'report_year': 2019,
#    'line_number_label': 'Contributions From Individuals/Persons Other Than Political Committees',
#    'contributor_occupation': 'RETIRED',
#    'link_id': 4040720191646004836},
#   {'committee': {'committee_type': 'S',
#     'filing_frequency': 'Q',
#     'street_2': None,
#     'treasurer_name': 'MCCANDLESS, ELIZABETH T.',
#     'organization_type': None,
#     'city': 'BANGOR',
#     'name': 'COLLINS FOR SENATOR',
#     'party': 'REP',
#     'party_full': 'REPUBLICAN PARTY',
#     'designation': 'P',
#     'zip': '04402',
#     'state_full': 'Maine',
#     'cycle': 2020,
#     'committee_type_full': 'Senate',
#     'designation_full': 'Principal campaign committee',
#     'committee_id': 'C00314575',
#     'street_1': 'PO BOX 1096',
#     'organization_type_full': None,
#     'candidate_ids': ['S6ME00159'],
#     'state': 'ME',
#     'cycles': [1996,
#      1998,
#      2000,
#      2002,
#      2004,
#      2006,
#      2008,
#      2010,
#      2012,
#      2014,
#      2016,
#      2018,
#      2020]},
#    'fec_election_type_desc': 'PRIMARY',
#    'memo_code': None,
#    'memo_text': None,
#    'contributor_employer': 'RETIRED',
#    'candidate_prefix': None,
#    'amendment_indicator_desc': 'ADD',
#    'load_date': '2019-04-09T02:42:36.852000+00:00',
#    'contributor_zip': '983706907',
#    'schedule_type_full': 'ITEMIZED RECEIPTS',
#    'contributor_prefix': None,
#    'contributor_aggregate_ytd': 200.0,
#    'contributor_street_1': '10750 OGLE RD NE',
#    'amendment_indicator': 'A',
#    'contributor_street_2': None,
#    'committee_name': None,
#    'candidate_middle_name': None,
#    'contributor_first_name': 'FRANK',
#    'memoed_subtotal': False,
#    'committee_id': 'C00314575',
#    'filing_form': 'F3',
#    'unused_contbr_id': None,
#    'entity_type': 'IND',
#    'schedule_type': 'SA',
#    'is_individual': True,
#    'line_number': '11AI',
#    'increased_limit': None,
#    'election_type': 'P2020',
#    'receipt_type_desc': None,
#    'contributor_city': 'POULSBO',
#    'entity_type_desc': 'INDIVIDUAL',
#    'election_type_full': None,
#    'candidate_suffix': None,
#    'original_sub_id': None,
#    'conduit_committee_state': None,
#    'contributor_id': None,
#    'candidate_first_name': None,
#    'conduit_committee_street2': None,
#    'memo_code_full': None,
#    'candidate_last_name': None,
#    'contributor_name': 'REED, FRANK',
#    'candidate_name': None,
#    'contributor_suffix': None,
#    'contributor_last_name': 'REED',
#    'receipt_type_full': None,
#    'candidate_id': None,
#    'candidate_office_state': None,
#    'two_year_transaction_period': 2020,
#    'transaction_id': 'AA2E9430417814DCAB3B',
#    'candidate_office': None,
#    'candidate_office_state_full': None,
#    'donor_committee_name': None,
#    'contributor': None,
#    'receipt_type': None,
#    'candidate_office_district': None,
#    'conduit_committee_zip': None,
#    'candidate_office_full': None,
#    'conduit_committee_city': None,
#    'back_reference_transaction_id': None,
#    'contribution_receipt_amount': 100.0,
#    'back_reference_schedule_name': None,
#    'image_number': '201904079146047163',
#    'conduit_committee_id': None,
#    'report_type': 'Q1',
#    'conduit_committee_name': None,
#    'file_number': 1322783,
#    'contribution_receipt_date': '2019-01-01T00:00:00',
#    'national_committee_nonfederal_account': None,
#    'contributor_state': 'WA',
#    'conduit_committee_street1': None,
#    'sub_id': '4040820191646013508',
#    'pdf_url': 'http://docquery.fec.gov/cgi-bin/fecimg/?201904079146047163',
#    'recipient_committee_type': 'S',
#    'fec_election_year': '2020',
#    'contributor_middle_name': None,
#    'report_year': 2019,
#    'line_number_label': 'Contributions From Individuals/Persons Other Than Political Committees',
#    'contributor_occupation': 'RETIRED',
#    'link_id': 4040720191646004836},
#   {'committee': {'committee_type': 'S',
#     'filing_frequency': 'Q',
#     'street_2': None,
#     'treasurer_name': 'MCCANDLESS, ELIZABETH T.',
#     'organization_type': None,
#     'city': 'BANGOR',
#     'name': 'COLLINS FOR SENATOR',
#     'party': 'REP',
#     'party_full': 'REPUBLICAN PARTY',
#     'designation': 'P',
#     'zip': '04402',
#     'state_full': 'Maine',
#     'cycle': 2020,
#     'committee_type_full': 'Senate',
#     'designation_full': 'Principal campaign committee',
#     'committee_id': 'C00314575',
#     'street_1': 'PO BOX 1096',
#     'organization_type_full': None,
#     'candidate_ids': ['S6ME00159'],
#     'state': 'ME',
#     'cycles': [1996,
#      1998,
#      2000,
#      2002,
#      2004,
#      2006,
#      2008,
#      2010,
#      2012,
#      2014,
#      2016,
#      2018,
#      2020]},
#    'fec_election_type_desc': 'PRIMARY',
#    'memo_code': None,
#    'memo_text': None,
#    'contributor_employer': 'HTPN',
#    'candidate_prefix': None,
#    'amendment_indicator_desc': 'ADD',
#    'load_date': '2019-04-09T02:42:36.867000+00:00',
#    'contributor_zip': '752051621',
#    'schedule_type_full': 'ITEMIZED RECEIPTS',
#    'contributor_prefix': None,
#    'contributor_aggregate_ytd': 400.0,
#    'contributor_street_1': '4412 LARCHMONT ST',
#    'amendment_indicator': 'A',
#    'contributor_street_2': None,
#    'committee_name': None,
#    'candidate_middle_name': None,
#    'contributor_first_name': 'JOHN',
#    'memoed_subtotal': False,
#    'committee_id': 'C00314575',
#    'filing_form': 'F3',
#    'unused_contbr_id': None,
#    'entity_type': 'IND',
#    'schedule_type': 'SA',
#    'is_individual': True,
#    'line_number': '11AI',
#    'increased_limit': None,
#    'election_type': 'P2020',
#    'receipt_type_desc': 'CONTRIBUTION',
#    'contributor_city': 'DALLAS',
#    'entity_type_desc': 'INDIVIDUAL',
#    'election_type_full': None,
#    'candidate_suffix': None,
#    'original_sub_id': None,
#    'conduit_committee_state': None,
#    'contributor_id': None,
#    'candidate_first_name': None,
#    'conduit_committee_street2': None,
#    'memo_code_full': None,
#    'candidate_last_name': None,
#    'contributor_name': 'SCHUMACHER, JOHN',
#    'candidate_name': None,
#    'contributor_suffix': None,
#    'contributor_last_name': 'SCHUMACHER',
#    'receipt_type_full': None,
#    'candidate_id': None,
#    'candidate_office_state': None,
#    'two_year_transaction_period': 2020,
#    'transaction_id': 'A0950552B2BCE4148A89',
#    'candidate_office': None,
#    'candidate_office_state_full': None,
#    'donor_committee_name': None,
#    'contributor': None,
#    'receipt_type': '15',
#    'candidate_office_district': None,
#    'conduit_committee_zip': None,
#    'candidate_office_full': None,
#    'conduit_committee_city': None,
#    'back_reference_transaction_id': None,
#    'contribution_receipt_amount': 100.0,
#    'back_reference_schedule_name': None,
#    'image_number': '201904079146047184',
#    'conduit_committee_id': None,
#    'report_type': 'Q1',
#    'conduit_committee_name': None,
#    'file_number': 1322783,
#    'contribution_receipt_date': '2019-01-01T00:00:00',
#    'national_committee_nonfederal_account': None,
#    'contributor_state': 'TX',
#    'conduit_committee_street1': None,
#    'sub_id': '4040820191646013572',
#    'pdf_url': 'http://docquery.fec.gov/cgi-bin/fecimg/?201904079146047184',
#    'recipient_committee_type': 'S',
#    'fec_election_year': '2020',
#    'contributor_middle_name': None,
#    'report_year': 2019,
#    'line_number_label': 'Contributions From Individuals/Persons Other Than Political Committees',
#    'contributor_occupation': 'PHYSICIAN',
#    'link_id': 4040720191646004836},
#   {'committee': {'committee_type': 'S',
#     'filing_frequency': 'Q',
#     'street_2': None,
#     'treasurer_name': 'MCCANDLESS, ELIZABETH T.',
#     'organization_type': None,
#     'city': 'BANGOR',
#     'name': 'COLLINS FOR SENATOR',
#     'party': 'REP',
#     'party_full': 'REPUBLICAN PARTY',
#     'designation': 'P',
#     'zip': '04402',
#     'state_full': 'Maine',
#     'cycle': 2020,
#     'committee_type_full': 'Senate',
#     'designation_full': 'Principal campaign committee',
#     'committee_id': 'C00314575',
#     'street_1': 'PO BOX 1096',
#     'organization_type_full': None,
#     'candidate_ids': ['S6ME00159'],
#     'state': 'ME',
#     'cycles': [1996,
#      1998,
#      2000,
#      2002,
#      2004,
#      2006,
#      2008,
#      2010,
#      2012,
#      2014,
#      2016,
#      2018,
#      2020]},
#    'fec_election_type_desc': 'PRIMARY',
#    'memo_code': None,
#    'memo_text': None,
#    'contributor_employer': 'ALL SEASONS ROOFING',
#    'candidate_prefix': None,
#    'amendment_indicator_desc': 'ADD',
#    'load_date': '2019-04-09T02:42:36.769000+00:00',
#    'contributor_zip': '950303085',
#    'schedule_type_full': 'ITEMIZED RECEIPTS',
#    'contributor_prefix': None,
#    'contributor_aggregate_ytd': 300.0,
#    'contributor_street_1': '15965 LANCASTER RD',
#    'amendment_indicator': 'A',
#    'contributor_street_2': None,
#    'committee_name': None,
#    'candidate_middle_name': None,
#    'contributor_first_name': 'VLAD',
#    'memoed_subtotal': False,
#    'committee_id': 'C00314575',
#    'filing_form': 'F3',
#    'unused_contbr_id': None,
#    'entity_type': 'IND',
#    'schedule_type': 'SA',
#    'is_individual': True,
#    'line_number': '11AI',
#    'increased_limit': None,
#    'election_type': 'P2020',
#    'receipt_type_desc': 'CONTRIBUTION',
#    'contributor_city': 'LOS GATOS',
#    'entity_type_desc': 'INDIVIDUAL',
#    'election_type_full': None,
#    'candidate_suffix': None,
#    'original_sub_id': None,
#    'conduit_committee_state': None,
#    'contributor_id': None,
#    'candidate_first_name': None,
#    'conduit_committee_street2': None,
#    'memo_code_full': None,
#    'candidate_last_name': None,
#    'contributor_name': 'GORSHTEYN, VLAD',
#    'candidate_name': None,
#    'contributor_suffix': None,
#    'contributor_last_name': 'GORSHTEYN',
#    'receipt_type_full': None,
#    'candidate_id': None,
#    'candidate_office_state': None,
#    'two_year_transaction_period': 2020,
#    'transaction_id': 'AB2FD1F7334D440D0917',
#    'candidate_office': None,
#    'candidate_office_state_full': None,
#    'donor_committee_name': None,
#    'contributor': None,
#    'receipt_type': '15',
#    'candidate_office_district': None,
#    'conduit_committee_zip': None,
#    'candidate_office_full': None,
#    'conduit_committee_city': None,
#    'back_reference_transaction_id': None,
#    'contribution_receipt_amount': 100.0,
#    'back_reference_schedule_name': None,
#    'image_number': '201904079146047048',
#    'conduit_committee_id': None,
#    'report_type': 'Q1',
#    'conduit_committee_name': None,
#    'file_number': 1322783,
#    'contribution_receipt_date': '2019-01-02T00:00:00',
#    'national_committee_nonfederal_account': None,
#    'contributor_state': 'CA',
#    'conduit_committee_street1': None,
#    'sub_id': '4040820191646013163',
#    'pdf_url': 'http://docquery.fec.gov/cgi-bin/fecimg/?201904079146047048',
#    'recipient_committee_type': 'S',
#    'fec_election_year': '2020',
#    'contributor_middle_name': None,
#    'report_year': 2019,
#    'line_number_label': 'Contributions From Individuals/Persons Other Than Political Committees',
#    'contributor_occupation': 'CONSTRUCTION EXECUTIVE',
#    'link_id': 4040720191646004836},
#   {'committee': {'committee_type': 'S',
#     'filing_frequency': 'Q',
#     'street_2': None,
#     'treasurer_name': 'MCCANDLESS, ELIZABETH T.',
#     'organization_type': None,
#     'city': 'BANGOR',
#     'name': 'COLLINS FOR SENATOR',
#     'party': 'REP',
#     'party_full': 'REPUBLICAN PARTY',
#     'designation': 'P',
#     'zip': '04402',
#     'state_full': 'Maine',
#     'cycle': 2020,
#     'committee_type_full': 'Senate',
#     'designation_full': 'Principal campaign committee',
#     'committee_id': 'C00314575',
#     'street_1': 'PO BOX 1096',
#     'organization_type_full': None,
#     'candidate_ids': ['S6ME00159'],
#     'state': 'ME',
#     'cycles': [1996,
#      1998,
#      2000,
#      2002,
#      2004,
#      2006,
#      2008,
#      2010,
#      2012,
#      2014,
#      2016,
#      2018,
#      2020]},
#    'fec_election_type_desc': 'PRIMARY',
#    'memo_code': None,
#    'memo_text': None,
#    'contributor_employer': 'INDEPENDENT CONTRACTOR',
#    'candidate_prefix': None,
#    'amendment_indicator_desc': 'ADD',
#    'load_date': '2019-04-09T02:42:36.838000+00:00',
#    'contributor_zip': '395328383',
#    'schedule_type_full': 'ITEMIZED RECEIPTS',
#    'contributor_prefix': None,
#    'contributor_aggregate_ytd': 250.0,
#    'contributor_street_1': '8051 CRESTWOOD CV',
#    'amendment_indicator': 'A',
#    'contributor_street_2': None,
#    'committee_name': None,
#    'candidate_middle_name': None,
#    'contributor_first_name': 'RICHARD',
#    'memoed_subtotal': False,
#    'committee_id': 'C00314575',
#    'filing_form': 'F3',
#    'unused_contbr_id': None,
#    'entity_type': 'IND',
#    'schedule_type': 'SA',
#    'is_individual': True,
#    'line_number': '11AI',
#    'increased_limit': None,
#    'election_type': 'P2020',
#    'receipt_type_desc': 'CONTRIBUTION',
#    'contributor_city': 'BILOXI',
#    'entity_type_desc': 'INDIVIDUAL',
#    'election_type_full': None,
#    'candidate_suffix': None,
#    'original_sub_id': None,
#    'conduit_committee_state': None,
#    'contributor_id': None,
#    'candidate_first_name': None,
#    'conduit_committee_street2': None,
#    'memo_code_full': None,
#    'candidate_last_name': None,
#    'contributor_name': "O'CONNOR, RICHARD",
#    'candidate_name': None,
#    'contributor_suffix': None,
#    'contributor_last_name': "O'CONNOR",
#    'receipt_type_full': None,
#    'candidate_id': None,
#    'candidate_office_state': None,
#    'two_year_transaction_period': 2020,
#    'transaction_id': 'ADFE3250EAA894F028D3',
#    'candidate_office': None,
#    'candidate_office_state_full': None,
#    'donor_committee_name': None,
#    'contributor': None,
#    'receipt_type': '15',
#    'candidate_office_district': None,
#    'conduit_committee_zip': None,
#    'candidate_office_full': None,
#    'conduit_committee_city': None,
#    'back_reference_transaction_id': None,
#    'contribution_receipt_amount': 250.0,
#    'back_reference_schedule_name': None,
#    'image_number': '201904079146047144',
#    'conduit_committee_id': None,
#    'report_type': 'Q1',
#    'conduit_committee_name': None,
#    'file_number': 1322783,
#    'contribution_receipt_date': '2019-01-02T00:00:00',
#    'national_committee_nonfederal_account': None,
#    'contributor_state': 'MS',
#    'conduit_committee_street1': None,
#    'sub_id': '4040820191646013450',
#    'pdf_url': 'http://docquery.fec.gov/cgi-bin/fecimg/?201904079146047144',
#    'recipient_committee_type': 'S',
#    'fec_election_year': '2020',
#    'contributor_middle_name': None,
#    'report_year': 2019,
#    'line_number_label': 'Contributions From Individuals/Persons Other Than Political Committees',
#    'contributor_occupation': 'IT SECURITY MGR',
#    'link_id': 4040720191646004836},
#   {'committee': {'committee_type': 'S',
#     'filing_frequency': 'Q',
#     'street_2': None,
#     'treasurer_name': 'MCCANDLESS, ELIZABETH T.',
#     'organization_type': None,
#     'city': 'BANGOR',
#     'name': 'COLLINS FOR SENATOR',
#     'party': 'REP',
#     'party_full': 'REPUBLICAN PARTY',
#     'designation': 'P',
#     'zip': '04402',
#     'state_full': 'Maine',
#     'cycle': 2020,
#     'committee_type_full': 'Senate',
#     'designation_full': 'Principal campaign committee',
#     'committee_id': 'C00314575',
#     'street_1': 'PO BOX 1096',
#     'organization_type_full': None,
#     'candidate_ids': ['S6ME00159'],
#     'state': 'ME',
#     'cycles': [1996,
#      1998,
#      2000,
#      2002,
#      2004,
#      2006,
#      2008,
#      2010,
#      2012,
#      2014,
#      2016,
#      2018,
#      2020]},
#    'fec_election_type_desc': 'PRIMARY',
#    'memo_code': None,
#    'memo_text': None,
#    'contributor_employer': 'RETIRED',
#    'candidate_prefix': None,
#    'amendment_indicator_desc': 'ADD',
#    'load_date': '2019-04-09T02:42:36.744000+00:00',
#    'contributor_zip': '326072693',
#    'schedule_type_full': 'ITEMIZED RECEIPTS',
#    'contributor_prefix': None,
#    'contributor_aggregate_ytd': 250.0,
#    'contributor_street_1': '309 NW 24TH ST',
#    'amendment_indicator': 'A',
#    'contributor_street_2': None,
#    'committee_name': None,
#    'candidate_middle_name': None,
#    'contributor_first_name': 'JOHN',
#    'memoed_subtotal': False,
#    'committee_id': 'C00314575',
#    'filing_form': 'F3',
#    'unused_contbr_id': None,
#    'entity_type': 'IND',
#    'schedule_type': 'SA',
#    'is_individual': True,
#    'line_number': '11AI',
#    'increased_limit': None,
#    'election_type': 'P2020',
#    'receipt_type_desc': 'CONTRIBUTION',
#    'contributor_city': 'GAINESVILLE',
#    'entity_type_desc': 'INDIVIDUAL',
#    'election_type_full': None,
#    'candidate_suffix': None,
#    'original_sub_id': None,
#    'conduit_committee_state': None,
#    'contributor_id': None,
#    'candidate_first_name': None,
#    'conduit_committee_street2': None,
#    'memo_code_full': None,
#    'candidate_last_name': None,
#    'contributor_name': 'FOX, JOHN',
#    'candidate_name': None,
#    'contributor_suffix': None,
#    'contributor_last_name': 'FOX',
#    'receipt_type_full': None,
#    'candidate_id': None,
#    'candidate_office_state': None,
#    'two_year_transaction_period': 2020,
#    'transaction_id': 'AC9527181AD7C477EB4D',
#    'candidate_office': None,
#    'candidate_office_state_full': None,
#    'donor_committee_name': None,
#    'contributor': None,
#    'receipt_type': '15',
#    'candidate_office_district': None,
#    'conduit_committee_zip': None,
#    'candidate_office_full': None,
#    'conduit_committee_city': None,
#    'back_reference_transaction_id': None,
#    'contribution_receipt_amount': 50.0,
#    'back_reference_schedule_name': None,
#    'image_number': '201904079146047027',
#    'conduit_committee_id': None,
#    'report_type': 'Q1',
#    'conduit_committee_name': None,
#    'file_number': 1322783,
#    'contribution_receipt_date': '2019-01-03T00:00:00',
#    'national_committee_nonfederal_account': None,
#    'contributor_state': 'FL',
#    'conduit_committee_street1': None,
#    'sub_id': '4040820191646013099',
#    'pdf_url': 'http://docquery.fec.gov/cgi-bin/fecimg/?201904079146047027',
#    'recipient_committee_type': 'S',
#    'fec_election_year': '2020',
#    'contributor_middle_name': None,
#    'report_year': 2019,
#    'line_number_label': 'Contributions From Individuals/Persons Other Than Political Committees',
#    'contributor_occupation': 'RETIRED',
#    'link_id': 4040720191646004836},
#   {'committee': {'committee_type': 'S',
#     'filing_frequency': 'Q',
#     'street_2': None,
#     'treasurer_name': 'MCCANDLESS, ELIZABETH T.',
#     'organization_type': None,
#     'city': 'BANGOR',
#     'name': 'COLLINS FOR SENATOR',
#     'party': 'REP',
#     'party_full': 'REPUBLICAN PARTY',
#     'designation': 'P',
#     'zip': '04402',
#     'state_full': 'Maine',
#     'cycle': 2020,
#     'committee_type_full': 'Senate',
#     'designation_full': 'Principal campaign committee',
#     'committee_id': 'C00314575',
#     'street_1': 'PO BOX 1096',
#     'organization_type_full': None,
#     'candidate_ids': ['S6ME00159'],
#     'state': 'ME',
#     'cycles': [1996,
#      1998,
#      2000,
#      2002,
#      2004,
#      2006,
#      2008,
#      2010,
#      2012,
#      2014,
#      2016,
#      2018,
#      2020]},
#    'fec_election_type_desc': 'PRIMARY',
#    'memo_code': None,
#    'memo_text': None,
#    'contributor_employer': 'GIBSONBURG HEALTH',
#    'candidate_prefix': None,
#    'amendment_indicator_desc': 'ADD',
#    'load_date': '2019-04-09T02:42:36.773000+00:00',
#    'contributor_zip': '301885218',
#    'schedule_type_full': 'ITEMIZED RECEIPTS',
#    'contributor_prefix': None,
#    'contributor_aggregate_ytd': 1000.0,
#    'contributor_street_1': '4066 EARNEY RD',
#    'amendment_indicator': 'A',
#    'contributor_street_2': None,
#    'committee_name': None,
#    'candidate_middle_name': None,
#    'contributor_first_name': 'JACK',
#    'memoed_subtotal': False,
#    'committee_id': 'C00314575',
#    'filing_form': 'F3',
#    'unused_contbr_id': None,
#    'entity_type': 'IND',
#    'schedule_type': 'SA',
#    'is_individual': True,
#    'line_number': '11AI',
#    'increased_limit': None,
#    'election_type': 'P2020',
#    'receipt_type_desc': 'CONTRIBUTION',
#    'contributor_city': 'WOODSTOCK',
#    'entity_type_desc': 'INDIVIDUAL',
#    'election_type_full': None,
#    'candidate_suffix': None,
#    'original_sub_id': None,
#    'conduit_committee_state': None,
#    'contributor_id': None,
#    'candidate_first_name': None,
#    'conduit_committee_street2': None,
#    'memo_code_full': None,
#    'candidate_last_name': None,
#    'contributor_name': 'HERETH, JACK',
#    'candidate_name': None,
#    'contributor_suffix': None,
#    'contributor_last_name': 'HERETH',
#    'receipt_type_full': None,
#    'candidate_id': None,
#    'candidate_office_state': None,
#    'two_year_transaction_period': 2020,
#    'transaction_id': 'A17BBA885375946F7AD0',
#    'candidate_office': None,
#    'candidate_office_state_full': None,
#    'donor_committee_name': None,
#    'contributor': None,
#    'receipt_type': '15',
#    'candidate_office_district': None,
#    'conduit_committee_zip': None,
#    'candidate_office_full': None,
#    'conduit_committee_city': None,
#    'back_reference_transaction_id': None,
#    'contribution_receipt_amount': 250.0,
#    'back_reference_schedule_name': None,
#    'image_number': '201904079146047058',
#    'conduit_committee_id': None,
#    'report_type': 'Q1',
#    'conduit_committee_name': None,
#    'file_number': 1322783,
#    'contribution_receipt_date': '2019-01-04T00:00:00',
#    'national_committee_nonfederal_account': None,
#    'contributor_state': 'GA',
#    'conduit_committee_street1': None,
#    'sub_id': '4040820191646013192',
#    'pdf_url': 'http://docquery.fec.gov/cgi-bin/fecimg/?201904079146047058',
#    'recipient_committee_type': 'S',
#    'fec_election_year': '2020',
#    'contributor_middle_name': None,
#    'report_year': 2019,
#    'line_number_label': 'Contributions From Individuals/Persons Other Than Political Committees',
#    'contributor_occupation': 'EXECUTIVE',
#    'link_id': 4040720191646004836},
#   {'committee': {'committee_type': 'S',
#     'filing_frequency': 'Q',
#     'street_2': None,
#     'treasurer_name': 'MCCANDLESS, ELIZABETH T.',
#     'organization_type': None,
#     'city': 'BANGOR',
#     'name': 'COLLINS FOR SENATOR',
#     'party': 'REP',
#     'party_full': 'REPUBLICAN PARTY',
#     'designation': 'P',
#     'zip': '04402',
#     'state_full': 'Maine',
#     'cycle': 2020,
#     'committee_type_full': 'Senate',
#     'designation_full': 'Principal campaign committee',
#     'committee_id': 'C00314575',
#     'street_1': 'PO BOX 1096',
#     'organization_type_full': None,
#     'candidate_ids': ['S6ME00159'],
#     'state': 'ME',
#     'cycles': [1996,
#      1998,
#      2000,
#      2002,
#      2004,
#      2006,
#      2008,
#      2010,
#      2012,
#      2014,
#      2016,
#      2018,
#      2020]},
#    'fec_election_type_desc': 'PRIMARY',
#    'memo_code': None,
#    'memo_text': None,
#    'contributor_employer': 'RETIRED',
#    'candidate_prefix': None,
#    'amendment_indicator_desc': 'ADD',
#    'load_date': '2019-04-09T02:42:36.778000+00:00',
#    'contributor_zip': '106028236',
#    'schedule_type_full': 'ITEMIZED RECEIPTS',
#    'contributor_prefix': None,
#    'contributor_aggregate_ytd': 750.0,
#    'contributor_street_1': 'PO BOX 8236',
#    'amendment_indicator': 'A',
#    'contributor_street_2': None,
#    'committee_name': None,
#    'candidate_middle_name': None,
#    'contributor_first_name': 'MARK',
#    'memoed_subtotal': False,
#    'committee_id': 'C00314575',
#    'filing_form': 'F3',
#    'unused_contbr_id': None,
#    'entity_type': 'IND',
#    'schedule_type': 'SA',
#    'is_individual': True,
#    'line_number': '11AI',
#    'increased_limit': None,
#    'election_type': 'P2020',
#    'receipt_type_desc': 'CONTRIBUTION',
#    'contributor_city': 'WHITE PLAINS',
#    'entity_type_desc': 'INDIVIDUAL',
#    'election_type_full': None,
#    'candidate_suffix': None,
#    'original_sub_id': None,
#    'conduit_committee_state': None,
#    'contributor_id': None,
#    'candidate_first_name': None,
#    'conduit_committee_street2': None,
#    'memo_code_full': None,
#    'candidate_last_name': None,
#    'contributor_name': 'HOULIHAN, MARK',
#    'candidate_name': None,
#    'contributor_suffix': None,
#    'contributor_last_name': 'HOULIHAN',
#    'receipt_type_full': None,
#    'candidate_id': None,
#    'candidate_office_state': None,
#    'two_year_transaction_period': 2020,
#    'transaction_id': 'AADE9F7F67E9141DDA1E',
#    'candidate_office': None,
#    'candidate_office_state_full': None,
#    'donor_committee_name': None,
#    'contributor': None,
#    'receipt_type': '15',
#    'candidate_office_district': None,
#    'conduit_committee_zip': None,
#    'candidate_office_full': None,
#    'conduit_committee_city': None,
#    'back_reference_transaction_id': None,
#    'contribution_receipt_amount': 250.0,
#    'back_reference_schedule_name': None,
#    'image_number': '201904079146047067',
#    'conduit_committee_id': None,
#    'report_type': 'Q1',
#    'conduit_committee_name': None,
#    'file_number': 1322783,
#    'contribution_receipt_date': '2019-01-04T00:00:00',
#    'national_committee_nonfederal_account': None,
#    'contributor_state': 'NY',
#    'conduit_committee_street1': None,
#    'sub_id': '4040820191646013220',
#    'pdf_url': 'http://docquery.fec.gov/cgi-bin/fecimg/?201904079146047067',
#    'recipient_committee_type': 'S',
#    'fec_election_year': '2020',
#    'contributor_middle_name': None,
#    'report_year': 2019,
#    'line_number_label': 'Contributions From Individuals/Persons Other Than Political Committees',
#    'contributor_occupation': 'RETIRED',
#    'link_id': 4040720191646004836},
#   {'committee': {'committee_type': 'S',
#     'filing_frequency': 'Q',
#     'street_2': None,
#     'treasurer_name': 'MCCANDLESS, ELIZABETH T.',
#     'organization_type': None,
#     'city': 'BANGOR',
#     'name': 'COLLINS FOR SENATOR',
#     'party': 'REP',
#     'party_full': 'REPUBLICAN PARTY',
#     'designation': 'P',
#     'zip': '04402',
#     'state_full': 'Maine',
#     'cycle': 2020,
#     'committee_type_full': 'Senate',
#     'designation_full': 'Principal campaign committee',
#     'committee_id': 'C00314575',
#     'street_1': 'PO BOX 1096',
#     'organization_type_full': None,
#     'candidate_ids': ['S6ME00159'],
#     'state': 'ME',
#     'cycles': [1996,
#      1998,
#      2000,
#      2002,
#      2004,
#      2006,
#      2008,
#      2010,
#      2012,
#      2014,
#      2016,
#      2018,
#      2020]},
#    'fec_election_type_desc': 'PRIMARY',
#    'memo_code': None,
#    'memo_text': None,
#    'contributor_employer': 'STATE OF MD',
#    'candidate_prefix': None,
#    'amendment_indicator_desc': 'ADD',
#    'load_date': '2019-04-09T02:42:36.782000+00:00',
#    'contributor_zip': '208155030',
#    'schedule_type_full': 'ITEMIZED RECEIPTS',
#    'contributor_prefix': None,
#    'contributor_aggregate_ytd': 300.0,
#    'contributor_street_1': '3908 UNDERWOOD ST',
#    'amendment_indicator': 'A',
#    'contributor_street_2': None,
#    'committee_name': None,
#    'candidate_middle_name': None,
#    'contributor_first_name': 'STEPHEN',
#    'memoed_subtotal': False,
#    'committee_id': 'C00314575',
#    'filing_form': 'F3',
#    'unused_contbr_id': None,
#    'entity_type': 'IND',
#    'schedule_type': 'SA',
#    'is_individual': True,
#    'line_number': '11AI',
#    'increased_limit': None,
#    'election_type': 'P2020',
#    'receipt_type_desc': 'CONTRIBUTION',
#    'contributor_city': 'CHEVY CHASE',
#    'entity_type_desc': 'INDIVIDUAL',
#    'election_type_full': None,
#    'candidate_suffix': None,
#    'original_sub_id': None,
#    'conduit_committee_state': None,
#    'contributor_id': None,
#    'candidate_first_name': None,
#    'conduit_committee_street2': None,
#    'memo_code_full': None,
#    'candidate_last_name': None,
#    'contributor_name': 'HUT, STEPHEN',
#    'candidate_name': None,
#    'contributor_suffix': None,
#    'contributor_last_name': 'HUT',
#    'receipt_type_full': None,
#    'candidate_id': None,
#    'candidate_office_state': None,
#    'two_year_transaction_period': 2020,
#    'transaction_id': 'ACF36C6799A074832BA4',
#    'candidate_office': None,
#    'candidate_office_state_full': None,
#    'donor_committee_name': None,
#    'contributor': None,
#    'receipt_type': '15',
#    'candidate_office_district': None,
#    'conduit_committee_zip': None,
#    'candidate_office_full': None,
#    'conduit_committee_city': None,
#    'back_reference_transaction_id': None,
#    'contribution_receipt_amount': 100.0,
#    'back_reference_schedule_name': None,
#    'image_number': '201904079146047074',
#    'conduit_committee_id': None,
#    'report_type': 'Q1',
#    'conduit_committee_name': None,
#    'file_number': 1322783,
#    'contribution_receipt_date': '2019-01-04T00:00:00',
#    'national_committee_nonfederal_account': None,
#    'contributor_state': 'MD',
#    'conduit_committee_street1': None,
#    'sub_id': '4040820191646013241',
#    'pdf_url': 'http://docquery.fec.gov/cgi-bin/fecimg/?201904079146047074',
#    'recipient_committee_type': 'S',
#    'fec_election_year': '2020',
#    'contributor_middle_name': None,
#    'report_year': 2019,
#    'line_number_label': 'Contributions From Individuals/Persons Other Than Political Committees',
#    'contributor_occupation': 'LAWYER',
#    'link_id': 4040720191646004836},
#   {'committee': {'committee_type': 'S',
#     'filing_frequency': 'Q',
#     'street_2': None,
#     'treasurer_name': 'MCCANDLESS, ELIZABETH T.',
#     'organization_type': None,
#     'city': 'BANGOR',
#     'name': 'COLLINS FOR SENATOR',
#     'party': 'REP',
#     'party_full': 'REPUBLICAN PARTY',
#     'designation': 'P',
#     'zip': '04402',
#     'state_full': 'Maine',
#     'cycle': 2020,
#     'committee_type_full': 'Senate',
#     'designation_full': 'Principal campaign committee',
#     'committee_id': 'C00314575',
#     'street_1': 'PO BOX 1096',
#     'organization_type_full': None,
#     'candidate_ids': ['S6ME00159'],
#     'state': 'ME',
#     'cycles': [1996,
#      1998,
#      2000,
#      2002,
#      2004,
#      2006,
#      2008,
#      2010,
#      2012,
#      2014,
#      2016,
#      2018,
#      2020]},
#    'fec_election_type_desc': 'PRIMARY',
#    'memo_code': None,
#    'memo_text': None,
#    'contributor_employer': 'SELF',
#    'candidate_prefix': None,
#    'amendment_indicator_desc': 'ADD',
#    'load_date': '2019-04-09T02:42:36.802000+00:00',
#    'contributor_zip': '920835502',
#    'schedule_type_full': 'ITEMIZED RECEIPTS',
#    'contributor_prefix': None,
#    'contributor_aggregate_ytd': 300.0,
#    'contributor_street_1': '558 COLLYN ST',
#    'amendment_indicator': 'A',
#    'contributor_street_2': None,
#    'committee_name': None,
#    'candidate_middle_name': None,
#    'contributor_first_name': 'KENNETH',
#    'memoed_subtotal': False,
#    'committee_id': 'C00314575',
#    'filing_form': 'F3',
#    'unused_contbr_id': None,
#    'entity_type': 'IND',
#    'schedule_type': 'SA',
#    'is_individual': True,
#    'line_number': '11AI',
#    'increased_limit': None,
#    'election_type': 'P2020',
#    'receipt_type_desc': 'CONTRIBUTION',
#    'contributor_city': 'VISTA',
#    'entity_type_desc': 'INDIVIDUAL',
#    'election_type_full': None,
#    'candidate_suffix': None,
#    'original_sub_id': None,
#    'conduit_committee_state': None,
#    'contributor_id': None,
#    'candidate_first_name': None,
#    'conduit_committee_street2': None,
#    'memo_code_full': None,
#    'candidate_last_name': None,
# ...
#    'contributor_id': None,
#    'candidate_first_name': None,
#    'conduit_committee_street2': None,
#    'memo_code_full': None,
#    'candidate_last_name': None,
#    'contributor_name': 'BARROSO, LUIS F.',
#    'candidate_name': None,
#    'contributor_suffix': None,
#    'contributor_last_name': 'BARROSO',
#    'receipt_type_full': None,
#    'candidate_id': None,
#    'candidate_office_state': None,
#    'two_year_transaction_period': 2020,
#    'transaction_id': 'A3621EB0DFE0843ABAB1',
#    'candidate_office': None,
#    'candidate_office_state_full': None,
#    'donor_committee_name': None,
#    'contributor': None,
#    'receipt_type': '15',
#    'candidate_office_district': None,
#    'conduit_committee_zip': None,
#    'candidate_office_full': None,
#    'conduit_committee_city': None,
#    'back_reference_transaction_id': None,
#    'contribution_receipt_amount': 100.0,
#    'back_reference_schedule_name': None,
#    'image_number': '201904079146046967',
#    'conduit_committee_id': None,
#    'report_type': 'Q1',
#    'conduit_committee_name': None,
#    'file_number': 1322783,
#    'contribution_receipt_date': '2019-01-25T00:00:00',
#    'national_committee_nonfederal_account': None,
#    'contributor_state': 'FL',
#    'conduit_committee_street1': None,
#    'sub_id': '4040820191646012921',
#    'pdf_url': 'http://docquery.fec.gov/cgi-bin/fecimg/?201904079146046967',
#    'recipient_committee_type': 'S',
#    'fec_election_year': '2020',
#    'contributor_middle_name': 'F.',
#    'report_year': 2019,
#    'line_number_label': 'Contributions From Individuals/Persons Other Than Political Committees',
#    'contributor_occupation': 'RETIRED',
#    'link_id': 4040720191646004836},
#   {'committee': {'committee_type': 'S',
#     'filing_frequency': 'Q',
#     'street_2': None,
#     'treasurer_name': 'MCCANDLESS, ELIZABETH T.',
#     'organization_type': None,
#     'city': 'BANGOR',
#     'name': 'COLLINS FOR SENATOR',
#     'party': 'REP',
#     'party_full': 'REPUBLICAN PARTY',
#     'designation': 'P',
#     'zip': '04402',
#     'state_full': 'Maine',
#     'cycle': 2020,
#     'committee_type_full': 'Senate',
#     'designation_full': 'Principal campaign committee',
#     'committee_id': 'C00314575',
#     'street_1': 'PO BOX 1096',
#     'organization_type_full': None,
#     'candidate_ids': ['S6ME00159'],
#     'state': 'ME',
#     'cycles': [1996,
#      1998,
#      2000,
#      2002,
#      2004,
#      2006,
#      2008,
#      2010,
#      2012,
#      2014,
#      2016,
#      2018,
#      2020]},
#    'fec_election_type_desc': 'PRIMARY',
#    'memo_code': None,
#    'memo_text': None,
#    'contributor_employer': 'SELF',
#    'candidate_prefix': None,
#    'amendment_indicator_desc': 'ADD',
#    'load_date': '2019-04-09T02:42:36.669000+00:00',
#    'contributor_zip': '200071513',
#    'schedule_type_full': 'ITEMIZED RECEIPTS',
#    'contributor_prefix': None,
#    'contributor_aggregate_ytd': 5000.0,
#    'contributor_street_1': '4515 W ST NW',
#    'amendment_indicator': 'A',
#    'contributor_street_2': None,
#    'committee_name': None,
#    'candidate_middle_name': None,
#    'contributor_first_name': 'DOYCE',
#    'memoed_subtotal': False,
#    'committee_id': 'C00314575',
#    'filing_form': 'F3',
#    'unused_contbr_id': None,
#    'entity_type': 'IND',
#    'schedule_type': 'SA',
#    'is_individual': True,
#    'line_number': '11AI',
#    'increased_limit': None,
#    'election_type': 'P2020',
#    'receipt_type_desc': 'CONTRIBUTION',
#    'contributor_city': 'WASHINGTON',
#    'entity_type_desc': 'INDIVIDUAL',
#    'election_type_full': None,
#    'candidate_suffix': None,
#    'original_sub_id': None,
#    'conduit_committee_state': None,
#    'contributor_id': None,
#    'candidate_first_name': None,
#    'conduit_committee_street2': None,
#    'memo_code_full': None,
#    'candidate_last_name': None,
#    'contributor_name': 'BOESCH, DOYCE',
#    'candidate_name': None,
#    'contributor_suffix': None,
#    'contributor_last_name': 'BOESCH',
#    'receipt_type_full': None,
#    'candidate_id': None,
#    'candidate_office_state': None,
#    'two_year_transaction_period': 2020,
#    'transaction_id': 'A6AF3C902551C4DC7AF6',
#    'candidate_office': None,
#    'candidate_office_state_full': None,
#    'donor_committee_name': None,
#    'contributor': None,
#    'receipt_type': '15',
#    'candidate_office_district': None,
#    'conduit_committee_zip': None,
#    'candidate_office_full': None,
#    'conduit_committee_city': None,
#    'back_reference_transaction_id': None,
#    'contribution_receipt_amount': 500.0,
#    'back_reference_schedule_name': None,
#    'image_number': '201904079146046976',
#    'conduit_committee_id': None,
#    'report_type': 'Q1',
#    'conduit_committee_name': None,
#    'file_number': 1322783,
#    'contribution_receipt_date': '2019-01-25T00:00:00',
#    'national_committee_nonfederal_account': None,
#    'contributor_state': 'DC',
#    'conduit_committee_street1': None,
#    'sub_id': '4040820191646012946',
#    'pdf_url': 'http://docquery.fec.gov/cgi-bin/fecimg/?201904079146046976',
#    'recipient_committee_type': 'S',
#    'fec_election_year': '2020',
#    'contributor_middle_name': None,
#    'report_year': 2019,
#    'line_number_label': 'Contributions From Individuals/Persons Other Than Political Committees',
#    'contributor_occupation': 'GOVT RELATIONS',
#    'link_id': 4040720191646004836},
#   {'committee': {'committee_type': 'S',
#     'filing_frequency': 'Q',
#     'street_2': None,
#     'treasurer_name': 'MCCANDLESS, ELIZABETH T.',
#     'organization_type': None,
#     'city': 'BANGOR',
#     'name': 'COLLINS FOR SENATOR',
#     'party': 'REP',
#     'party_full': 'REPUBLICAN PARTY',
#     'designation': 'P',
#     'zip': '04402',
#     'state_full': 'Maine',
#     'cycle': 2020,
#     'committee_type_full': 'Senate',
#     'designation_full': 'Principal campaign committee',
#     'committee_id': 'C00314575',
#     'street_1': 'PO BOX 1096',
#     'organization_type_full': None,
#     'candidate_ids': ['S6ME00159'],
#     'state': 'ME',
#     'cycles': [1996,
#      1998,
#      2000,
#      2002,
#      2004,
#      2006,
#      2008,
#      2010,
#      2012,
#      2014,
#      2016,
#      2018,
#      2020]},
#    'fec_election_type_desc': 'PRIMARY',
#    'memo_code': None,
#    'memo_text': None,
#    'contributor_employer': 'HOMELAND VINYL PRODUCTS',
#    'candidate_prefix': None,
#    'amendment_indicator_desc': 'ADD',
#    'load_date': '2019-04-09T02:42:36.676000+00:00',
#    'contributor_zip': '352444512',
#    'schedule_type_full': 'ITEMIZED RECEIPTS',
#    'contributor_prefix': None,
#    'contributor_aggregate_ytd': 200.0,
#    'contributor_street_1': '143 MAPLE TRCE',
#    'amendment_indicator': 'A',
#    'contributor_street_2': None,
#    'committee_name': None,
#    'candidate_middle_name': None,
#    'contributor_first_name': 'WILLIAM',
#    'memoed_subtotal': False,
#    'committee_id': 'C00314575',
#    'filing_form': 'F3',
#    'unused_contbr_id': None,
#    'entity_type': 'IND',
#    'schedule_type': 'SA',
#    'is_individual': True,
#    'line_number': '11AI',
#    'increased_limit': None,
#    'election_type': 'P2020',
#    'receipt_type_desc': None,
#    'contributor_city': 'HOOVER',
#    'entity_type_desc': 'INDIVIDUAL',
#    'election_type_full': None,
#    'candidate_suffix': None,
#    'original_sub_id': None,
#    'conduit_committee_state': None,
#    'contributor_id': None,
#    'candidate_first_name': None,
#    'conduit_committee_street2': None,
#    'memo_code_full': None,
#    'candidate_last_name': None,
#    'contributor_name': 'BRADLEY, WILLIAM',
#    'candidate_name': None,
#    'contributor_suffix': None,
#    'contributor_last_name': 'BRADLEY',
#    'receipt_type_full': None,
#    'candidate_id': None,
#    'candidate_office_state': None,
#    'two_year_transaction_period': 2020,
#    'transaction_id': 'A1C7606C4EB9C4234A59',
#    'candidate_office': None,
#    'candidate_office_state_full': None,
#    'donor_committee_name': None,
#    'contributor': None,
#    'receipt_type': None,
#    'candidate_office_district': None,
#    'conduit_committee_zip': None,
#    'candidate_office_full': None,
#    'conduit_committee_city': None,
#    'back_reference_transaction_id': None,
#    'contribution_receipt_amount': 50.0,
#    'back_reference_schedule_name': None,
#    'image_number': '201904079146046979',
#    'conduit_committee_id': None,
#    'report_type': 'Q1',
#    'conduit_committee_name': None,
#    'file_number': 1322783,
#    'contribution_receipt_date': '2019-01-25T00:00:00',
#    'national_committee_nonfederal_account': None,
#    'contributor_state': 'AL',
#    'conduit_committee_street1': None,
#    'sub_id': '4040820191646012955',
#    'pdf_url': 'http://docquery.fec.gov/cgi-bin/fecimg/?201904079146046979',
#    'recipient_committee_type': 'S',
#    'fec_election_year': '2020',
#    'contributor_middle_name': None,
#    'report_year': 2019,
#    'line_number_label': 'Contributions From Individuals/Persons Other Than Political Committees',
#    'contributor_occupation': 'PURCHASING MANAGER',
#    'link_id': 4040720191646004836},
#   {'committee': {'committee_type': 'S',
#     'filing_frequency': 'Q',
#     'street_2': None,
#     'treasurer_name': 'MCCANDLESS, ELIZABETH T.',
#     'organization_type': None,
#     'city': 'BANGOR',
#     'name': 'COLLINS FOR SENATOR',
#     'party': 'REP',
#     'party_full': 'REPUBLICAN PARTY',
#     'designation': 'P',
#     'zip': '04402',
#     'state_full': 'Maine',
#     'cycle': 2020,
#     'committee_type_full': 'Senate',
#     'designation_full': 'Principal campaign committee',
#     'committee_id': 'C00314575',
#     'street_1': 'PO BOX 1096',
#     'organization_type_full': None,
#     'candidate_ids': ['S6ME00159'],
#     'state': 'ME',
#     'cycles': [1996,
#      1998,
#      2000,
#      2002,
#      2004,
#      2006,
#      2008,
#      2010,
#      2012,
#      2014,
#      2016,
#      2018,
#      2020]},
#    'fec_election_type_desc': 'PRIMARY',
#    'memo_code': None,
#    'memo_text': None,
#    'contributor_employer': 'CORNERSTONE DEVELOPMENT CO',
#    'candidate_prefix': None,
#    'amendment_indicator_desc': 'ADD',
#    'load_date': '2019-04-09T02:42:36.701000+00:00',
#    'contributor_zip': '441393881',
#    'schedule_type_full': 'ITEMIZED RECEIPTS',
#    'contributor_prefix': None,
#    'contributor_aggregate_ytd': 400.0,
#    'contributor_street_1': '34200 BROOKMEADE CT',
#    'amendment_indicator': 'A',
#    'contributor_street_2': 'APT 416',
#    'committee_name': None,
#    'candidate_middle_name': None,
#    'contributor_first_name': 'STEVEN',
#    'memoed_subtotal': False,
#    'committee_id': 'C00314575',
#    'filing_form': 'F3',
#    'unused_contbr_id': None,
#    'entity_type': 'IND',
#    'schedule_type': 'SA',
#    'is_individual': True,
#    'line_number': '11AI',
#    'increased_limit': None,
#    'election_type': 'P2020',
#    'receipt_type_desc': 'CONTRIBUTION',
#    'contributor_city': 'SOLON',
#    'entity_type_desc': 'INDIVIDUAL',
#    'election_type_full': None,
#    'candidate_suffix': None,
#    'original_sub_id': None,
#    'conduit_committee_state': None,
#    'contributor_id': None,
#    'candidate_first_name': None,
#    'conduit_committee_street2': None,
#    'memo_code_full': None,
#    'candidate_last_name': None,
#    'contributor_name': 'CHARLTON, STEVEN',
#    'candidate_name': None,
#    'contributor_suffix': None,
#    'contributor_last_name': 'CHARLTON',
#    'receipt_type_full': None,
#    'candidate_id': None,
#    'candidate_office_state': None,
#    'two_year_transaction_period': 2020,
#    'transaction_id': 'AFDB49FD9CAFF4E7CAAC',
#    'candidate_office': None,
#    'candidate_office_state_full': None,
#    'donor_committee_name': None,
#    'contributor': None,
#    'receipt_type': '15',
#    'candidate_office_district': None,
#    'conduit_committee_zip': None,
#    'candidate_office_full': None,
#    'conduit_committee_city': None,
#    'back_reference_transaction_id': None,
#    'contribution_receipt_amount': 100.0,
#    'back_reference_schedule_name': None,
#    'image_number': '201904079146046992',
#    'conduit_committee_id': None,
#    'report_type': 'Q1',
#    'conduit_committee_name': None,
#    'file_number': 1322783,
#    'contribution_receipt_date': '2019-01-25T00:00:00',
#    'national_committee_nonfederal_account': None,
#    'contributor_state': 'OH',
#    'conduit_committee_street1': None,
#    'sub_id': '4040820191646012995',
#    'pdf_url': 'http://docquery.fec.gov/cgi-bin/fecimg/?201904079146046992',
#    'recipient_committee_type': 'S',
#    'fec_election_year': '2020',
#    'contributor_middle_name': None,
#    'report_year': 2019,
#    'line_number_label': 'Contributions From Individuals/Persons Other Than Political Committees',
#    'contributor_occupation': 'REAL ESTATE INVESTMENT',
#    'link_id': 4040720191646004836},
#   {'committee': {'committee_type': 'S',
#     'filing_frequency': 'Q',
#     'street_2': None,
#     'treasurer_name': 'MCCANDLESS, ELIZABETH T.',
#     'organization_type': None,
#     'city': 'BANGOR',
#     'name': 'COLLINS FOR SENATOR',
#     'party': 'REP',
#     'party_full': 'REPUBLICAN PARTY',
#     'designation': 'P',
#     'zip': '04402',
#     'state_full': 'Maine',
#     'cycle': 2020,
#     'committee_type_full': 'Senate',
#     'designation_full': 'Principal campaign committee',
#     'committee_id': 'C00314575',
#     'street_1': 'PO BOX 1096',
#     'organization_type_full': None,
#     'candidate_ids': ['S6ME00159'],
#     'state': 'ME',
#     'cycles': [1996,
#      1998,
#      2000,
#      2002,
#      2004,
#      2006,
#      2008,
#      2010,
#      2012,
#      2014,
#      2016,
#      2018,
#      2020]},
#    'fec_election_type_desc': 'PRIMARY',
#    'memo_code': None,
#    'memo_text': None,
#    'contributor_employer': 'RETIRED',
#    'candidate_prefix': None,
#    'amendment_indicator_desc': 'ADD',
#    'load_date': '2019-04-09T02:42:36.713000+00:00',
#    'contributor_zip': '894480546',
#    'schedule_type_full': 'ITEMIZED RECEIPTS',
#    'contributor_prefix': None,
#    'contributor_aggregate_ytd': 2000.0,
#    'contributor_street_1': 'PO BOX 546',
#    'amendment_indicator': 'A',
#    'contributor_street_2': None,
#    'committee_name': None,
#    'candidate_middle_name': None,
#    'contributor_first_name': 'ALFONSO',
#    'memoed_subtotal': False,
#    'committee_id': 'C00314575',
#    'filing_form': 'F3',
#    'unused_contbr_id': None,
#    'entity_type': 'IND',
#    'schedule_type': 'SA',
#    'is_individual': True,
#    'line_number': '11AI',
#    'increased_limit': None,
#    'election_type': 'P2020',
#    'receipt_type_desc': 'CONTRIBUTION',
#    'contributor_city': 'ZEPHYR COVE',
#    'entity_type_desc': 'INDIVIDUAL',
#    'election_type_full': None,
#    'candidate_suffix': None,
#    'original_sub_id': None,
#    'conduit_committee_state': None,
#    'contributor_id': None,
#    'candidate_first_name': None,
#    'conduit_committee_street2': None,
#    'memo_code_full': None,
#    'candidate_last_name': None,
#    'contributor_name': 'CORDERO, ALFONSO',
#    'candidate_name': None,
#    'contributor_suffix': None,
#    'contributor_last_name': 'CORDERO',
#    'receipt_type_full': None,
#    'candidate_id': None,
#    'candidate_office_state': None,
#    'two_year_transaction_period': 2020,
#    'transaction_id': 'ABCA00568C4B841BEB92',
#    'candidate_office': None,
#    'candidate_office_state_full': None,
#    'donor_committee_name': None,
#    'contributor': None,
#    'receipt_type': '15',
#    'candidate_office_district': None,
#    'conduit_committee_zip': None,
#    'candidate_office_full': None,
#    'conduit_committee_city': None,
#    'back_reference_transaction_id': None,
#    'contribution_receipt_amount': 500.0,
#    'back_reference_schedule_name': None,
#    'image_number': '201904079146047001',
#    'conduit_committee_id': None,
#    'report_type': 'Q1',
#    'conduit_committee_name': None,
#    'file_number': 1322783,
#    'contribution_receipt_date': '2019-01-25T00:00:00',
#    'national_committee_nonfederal_account': None,
#    'contributor_state': 'NV',
#    'conduit_committee_street1': None,
#    'sub_id': '4040820191646013022',
#    'pdf_url': 'http://docquery.fec.gov/cgi-bin/fecimg/?201904079146047001',
#    'recipient_committee_type': 'S',
#    'fec_election_year': '2020',
#    'contributor_middle_name': None,
#    'report_year': 2019,
#    'line_number_label': 'Contributions From Individuals/Persons Other Than Political Committees',
#    'contributor_occupation': 'RETIRED',
#    'link_id': 4040720191646004836}],
#  'pagination': {'last_indexes': {'last_index': '4040820191646013022',
#    'last_contribution_receipt_date': '2019-01-25T00:00:00'},
#   'pages': 9,
#   'count': 859,
#   'per_page': 100}}

# %%
test_index = 4040820191646013022

#Add last_index and date to query
querydict = {'per_page':'100'
             ,'committee_id':comm_id['committee_id']
             ,'sort':'contribution_receipt_date'
             ,'api_key':config.api_key
             ,'is_individual':'true'
             ,'two_year_transaction_period':period
             ,'last_index':test_index
             ,'last_contribution_receipt_date':last_date
      }

result = requests.get('https://api.open.fec.gov/v1/schedules/schedule_a/',params=querydict).json()
# Out:
# {'api_version': '1.0',
#  'results': [{'candidate_last_name': None,
#    'candidate_middle_name': None,
#    'sub_id': '4040820191646013039',
#    'amendment_indicator_desc': 'ADD',
#    'contributor_last_name': 'DICKERSON',
#    'line_number': '11AI',
#    'link_id': 4040720191646004836,
#    'report_year': 2019,
#    'candidate_office_state': None,
#    'schedule_type_full': 'ITEMIZED RECEIPTS',
#    'candidate_office_state_full': None,
#    'schedule_type': 'SA',
#    'line_number_label': 'Contributions From Individuals/Persons Other Than Political Committees',
#    'committee_name': None,
#    'candidate_prefix': None,
#    'fec_election_year': '2020',
#    'memo_code_full': None,
#    'contributor_zip': '770053714',
#    'conduit_committee_street2': None,
#    'transaction_id': 'AC1C778FAA9F947FCB5B',
#    'conduit_committee_zip': None,
#    'receipt_type_full': None,
#    'contributor_name': 'DICKERSON, LAWRENCE',
#    'filing_form': 'F3',
#    'unused_contbr_id': None,
#    'memo_code': None,
#    'candidate_office_district': None,
#    'contributor': None,
#    'committee_id': 'C00314575',
#    'candidate_office_full': None,
#    'candidate_office': None,
#    'conduit_committee_state': None,
#    'receipt_type_desc': 'CONTRIBUTION',
#    'election_type_full': None,
#    'memo_text': None,
#    'contribution_receipt_amount': 100.0,
#    'donor_committee_name': None,
#    'contributor_street_2': None,
#    'conduit_committee_street1': None,
#    'amendment_indicator': 'A',
#    'candidate_suffix': None,
#    'load_date': '2019-04-09T02:42:36.720000+00:00',
#    'contributor_state': 'TX',
#    'file_number': 1322783,
#    'contributor_employer': 'RETIRED',
#    'contributor_city': 'HOUSTON',
#    'recipient_committee_type': 'S',
#    'conduit_committee_id': None,
#    'pdf_url': 'http://docquery.fec.gov/cgi-bin/fecimg/?201904079146047007',
#    'election_type': 'P2020',
#    'committee': {'filing_frequency': 'Q',
#     'cycle': 2020,
#     'committee_type': 'S',
#     'organization_type': None,
#     'organization_type_full': None,
#     'designation': 'P',
#     'committee_id': 'C00314575',
#     'street_1': 'PO BOX 1096',
#     'state_full': 'Maine',
#     'zip': '04402',
#     'name': 'COLLINS FOR SENATOR',
#     'state': 'ME',
#     'street_2': None,
#     'party_full': 'REPUBLICAN PARTY',
#     'designation_full': 'Principal campaign committee',
#     'treasurer_name': 'MCCANDLESS, ELIZABETH T.',
#     'candidate_ids': ['S6ME00159'],
#     'cycles': [1996,
#      1998,
#      2000,
#      2002,
#      2004,
#      2006,
#      2008,
#      2010,
#      2012,
#      2014,
#      2016,
#      2018,
#      2020],
#     'city': 'BANGOR',
#     'committee_type_full': 'Senate',
#     'party': 'REP'},
#    'entity_type_desc': 'INDIVIDUAL',
#    'two_year_transaction_period': 2020,
#    'contributor_prefix': None,
#    'contributor_first_name': 'LAWRENCE',
#    'back_reference_transaction_id': None,
#    'contributor_middle_name': None,
#    'image_number': '201904079146047007',
#    'contributor_occupation': 'RETIRED',
#    'contributor_aggregate_ytd': 400.0,
#    'memoed_subtotal': False,
#    'entity_type': 'IND',
#    'contributor_suffix': None,
#    'contribution_receipt_date': '2019-01-25T00:00:00',
#    'back_reference_schedule_name': None,
#    'candidate_id': None,
#    'is_individual': True,
#    'fec_election_type_desc': 'PRIMARY',
#    'contributor_id': None,
#    'receipt_type': '15',
#    'increased_limit': None,
#    'conduit_committee_name': None,
#    'contributor_street_1': '3704 FARBER ST',
#    'candidate_first_name': None,
#    'conduit_committee_city': None,
#    'candidate_name': None,
#    'original_sub_id': None,
#    'national_committee_nonfederal_account': None,
#    'report_type': 'Q1'},
#   {'candidate_last_name': None,
#    'candidate_middle_name': None,
#    'sub_id': '4040820191646013082',
#    'amendment_indicator_desc': 'ADD',
#    'contributor_last_name': 'FANLO',
#    'line_number': '11AI',
#    'link_id': 4040720191646004836,
#    'report_year': 2019,
#    'candidate_office_state': None,
#    'schedule_type_full': 'ITEMIZED RECEIPTS',
#    'candidate_office_state_full': None,
#    'schedule_type': 'SA',
#    'line_number_label': 'Contributions From Individuals/Persons Other Than Political Committees',
#    'committee_name': None,
#    'candidate_prefix': None,
#    'fec_election_year': '2020',
#    'memo_code_full': None,
#    'contributor_zip': '941056657',
#    'conduit_committee_street2': None,
#    'transaction_id': 'AC89769045D39476184F',
#    'conduit_committee_zip': None,
#    'receipt_type_full': None,
#    'contributor_name': 'FANLO, NINO',
#    'filing_form': 'F3',
#    'unused_contbr_id': None,
#    'memo_code': None,
#    'candidate_office_district': None,
#    'contributor': None,
#    'committee_id': 'C00314575',
#    'candidate_office_full': None,
#    'candidate_office': None,
#    'conduit_committee_state': None,
#    'receipt_type_desc': 'CONTRIBUTION',
#    'election_type_full': None,
#    'memo_text': None,
#    'contribution_receipt_amount': 100.0,
#    'donor_committee_name': None,
#    'contributor_street_2': 'APT 57C',
#    'conduit_committee_street1': None,
#    'amendment_indicator': 'A',
#    'candidate_suffix': None,
#    'load_date': '2019-04-09T02:42:36.737000+00:00',
#    'contributor_state': 'CA',
#    'file_number': 1322783,
#    'contributor_employer': 'RETIRED',
#    'contributor_city': 'SAN FRANCISCO',
#    'recipient_committee_type': 'S',
#    'conduit_committee_id': None,
#    'pdf_url': 'http://docquery.fec.gov/cgi-bin/fecimg/?201904079146047021',
#    'election_type': 'P2020',
#    'committee': {'filing_frequency': 'Q',
#     'cycle': 2020,
#     'committee_type': 'S',
#     'organization_type': None,
#     'organization_type_full': None,
#     'designation': 'P',
#     'committee_id': 'C00314575',
#     'street_1': 'PO BOX 1096',
#     'state_full': 'Maine',
#     'zip': '04402',
#     'name': 'COLLINS FOR SENATOR',
#     'state': 'ME',
#     'street_2': None,
#     'party_full': 'REPUBLICAN PARTY',
#     'designation_full': 'Principal campaign committee',
#     'treasurer_name': 'MCCANDLESS, ELIZABETH T.',
#     'candidate_ids': ['S6ME00159'],
#     'cycles': [1996,
#      1998,
#      2000,
#      2002,
#      2004,
#      2006,
#      2008,
#      2010,
#      2012,
#      2014,
#      2016,
#      2018,
#      2020],
#     'city': 'BANGOR',
#     'committee_type_full': 'Senate',
#     'party': 'REP'},
#    'entity_type_desc': 'INDIVIDUAL',
#    'two_year_transaction_period': 2020,
#    'contributor_prefix': None,
#    'contributor_first_name': 'NINO',
#    'back_reference_transaction_id': None,
#    'contributor_middle_name': None,
#    'image_number': '201904079146047021',
#    'contributor_occupation': 'RETIRED',
#    'contributor_aggregate_ytd': 400.0,
#    'memoed_subtotal': False,
#    'entity_type': 'IND',
#    'contributor_suffix': None,
#    'contribution_receipt_date': '2019-01-25T00:00:00',
#    'back_reference_schedule_name': None,
#    'candidate_id': None,
#    'is_individual': True,
#    'fec_election_type_desc': 'PRIMARY',
#    'contributor_id': None,
#    'receipt_type': '15',
#    'increased_limit': None,
#    'conduit_committee_name': None,
#    'contributor_street_1': '301 MISSION ST',
#    'candidate_first_name': None,
#    'conduit_committee_city': None,
#    'candidate_name': None,
#    'original_sub_id': None,
#    'national_committee_nonfederal_account': None,
#    'report_type': 'Q1'},
#   {'candidate_last_name': None,
#    'candidate_middle_name': None,
#    'sub_id': '4040820191646013115',
#    'amendment_indicator_desc': 'ADD',
#    'contributor_last_name': 'FREISTEDT',
#    'line_number': '11AI',
#    'link_id': 4040720191646004836,
#    'report_year': 2019,
#    'candidate_office_state': None,
#    'schedule_type_full': 'ITEMIZED RECEIPTS',
#    'candidate_office_state_full': None,
#    'schedule_type': 'SA',
#    'line_number_label': 'Contributions From Individuals/Persons Other Than Political Committees',
#    'committee_name': None,
#    'candidate_prefix': None,
#    'fec_election_year': '2020',
#    'memo_code_full': None,
#    'contributor_zip': '921193048',
#    'conduit_committee_street2': None,
#    'transaction_id': 'A280B235C4F5B43DDA6A',
#    'conduit_committee_zip': None,
#    'receipt_type_full': None,
#    'contributor_name': 'FREISTEDT, ROBERT',
#    'filing_form': 'F3',
#    'unused_contbr_id': None,
#    'memo_code': None,
#    'candidate_office_district': None,
#    'contributor': None,
#    'committee_id': 'C00314575',
#    'candidate_office_full': None,
#    'candidate_office': None,
#    'conduit_committee_state': None,
#    'receipt_type_desc': 'CONTRIBUTION',
#    'election_type_full': None,
#    'memo_text': None,
#    'contribution_receipt_amount': 50.0,
#    'donor_committee_name': None,
#    'contributor_street_2': None,
#    'conduit_committee_street1': None,
#    'amendment_indicator': 'A',
#    'candidate_suffix': None,
#    'load_date': '2019-04-09T02:42:36.751000+00:00',
#    'contributor_state': 'CA',
#    'file_number': 1322783,
#    'contributor_employer': 'RETIRED',
#    'contributor_city': 'SAN DIEGO',
#    'recipient_committee_type': 'S',
#    'conduit_committee_id': None,
#    'pdf_url': 'http://docquery.fec.gov/cgi-bin/fecimg/?201904079146047032',
#    'election_type': 'P2020',
#    'committee': {'filing_frequency': 'Q',
#     'cycle': 2020,
#     'committee_type': 'S',
#     'organization_type': None,
#     'organization_type_full': None,
#     'designation': 'P',
#     'committee_id': 'C00314575',
#     'street_1': 'PO BOX 1096',
#     'state_full': 'Maine',
#     'zip': '04402',
#     'name': 'COLLINS FOR SENATOR',
#     'state': 'ME',
#     'street_2': None,
#     'party_full': 'REPUBLICAN PARTY',
#     'designation_full': 'Principal campaign committee',
#     'treasurer_name': 'MCCANDLESS, ELIZABETH T.',
#     'candidate_ids': ['S6ME00159'],
#     'cycles': [1996,
#      1998,
#      2000,
#      2002,
#      2004,
#      2006,
#      2008,
#      2010,
#      2012,
#      2014,
#      2016,
#      2018,
#      2020],
#     'city': 'BANGOR',
#     'committee_type_full': 'Senate',
#     'party': 'REP'},
#    'entity_type_desc': 'INDIVIDUAL',
#    'two_year_transaction_period': 2020,
#    'contributor_prefix': None,
#    'contributor_first_name': 'ROBERT',
#    'back_reference_transaction_id': None,
#    'contributor_middle_name': None,
#    'image_number': '201904079146047032',
#    'contributor_occupation': 'RETIRED',
#    'contributor_aggregate_ytd': 250.0,
#    'memoed_subtotal': False,
#    'entity_type': 'IND',
#    'contributor_suffix': None,
#    'contribution_receipt_date': '2019-01-25T00:00:00',
#    'back_reference_schedule_name': None,
#    'candidate_id': None,
#    'is_individual': True,
#    'fec_election_type_desc': 'PRIMARY',
#    'contributor_id': None,
#    'receipt_type': '15',
#    'increased_limit': None,
#    'conduit_committee_name': None,
#    'contributor_street_1': '7772 TOPAZ LAKE AVE',
#    'candidate_first_name': None,
#    'conduit_committee_city': None,
#    'candidate_name': None,
#    'original_sub_id': None,
#    'national_committee_nonfederal_account': None,
#    'report_type': 'Q1'},
#   {'candidate_last_name': None,
#    'candidate_middle_name': None,
#    'sub_id': '4040820191646013134',
#    'amendment_indicator_desc': 'ADD',
#    'contributor_last_name': 'GAREAU',
#    'line_number': '11AI',
#    'link_id': 4040720191646004836,
#    'report_year': 2019,
#    'candidate_office_state': None,
#    'schedule_type_full': 'ITEMIZED RECEIPTS',
#    'candidate_office_state_full': None,
#    'schedule_type': 'SA',
#    'line_number_label': 'Contributions From Individuals/Persons Other Than Political Committees',
#    'committee_name': None,
#    'candidate_prefix': None,
#    'fec_election_year': '2020',
#    'memo_code_full': None,
#    'contributor_zip': '299104976',
#    'conduit_committee_street2': None,
#    'transaction_id': 'AFDAAA9D1244C4274AE0',
#    'conduit_committee_zip': None,
#    'receipt_type_full': None,
#    'contributor_name': 'GAREAU, JOSEPH',
#    'filing_form': 'F3',
#    'unused_contbr_id': None,
#    'memo_code': None,
#    'candidate_office_district': None,
#    'contributor': None,
#    'committee_id': 'C00314575',
#    'candidate_office_full': None,
#    'candidate_office': None,
#    'conduit_committee_state': None,
#    'receipt_type_desc': None,
#    'election_type_full': None,
#    'memo_text': None,
#    'contribution_receipt_amount': 50.0,
#    'donor_committee_name': None,
#    'contributor_street_2': None,
#    'conduit_committee_street1': None,
#    'amendment_indicator': 'A',
#    'candidate_suffix': None,
#    'load_date': '2019-04-09T02:42:36.758000+00:00',
#    'contributor_state': 'SC',
#    'file_number': 1322783,
#    'contributor_employer': 'RETIRED',
#    'contributor_city': 'BLUFFTON',
#    'recipient_committee_type': 'S',
#    'conduit_committee_id': None,
#    'pdf_url': 'http://docquery.fec.gov/cgi-bin/fecimg/?201904079146047038',
#    'election_type': 'P2020',
#    'committee': {'filing_frequency': 'Q',
#     'cycle': 2020,
#     'committee_type': 'S',
#     'organization_type': None,
#     'organization_type_full': None,
#     'designation': 'P',
#     'committee_id': 'C00314575',
#     'street_1': 'PO BOX 1096',
#     'state_full': 'Maine',
#     'zip': '04402',
#     'name': 'COLLINS FOR SENATOR',
#     'state': 'ME',
#     'street_2': None,
#     'party_full': 'REPUBLICAN PARTY',
#     'designation_full': 'Principal campaign committee',
#     'treasurer_name': 'MCCANDLESS, ELIZABETH T.',
#     'candidate_ids': ['S6ME00159'],
#     'cycles': [1996,
#      1998,
#      2000,
#      2002,
#      2004,
#      2006,
#      2008,
#      2010,
#      2012,
#      2014,
#      2016,
#      2018,
#      2020],
#     'city': 'BANGOR',
#     'committee_type_full': 'Senate',
#     'party': 'REP'},
#    'entity_type_desc': 'INDIVIDUAL',
#    'two_year_transaction_period': 2020,
#    'contributor_prefix': None,
#    'contributor_first_name': 'JOSEPH',
#    'back_reference_transaction_id': None,
#    'contributor_middle_name': None,
#    'image_number': '201904079146047038',
#    'contributor_occupation': 'RETIRED',
#    'contributor_aggregate_ytd': 200.0,
#    'memoed_subtotal': False,
#    'entity_type': 'IND',
#    'contributor_suffix': None,
#    'contribution_receipt_date': '2019-01-25T00:00:00',
#    'back_reference_schedule_name': None,
#    'candidate_id': None,
#    'is_individual': True,
#    'fec_election_type_desc': 'PRIMARY',
#    'contributor_id': None,
#    'receipt_type': None,
#    'increased_limit': None,
#    'conduit_committee_name': None,
#    'contributor_street_1': '121 INVERNESS DR',
#    'candidate_first_name': None,
#    'conduit_committee_city': None,
#    'candidate_name': None,
#    'original_sub_id': None,
#    'national_committee_nonfederal_account': None,
#    'report_type': 'Q1'},
#   {'candidate_last_name': None,
#    'candidate_middle_name': None,
#    'sub_id': '4040820191646013157',
#    'amendment_indicator_desc': 'ADD',
#    'contributor_last_name': 'GLENN',
#    'line_number': '11AI',
#    'link_id': 4040720191646004836,
#    'report_year': 2019,
#    'candidate_office_state': None,
#    'schedule_type_full': 'ITEMIZED RECEIPTS',
#    'candidate_office_state_full': None,
#    'schedule_type': 'SA',
#    'line_number_label': 'Contributions From Individuals/Persons Other Than Political Committees',
#    'committee_name': None,
#    'candidate_prefix': None,
#    'fec_election_year': '2020',
#    'memo_code_full': None,
#    'contributor_zip': '082211137',
#    'conduit_committee_street2': None,
#    'transaction_id': 'A9789D8329FB84C3A976',
#    'conduit_committee_zip': None,
#    'receipt_type_full': None,
#    'contributor_name': 'GLENN, THOMAS',
#    'filing_form': 'F3',
#    'unused_contbr_id': None,
#    'memo_code': None,
#    'candidate_office_district': None,
#    'contributor': None,
#    'committee_id': 'C00314575',
#    'candidate_office_full': None,
#    'candidate_office': None,
#    'conduit_committee_state': None,
#    'receipt_type_desc': 'CONTRIBUTION',
#    'election_type_full': None,
#    'memo_text': None,
#    'contribution_receipt_amount': 100.0,
#    'donor_committee_name': None,
#    'contributor_street_2': None,
#    'conduit_committee_street1': None,
#    'amendment_indicator': 'A',
#    'candidate_suffix': None,
#    'load_date': '2019-04-09T02:42:36.768000+00:00',
#    'contributor_state': 'NJ',
#    'file_number': 1322783,
#    'contributor_employer': 'GLENN INSURANCE INC',
#    'contributor_city': 'LINWOOD',
#    'recipient_committee_type': 'S',
#    'conduit_committee_id': None,
#    'pdf_url': 'http://docquery.fec.gov/cgi-bin/fecimg/?201904079146047046',
#    'election_type': 'P2020',
#    'committee': {'filing_frequency': 'Q',
#     'cycle': 2020,
#     'committee_type': 'S',
#     'organization_type': None,
#     'organization_type_full': None,
#     'designation': 'P',
#     'committee_id': 'C00314575',
#     'street_1': 'PO BOX 1096',
#     'state_full': 'Maine',
#     'zip': '04402',
#     'name': 'COLLINS FOR SENATOR',
#     'state': 'ME',
#     'street_2': None,
#     'party_full': 'REPUBLICAN PARTY',
#     'designation_full': 'Principal campaign committee',
#     'treasurer_name': 'MCCANDLESS, ELIZABETH T.',
#     'candidate_ids': ['S6ME00159'],
#     'cycles': [1996,
#      1998,
#      2000,
#      2002,
#      2004,
#      2006,
#      2008,
#      2010,
#      2012,
#      2014,
#      2016,
#      2018,
#      2020],
#     'city': 'BANGOR',
#     'committee_type_full': 'Senate',
#     'party': 'REP'},
#    'entity_type_desc': 'INDIVIDUAL',
#    'two_year_transaction_period': 2020,
#    'contributor_prefix': None,
#    'contributor_first_name': 'THOMAS',
#    'back_reference_transaction_id': None,
#    'contributor_middle_name': None,
#    'image_number': '201904079146047046',
#    'contributor_occupation': 'INSURANCE AGENT',
#    'contributor_aggregate_ytd': 400.0,
#    'memoed_subtotal': False,
#    'entity_type': 'IND',
#    'contributor_suffix': None,
#    'contribution_receipt_date': '2019-01-25T00:00:00',
#    'back_reference_schedule_name': None,
#    'candidate_id': None,
#    'is_individual': True,
#    'fec_election_type_desc': 'PRIMARY',
#    'contributor_id': None,
#    'receipt_type': '15',
#    'increased_limit': None,
#    'conduit_committee_name': None,
#    'contributor_street_1': '1011 BARTLETT AVE',
#    'candidate_first_name': None,
#    'conduit_committee_city': None,
#    'candidate_name': None,
#    'original_sub_id': None,
#    'national_committee_nonfederal_account': None,
#    'report_type': 'Q1'},
#   {'candidate_last_name': None,
#    'candidate_middle_name': None,
#    'sub_id': '4040820191646013179',
#    'amendment_indicator_desc': 'ADD',
#    'contributor_last_name': 'HARRIS',
#    'line_number': '11AI',
#    'link_id': 4040720191646004836,
#    'report_year': 2019,
#    'candidate_office_state': None,
#    'schedule_type_full': 'ITEMIZED RECEIPTS',
#    'candidate_office_state_full': None,
#    'schedule_type': 'SA',
#    'line_number_label': 'Contributions From Individuals/Persons Other Than Political Committees',
#    'committee_name': None,
#    'candidate_prefix': None,
#    'fec_election_year': '2020',
#    'memo_code_full': None,
#    'contributor_zip': '121865324',
#    'conduit_committee_street2': None,
#    'transaction_id': 'AB9B3C7DCE9E748F6BC1',
#    'conduit_committee_zip': None,
#    'receipt_type_full': None,
#    'contributor_name': 'HARRIS, JIM SR.',
#    'filing_form': 'F3',
#    'unused_contbr_id': None,
#    'memo_code': None,
#    'candidate_office_district': None,
#    'contributor': None,
#    'committee_id': 'C00314575',
#    'candidate_office_full': None,
#    'candidate_office': None,
#    'conduit_committee_state': None,
#    'receipt_type_desc': 'CONTRIBUTION',
#    'election_type_full': None,
#    'memo_text': None,
#    'contribution_receipt_amount': 250.0,
#    'donor_committee_name': None,
#    'contributor_street_2': None,
#    'conduit_committee_street1': None,
#    'amendment_indicator': 'A',
#    'candidate_suffix': None,
#    'load_date': '2019-04-09T02:42:36.772000+00:00',
#    'contributor_state': 'NY',
#    'file_number': 1322783,
#    'contributor_employer': 'JANITRONICS INC',
#    'contributor_city': 'VOORHEESVILLE',
#    'recipient_committee_type': 'S',
#    'conduit_committee_id': None,
#    'pdf_url': 'http://docquery.fec.gov/cgi-bin/fecimg/?201904079146047053',
#    'election_type': 'P2020',
#    'committee': {'filing_frequency': 'Q',
#     'cycle': 2020,
#     'committee_type': 'S',
#     'organization_type': None,
#     'organization_type_full': None,
#     'designation': 'P',
#     'committee_id': 'C00314575',
#     'street_1': 'PO BOX 1096',
#     'state_full': 'Maine',
#     'zip': '04402',
#     'name': 'COLLINS FOR SENATOR',
#     'state': 'ME',
#     'street_2': None,
#     'party_full': 'REPUBLICAN PARTY',
#     'designation_full': 'Principal campaign committee',
#     'treasurer_name': 'MCCANDLESS, ELIZABETH T.',
#     'candidate_ids': ['S6ME00159'],
#     'cycles': [1996,
#      1998,
#      2000,
#      2002,
#      2004,
#      2006,
#      2008,
#      2010,
#      2012,
#      2014,
#      2016,
#      2018,
#      2020],
#     'city': 'BANGOR',
#     'committee_type_full': 'Senate',
#     'party': 'REP'},
#    'entity_type_desc': 'INDIVIDUAL',
#    'two_year_transaction_period': 2020,
#    'contributor_prefix': None,
#    'contributor_first_name': 'JIM',
#    'back_reference_transaction_id': None,
#    'contributor_middle_name': None,
#    'image_number': '201904079146047053',
#    'contributor_occupation': 'BUSINESS OWNER',
#    'contributor_aggregate_ytd': 1000.0,
#    'memoed_subtotal': False,
#    'entity_type': 'IND',
#    'contributor_suffix': 'SR.',
#    'contribution_receipt_date': '2019-01-25T00:00:00',
#    'back_reference_schedule_name': None,
#    'candidate_id': None,
#    'is_individual': True,
#    'fec_election_type_desc': 'PRIMARY',
#    'contributor_id': None,
#    'receipt_type': '15',
#    'increased_limit': None,
#    'conduit_committee_name': None,
#    'contributor_street_1': '201 WORMER RD',
#    'candidate_first_name': None,
#    'conduit_committee_city': None,
#    'candidate_name': None,
#    'original_sub_id': None,
#    'national_committee_nonfederal_account': None,
#    'report_type': 'Q1'},
#   {'candidate_last_name': None,
#    'candidate_middle_name': None,
#    'sub_id': '4040820191646013225',
#    'amendment_indicator_desc': 'ADD',
#    'contributor_last_name': 'HOWARD',
#    'line_number': '11AI',
#    'link_id': 4040720191646004836,
#    'report_year': 2019,
#    'candidate_office_state': None,
#    'schedule_type_full': 'ITEMIZED RECEIPTS',
#    'candidate_office_state_full': None,
#    'schedule_type': 'SA',
#    'line_number_label': 'Contributions From Individuals/Persons Other Than Political Committees',
#    'committee_name': None,
#    'candidate_prefix': None,
#    'fec_election_year': '2020',
#    'memo_code_full': None,
#    'contributor_zip': '189381122',
#    'conduit_committee_street2': None,
#    'transaction_id': 'AADD9C48ECDD44E7DBC0',
#    'conduit_committee_zip': None,
#    'receipt_type_full': None,
#    'contributor_name': 'HOWARD, LOIS',
#    'filing_form': 'F3',
#    'unused_contbr_id': None,
#    'memo_code': None,
#    'candidate_office_district': None,
#    'contributor': None,
#    'committee_id': 'C00314575',
#    'candidate_office_full': None,
#    'candidate_office': None,
#    'conduit_committee_state': None,
#    'receipt_type_desc': None,
#    'election_type_full': None,
#    'memo_text': None,
#    'contribution_receipt_amount': 50.0,
#    'donor_committee_name': None,
#    'contributor_street_2': None,
#    'conduit_committee_street1': None,
#    'amendment_indicator': 'A',
#    'candidate_suffix': None,
#    'load_date': '2019-04-09T02:42:36.780000+00:00',
#    'contributor_state': 'PA',
#    'file_number': 1322783,
#    'contributor_employer': 'RETIRED',
#    'contributor_city': 'NEW HOPE',
#    'recipient_committee_type': 'S',
#    'conduit_committee_id': None,
#    'pdf_url': 'http://docquery.fec.gov/cgi-bin/fecimg/?201904079146047069',
#    'election_type': 'P2020',
#    'committee': {'filing_frequency': 'Q',
#     'cycle': 2020,
#     'committee_type': 'S',
#     'organization_type': None,
#     'organization_type_full': None,
#     'designation': 'P',
#     'committee_id': 'C00314575',
#     'street_1': 'PO BOX 1096',
#     'state_full': 'Maine',
#     'zip': '04402',
#     'name': 'COLLINS FOR SENATOR',
#     'state': 'ME',
#     'street_2': None,
#     'party_full': 'REPUBLICAN PARTY',
#     'designation_full': 'Principal campaign committee',
#     'treasurer_name': 'MCCANDLESS, ELIZABETH T.',
#     'candidate_ids': ['S6ME00159'],
#     'cycles': [1996,
#      1998,
#      2000,
#      2002,
#      2004,
#      2006,
#      2008,
#      2010,
#      2012,
#      2014,
#      2016,
#      2018,
#      2020],
#     'city': 'BANGOR',
#     'committee_type_full': 'Senate',
#     'party': 'REP'},
#    'entity_type_desc': 'INDIVIDUAL',
#    'two_year_transaction_period': 2020,
#    'contributor_prefix': None,
#    'contributor_first_name': 'LOIS',
#    'back_reference_transaction_id': None,
#    'contributor_middle_name': None,
#    'image_number': '201904079146047069',
#    'contributor_occupation': 'RETIRED',
#    'contributor_aggregate_ytd': 200.0,
#    'memoed_subtotal': False,
#    'entity_type': 'IND',
#    'contributor_suffix': None,
#    'contribution_receipt_date': '2019-01-25T00:00:00',
#    'back_reference_schedule_name': None,
#    'candidate_id': None,
#    'is_individual': True,
#    'fec_election_type_desc': 'PRIMARY',
#    'contributor_id': None,
#    'receipt_type': None,
#    'increased_limit': None,
#    'conduit_committee_name': None,
#    'contributor_street_1': '35 SOLEBURY MOUNTAIN RD',
#    'candidate_first_name': None,
#    'conduit_committee_city': None,
#    'candidate_name': None,
#    'original_sub_id': None,
#    'national_committee_nonfederal_account': None,
#    'report_type': 'Q1'},
#   {'candidate_last_name': None,
#    'candidate_middle_name': None,
#    'sub_id': '4040820191646013255',
#    'amendment_indicator_desc': 'ADD',
#    'contributor_last_name': 'JOHNSON',
#    'line_number': '11AI',
#    'link_id': 4040720191646004836,
#    'report_year': 2019,
#    'candidate_office_state': None,
#    'schedule_type_full': 'ITEMIZED RECEIPTS',
#    'candidate_office_state_full': None,
#    'schedule_type': 'SA',
#    'line_number_label': 'Contributions From Individuals/Persons Other Than Political Committees',
#    'committee_name': None,
#    'candidate_prefix': None,
#    'fec_election_year': '2020',
#    'memo_code_full': None,
#    'contributor_zip': '494569110',
#    'conduit_committee_street2': None,
#    'transaction_id': 'A6917801701764472B28',
#    'conduit_committee_zip': None,
#    'receipt_type_full': None,
#    'contributor_name': 'JOHNSON, PHIL',
#    'filing_form': 'F3',
#    'unused_contbr_id': None,
#    'memo_code': None,
#    'candidate_office_district': None,
#    'contributor': None,
#    'committee_id': 'C00314575',
#    'candidate_office_full': None,
#    'candidate_office': None,
#    'conduit_committee_state': None,
#    'receipt_type_desc': 'CONTRIBUTION',
#    'election_type_full': None,
#    'memo_text': None,
#    'contribution_receipt_amount': 100.0,
#    'donor_committee_name': None,
#    'contributor_street_2': None,
#    'conduit_committee_street1': None,
#    'amendment_indicator': 'A',
#    'candidate_suffix': None,
#    'load_date': '2019-04-09T02:42:36.785000+00:00',
#    'contributor_state': 'MI',
#    'file_number': 1322783,
#    'contributor_employer': 'VAPROSHIELD',
#    'contributor_city': 'SPRING LAKE',
#    'recipient_committee_type': 'S',
#    'conduit_committee_id': None,
#    'pdf_url': 'http://docquery.fec.gov/cgi-bin/fecimg/?201904079146047079',
#    'election_type': 'P2020',
#    'committee': {'filing_frequency': 'Q',
#     'cycle': 2020,
#     'committee_type': 'S',
#     'organization_type': None,
#     'organization_type_full': None,
#     'designation': 'P',
#     'committee_id': 'C00314575',
#     'street_1': 'PO BOX 1096',
#     'state_full': 'Maine',
#     'zip': '04402',
#     'name': 'COLLINS FOR SENATOR',
#     'state': 'ME',
#     'street_2': None,
#     'party_full': 'REPUBLICAN PARTY',
#     'designation_full': 'Principal campaign committee',
#     'treasurer_name': 'MCCANDLESS, ELIZABETH T.',
#     'candidate_ids': ['S6ME00159'],
#     'cycles': [1996,
#      1998,
#      2000,
#      2002,
#      2004,
#      2006,
#      2008,
#      2010,
#      2012,
#      2014,
#      2016,
#      2018,
#      2020],
#     'city': 'BANGOR',
#     'committee_type_full': 'Senate',
#     'party': 'REP'},
#    'entity_type_desc': 'INDIVIDUAL',
#    'two_year_transaction_period': 2020,
#    'contributor_prefix': None,
#    'contributor_first_name': 'PHIL',
#    'back_reference_transaction_id': None,
#    'contributor_middle_name': None,
#    'image_number': '201904079146047079',
#    'contributor_occupation': 'EXECUTIVE',
#    'contributor_aggregate_ytd': 500.0,
#    'memoed_subtotal': False,
#    'entity_type': 'IND',
#    'contributor_suffix': None,
#    'contribution_receipt_date': '2019-01-25T00:00:00',
#    'back_reference_schedule_name': None,
#    'candidate_id': None,
#    'is_individual': True,
#    'fec_election_type_desc': 'PRIMARY',
#    'contributor_id': None,
#    'receipt_type': '15',
#    'increased_limit': None,
#    'conduit_committee_name': None,
#    'contributor_street_1': '17397 N SHORE ESTATES RD',
#    'candidate_first_name': None,
#    'conduit_committee_city': None,
#    'candidate_name': None,
#    'original_sub_id': None,
#    'national_committee_nonfederal_account': None,
#    'report_type': 'Q1'},
#   {'candidate_last_name': None,
#    'candidate_middle_name': None,
#    'sub_id': '4040820191646013279',
#    'amendment_indicator_desc': 'ADD',
#    'contributor_last_name': 'KESSLER',
#    'line_number': '11AI',
#    'link_id': 4040720191646004836,
#    'report_year': 2019,
#    'candidate_office_state': None,
#    'schedule_type_full': 'ITEMIZED RECEIPTS',
#    'candidate_office_state_full': None,
#    'schedule_type': 'SA',
#    'line_number_label': 'Contributions From Individuals/Persons Other Than Political Committees',
#    'committee_name': None,
#    'candidate_prefix': None,
#    'fec_election_year': '2020',
#    'memo_code_full': None,
#    'contributor_zip': '902925968',
#    'conduit_committee_street2': None,
#    'transaction_id': 'A73AF2BDC237D43DBB68',
#    'conduit_committee_zip': None,
#    'receipt_type_full': None,
#    'contributor_name': 'KESSLER, BIRGITTA',
#    'filing_form': 'F3',
#    'unused_contbr_id': None,
#    'memo_code': None,
#    'candidate_office_district': None,
#    'contributor': None,
#    'committee_id': 'C00314575',
#    'candidate_office_full': None,
#    'candidate_office': None,
#    'conduit_committee_state': None,
#    'receipt_type_desc': 'CONTRIBUTION',
#    'election_type_full': None,
#    'memo_text': None,
#    'contribution_receipt_amount': 100.0,
#    'donor_committee_name': None,
#    'contributor_street_2': None,
#    'conduit_committee_street1': None,
#    'amendment_indicator': 'A',
#    'candidate_suffix': None,
#    'load_date': '2019-04-09T02:42:36.790000+00:00',
#    'contributor_state': 'CA',
#    'file_number': 1322783,
#    'contributor_employer': 'RETIRED',
#    'contributor_city': 'MARINA DEL REY',
#    'recipient_committee_type': 'S',
#    'conduit_committee_id': None,
#    'pdf_url': 'http://docquery.fec.gov/cgi-bin/fecimg/?201904079146047087',
#    'election_type': 'P2020',
#    'committee': {'filing_frequency': 'Q',
#     'cycle': 2020,
#     'committee_type': 'S',
#     'organization_type': None,
#     'organization_type_full': None,
#     'designation': 'P',
#     'committee_id': 'C00314575',
#     'street_1': 'PO BOX 1096',
#     'state_full': 'Maine',
#     'zip': '04402',
#     'name': 'COLLINS FOR SENATOR',
#     'state': 'ME',
#     'street_2': None,
#     'party_full': 'REPUBLICAN PARTY',
#     'designation_full': 'Principal campaign committee',
#     'treasurer_name': 'MCCANDLESS, ELIZABETH T.',
#     'candidate_ids': ['S6ME00159'],
#     'cycles': [1996,
#      1998,
#      2000,
#      2002,
#      2004,
#      2006,
#      2008,
#      2010,
#      2012,
#      2014,
#      2016,
#      2018,
#      2020],
#     'city': 'BANGOR',
#     'committee_type_full': 'Senate',
#     'party': 'REP'},
#    'entity_type_desc': 'INDIVIDUAL',
#    'two_year_transaction_period': 2020,
#    'contributor_prefix': None,
#    'contributor_first_name': 'BIRGITTA',
#    'back_reference_transaction_id': None,
#    'contributor_middle_name': None,
#    'image_number': '201904079146047087',
#    'contributor_occupation': 'RETIRED',
#    'contributor_aggregate_ytd': 400.0,
#    'memoed_subtotal': False,
#    'entity_type': 'IND',
#    'contributor_suffix': None,
#    'contribution_receipt_date': '2019-01-25T00:00:00',
#    'back_reference_schedule_name': None,
#    'candidate_id': None,
#    'is_individual': True,
#    'fec_election_type_desc': 'PRIMARY',
#    'contributor_id': None,
#    'receipt_type': '15',
#    'increased_limit': None,
#    'conduit_committee_name': None,
#    'contributor_street_1': '135 ROMA CT',
#    'candidate_first_name': None,
#    'conduit_committee_city': None,
#    'candidate_name': None,
#    'original_sub_id': None,
#    'national_committee_nonfederal_account': None,
#    'report_type': 'Q1'},
#   {'candidate_last_name': None,
#    'candidate_middle_name': None,
#    'sub_id': '4040820191646013315',
#    'amendment_indicator_desc': 'ADD',
#    'contributor_last_name': 'LOMAS',
#    'line_number': '11AI',
#    'link_id': 4040720191646004836,
#    'report_year': 2019,
#    'candidate_office_state': None,
#    'schedule_type_full': 'ITEMIZED RECEIPTS',
#    'candidate_office_state_full': None,
#    'schedule_type': 'SA',
#    'line_number_label': 'Contributions From Individuals/Persons Other Than Political Committees',
#    'committee_name': None,
#    'candidate_prefix': None,
#    'fec_election_year': '2020',
#    'memo_code_full': None,
#    'contributor_zip': '440223392',
#    'conduit_committee_street2': None,
#    'transaction_id': 'A0865815980C7485AA1A',
#    'conduit_committee_zip': None,
#    'receipt_type_full': None,
#    'contributor_name': 'LOMAS, ROBERT',
#    'filing_form': 'F3',
#    'unused_contbr_id': None,
#    'memo_code': None,
#    'candidate_office_district': None,
#    'contributor': None,
#    'committee_id': 'C00314575',
#    'candidate_office_full': None,
#    'candidate_office': None,
#    'conduit_committee_state': None,
#    'receipt_type_desc': 'CONTRIBUTION',
#    'election_type_full': None,
#    'memo_text': None,
#    'contribution_receipt_amount': 100.0,
#    'donor_committee_name': None,
#    'contributor_street_2': None,
#    'conduit_committee_street1': None,
#    'amendment_indicator': 'A',
#    'candidate_suffix': None,
#    'load_date': '2019-04-09T02:42:36.801000+00:00',
#    'contributor_state': 'OH',
#    'file_number': 1322783,
#    'contributor_employer': 'RETIRED',
#    'contributor_city': 'CHAGRIN FALLS',
#    'recipient_committee_type': 'S',
#    'conduit_committee_id': None,
#    'pdf_url': 'http://docquery.fec.gov/cgi-bin/fecimg/?201904079146047099',
#    'election_type': 'P2020',
#    'committee': {'filing_frequency': 'Q',
#     'cycle': 2020,
#     'committee_type': 'S',
#     'organization_type': None,
#     'organization_type_full': None,
#     'designation': 'P',
#     'committee_id': 'C00314575',
#     'street_1': 'PO BOX 1096',
#     'state_full': 'Maine',
#     'zip': '04402',
#     'name': 'COLLINS FOR SENATOR',
#     'state': 'ME',
#     'street_2': None,
#     'party_full': 'REPUBLICAN PARTY',
#     'designation_full': 'Principal campaign committee',
#     'treasurer_name': 'MCCANDLESS, ELIZABETH T.',
#     'candidate_ids': ['S6ME00159'],
#     'cycles': [1996,
#      1998,
#      2000,
#      2002,
#      2004,
#      2006,
#      2008,
#      2010,
#      2012,
#      2014,
#      2016,
#      2018,
#      2020],
#     'city': 'BANGOR',
#     'committee_type_full': 'Senate',
#     'party': 'REP'},
#    'entity_type_desc': 'INDIVIDUAL',
#    'two_year_transaction_period': 2020,
#    'contributor_prefix': None,
#    'contributor_first_name': 'ROBERT',
#    'back_reference_transaction_id': None,
#    'contributor_middle_name': None,
#    'image_number': '201904079146047099',
#    'contributor_occupation': 'RETIRED',
#    'contributor_aggregate_ytd': 400.0,
#    'memoed_subtotal': False,
#    'entity_type': 'IND',
#    'contributor_suffix': None,
#    'contribution_receipt_date': '2019-01-25T00:00:00',
#    'back_reference_schedule_name': None,
#    'candidate_id': None,
#    'is_individual': True,
#    'fec_election_type_desc': 'PRIMARY',
#    'contributor_id': None,
#    'receipt_type': '15',
#    'increased_limit': None,
#    'conduit_committee_name': None,
#    'contributor_street_1': '10 GREY FOX RUN',
#    'candidate_first_name': None,
#    'conduit_committee_city': None,
#    'candidate_name': None,
#    'original_sub_id': None,
#    'national_committee_nonfederal_account': None,
#    'report_type': 'Q1'},
#   {'candidate_last_name': None,
#    'candidate_middle_name': None,
#    'sub_id': '4040820191646013336',
#    'amendment_indicator_desc': 'ADD',
#    'contributor_last_name': 'MAKI',
#    'line_number': '11AI',
#    'link_id': 4040720191646004836,
#    'report_year': 2019,
#    'candidate_office_state': None,
#    'schedule_type_full': 'ITEMIZED RECEIPTS',
#    'candidate_office_state_full': None,
#    'schedule_type': 'SA',
#    'line_number_label': 'Contributions From Individuals/Persons Other Than Political Committees',
#    'committee_name': None,
#    'candidate_prefix': None,
#    'fec_election_year': '2020',
#    'memo_code_full': None,
#    'contributor_zip': '703012627',
#    'conduit_committee_street2': None,
#    'transaction_id': 'A99470A6BF09641C0B17',
#    'conduit_committee_zip': None,
#    'receipt_type_full': None,
#    'contributor_name': 'MAKI, NEIL',
#    'filing_form': 'F3',
#    'unused_contbr_id': None,
#    'memo_code': None,
#    'candidate_office_district': None,
#    'contributor': None,
#    'committee_id': 'C00314575',
#    'candidate_office_full': None,
#    'candidate_office': None,
#    'conduit_committee_state': None,
#    'receipt_type_desc': 'CONTRIBUTION',
#    'election_type_full': None,
#    'memo_text': None,
#    'contribution_receipt_amount': 100.0,
#    'donor_committee_name': None,
#    'contributor_street_2': None,
#    'conduit_committee_street1': None,
#    'amendment_indicator': 'A',
#    'candidate_suffix': None,
#    'load_date': '2019-04-09T02:42:36.807000+00:00',
#    'contributor_state': 'LA',
#    'file_number': 1322783,
#    'contributor_employer': 'THIBODAUX ORTHOPAEDICS',
#    'contributor_city': 'THIBODAUX',
#    'recipient_committee_type': 'S',
#    'conduit_committee_id': None,
#    'pdf_url': 'http://docquery.fec.gov/cgi-bin/fecimg/?201904079146047106',
#    'election_type': 'P2020',
#    'committee': {'filing_frequency': 'Q',
#     'cycle': 2020,
#     'committee_type': 'S',
#     'organization_type': None,
#     'organization_type_full': None,
#     'designation': 'P',
#     'committee_id': 'C00314575',
#     'street_1': 'PO BOX 1096',
#     'state_full': 'Maine',
#     'zip': '04402',
#     'name': 'COLLINS FOR SENATOR',
#     'state': 'ME',
#     'street_2': None,
#     'party_full': 'REPUBLICAN PARTY',
#     'designation_full': 'Principal campaign committee',
#     'treasurer_name': 'MCCANDLESS, ELIZABETH T.',
#     'candidate_ids': ['S6ME00159'],
#     'cycles': [1996,
#      1998,
#      2000,
#      2002,
#      2004,
#      2006,
#      2008,
#      2010,
#      2012,
#      2014,
#      2016,
#      2018,
#      2020],
#     'city': 'BANGOR',
#     'committee_type_full': 'Senate',
#     'party': 'REP'},
#    'entity_type_desc': 'INDIVIDUAL',
#    'two_year_transaction_period': 2020,
#    'contributor_prefix': None,
#    'contributor_first_name': 'NEIL',
#    'back_reference_transaction_id': None,
#    'contributor_middle_name': None,
#    'image_number': '201904079146047106',
#    'contributor_occupation': 'PHYSICIAN',
#    'contributor_aggregate_ytd': 400.0,
#    'memoed_subtotal': False,
#    'entity_type': 'IND',
#    'contributor_suffix': None,
#    'contribution_receipt_date': '2019-01-25T00:00:00',
#    'back_reference_schedule_name': None,
#    'candidate_id': None,
#    'is_individual': True,
#    'fec_election_type_desc': 'PRIMARY',
#    'contributor_id': None,
#    'receipt_type': '15',
#    'increased_limit': None,
#    'conduit_committee_name': None,
#    'contributor_street_1': '525 SAINT MARY ST',
#    'candidate_first_name': None,
#    'conduit_committee_city': None,
#    'candidate_name': None,
#    'original_sub_id': None,
#    'national_committee_nonfederal_account': None,
#    'report_type': 'Q1'},
#   {'candidate_last_name': None,
#    'candidate_middle_name': None,
#    'sub_id': '4040820191646013356',
#    'amendment_indicator_desc': 'ADD',
#    'contributor_last_name': 'MARLOWE',
#    'line_number': '11AI',
#    'link_id': 4040720191646004836,
#    'report_year': 2019,
#    'candidate_office_state': None,
#    'schedule_type_full': 'ITEMIZED RECEIPTS',
#    'candidate_office_state_full': None,
#    'schedule_type': 'SA',
#    'line_number_label': 'Contributions From Individuals/Persons Other Than Political Committees',
#    'committee_name': None,
#    'candidate_prefix': None,
#    'fec_election_year': '2020',
#    'memo_code_full': None,
#    'contributor_zip': '018791070',
#    'conduit_committee_street2': None,
#    'transaction_id': 'A4F423F06190D4119A1D',
#    'conduit_committee_zip': None,
#    'receipt_type_full': None,
#    'contributor_name': 'MARLOWE, PETER',
#    'filing_form': 'F3',
#    'unused_contbr_id': None,
#    'memo_code': None,
#    'candidate_office_district': None,
#    'contributor': None,
#    'committee_id': 'C00314575',
#    'candidate_office_full': None,
#    'candidate_office': None,
#    'conduit_committee_state': None,
#    'receipt_type_desc': None,
#    'election_type_full': None,
#    'memo_text': None,
#    'contribution_receipt_amount': 50.0,
#    'donor_committee_name': None,
#    'contributor_street_2': None,
#    'conduit_committee_street1': None,
#    'amendment_indicator': 'A',
#    'candidate_suffix': None,
#    'load_date': '2019-04-09T02:42:36.813000+00:00',
#    'contributor_state': 'MA',
#    'file_number': 1322783,
#    'contributor_employer': 'SELF',
#    'contributor_city': 'TYNGSBORO',
#    'recipient_committee_type': 'S',
#    'conduit_committee_id': None,
#    'pdf_url': 'http://docquery.fec.gov/cgi-bin/fecimg/?201904079146047112',
#    'election_type': 'P2020',
#    'committee': {'filing_frequency': 'Q',
#     'cycle': 2020,
#     'committee_type': 'S',
#     'organization_type': None,
#     'organization_type_full': None,
#     'designation': 'P',
#     'committee_id': 'C00314575',
#     'street_1': 'PO BOX 1096',
#     'state_full': 'Maine',
#     'zip': '04402',
#     'name': 'COLLINS FOR SENATOR',
#     'state': 'ME',
#     'street_2': None,
#     'party_full': 'REPUBLICAN PARTY',
#     'designation_full': 'Principal campaign committee',
#     'treasurer_name': 'MCCANDLESS, ELIZABETH T.',
#     'candidate_ids': ['S6ME00159'],
#     'cycles': [1996,
#      1998,
#      2000,
#      2002,
#      2004,
#      2006,
#      2008,
#      2010,
#      2012,
#      2014,
#      2016,
#      2018,
#      2020],
#     'city': 'BANGOR',
#     'committee_type_full': 'Senate',
#     'party': 'REP'},
#    'entity_type_desc': 'INDIVIDUAL',
#    'two_year_transaction_period': 2020,
#    'contributor_prefix': None,
#    'contributor_first_name': 'PETER',
#    'back_reference_transaction_id': None,
#    'contributor_middle_name': None,
#    'image_number': '201904079146047112',
#    'contributor_occupation': 'CONSTRUCTION',
#    'contributor_aggregate_ytd': 200.0,
#    'memoed_subtotal': False,
#    'entity_type': 'IND',
#    'contributor_suffix': None,
#    'contribution_receipt_date': '2019-01-25T00:00:00',
#    'back_reference_schedule_name': None,
#    'candidate_id': None,
#    'is_individual': True,
#    'fec_election_type_desc': 'PRIMARY',
#    'contributor_id': None,
#    'receipt_type': None,
#    'increased_limit': None,
#    'conduit_committee_name': None,
#    'contributor_street_1': '440 MIDDLESEX RD',
#    'candidate_first_name': None,
#    'conduit_committee_city': None,
#    'candidate_name': None,
#    'original_sub_id': None,
#    'national_committee_nonfederal_account': None,
#    'report_type': 'Q1'},
#   {'candidate_last_name': None,
#    'candidate_middle_name': None,
#    'sub_id': '4040820191646013361',
#    'amendment_indicator_desc': 'ADD',
#    'contributor_last_name': 'MASS',
#    'line_number': '11AI',
#    'link_id': 4040720191646004836,
#    'report_year': 2019,
#    'candidate_office_state': None,
#    'schedule_type_full': 'ITEMIZED RECEIPTS',
#    'candidate_office_state_full': None,
#    'schedule_type': 'SA',
#    'line_number_label': 'Contributions From Individuals/Persons Other Than Political Committees',
#    'committee_name': None,
#    'candidate_prefix': None,
#    'fec_election_year': '2020',
#    'memo_code_full': None,
#    'contributor_zip': '600501528',
#    'conduit_committee_street2': None,
#    'transaction_id': 'A115F086262FC4A47991',
#    'conduit_committee_zip': None,
#    'receipt_type_full': None,
#    'contributor_name': 'MASS, EDWARD',
#    'filing_form': 'F3',
#    'unused_contbr_id': None,
#    'memo_code': None,
#    'candidate_office_district': None,
#    'contributor': None,
#    'committee_id': 'C00314575',
#    'candidate_office_full': None,
#    'candidate_office': None,
#    'conduit_committee_state': None,
#    'receipt_type_desc': 'CONTRIBUTION',
#    'election_type_full': None,
#    'memo_text': None,
#    'contribution_receipt_amount': 100.0,
#    'donor_committee_name': None,
#    'contributor_street_2': None,
#    'conduit_committee_street1': None,
#    'amendment_indicator': 'A',
#    'candidate_suffix': None,
#    'load_date': '2019-04-09T02:42:36.814000+00:00',
#    'contributor_state': 'IL',
#    'file_number': 1322783,
#    'contributor_employer': 'DIAMOND CORING',
#    'contributor_city': 'MCHENRY',
#    'recipient_committee_type': 'S',
#    'conduit_committee_id': None,
#    'pdf_url': 'http://docquery.fec.gov/cgi-bin/fecimg/?201904079146047114',
#    'election_type': 'P2020',
#    'committee': {'filing_frequency': 'Q',
#     'cycle': 2020,
#     'committee_type': 'S',
#     'organization_type': None,
#     'organization_type_full': None,
#     'designation': 'P',
#     'committee_id': 'C00314575',
#     'street_1': 'PO BOX 1096',
#     'state_full': 'Maine',
#     'zip': '04402',
#     'name': 'COLLINS FOR SENATOR',
#     'state': 'ME',
#     'street_2': None,
#     'party_full': 'REPUBLICAN PARTY',
#     'designation_full': 'Principal campaign committee',
#     'treasurer_name': 'MCCANDLESS, ELIZABETH T.',
#     'candidate_ids': ['S6ME00159'],
#     'cycles': [1996,
#      1998,
#      2000,
#      2002,
#      2004,
#      2006,
#      2008,
#      2010,
#      2012,
#      2014,
#      2016,
#      2018,
#      2020],
#     'city': 'BANGOR',
#     'committee_type_full': 'Senate',
#     'party': 'REP'},
#    'entity_type_desc': 'INDIVIDUAL',
#    'two_year_transaction_period': 2020,
#    'contributor_prefix': None,
#    'contributor_first_name': 'EDWARD',
#    'back_reference_transaction_id': None,
#    'contributor_middle_name': None,
#    'image_number': '201904079146047114',
#    'contributor_occupation': 'ENGINEER',
#    'contributor_aggregate_ytd': 400.0,
#    'memoed_subtotal': False,
#    'entity_type': 'IND',
#    'contributor_suffix': None,
#    'contribution_receipt_date': '2019-01-25T00:00:00',
#    'back_reference_schedule_name': None,
#    'candidate_id': None,
#    'is_individual': True,
#    'fec_election_type_desc': 'PRIMARY',
#    'contributor_id': None,
#    'receipt_type': '15',
#    'increased_limit': None,
#    'conduit_committee_name': None,
#    'contributor_street_1': '4908 MCCULLOM LAKE RD',
#    'candidate_first_name': None,
#    'conduit_committee_city': None,
#    'candidate_name': None,
#    'original_sub_id': None,
#    'national_committee_nonfederal_account': None,
#    'report_type': 'Q1'},
#   {'candidate_last_name': None,
#    'candidate_middle_name': None,
#    'sub_id': '4040820191646013366',
#    'amendment_indicator_desc': 'ADD',
#    'contributor_last_name': 'MCCARREY',
#    'line_number': '11AI',
#    'link_id': 4040720191646004836,
#    'report_year': 2019,
#    'candidate_office_state': None,
#    'schedule_type_full': 'ITEMIZED RECEIPTS',
#    'candidate_office_state_full': None,
#    'schedule_type': 'SA',
#    'line_number_label': 'Contributions From Individuals/Persons Other Than Political Committees',
#    'committee_name': None,
#    'candidate_prefix': None,
#    'fec_election_year': '2020',
#    'memo_code_full': None,
#    'contributor_zip': '995164517',
#    'conduit_committee_street2': None,
#    'transaction_id': 'ACF77730188AC4E48B5E',
#    'conduit_committee_zip': None,
#    'receipt_type_full': None,
#    'contributor_name': 'MCCARREY, DONNA',
#    'filing_form': 'F3',
#    'unused_contbr_id': None,
#    'memo_code': None,
#    'candidate_office_district': None,
#    'contributor': None,
#    'committee_id': 'C00314575',
#    'candidate_office_full': None,
#    'candidate_office': None,
#    'conduit_committee_state': None,
#    'receipt_type_desc': None,
#    'election_type_full': None,
#    'memo_text': None,
#    'contribution_receipt_amount': 50.0,
#    'donor_committee_name': None,
#    'contributor_street_2': None,
#    'conduit_committee_street1': None,
#    'amendment_indicator': 'A',
#    'candidate_suffix': None,
#    'load_date': '2019-04-09T02:42:36.816000+00:00',
#    'contributor_state': 'AK',
#    'file_number': 1322783,
#    'contributor_employer': 'RETIRED',
#    'contributor_city': 'ANCHORAGE',
#    'recipient_committee_type': 'S',
#    'conduit_committee_id': None,
#    'pdf_url': 'http://docquery.fec.gov/cgi-bin/fecimg/?201904079146047116',
#    'election_type': 'P2020',
#    'committee': {'filing_frequency': 'Q',
#     'cycle': 2020,
#     'committee_type': 'S',
#     'organization_type': None,
#     'organization_type_full': None,
#     'designation': 'P',
#     'committee_id': 'C00314575',
#     'street_1': 'PO BOX 1096',
#     'state_full': 'Maine',
#     'zip': '04402',
# ...
#     'designation': 'P',
#     'committee_id': 'C00314575',
#     'street_1': 'PO BOX 1096',
#     'state_full': 'Maine',
#     'zip': '04402',
#     'name': 'COLLINS FOR SENATOR',
#     'state': 'ME',
#     'street_2': None,
#     'party_full': 'REPUBLICAN PARTY',
#     'designation_full': 'Principal campaign committee',
#     'treasurer_name': 'MCCANDLESS, ELIZABETH T.',
#     'candidate_ids': ['S6ME00159'],
#     'cycles': [1996,
#      1998,
#      2000,
#      2002,
#      2004,
#      2006,
#      2008,
#      2010,
#      2012,
#      2014,
#      2016,
#      2018,
#      2020],
#     'city': 'BANGOR',
#     'committee_type_full': 'Senate',
#     'party': 'REP'},
#    'entity_type_desc': 'INDIVIDUAL',
#    'two_year_transaction_period': 2020,
#    'contributor_prefix': None,
#    'contributor_first_name': 'ROBERT',
#    'back_reference_transaction_id': None,
#    'contributor_middle_name': 'L.',
#    'image_number': '201904079146047123',
#    'contributor_occupation': 'FINANCE',
#    'contributor_aggregate_ytd': 5400.0,
#    'memoed_subtotal': False,
#    'entity_type': 'IND',
#    'contributor_suffix': None,
#    'contribution_receipt_date': '2019-02-02T00:00:00',
#    'back_reference_schedule_name': None,
#    'candidate_id': None,
#    'is_individual': True,
#    'fec_election_type_desc': 'GENERAL',
#    'contributor_id': None,
#    'receipt_type': '15',
#    'increased_limit': None,
#    'conduit_committee_name': None,
#    'contributor_street_1': '149 HARBOR RD',
#    'candidate_first_name': None,
#    'conduit_committee_city': None,
#    'candidate_name': None,
#    'original_sub_id': None,
#    'national_committee_nonfederal_account': None,
#    'report_type': 'Q1'},
#   {'candidate_last_name': None,
#    'candidate_middle_name': None,
#    'sub_id': '4040820191646013390',
#    'amendment_indicator_desc': 'ADD',
#    'contributor_last_name': 'MEYER',
#    'line_number': '11AI',
#    'link_id': 4040720191646004836,
#    'report_year': 2019,
#    'candidate_office_state': None,
#    'schedule_type_full': 'ITEMIZED RECEIPTS',
#    'candidate_office_state_full': None,
#    'schedule_type': 'SA',
#    'line_number_label': 'Contributions From Individuals/Persons Other Than Political Committees',
#    'committee_name': None,
#    'candidate_prefix': None,
#    'fec_election_year': '2020',
#    'memo_code_full': None,
#    'contributor_zip': '223092718',
#    'conduit_committee_street2': None,
#    'transaction_id': 'A2B14CFA5C3B74025892',
#    'conduit_committee_zip': None,
#    'receipt_type_full': None,
#    'contributor_name': 'MEYER, DANIEL P.',
#    'filing_form': 'F3',
#    'unused_contbr_id': None,
#    'memo_code': None,
#    'candidate_office_district': None,
#    'contributor': None,
#    'committee_id': 'C00314575',
#    'candidate_office_full': None,
#    'candidate_office': None,
#    'conduit_committee_state': None,
#    'receipt_type_desc': 'CONTRIBUTION',
#    'election_type_full': None,
#    'memo_text': None,
#    'contribution_receipt_amount': 1000.0,
#    'donor_committee_name': None,
#    'contributor_street_2': None,
#    'conduit_committee_street1': None,
#    'amendment_indicator': 'A',
#    'candidate_suffix': None,
#    'load_date': '2019-04-09T02:42:36.822000+00:00',
#    'contributor_state': 'VA',
#    'file_number': 1322783,
#    'contributor_employer': 'THE DUBERSTEIN GROUP',
#    'contributor_city': 'ALEXANDRIA',
#    'recipient_committee_type': 'S',
#    'conduit_committee_id': None,
#    'pdf_url': 'http://docquery.fec.gov/cgi-bin/fecimg/?201904079146047124',
#    'election_type': 'P2020',
#    'committee': {'filing_frequency': 'Q',
#     'cycle': 2020,
#     'committee_type': 'S',
#     'organization_type': None,
#     'organization_type_full': None,
#     'designation': 'P',
#     'committee_id': 'C00314575',
#     'street_1': 'PO BOX 1096',
#     'state_full': 'Maine',
#     'zip': '04402',
#     'name': 'COLLINS FOR SENATOR',
#     'state': 'ME',
#     'street_2': None,
#     'party_full': 'REPUBLICAN PARTY',
#     'designation_full': 'Principal campaign committee',
#     'treasurer_name': 'MCCANDLESS, ELIZABETH T.',
#     'candidate_ids': ['S6ME00159'],
#     'cycles': [1996,
#      1998,
#      2000,
#      2002,
#      2004,
#      2006,
#      2008,
#      2010,
#      2012,
#      2014,
#      2016,
#      2018,
#      2020],
#     'city': 'BANGOR',
#     'committee_type_full': 'Senate',
#     'party': 'REP'},
#    'entity_type_desc': 'INDIVIDUAL',
#    'two_year_transaction_period': 2020,
#    'contributor_prefix': None,
#    'contributor_first_name': 'DANIEL',
#    'back_reference_transaction_id': None,
#    'contributor_middle_name': 'P.',
#    'image_number': '201904079146047124',
#    'contributor_occupation': 'SENIOR VICE PRESIDENT',
#    'contributor_aggregate_ytd': 2000.0,
#    'memoed_subtotal': False,
#    'entity_type': 'IND',
#    'contributor_suffix': None,
#    'contribution_receipt_date': '2019-02-02T00:00:00',
#    'back_reference_schedule_name': None,
#    'candidate_id': None,
#    'is_individual': True,
#    'fec_election_type_desc': 'PRIMARY',
#    'contributor_id': None,
#    'receipt_type': '15',
#    'increased_limit': None,
#    'conduit_committee_name': None,
#    'contributor_street_1': '3900 PICARDY CT',
#    'candidate_first_name': None,
#    'conduit_committee_city': None,
#    'candidate_name': None,
#    'original_sub_id': None,
#    'national_committee_nonfederal_account': None,
#    'report_type': 'Q1'},
#   {'candidate_last_name': None,
#    'candidate_middle_name': None,
#    'sub_id': '4040820191646013415',
#    'amendment_indicator_desc': 'ADD',
#    'contributor_last_name': 'MOE',
#    'line_number': '11AI',
#    'link_id': 4040720191646004836,
#    'report_year': 2019,
#    'candidate_office_state': None,
#    'schedule_type_full': 'ITEMIZED RECEIPTS',
#    'candidate_office_state_full': None,
#    'schedule_type': 'SA',
#    'line_number_label': 'Contributions From Individuals/Persons Other Than Political Committees',
#    'committee_name': None,
#    'candidate_prefix': None,
#    'fec_election_year': '2020',
#    'memo_code_full': None,
#    'contributor_zip': '786439377',
#    'conduit_committee_street2': None,
#    'transaction_id': 'A8E7C2ABB59784D44BB5',
#    'conduit_committee_zip': None,
#    'receipt_type_full': None,
#    'contributor_name': 'MOE, PALMER',
#    'filing_form': 'F3',
#    'unused_contbr_id': None,
#    'memo_code': None,
#    'candidate_office_district': None,
#    'contributor': None,
#    'committee_id': 'C00314575',
#    'candidate_office_full': None,
#    'candidate_office': None,
#    'conduit_committee_state': None,
#    'receipt_type_desc': 'CONTRIBUTION',
#    'election_type_full': None,
#    'memo_text': None,
#    'contribution_receipt_amount': 250.0,
#    'donor_committee_name': None,
#    'contributor_street_2': None,
#    'conduit_committee_street1': None,
#    'amendment_indicator': 'A',
#    'candidate_suffix': None,
#    'load_date': '2019-04-09T02:42:36.830000+00:00',
#    'contributor_state': 'TX',
#    'file_number': 1322783,
#    'contributor_employer': 'RETIRED',
#    'contributor_city': 'SUNRISE BEACH',
#    'recipient_committee_type': 'S',
#    'conduit_committee_id': None,
#    'pdf_url': 'http://docquery.fec.gov/cgi-bin/fecimg/?201904079146047132',
#    'election_type': 'P2020',
#    'committee': {'filing_frequency': 'Q',
#     'cycle': 2020,
#     'committee_type': 'S',
#     'organization_type': None,
#     'organization_type_full': None,
#     'designation': 'P',
#     'committee_id': 'C00314575',
#     'street_1': 'PO BOX 1096',
#     'state_full': 'Maine',
#     'zip': '04402',
#     'name': 'COLLINS FOR SENATOR',
#     'state': 'ME',
#     'street_2': None,
#     'party_full': 'REPUBLICAN PARTY',
#     'designation_full': 'Principal campaign committee',
#     'treasurer_name': 'MCCANDLESS, ELIZABETH T.',
#     'candidate_ids': ['S6ME00159'],
#     'cycles': [1996,
#      1998,
#      2000,
#      2002,
#      2004,
#      2006,
#      2008,
#      2010,
#      2012,
#      2014,
#      2016,
#      2018,
#      2020],
#     'city': 'BANGOR',
#     'committee_type_full': 'Senate',
#     'party': 'REP'},
#    'entity_type_desc': 'INDIVIDUAL',
#    'two_year_transaction_period': 2020,
#    'contributor_prefix': None,
#    'contributor_first_name': 'PALMER',
#    'back_reference_transaction_id': None,
#    'contributor_middle_name': None,
#    'image_number': '201904079146047132',
#    'contributor_occupation': 'RETIRED',
#    'contributor_aggregate_ytd': 250.0,
#    'memoed_subtotal': False,
#    'entity_type': 'IND',
#    'contributor_suffix': None,
#    'contribution_receipt_date': '2019-02-02T00:00:00',
#    'back_reference_schedule_name': None,
#    'candidate_id': None,
#    'is_individual': True,
#    'fec_election_type_desc': 'PRIMARY',
#    'contributor_id': None,
#    'receipt_type': '15',
#    'increased_limit': None,
#    'conduit_committee_name': None,
#    'contributor_street_1': '319 GRANITE SHOALS LANE',
#    'candidate_first_name': None,
#    'conduit_committee_city': None,
#    'candidate_name': None,
#    'original_sub_id': None,
#    'national_committee_nonfederal_account': None,
#    'report_type': 'Q1'},
#   {'candidate_last_name': None,
#    'candidate_middle_name': None,
#    'sub_id': '4040820191646013430',
#    'amendment_indicator_desc': 'ADD',
#    'contributor_last_name': 'NAU',
#    'line_number': '11AI',
#    'link_id': 4040720191646004836,
#    'report_year': 2019,
#    'candidate_office_state': None,
#    'schedule_type_full': 'ITEMIZED RECEIPTS',
#    'candidate_office_state_full': None,
#    'schedule_type': 'SA',
#    'line_number_label': 'Contributions From Individuals/Persons Other Than Political Committees',
#    'committee_name': None,
#    'candidate_prefix': None,
#    'fec_election_year': '2020',
#    'memo_code_full': None,
#    'contributor_zip': '772190130',
#    'conduit_committee_street2': None,
#    'transaction_id': 'ADE6B73A3853B4068ACB',
#    'conduit_committee_zip': None,
#    'receipt_type_full': None,
#    'contributor_name': 'NAU, JOHN L. III',
#    'filing_form': 'F3',
#    'unused_contbr_id': None,
#    'memo_code': None,
#    'candidate_office_district': None,
#    'contributor': None,
#    'committee_id': 'C00314575',
#    'candidate_office_full': None,
#    'candidate_office': None,
#    'conduit_committee_state': None,
#    'receipt_type_desc': 'CONTRIBUTION',
#    'election_type_full': None,
#    'memo_text': None,
#    'contribution_receipt_amount': 2700.0,
#    'donor_committee_name': None,
#    'contributor_street_2': None,
#    'conduit_committee_street1': None,
#    'amendment_indicator': 'A',
#    'candidate_suffix': None,
#    'load_date': '2019-04-09T02:42:36.833000+00:00',
#    'contributor_state': 'TX',
#    'file_number': 1322783,
#    'contributor_employer': 'SILVER EAGLE DISTRIBUTORS',
#    'contributor_city': 'HOUSTON',
#    'recipient_committee_type': 'S',
#    'conduit_committee_id': None,
#    'pdf_url': 'http://docquery.fec.gov/cgi-bin/fecimg/?201904079146047137',
#    'election_type': 'P2020',
#    'committee': {'filing_frequency': 'Q',
#     'cycle': 2020,
#     'committee_type': 'S',
#     'organization_type': None,
#     'organization_type_full': None,
#     'designation': 'P',
#     'committee_id': 'C00314575',
#     'street_1': 'PO BOX 1096',
#     'state_full': 'Maine',
#     'zip': '04402',
#     'name': 'COLLINS FOR SENATOR',
#     'state': 'ME',
#     'street_2': None,
#     'party_full': 'REPUBLICAN PARTY',
#     'designation_full': 'Principal campaign committee',
#     'treasurer_name': 'MCCANDLESS, ELIZABETH T.',
#     'candidate_ids': ['S6ME00159'],
#     'cycles': [1996,
#      1998,
#      2000,
#      2002,
#      2004,
#      2006,
#      2008,
#      2010,
#      2012,
#      2014,
#      2016,
#      2018,
#      2020],
#     'city': 'BANGOR',
#     'committee_type_full': 'Senate',
#     'party': 'REP'},
#    'entity_type_desc': 'INDIVIDUAL',
#    'two_year_transaction_period': 2020,
#    'contributor_prefix': None,
#    'contributor_first_name': 'JOHN',
#    'back_reference_transaction_id': None,
#    'contributor_middle_name': 'L.',
#    'image_number': '201904079146047137',
#    'contributor_occupation': 'PRESIDENT AND C.E.O.',
#    'contributor_aggregate_ytd': 2700.0,
#    'memoed_subtotal': False,
#    'entity_type': 'IND',
#    'contributor_suffix': 'III',
#    'contribution_receipt_date': '2019-02-02T00:00:00',
#    'back_reference_schedule_name': None,
#    'candidate_id': None,
#    'is_individual': True,
#    'fec_election_type_desc': 'PRIMARY',
#    'contributor_id': None,
#    'receipt_type': '15',
#    'increased_limit': None,
#    'conduit_committee_name': None,
#    'contributor_street_1': 'PO BOX 130130',
#    'candidate_first_name': None,
#    'conduit_committee_city': None,
#    'candidate_name': None,
#    'original_sub_id': None,
#    'national_committee_nonfederal_account': None,
#    'report_type': 'Q1'},
#   {'candidate_last_name': None,
#    'candidate_middle_name': None,
#    'sub_id': '4040820191646013446',
#    'amendment_indicator_desc': 'ADD',
#    'contributor_last_name': 'OBERNDORF',
#    'line_number': '11AI',
#    'link_id': 4040720191646004836,
#    'report_year': 2019,
#    'candidate_office_state': None,
#    'schedule_type_full': 'ITEMIZED RECEIPTS',
#    'candidate_office_state_full': None,
#    'schedule_type': 'SA',
#    'line_number_label': 'Contributions From Individuals/Persons Other Than Political Committees',
#    'committee_name': None,
#    'candidate_prefix': None,
#    'fec_election_year': '2020',
#    'memo_code_full': None,
#    'contributor_zip': '941111913',
#    'conduit_committee_street2': None,
#    'transaction_id': 'ADFC01FA3F5A94C4FB23',
#    'conduit_committee_zip': None,
#    'receipt_type_full': None,
#    'contributor_name': 'OBERNDORF, SUSAN C.',
#    'filing_form': 'F3',
#    'unused_contbr_id': None,
#    'memo_code': None,
#    'candidate_office_district': None,
#    'contributor': None,
#    'committee_id': 'C00314575',
#    'candidate_office_full': None,
#    'candidate_office': None,
#    'conduit_committee_state': None,
#    'receipt_type_desc': 'CONTRIBUTION',
#    'election_type_full': None,
#    'memo_text': None,
#    'contribution_receipt_amount': 2700.0,
#    'donor_committee_name': None,
#    'contributor_street_2': None,
#    'conduit_committee_street1': None,
#    'amendment_indicator': 'A',
#    'candidate_suffix': None,
#    'load_date': '2019-04-09T02:42:36.838000+00:00',
#    'contributor_state': 'CA',
#    'file_number': 1322783,
#    'contributor_employer': 'OBERNDORF FOUNDATION',
#    'contributor_city': 'SAN FRANCISCO',
#    'recipient_committee_type': 'S',
#    'conduit_committee_id': None,
#    'pdf_url': 'http://docquery.fec.gov/cgi-bin/fecimg/?201904079146047142',
#    'election_type': 'G2020',
#    'committee': {'filing_frequency': 'Q',
#     'cycle': 2020,
#     'committee_type': 'S',
#     'organization_type': None,
#     'organization_type_full': None,
#     'designation': 'P',
#     'committee_id': 'C00314575',
#     'street_1': 'PO BOX 1096',
#     'state_full': 'Maine',
#     'zip': '04402',
#     'name': 'COLLINS FOR SENATOR',
#     'state': 'ME',
#     'street_2': None,
#     'party_full': 'REPUBLICAN PARTY',
#     'designation_full': 'Principal campaign committee',
#     'treasurer_name': 'MCCANDLESS, ELIZABETH T.',
#     'candidate_ids': ['S6ME00159'],
#     'cycles': [1996,
#      1998,
#      2000,
#      2002,
#      2004,
#      2006,
#      2008,
#      2010,
#      2012,
#      2014,
#      2016,
#      2018,
#      2020],
#     'city': 'BANGOR',
#     'committee_type_full': 'Senate',
#     'party': 'REP'},
#    'entity_type_desc': 'INDIVIDUAL',
#    'two_year_transaction_period': 2020,
#    'contributor_prefix': None,
#    'contributor_first_name': 'SUSAN',
#    'back_reference_transaction_id': None,
#    'contributor_middle_name': 'C.',
#    'image_number': '201904079146047142',
#    'contributor_occupation': 'EXECUTIVE',
#    'contributor_aggregate_ytd': 5400.0,
#    'memoed_subtotal': False,
#    'entity_type': 'IND',
#    'contributor_suffix': None,
#    'contribution_receipt_date': '2019-02-02T00:00:00',
#    'back_reference_schedule_name': None,
#    'candidate_id': None,
#    'is_individual': True,
#    'fec_election_type_desc': 'GENERAL',
#    'contributor_id': None,
#    'receipt_type': '15',
#    'increased_limit': None,
#    'conduit_committee_name': None,
#    'contributor_street_1': '615 FRONT STREET',
#    'candidate_first_name': None,
#    'conduit_committee_city': None,
#    'candidate_name': None,
#    'original_sub_id': None,
#    'national_committee_nonfederal_account': None,
#    'report_type': 'Q1'}],
#  'pagination': {'count': 859,
#   'last_indexes': {'last_index': '4040820191646013446',
#    'last_contribution_receipt_date': '2019-02-02T00:00:00'},
#   'pages': 9,
#   'per_page': 100}}

# %%
#Write results to a CSV
cwd = os.getcwd()
contribs.to_csv(cwd+'/collins-itemized-receipts.csv')

# %%
#Template for paging through results

page = 1

def getNextPage(nextpage):
    global page
    page = page + 1
    print('PAGE ', page)
    headers = {"Authorization": "Bearer " + token}
    r = requests.get(nextpage, headers=headers)
    nextpage = r.json()['pagination']['next_link']
    records = r.json()['data']
    for user in records:
        s  = pd.Series(user,index=user.keys())
        global records_df
        records_df.loc[len(records_df)] = s
    records_df.to_csv('records.csv')
    if nextpage:
        getNextPage(nextpage)

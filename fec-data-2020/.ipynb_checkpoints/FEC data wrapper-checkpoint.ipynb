# %%
import numpy as np
import pandas as pd
import config
import requests

import os
import json
import time

from pandas.io.json import json_normalize

from copy import deepcopy


##Schedule_a API guide: https://api.open.fec.gov/developers/#/receipts/get_schedules_schedule_a_

# %%
#Candidate Search

candidate = {'q':'COLLINS, SUSAN M'
            ,'api_key':config.api_key}

c = requests.get('https://api.open.fec.gov/v1/candidates/search',params=candidate).json()
c['results']['cycles']
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-171-f6c5169ccc4c> in <module>()
#       5
#       6 c = requests.get('https://api.open.fec.gov/v1/candidates/search',params=candidate).json()
# ----> 7 c['results']['cycles']
#
# TypeError: list indices must be integers or slices, not str

# %%
# %env OPENFEC_API_KEY=config.api_key
import pyopenfec as api
# Out:
# env: OPENFEC_API_KEY=config.api_key

# %%
collins_id = 'C00314575'

payload = {'per_page':'100'
          ,'committee_id':collins_id
          ,'sort':'contribution_receipt_date'
          ,'api_key':config.api_key
          ,'is_individual':'true'
          ,'two_year_transaction_period':'2020'
          ,'last_index':'4040820191646013022'
          ,'last_contribution_receipt_date': '2019-01-25T00:00:00'}

r = requests.get('https://api.open.fec.gov/v1/schedules/schedule_a/',params=payload).json()
r
# Out:
# {'api_version': '1.0',
#  'pagination': {'count': 859,
#   'last_indexes': {'last_contribution_receipt_date': '2019-02-02T00:00:00',
#    'last_index': '4040820191646013446'},
#   'pages': 9,
#   'per_page': 100},
#  'results': [{'amendment_indicator': 'A',
#    'amendment_indicator_desc': 'ADD',
#    'back_reference_schedule_name': None,
#    'back_reference_transaction_id': None,
#    'candidate_first_name': None,
#    'candidate_id': None,
#    'candidate_last_name': None,
#    'candidate_middle_name': None,
#    'candidate_name': None,
#    'candidate_office': None,
#    'candidate_office_district': None,
#    'candidate_office_full': None,
#    'candidate_office_state': None,
#    'candidate_office_state_full': None,
#    'candidate_prefix': None,
#    'candidate_suffix': None,
#    'committee': {'candidate_ids': ['S6ME00159'],
#     'city': 'BANGOR',
#     'committee_id': 'C00314575',
#     'committee_type': 'S',
#     'committee_type_full': 'Senate',
#     'cycle': 2020,
#     'cycles': [1996,
#      1998,
#      2000,
#      2002,
#      2004,
#      2006,
#      2008,
#      2010,
#      2012,
#      2014,
#      2016,
#      2018,
#      2020],
#     'designation': 'P',
#     'designation_full': 'Principal campaign committee',
#     'filing_frequency': 'Q',
#     'name': 'COLLINS FOR SENATOR',
#     'organization_type': None,
#     'organization_type_full': None,
#     'party': 'REP',
#     'party_full': 'REPUBLICAN PARTY',
#     'state': 'ME',
#     'state_full': 'Maine',
#     'street_1': 'PO BOX 1096',
#     'street_2': None,
#     'treasurer_name': 'MCCANDLESS, ELIZABETH T.',
#     'zip': '04402'},
#    'committee_id': 'C00314575',
#    'committee_name': None,
#    'conduit_committee_city': None,
#    'conduit_committee_id': None,
#    'conduit_committee_name': None,
#    'conduit_committee_state': None,
#    'conduit_committee_street1': None,
#    'conduit_committee_street2': None,
#    'conduit_committee_zip': None,
#    'contribution_receipt_amount': 100.0,
#    'contribution_receipt_date': '2019-01-25T00:00:00',
#    'contributor': None,
#    'contributor_aggregate_ytd': 400.0,
#    'contributor_city': 'HOUSTON',
#    'contributor_employer': 'RETIRED',
#    'contributor_first_name': 'LAWRENCE',
#    'contributor_id': None,
#    'contributor_last_name': 'DICKERSON',
#    'contributor_middle_name': None,
#    'contributor_name': 'DICKERSON, LAWRENCE',
#    'contributor_occupation': 'RETIRED',
#    'contributor_prefix': None,
#    'contributor_state': 'TX',
#    'contributor_street_1': '3704 FARBER ST',
#    'contributor_street_2': None,
#    'contributor_suffix': None,
#    'contributor_zip': '770053714',
#    'donor_committee_name': None,
#    'election_type': 'P2020',
#    'election_type_full': None,
#    'entity_type': 'IND',
#    'entity_type_desc': 'INDIVIDUAL',
#    'fec_election_type_desc': 'PRIMARY',
#    'fec_election_year': '2020',
#    'file_number': 1322783,
#    'filing_form': 'F3',
#    'image_number': '201904079146047007',
#    'increased_limit': None,
#    'is_individual': True,
#    'line_number': '11AI',
#    'line_number_label': 'Contributions From Individuals/Persons Other Than Political Committees',
#    'link_id': 4040720191646004836,
#    'load_date': '2019-04-09T02:42:36.720000+00:00',
#    'memo_code': None,
#    'memo_code_full': None,
#    'memo_text': None,
#    'memoed_subtotal': False,
#    'national_committee_nonfederal_account': None,
#    'original_sub_id': None,
#    'pdf_url': 'http://docquery.fec.gov/cgi-bin/fecimg/?201904079146047007',
#    'receipt_type': '15',
#    'receipt_type_desc': 'CONTRIBUTION',
#    'receipt_type_full': None,
#    'recipient_committee_type': 'S',
#    'report_type': 'Q1',
#    'report_year': 2019,
#    'schedule_type': 'SA',
#    'schedule_type_full': 'ITEMIZED RECEIPTS',
#    'sub_id': '4040820191646013039',
#    'transaction_id': 'AC1C778FAA9F947FCB5B',
#    'two_year_transaction_period': 2020,
#    'unused_contbr_id': None},
#   {'amendment_indicator': 'A',
#    'amendment_indicator_desc': 'ADD',
#    'back_reference_schedule_name': None,
#    'back_reference_transaction_id': None,
#    'candidate_first_name': None,
#    'candidate_id': None,
#    'candidate_last_name': None,
#    'candidate_middle_name': None,
#    'candidate_name': None,
#    'candidate_office': None,
#    'candidate_office_district': None,
#    'candidate_office_full': None,
#    'candidate_office_state': None,
#    'candidate_office_state_full': None,
#    'candidate_prefix': None,
#    'candidate_suffix': None,
#    'committee': {'candidate_ids': ['S6ME00159'],
#     'city': 'BANGOR',
#     'committee_id': 'C00314575',
#     'committee_type': 'S',
#     'committee_type_full': 'Senate',
#     'cycle': 2020,
#     'cycles': [1996,
#      1998,
#      2000,
#      2002,
#      2004,
#      2006,
#      2008,
#      2010,
#      2012,
#      2014,
#      2016,
#      2018,
#      2020],
#     'designation': 'P',
#     'designation_full': 'Principal campaign committee',
#     'filing_frequency': 'Q',
#     'name': 'COLLINS FOR SENATOR',
#     'organization_type': None,
#     'organization_type_full': None,
#     'party': 'REP',
#     'party_full': 'REPUBLICAN PARTY',
#     'state': 'ME',
#     'state_full': 'Maine',
#     'street_1': 'PO BOX 1096',
#     'street_2': None,
#     'treasurer_name': 'MCCANDLESS, ELIZABETH T.',
#     'zip': '04402'},
#    'committee_id': 'C00314575',
#    'committee_name': None,
#    'conduit_committee_city': None,
#    'conduit_committee_id': None,
#    'conduit_committee_name': None,
#    'conduit_committee_state': None,
#    'conduit_committee_street1': None,
#    'conduit_committee_street2': None,
#    'conduit_committee_zip': None,
#    'contribution_receipt_amount': 100.0,
#    'contribution_receipt_date': '2019-01-25T00:00:00',
#    'contributor': None,
#    'contributor_aggregate_ytd': 400.0,
#    'contributor_city': 'SAN FRANCISCO',
#    'contributor_employer': 'RETIRED',
#    'contributor_first_name': 'NINO',
#    'contributor_id': None,
#    'contributor_last_name': 'FANLO',
#    'contributor_middle_name': None,
#    'contributor_name': 'FANLO, NINO',
#    'contributor_occupation': 'RETIRED',
#    'contributor_prefix': None,
#    'contributor_state': 'CA',
#    'contributor_street_1': '301 MISSION ST',
#    'contributor_street_2': 'APT 57C',
#    'contributor_suffix': None,
#    'contributor_zip': '941056657',
#    'donor_committee_name': None,
#    'election_type': 'P2020',
#    'election_type_full': None,
#    'entity_type': 'IND',
#    'entity_type_desc': 'INDIVIDUAL',
#    'fec_election_type_desc': 'PRIMARY',
#    'fec_election_year': '2020',
#    'file_number': 1322783,
#    'filing_form': 'F3',
#    'image_number': '201904079146047021',
#    'increased_limit': None,
#    'is_individual': True,
#    'line_number': '11AI',
#    'line_number_label': 'Contributions From Individuals/Persons Other Than Political Committees',
#    'link_id': 4040720191646004836,
#    'load_date': '2019-04-09T02:42:36.737000+00:00',
#    'memo_code': None,
#    'memo_code_full': None,
#    'memo_text': None,
#    'memoed_subtotal': False,
#    'national_committee_nonfederal_account': None,
#    'original_sub_id': None,
#    'pdf_url': 'http://docquery.fec.gov/cgi-bin/fecimg/?201904079146047021',
#    'receipt_type': '15',
#    'receipt_type_desc': 'CONTRIBUTION',
#    'receipt_type_full': None,
#    'recipient_committee_type': 'S',
#    'report_type': 'Q1',
#    'report_year': 2019,
#    'schedule_type': 'SA',
#    'schedule_type_full': 'ITEMIZED RECEIPTS',
#    'sub_id': '4040820191646013082',
#    'transaction_id': 'AC89769045D39476184F',
#    'two_year_transaction_period': 2020,
#    'unused_contbr_id': None},
#   {'amendment_indicator': 'A',
#    'amendment_indicator_desc': 'ADD',
#    'back_reference_schedule_name': None,
#    'back_reference_transaction_id': None,
#    'candidate_first_name': None,
#    'candidate_id': None,
#    'candidate_last_name': None,
#    'candidate_middle_name': None,
#    'candidate_name': None,
#    'candidate_office': None,
#    'candidate_office_district': None,
#    'candidate_office_full': None,
#    'candidate_office_state': None,
#    'candidate_office_state_full': None,
#    'candidate_prefix': None,
#    'candidate_suffix': None,
#    'committee': {'candidate_ids': ['S6ME00159'],
#     'city': 'BANGOR',
#     'committee_id': 'C00314575',
#     'committee_type': 'S',
#     'committee_type_full': 'Senate',
#     'cycle': 2020,
#     'cycles': [1996,
#      1998,
#      2000,
#      2002,
#      2004,
#      2006,
#      2008,
#      2010,
#      2012,
#      2014,
#      2016,
#      2018,
#      2020],
#     'designation': 'P',
#     'designation_full': 'Principal campaign committee',
#     'filing_frequency': 'Q',
#     'name': 'COLLINS FOR SENATOR',
#     'organization_type': None,
#     'organization_type_full': None,
#     'party': 'REP',
#     'party_full': 'REPUBLICAN PARTY',
#     'state': 'ME',
#     'state_full': 'Maine',
#     'street_1': 'PO BOX 1096',
#     'street_2': None,
#     'treasurer_name': 'MCCANDLESS, ELIZABETH T.',
#     'zip': '04402'},
#    'committee_id': 'C00314575',
#    'committee_name': None,
#    'conduit_committee_city': None,
#    'conduit_committee_id': None,
#    'conduit_committee_name': None,
#    'conduit_committee_state': None,
#    'conduit_committee_street1': None,
#    'conduit_committee_street2': None,
#    'conduit_committee_zip': None,
#    'contribution_receipt_amount': 50.0,
#    'contribution_receipt_date': '2019-01-25T00:00:00',
#    'contributor': None,
#    'contributor_aggregate_ytd': 250.0,
#    'contributor_city': 'SAN DIEGO',
#    'contributor_employer': 'RETIRED',
#    'contributor_first_name': 'ROBERT',
#    'contributor_id': None,
#    'contributor_last_name': 'FREISTEDT',
#    'contributor_middle_name': None,
#    'contributor_name': 'FREISTEDT, ROBERT',
#    'contributor_occupation': 'RETIRED',
#    'contributor_prefix': None,
#    'contributor_state': 'CA',
#    'contributor_street_1': '7772 TOPAZ LAKE AVE',
#    'contributor_street_2': None,
#    'contributor_suffix': None,
#    'contributor_zip': '921193048',
#    'donor_committee_name': None,
#    'election_type': 'P2020',
#    'election_type_full': None,
#    'entity_type': 'IND',
#    'entity_type_desc': 'INDIVIDUAL',
#    'fec_election_type_desc': 'PRIMARY',
#    'fec_election_year': '2020',
#    'file_number': 1322783,
#    'filing_form': 'F3',
#    'image_number': '201904079146047032',
#    'increased_limit': None,
#    'is_individual': True,
#    'line_number': '11AI',
#    'line_number_label': 'Contributions From Individuals/Persons Other Than Political Committees',
#    'link_id': 4040720191646004836,
#    'load_date': '2019-04-09T02:42:36.751000+00:00',
#    'memo_code': None,
#    'memo_code_full': None,
#    'memo_text': None,
#    'memoed_subtotal': False,
#    'national_committee_nonfederal_account': None,
#    'original_sub_id': None,
#    'pdf_url': 'http://docquery.fec.gov/cgi-bin/fecimg/?201904079146047032',
#    'receipt_type': '15',
#    'receipt_type_desc': 'CONTRIBUTION',
#    'receipt_type_full': None,
#    'recipient_committee_type': 'S',
#    'report_type': 'Q1',
#    'report_year': 2019,
#    'schedule_type': 'SA',
#    'schedule_type_full': 'ITEMIZED RECEIPTS',
#    'sub_id': '4040820191646013115',
#    'transaction_id': 'A280B235C4F5B43DDA6A',
#    'two_year_transaction_period': 2020,
#    'unused_contbr_id': None},
#   {'amendment_indicator': 'A',
#    'amendment_indicator_desc': 'ADD',
#    'back_reference_schedule_name': None,
#    'back_reference_transaction_id': None,
#    'candidate_first_name': None,
#    'candidate_id': None,
#    'candidate_last_name': None,
#    'candidate_middle_name': None,
#    'candidate_name': None,
#    'candidate_office': None,
#    'candidate_office_district': None,
#    'candidate_office_full': None,
#    'candidate_office_state': None,
#    'candidate_office_state_full': None,
#    'candidate_prefix': None,
#    'candidate_suffix': None,
#    'committee': {'candidate_ids': ['S6ME00159'],
#     'city': 'BANGOR',
#     'committee_id': 'C00314575',
#     'committee_type': 'S',
#     'committee_type_full': 'Senate',
#     'cycle': 2020,
#     'cycles': [1996,
#      1998,
#      2000,
#      2002,
#      2004,
#      2006,
#      2008,
#      2010,
#      2012,
#      2014,
#      2016,
#      2018,
#      2020],
#     'designation': 'P',
#     'designation_full': 'Principal campaign committee',
#     'filing_frequency': 'Q',
#     'name': 'COLLINS FOR SENATOR',
#     'organization_type': None,
#     'organization_type_full': None,
#     'party': 'REP',
#     'party_full': 'REPUBLICAN PARTY',
#     'state': 'ME',
#     'state_full': 'Maine',
#     'street_1': 'PO BOX 1096',
#     'street_2': None,
#     'treasurer_name': 'MCCANDLESS, ELIZABETH T.',
#     'zip': '04402'},
#    'committee_id': 'C00314575',
#    'committee_name': None,
#    'conduit_committee_city': None,
#    'conduit_committee_id': None,
#    'conduit_committee_name': None,
#    'conduit_committee_state': None,
#    'conduit_committee_street1': None,
#    'conduit_committee_street2': None,
#    'conduit_committee_zip': None,
#    'contribution_receipt_amount': 50.0,
#    'contribution_receipt_date': '2019-01-25T00:00:00',
#    'contributor': None,
#    'contributor_aggregate_ytd': 200.0,
#    'contributor_city': 'BLUFFTON',
#    'contributor_employer': 'RETIRED',
#    'contributor_first_name': 'JOSEPH',
#    'contributor_id': None,
#    'contributor_last_name': 'GAREAU',
#    'contributor_middle_name': None,
#    'contributor_name': 'GAREAU, JOSEPH',
#    'contributor_occupation': 'RETIRED',
#    'contributor_prefix': None,
#    'contributor_state': 'SC',
#    'contributor_street_1': '121 INVERNESS DR',
#    'contributor_street_2': None,
#    'contributor_suffix': None,
#    'contributor_zip': '299104976',
#    'donor_committee_name': None,
#    'election_type': 'P2020',
#    'election_type_full': None,
#    'entity_type': 'IND',
#    'entity_type_desc': 'INDIVIDUAL',
#    'fec_election_type_desc': 'PRIMARY',
#    'fec_election_year': '2020',
#    'file_number': 1322783,
#    'filing_form': 'F3',
#    'image_number': '201904079146047038',
#    'increased_limit': None,
#    'is_individual': True,
#    'line_number': '11AI',
#    'line_number_label': 'Contributions From Individuals/Persons Other Than Political Committees',
#    'link_id': 4040720191646004836,
#    'load_date': '2019-04-09T02:42:36.758000+00:00',
#    'memo_code': None,
#    'memo_code_full': None,
#    'memo_text': None,
#    'memoed_subtotal': False,
#    'national_committee_nonfederal_account': None,
#    'original_sub_id': None,
#    'pdf_url': 'http://docquery.fec.gov/cgi-bin/fecimg/?201904079146047038',
#    'receipt_type': None,
#    'receipt_type_desc': None,
#    'receipt_type_full': None,
#    'recipient_committee_type': 'S',
#    'report_type': 'Q1',
#    'report_year': 2019,
#    'schedule_type': 'SA',
#    'schedule_type_full': 'ITEMIZED RECEIPTS',
#    'sub_id': '4040820191646013134',
#    'transaction_id': 'AFDAAA9D1244C4274AE0',
#    'two_year_transaction_period': 2020,
#    'unused_contbr_id': None},
#   {'amendment_indicator': 'A',
#    'amendment_indicator_desc': 'ADD',
#    'back_reference_schedule_name': None,
#    'back_reference_transaction_id': None,
#    'candidate_first_name': None,
#    'candidate_id': None,
#    'candidate_last_name': None,
#    'candidate_middle_name': None,
#    'candidate_name': None,
#    'candidate_office': None,
#    'candidate_office_district': None,
#    'candidate_office_full': None,
#    'candidate_office_state': None,
#    'candidate_office_state_full': None,
#    'candidate_prefix': None,
#    'candidate_suffix': None,
#    'committee': {'candidate_ids': ['S6ME00159'],
#     'city': 'BANGOR',
#     'committee_id': 'C00314575',
#     'committee_type': 'S',
#     'committee_type_full': 'Senate',
#     'cycle': 2020,
#     'cycles': [1996,
#      1998,
#      2000,
#      2002,
#      2004,
#      2006,
#      2008,
#      2010,
#      2012,
#      2014,
#      2016,
#      2018,
#      2020],
#     'designation': 'P',
#     'designation_full': 'Principal campaign committee',
#     'filing_frequency': 'Q',
#     'name': 'COLLINS FOR SENATOR',
#     'organization_type': None,
#     'organization_type_full': None,
#     'party': 'REP',
#     'party_full': 'REPUBLICAN PARTY',
#     'state': 'ME',
#     'state_full': 'Maine',
#     'street_1': 'PO BOX 1096',
#     'street_2': None,
#     'treasurer_name': 'MCCANDLESS, ELIZABETH T.',
#     'zip': '04402'},
#    'committee_id': 'C00314575',
#    'committee_name': None,
#    'conduit_committee_city': None,
#    'conduit_committee_id': None,
#    'conduit_committee_name': None,
#    'conduit_committee_state': None,
#    'conduit_committee_street1': None,
#    'conduit_committee_street2': None,
#    'conduit_committee_zip': None,
#    'contribution_receipt_amount': 100.0,
#    'contribution_receipt_date': '2019-01-25T00:00:00',
#    'contributor': None,
#    'contributor_aggregate_ytd': 400.0,
#    'contributor_city': 'LINWOOD',
#    'contributor_employer': 'GLENN INSURANCE INC',
#    'contributor_first_name': 'THOMAS',
#    'contributor_id': None,
#    'contributor_last_name': 'GLENN',
#    'contributor_middle_name': None,
#    'contributor_name': 'GLENN, THOMAS',
#    'contributor_occupation': 'INSURANCE AGENT',
#    'contributor_prefix': None,
#    'contributor_state': 'NJ',
#    'contributor_street_1': '1011 BARTLETT AVE',
#    'contributor_street_2': None,
#    'contributor_suffix': None,
#    'contributor_zip': '082211137',
#    'donor_committee_name': None,
#    'election_type': 'P2020',
#    'election_type_full': None,
#    'entity_type': 'IND',
#    'entity_type_desc': 'INDIVIDUAL',
#    'fec_election_type_desc': 'PRIMARY',
#    'fec_election_year': '2020',
#    'file_number': 1322783,
#    'filing_form': 'F3',
#    'image_number': '201904079146047046',
#    'increased_limit': None,
#    'is_individual': True,
#    'line_number': '11AI',
#    'line_number_label': 'Contributions From Individuals/Persons Other Than Political Committees',
#    'link_id': 4040720191646004836,
#    'load_date': '2019-04-09T02:42:36.768000+00:00',
#    'memo_code': None,
#    'memo_code_full': None,
#    'memo_text': None,
#    'memoed_subtotal': False,
#    'national_committee_nonfederal_account': None,
#    'original_sub_id': None,
#    'pdf_url': 'http://docquery.fec.gov/cgi-bin/fecimg/?201904079146047046',
#    'receipt_type': '15',
#    'receipt_type_desc': 'CONTRIBUTION',
#    'receipt_type_full': None,
#    'recipient_committee_type': 'S',
#    'report_type': 'Q1',
#    'report_year': 2019,
#    'schedule_type': 'SA',
#    'schedule_type_full': 'ITEMIZED RECEIPTS',
#    'sub_id': '4040820191646013157',
#    'transaction_id': 'A9789D8329FB84C3A976',
#    'two_year_transaction_period': 2020,
#    'unused_contbr_id': None},
#   {'amendment_indicator': 'A',
#    'amendment_indicator_desc': 'ADD',
#    'back_reference_schedule_name': None,
#    'back_reference_transaction_id': None,
#    'candidate_first_name': None,
#    'candidate_id': None,
#    'candidate_last_name': None,
#    'candidate_middle_name': None,
#    'candidate_name': None,
#    'candidate_office': None,
#    'candidate_office_district': None,
#    'candidate_office_full': None,
#    'candidate_office_state': None,
#    'candidate_office_state_full': None,
#    'candidate_prefix': None,
#    'candidate_suffix': None,
#    'committee': {'candidate_ids': ['S6ME00159'],
#     'city': 'BANGOR',
#     'committee_id': 'C00314575',
#     'committee_type': 'S',
#     'committee_type_full': 'Senate',
#     'cycle': 2020,
#     'cycles': [1996,
#      1998,
#      2000,
#      2002,
#      2004,
#      2006,
#      2008,
#      2010,
#      2012,
#      2014,
#      2016,
#      2018,
#      2020],
#     'designation': 'P',
#     'designation_full': 'Principal campaign committee',
#     'filing_frequency': 'Q',
#     'name': 'COLLINS FOR SENATOR',
#     'organization_type': None,
#     'organization_type_full': None,
#     'party': 'REP',
#     'party_full': 'REPUBLICAN PARTY',
#     'state': 'ME',
#     'state_full': 'Maine',
#     'street_1': 'PO BOX 1096',
#     'street_2': None,
#     'treasurer_name': 'MCCANDLESS, ELIZABETH T.',
#     'zip': '04402'},
#    'committee_id': 'C00314575',
#    'committee_name': None,
#    'conduit_committee_city': None,
#    'conduit_committee_id': None,
#    'conduit_committee_name': None,
#    'conduit_committee_state': None,
#    'conduit_committee_street1': None,
#    'conduit_committee_street2': None,
#    'conduit_committee_zip': None,
#    'contribution_receipt_amount': 250.0,
#    'contribution_receipt_date': '2019-01-25T00:00:00',
#    'contributor': None,
#    'contributor_aggregate_ytd': 1000.0,
#    'contributor_city': 'VOORHEESVILLE',
#    'contributor_employer': 'JANITRONICS INC',
#    'contributor_first_name': 'JIM',
#    'contributor_id': None,
#    'contributor_last_name': 'HARRIS',
#    'contributor_middle_name': None,
#    'contributor_name': 'HARRIS, JIM SR.',
#    'contributor_occupation': 'BUSINESS OWNER',
#    'contributor_prefix': None,
#    'contributor_state': 'NY',
#    'contributor_street_1': '201 WORMER RD',
#    'contributor_street_2': None,
#    'contributor_suffix': 'SR.',
#    'contributor_zip': '121865324',
#    'donor_committee_name': None,
#    'election_type': 'P2020',
#    'election_type_full': None,
#    'entity_type': 'IND',
#    'entity_type_desc': 'INDIVIDUAL',
#    'fec_election_type_desc': 'PRIMARY',
#    'fec_election_year': '2020',
#    'file_number': 1322783,
#    'filing_form': 'F3',
#    'image_number': '201904079146047053',
#    'increased_limit': None,
#    'is_individual': True,
#    'line_number': '11AI',
#    'line_number_label': 'Contributions From Individuals/Persons Other Than Political Committees',
#    'link_id': 4040720191646004836,
#    'load_date': '2019-04-09T02:42:36.772000+00:00',
#    'memo_code': None,
#    'memo_code_full': None,
#    'memo_text': None,
#    'memoed_subtotal': False,
#    'national_committee_nonfederal_account': None,
#    'original_sub_id': None,
#    'pdf_url': 'http://docquery.fec.gov/cgi-bin/fecimg/?201904079146047053',
#    'receipt_type': '15',
#    'receipt_type_desc': 'CONTRIBUTION',
#    'receipt_type_full': None,
#    'recipient_committee_type': 'S',
#    'report_type': 'Q1',
#    'report_year': 2019,
#    'schedule_type': 'SA',
#    'schedule_type_full': 'ITEMIZED RECEIPTS',
#    'sub_id': '4040820191646013179',
#    'transaction_id': 'AB9B3C7DCE9E748F6BC1',
#    'two_year_transaction_period': 2020,
#    'unused_contbr_id': None},
#   {'amendment_indicator': 'A',
#    'amendment_indicator_desc': 'ADD',
#    'back_reference_schedule_name': None,
#    'back_reference_transaction_id': None,
#    'candidate_first_name': None,
#    'candidate_id': None,
#    'candidate_last_name': None,
#    'candidate_middle_name': None,
#    'candidate_name': None,
#    'candidate_office': None,
#    'candidate_office_district': None,
#    'candidate_office_full': None,
#    'candidate_office_state': None,
#    'candidate_office_state_full': None,
#    'candidate_prefix': None,
#    'candidate_suffix': None,
#    'committee': {'candidate_ids': ['S6ME00159'],
#     'city': 'BANGOR',
#     'committee_id': 'C00314575',
#     'committee_type': 'S',
#     'committee_type_full': 'Senate',
#     'cycle': 2020,
#     'cycles': [1996,
#      1998,
#      2000,
#      2002,
#      2004,
#      2006,
#      2008,
#      2010,
#      2012,
#      2014,
#      2016,
#      2018,
#      2020],
#     'designation': 'P',
#     'designation_full': 'Principal campaign committee',
#     'filing_frequency': 'Q',
#     'name': 'COLLINS FOR SENATOR',
#     'organization_type': None,
#     'organization_type_full': None,
#     'party': 'REP',
#     'party_full': 'REPUBLICAN PARTY',
#     'state': 'ME',
#     'state_full': 'Maine',
#     'street_1': 'PO BOX 1096',
#     'street_2': None,
#     'treasurer_name': 'MCCANDLESS, ELIZABETH T.',
#     'zip': '04402'},
#    'committee_id': 'C00314575',
#    'committee_name': None,
#    'conduit_committee_city': None,
#    'conduit_committee_id': None,
#    'conduit_committee_name': None,
#    'conduit_committee_state': None,
#    'conduit_committee_street1': None,
#    'conduit_committee_street2': None,
#    'conduit_committee_zip': None,
#    'contribution_receipt_amount': 50.0,
#    'contribution_receipt_date': '2019-01-25T00:00:00',
#    'contributor': None,
#    'contributor_aggregate_ytd': 200.0,
#    'contributor_city': 'NEW HOPE',
#    'contributor_employer': 'RETIRED',
#    'contributor_first_name': 'LOIS',
#    'contributor_id': None,
#    'contributor_last_name': 'HOWARD',
#    'contributor_middle_name': None,
#    'contributor_name': 'HOWARD, LOIS',
#    'contributor_occupation': 'RETIRED',
#    'contributor_prefix': None,
#    'contributor_state': 'PA',
#    'contributor_street_1': '35 SOLEBURY MOUNTAIN RD',
#    'contributor_street_2': None,
#    'contributor_suffix': None,
#    'contributor_zip': '189381122',
#    'donor_committee_name': None,
#    'election_type': 'P2020',
#    'election_type_full': None,
#    'entity_type': 'IND',
#    'entity_type_desc': 'INDIVIDUAL',
#    'fec_election_type_desc': 'PRIMARY',
#    'fec_election_year': '2020',
#    'file_number': 1322783,
#    'filing_form': 'F3',
#    'image_number': '201904079146047069',
#    'increased_limit': None,
#    'is_individual': True,
#    'line_number': '11AI',
#    'line_number_label': 'Contributions From Individuals/Persons Other Than Political Committees',
#    'link_id': 4040720191646004836,
#    'load_date': '2019-04-09T02:42:36.780000+00:00',
#    'memo_code': None,
#    'memo_code_full': None,
#    'memo_text': None,
#    'memoed_subtotal': False,
#    'national_committee_nonfederal_account': None,
#    'original_sub_id': None,
#    'pdf_url': 'http://docquery.fec.gov/cgi-bin/fecimg/?201904079146047069',
#    'receipt_type': None,
#    'receipt_type_desc': None,
#    'receipt_type_full': None,
#    'recipient_committee_type': 'S',
#    'report_type': 'Q1',
#    'report_year': 2019,
#    'schedule_type': 'SA',
#    'schedule_type_full': 'ITEMIZED RECEIPTS',
#    'sub_id': '4040820191646013225',
#    'transaction_id': 'AADD9C48ECDD44E7DBC0',
#    'two_year_transaction_period': 2020,
#    'unused_contbr_id': None},
#   {'amendment_indicator': 'A',
#    'amendment_indicator_desc': 'ADD',
#    'back_reference_schedule_name': None,
#    'back_reference_transaction_id': None,
#    'candidate_first_name': None,
#    'candidate_id': None,
#    'candidate_last_name': None,
#    'candidate_middle_name': None,
#    'candidate_name': None,
#    'candidate_office': None,
#    'candidate_office_district': None,
#    'candidate_office_full': None,
#    'candidate_office_state': None,
#    'candidate_office_state_full': None,
#    'candidate_prefix': None,
#    'candidate_suffix': None,
#    'committee': {'candidate_ids': ['S6ME00159'],
#     'city': 'BANGOR',
#     'committee_id': 'C00314575',
#     'committee_type': 'S',
#     'committee_type_full': 'Senate',
#     'cycle': 2020,
#     'cycles': [1996,
#      1998,
#      2000,
#      2002,
#      2004,
#      2006,
#      2008,
#      2010,
#      2012,
#      2014,
#      2016,
#      2018,
#      2020],
#     'designation': 'P',
#     'designation_full': 'Principal campaign committee',
#     'filing_frequency': 'Q',
#     'name': 'COLLINS FOR SENATOR',
#     'organization_type': None,
#     'organization_type_full': None,
#     'party': 'REP',
#     'party_full': 'REPUBLICAN PARTY',
#     'state': 'ME',
#     'state_full': 'Maine',
#     'street_1': 'PO BOX 1096',
#     'street_2': None,
#     'treasurer_name': 'MCCANDLESS, ELIZABETH T.',
#     'zip': '04402'},
#    'committee_id': 'C00314575',
#    'committee_name': None,
#    'conduit_committee_city': None,
#    'conduit_committee_id': None,
#    'conduit_committee_name': None,
#    'conduit_committee_state': None,
#    'conduit_committee_street1': None,
#    'conduit_committee_street2': None,
#    'conduit_committee_zip': None,
#    'contribution_receipt_amount': 100.0,
#    'contribution_receipt_date': '2019-01-25T00:00:00',
#    'contributor': None,
#    'contributor_aggregate_ytd': 500.0,
#    'contributor_city': 'SPRING LAKE',
#    'contributor_employer': 'VAPROSHIELD',
#    'contributor_first_name': 'PHIL',
#    'contributor_id': None,
#    'contributor_last_name': 'JOHNSON',
#    'contributor_middle_name': None,
#    'contributor_name': 'JOHNSON, PHIL',
#    'contributor_occupation': 'EXECUTIVE',
#    'contributor_prefix': None,
#    'contributor_state': 'MI',
#    'contributor_street_1': '17397 N SHORE ESTATES RD',
#    'contributor_street_2': None,
#    'contributor_suffix': None,
#    'contributor_zip': '494569110',
#    'donor_committee_name': None,
#    'election_type': 'P2020',
#    'election_type_full': None,
#    'entity_type': 'IND',
#    'entity_type_desc': 'INDIVIDUAL',
#    'fec_election_type_desc': 'PRIMARY',
#    'fec_election_year': '2020',
#    'file_number': 1322783,
#    'filing_form': 'F3',
#    'image_number': '201904079146047079',
#    'increased_limit': None,
#    'is_individual': True,
#    'line_number': '11AI',
#    'line_number_label': 'Contributions From Individuals/Persons Other Than Political Committees',
#    'link_id': 4040720191646004836,
#    'load_date': '2019-04-09T02:42:36.785000+00:00',
#    'memo_code': None,
#    'memo_code_full': None,
#    'memo_text': None,
#    'memoed_subtotal': False,
#    'national_committee_nonfederal_account': None,
#    'original_sub_id': None,
#    'pdf_url': 'http://docquery.fec.gov/cgi-bin/fecimg/?201904079146047079',
#    'receipt_type': '15',
#    'receipt_type_desc': 'CONTRIBUTION',
#    'receipt_type_full': None,
#    'recipient_committee_type': 'S',
#    'report_type': 'Q1',
#    'report_year': 2019,
#    'schedule_type': 'SA',
#    'schedule_type_full': 'ITEMIZED RECEIPTS',
#    'sub_id': '4040820191646013255',
#    'transaction_id': 'A6917801701764472B28',
#    'two_year_transaction_period': 2020,
#    'unused_contbr_id': None},
#   {'amendment_indicator': 'A',
#    'amendment_indicator_desc': 'ADD',
#    'back_reference_schedule_name': None,
#    'back_reference_transaction_id': None,
#    'candidate_first_name': None,
#    'candidate_id': None,
#    'candidate_last_name': None,
#    'candidate_middle_name': None,
#    'candidate_name': None,
#    'candidate_office': None,
#    'candidate_office_district': None,
#    'candidate_office_full': None,
#    'candidate_office_state': None,
#    'candidate_office_state_full': None,
#    'candidate_prefix': None,
#    'candidate_suffix': None,
#    'committee': {'candidate_ids': ['S6ME00159'],
#     'city': 'BANGOR',
#     'committee_id': 'C00314575',
#     'committee_type': 'S',
#     'committee_type_full': 'Senate',
#     'cycle': 2020,
#     'cycles': [1996,
#      1998,
#      2000,
#      2002,
#      2004,
#      2006,
#      2008,
#      2010,
#      2012,
#      2014,
#      2016,
#      2018,
#      2020],
#     'designation': 'P',
#     'designation_full': 'Principal campaign committee',
#     'filing_frequency': 'Q',
#     'name': 'COLLINS FOR SENATOR',
#     'organization_type': None,
#     'organization_type_full': None,
#     'party': 'REP',
#     'party_full': 'REPUBLICAN PARTY',
#     'state': 'ME',
#     'state_full': 'Maine',
#     'street_1': 'PO BOX 1096',
#     'street_2': None,
#     'treasurer_name': 'MCCANDLESS, ELIZABETH T.',
#     'zip': '04402'},
#    'committee_id': 'C00314575',
#    'committee_name': None,
#    'conduit_committee_city': None,
#    'conduit_committee_id': None,
#    'conduit_committee_name': None,
#    'conduit_committee_state': None,
#    'conduit_committee_street1': None,
#    'conduit_committee_street2': None,
#    'conduit_committee_zip': None,
#    'contribution_receipt_amount': 100.0,
#    'contribution_receipt_date': '2019-01-25T00:00:00',
#    'contributor': None,
#    'contributor_aggregate_ytd': 400.0,
#    'contributor_city': 'MARINA DEL REY',
#    'contributor_employer': 'RETIRED',
#    'contributor_first_name': 'BIRGITTA',
#    'contributor_id': None,
#    'contributor_last_name': 'KESSLER',
#    'contributor_middle_name': None,
#    'contributor_name': 'KESSLER, BIRGITTA',
#    'contributor_occupation': 'RETIRED',
#    'contributor_prefix': None,
#    'contributor_state': 'CA',
#    'contributor_street_1': '135 ROMA CT',
#    'contributor_street_2': None,
#    'contributor_suffix': None,
#    'contributor_zip': '902925968',
#    'donor_committee_name': None,
#    'election_type': 'P2020',
#    'election_type_full': None,
#    'entity_type': 'IND',
#    'entity_type_desc': 'INDIVIDUAL',
#    'fec_election_type_desc': 'PRIMARY',
#    'fec_election_year': '2020',
#    'file_number': 1322783,
#    'filing_form': 'F3',
#    'image_number': '201904079146047087',
#    'increased_limit': None,
#    'is_individual': True,
#    'line_number': '11AI',
#    'line_number_label': 'Contributions From Individuals/Persons Other Than Political Committees',
#    'link_id': 4040720191646004836,
#    'load_date': '2019-04-09T02:42:36.790000+00:00',
#    'memo_code': None,
#    'memo_code_full': None,
#    'memo_text': None,
#    'memoed_subtotal': False,
#    'national_committee_nonfederal_account': None,
#    'original_sub_id': None,
#    'pdf_url': 'http://docquery.fec.gov/cgi-bin/fecimg/?201904079146047087',
#    'receipt_type': '15',
#    'receipt_type_desc': 'CONTRIBUTION',
#    'receipt_type_full': None,
#    'recipient_committee_type': 'S',
#    'report_type': 'Q1',
#    'report_year': 2019,
#    'schedule_type': 'SA',
#    'schedule_type_full': 'ITEMIZED RECEIPTS',
#    'sub_id': '4040820191646013279',
#    'transaction_id': 'A73AF2BDC237D43DBB68',
#    'two_year_transaction_period': 2020,
#    'unused_contbr_id': None},
#   {'amendment_indicator': 'A',
#    'amendment_indicator_desc': 'ADD',
#    'back_reference_schedule_name': None,
#    'back_reference_transaction_id': None,
#    'candidate_first_name': None,
#    'candidate_id': None,
#    'candidate_last_name': None,
#    'candidate_middle_name': None,
#    'candidate_name': None,
#    'candidate_office': None,
#    'candidate_office_district': None,
#    'candidate_office_full': None,
#    'candidate_office_state': None,
#    'candidate_office_state_full': None,
#    'candidate_prefix': None,
#    'candidate_suffix': None,
#    'committee': {'candidate_ids': ['S6ME00159'],
#     'city': 'BANGOR',
#     'committee_id': 'C00314575',
#     'committee_type': 'S',
#     'committee_type_full': 'Senate',
#     'cycle': 2020,
#     'cycles': [1996,
#      1998,
#      2000,
#      2002,
#      2004,
#      2006,
#      2008,
#      2010,
#      2012,
#      2014,
#      2016,
#      2018,
#      2020],
#     'designation': 'P',
#     'designation_full': 'Principal campaign committee',
#     'filing_frequency': 'Q',
#     'name': 'COLLINS FOR SENATOR',
#     'organization_type': None,
#     'organization_type_full': None,
#     'party': 'REP',
#     'party_full': 'REPUBLICAN PARTY',
#     'state': 'ME',
#     'state_full': 'Maine',
#     'street_1': 'PO BOX 1096',
#     'street_2': None,
#     'treasurer_name': 'MCCANDLESS, ELIZABETH T.',
#     'zip': '04402'},
#    'committee_id': 'C00314575',
#    'committee_name': None,
#    'conduit_committee_city': None,
#    'conduit_committee_id': None,
#    'conduit_committee_name': None,
#    'conduit_committee_state': None,
#    'conduit_committee_street1': None,
#    'conduit_committee_street2': None,
#    'conduit_committee_zip': None,
#    'contribution_receipt_amount': 100.0,
#    'contribution_receipt_date': '2019-01-25T00:00:00',
#    'contributor': None,
#    'contributor_aggregate_ytd': 400.0,
#    'contributor_city': 'CHAGRIN FALLS',
#    'contributor_employer': 'RETIRED',
#    'contributor_first_name': 'ROBERT',
#    'contributor_id': None,
#    'contributor_last_name': 'LOMAS',
#    'contributor_middle_name': None,
#    'contributor_name': 'LOMAS, ROBERT',
#    'contributor_occupation': 'RETIRED',
#    'contributor_prefix': None,
#    'contributor_state': 'OH',
#    'contributor_street_1': '10 GREY FOX RUN',
#    'contributor_street_2': None,
#    'contributor_suffix': None,
#    'contributor_zip': '440223392',
#    'donor_committee_name': None,
#    'election_type': 'P2020',
#    'election_type_full': None,
#    'entity_type': 'IND',
#    'entity_type_desc': 'INDIVIDUAL',
#    'fec_election_type_desc': 'PRIMARY',
#    'fec_election_year': '2020',
#    'file_number': 1322783,
#    'filing_form': 'F3',
#    'image_number': '201904079146047099',
#    'increased_limit': None,
#    'is_individual': True,
#    'line_number': '11AI',
#    'line_number_label': 'Contributions From Individuals/Persons Other Than Political Committees',
#    'link_id': 4040720191646004836,
#    'load_date': '2019-04-09T02:42:36.801000+00:00',
#    'memo_code': None,
#    'memo_code_full': None,
#    'memo_text': None,
#    'memoed_subtotal': False,
#    'national_committee_nonfederal_account': None,
#    'original_sub_id': None,
#    'pdf_url': 'http://docquery.fec.gov/cgi-bin/fecimg/?201904079146047099',
#    'receipt_type': '15',
#    'receipt_type_desc': 'CONTRIBUTION',
#    'receipt_type_full': None,
#    'recipient_committee_type': 'S',
#    'report_type': 'Q1',
#    'report_year': 2019,
#    'schedule_type': 'SA',
#    'schedule_type_full': 'ITEMIZED RECEIPTS',
#    'sub_id': '4040820191646013315',
#    'transaction_id': 'A0865815980C7485AA1A',
#    'two_year_transaction_period': 2020,
#    'unused_contbr_id': None},
#   {'amendment_indicator': 'A',
#    'amendment_indicator_desc': 'ADD',
#    'back_reference_schedule_name': None,
#    'back_reference_transaction_id': None,
#    'candidate_first_name': None,
#    'candidate_id': None,
#    'candidate_last_name': None,
#    'candidate_middle_name': None,
#    'candidate_name': None,
#    'candidate_office': None,
#    'candidate_office_district': None,
#    'candidate_office_full': None,
#    'candidate_office_state': None,
#    'candidate_office_state_full': None,
#    'candidate_prefix': None,
#    'candidate_suffix': None,
#    'committee': {'candidate_ids': ['S6ME00159'],
#     'city': 'BANGOR',
#     'committee_id': 'C00314575',
#     'committee_type': 'S',
#     'committee_type_full': 'Senate',
#     'cycle': 2020,
#     'cycles': [1996,
#      1998,
#      2000,
#      2002,
#      2004,
#      2006,
#      2008,
#      2010,
#      2012,
#      2014,
#      2016,
#      2018,
#      2020],
#     'designation': 'P',
#     'designation_full': 'Principal campaign committee',
#     'filing_frequency': 'Q',
#     'name': 'COLLINS FOR SENATOR',
#     'organization_type': None,
#     'organization_type_full': None,
#     'party': 'REP',
#     'party_full': 'REPUBLICAN PARTY',
#     'state': 'ME',
#     'state_full': 'Maine',
#     'street_1': 'PO BOX 1096',
#     'street_2': None,
#     'treasurer_name': 'MCCANDLESS, ELIZABETH T.',
#     'zip': '04402'},
#    'committee_id': 'C00314575',
#    'committee_name': None,
#    'conduit_committee_city': None,
#    'conduit_committee_id': None,
#    'conduit_committee_name': None,
#    'conduit_committee_state': None,
#    'conduit_committee_street1': None,
#    'conduit_committee_street2': None,
#    'conduit_committee_zip': None,
#    'contribution_receipt_amount': 100.0,
#    'contribution_receipt_date': '2019-01-25T00:00:00',
#    'contributor': None,
#    'contributor_aggregate_ytd': 400.0,
#    'contributor_city': 'THIBODAUX',
#    'contributor_employer': 'THIBODAUX ORTHOPAEDICS',
#    'contributor_first_name': 'NEIL',
#    'contributor_id': None,
#    'contributor_last_name': 'MAKI',
#    'contributor_middle_name': None,
#    'contributor_name': 'MAKI, NEIL',
#    'contributor_occupation': 'PHYSICIAN',
#    'contributor_prefix': None,
#    'contributor_state': 'LA',
#    'contributor_street_1': '525 SAINT MARY ST',
#    'contributor_street_2': None,
#    'contributor_suffix': None,
#    'contributor_zip': '703012627',
#    'donor_committee_name': None,
#    'election_type': 'P2020',
#    'election_type_full': None,
#    'entity_type': 'IND',
#    'entity_type_desc': 'INDIVIDUAL',
#    'fec_election_type_desc': 'PRIMARY',
#    'fec_election_year': '2020',
#    'file_number': 1322783,
#    'filing_form': 'F3',
#    'image_number': '201904079146047106',
#    'increased_limit': None,
#    'is_individual': True,
#    'line_number': '11AI',
#    'line_number_label': 'Contributions From Individuals/Persons Other Than Political Committees',
#    'link_id': 4040720191646004836,
#    'load_date': '2019-04-09T02:42:36.807000+00:00',
#    'memo_code': None,
#    'memo_code_full': None,
#    'memo_text': None,
#    'memoed_subtotal': False,
#    'national_committee_nonfederal_account': None,
#    'original_sub_id': None,
#    'pdf_url': 'http://docquery.fec.gov/cgi-bin/fecimg/?201904079146047106',
#    'receipt_type': '15',
#    'receipt_type_desc': 'CONTRIBUTION',
#    'receipt_type_full': None,
#    'recipient_committee_type': 'S',
#    'report_type': 'Q1',
#    'report_year': 2019,
#    'schedule_type': 'SA',
#    'schedule_type_full': 'ITEMIZED RECEIPTS',
#    'sub_id': '4040820191646013336',
#    'transaction_id': 'A99470A6BF09641C0B17',
#    'two_year_transaction_period': 2020,
#    'unused_contbr_id': None},
#   {'amendment_indicator': 'A',
#    'amendment_indicator_desc': 'ADD',
#    'back_reference_schedule_name': None,
#    'back_reference_transaction_id': None,
#    'candidate_first_name': None,
#    'candidate_id': None,
#    'candidate_last_name': None,
#    'candidate_middle_name': None,
#    'candidate_name': None,
#    'candidate_office': None,
#    'candidate_office_district': None,
#    'candidate_office_full': None,
#    'candidate_office_state': None,
#    'candidate_office_state_full': None,
#    'candidate_prefix': None,
#    'candidate_suffix': None,
#    'committee': {'candidate_ids': ['S6ME00159'],
#     'city': 'BANGOR',
#     'committee_id': 'C00314575',
#     'committee_type': 'S',
#     'committee_type_full': 'Senate',
#     'cycle': 2020,
#     'cycles': [1996,
#      1998,
#      2000,
#      2002,
#      2004,
#      2006,
#      2008,
#      2010,
#      2012,
#      2014,
#      2016,
#      2018,
#      2020],
#     'designation': 'P',
#     'designation_full': 'Principal campaign committee',
#     'filing_frequency': 'Q',
#     'name': 'COLLINS FOR SENATOR',
#     'organization_type': None,
#     'organization_type_full': None,
#     'party': 'REP',
#     'party_full': 'REPUBLICAN PARTY',
#     'state': 'ME',
#     'state_full': 'Maine',
#     'street_1': 'PO BOX 1096',
#     'street_2': None,
#     'treasurer_name': 'MCCANDLESS, ELIZABETH T.',
#     'zip': '04402'},
#    'committee_id': 'C00314575',
#    'committee_name': None,
#    'conduit_committee_city': None,
#    'conduit_committee_id': None,
#    'conduit_committee_name': None,
#    'conduit_committee_state': None,
#    'conduit_committee_street1': None,
#    'conduit_committee_street2': None,
#    'conduit_committee_zip': None,
#    'contribution_receipt_amount': 50.0,
#    'contribution_receipt_date': '2019-01-25T00:00:00',
#    'contributor': None,
#    'contributor_aggregate_ytd': 200.0,
#    'contributor_city': 'TYNGSBORO',
#    'contributor_employer': 'SELF',
#    'contributor_first_name': 'PETER',
#    'contributor_id': None,
#    'contributor_last_name': 'MARLOWE',
#    'contributor_middle_name': None,
#    'contributor_name': 'MARLOWE, PETER',
#    'contributor_occupation': 'CONSTRUCTION',
#    'contributor_prefix': None,
#    'contributor_state': 'MA',
#    'contributor_street_1': '440 MIDDLESEX RD',
#    'contributor_street_2': None,
#    'contributor_suffix': None,
#    'contributor_zip': '018791070',
#    'donor_committee_name': None,
#    'election_type': 'P2020',
#    'election_type_full': None,
#    'entity_type': 'IND',
#    'entity_type_desc': 'INDIVIDUAL',
#    'fec_election_type_desc': 'PRIMARY',
#    'fec_election_year': '2020',
#    'file_number': 1322783,
#    'filing_form': 'F3',
#    'image_number': '201904079146047112',
#    'increased_limit': None,
#    'is_individual': True,
#    'line_number': '11AI',
#    'line_number_label': 'Contributions From Individuals/Persons Other Than Political Committees',
#    'link_id': 4040720191646004836,
#    'load_date': '2019-04-09T02:42:36.813000+00:00',
#    'memo_code': None,
#    'memo_code_full': None,
#    'memo_text': None,
#    'memoed_subtotal': False,
#    'national_committee_nonfederal_account': None,
#    'original_sub_id': None,
#    'pdf_url': 'http://docquery.fec.gov/cgi-bin/fecimg/?201904079146047112',
#    'receipt_type': None,
#    'receipt_type_desc': None,
#    'receipt_type_full': None,
#    'recipient_committee_type': 'S',
#    'report_type': 'Q1',
#    'report_year': 2019,
#    'schedule_type': 'SA',
#    'schedule_type_full': 'ITEMIZED RECEIPTS',
#    'sub_id': '4040820191646013356',
#    'transaction_id': 'A4F423F06190D4119A1D',
#    'two_year_transaction_period': 2020,
#    'unused_contbr_id': None},
#   {'amendment_indicator': 'A',
#    'amendment_indicator_desc': 'ADD',
#    'back_reference_schedule_name': None,
#    'back_reference_transaction_id': None,
#    'candidate_first_name': None,
#    'candidate_id': None,
#    'candidate_last_name': None,
#    'candidate_middle_name': None,
#    'candidate_name': None,
#    'candidate_office': None,
#    'candidate_office_district': None,
#    'candidate_office_full': None,
#    'candidate_office_state': None,
#    'candidate_office_state_full': None,
#    'candidate_prefix': None,
#    'candidate_suffix': None,
#    'committee': {'candidate_ids': ['S6ME00159'],
#     'city': 'BANGOR',
#     'committee_id': 'C00314575',
#     'committee_type': 'S',
#     'committee_type_full': 'Senate',
#     'cycle': 2020,
#     'cycles': [1996,
#      1998,
#      2000,
#      2002,
#      2004,
#      2006,
#      2008,
#      2010,
#      2012,
#      2014,
#      2016,
#      2018,
#      2020],
#     'designation': 'P',
#     'designation_full': 'Principal campaign committee',
#     'filing_frequency': 'Q',
#     'name': 'COLLINS FOR SENATOR',
#     'organization_type': None,
#     'organization_type_full': None,
#     'party': 'REP',
#     'party_full': 'REPUBLICAN PARTY',
#     'state': 'ME',
#     'state_full': 'Maine',
#     'street_1': 'PO BOX 1096',
#     'street_2': None,
#     'treasurer_name': 'MCCANDLESS, ELIZABETH T.',
#     'zip': '04402'},
#    'committee_id': 'C00314575',
#    'committee_name': None,
#    'conduit_committee_city': None,
#    'conduit_committee_id': None,
#    'conduit_committee_name': None,
#    'conduit_committee_state': None,
#    'conduit_committee_street1': None,
#    'conduit_committee_street2': None,
#    'conduit_committee_zip': None,
#    'contribution_receipt_amount': 100.0,
#    'contribution_receipt_date': '2019-01-25T00:00:00',
#    'contributor': None,
#    'contributor_aggregate_ytd': 400.0,
#    'contributor_city': 'MCHENRY',
#    'contributor_employer': 'DIAMOND CORING',
#    'contributor_first_name': 'EDWARD',
#    'contributor_id': None,
#    'contributor_last_name': 'MASS',
#    'contributor_middle_name': None,
#    'contributor_name': 'MASS, EDWARD',
#    'contributor_occupation': 'ENGINEER',
#    'contributor_prefix': None,
#    'contributor_state': 'IL',
#    'contributor_street_1': '4908 MCCULLOM LAKE RD',
#    'contributor_street_2': None,
#    'contributor_suffix': None,
#    'contributor_zip': '600501528',
#    'donor_committee_name': None,
#    'election_type': 'P2020',
#    'election_type_full': None,
#    'entity_type': 'IND',
#    'entity_type_desc': 'INDIVIDUAL',
#    'fec_election_type_desc': 'PRIMARY',
#    'fec_election_year': '2020',
#    'file_number': 1322783,
#    'filing_form': 'F3',
#    'image_number': '201904079146047114',
#    'increased_limit': None,
#    'is_individual': True,
#    'line_number': '11AI',
#    'line_number_label': 'Contributions From Individuals/Persons Other Than Political Committees',
#    'link_id': 4040720191646004836,
#    'load_date': '2019-04-09T02:42:36.814000+00:00',
#    'memo_code': None,
#    'memo_code_full': None,
#    'memo_text': None,
#    'memoed_subtotal': False,
#    'national_committee_nonfederal_account': None,
#    'original_sub_id': None,
#    'pdf_url': 'http://docquery.fec.gov/cgi-bin/fecimg/?201904079146047114',
#    'receipt_type': '15',
#    'receipt_type_desc': 'CONTRIBUTION',
#    'receipt_type_full': None,
#    'recipient_committee_type': 'S',
#    'report_type': 'Q1',
#    'report_year': 2019,
#    'schedule_type': 'SA',
#    'schedule_type_full': 'ITEMIZED RECEIPTS',
#    'sub_id': '4040820191646013361',
#    'transaction_id': 'A115F086262FC4A47991',
#    'two_year_transaction_period': 2020,
#    'unused_contbr_id': None},
#   {'amendment_indicator': 'A',
#    'amendment_indicator_desc': 'ADD',
#    'back_reference_schedule_name': None,
#    'back_reference_transaction_id': None,
#    'candidate_first_name': None,
#    'candidate_id': None,
#    'candidate_last_name': None,
#    'candidate_middle_name': None,
#    'candidate_name': None,
#    'candidate_office': None,
#    'candidate_office_district': None,
#    'candidate_office_full': None,
#    'candidate_office_state': None,
#    'candidate_office_state_full': None,
#    'candidate_prefix': None,
#    'candidate_suffix': None,
#    'committee': {'candidate_ids': ['S6ME00159'],
#     'city': 'BANGOR',
#     'committee_id': 'C00314575',
#     'committee_type': 'S',
#     'committee_type_full': 'Senate',
#     'cycle': 2020,
#     'cycles': [1996,
#      1998,
#      2000,
#      2002,
#      2004,
#      2006,
#      2008,
#      2010,
#      2012,
#      2014,
#      2016,
#      2018,
#      2020],
#     'designation': 'P',
#     'designation_full': 'Principal campaign committee',
#     'filing_frequency': 'Q',
#     'name': 'COLLINS FOR SENATOR',
#     'organization_type': None,
#     'organization_type_full': None,
#     'party': 'REP',
#     'party_full': 'REPUBLICAN PARTY',
#     'state': 'ME',
#     'state_full': 'Maine',
#     'street_1': 'PO BOX 1096',
#     'street_2': None,
#     'treasurer_name': 'MCCANDLESS, ELIZABETH T.',
#     'zip': '04402'},
#    'committee_id': 'C00314575',
#    'committee_name': None,
#    'conduit_committee_city': None,
#    'conduit_committee_id': None,
#    'conduit_committee_name': None,
#    'conduit_committee_state': None,
#    'conduit_committee_street1': None,
#    'conduit_committee_street2': None,
#    'conduit_committee_zip': None,
#    'contribution_receipt_amount': 50.0,
#    'contribution_receipt_date': '2019-01-25T00:00:00',
#    'contributor': None,
#    'contributor_aggregate_ytd': 200.0,
#    'contributor_city': 'ANCHORAGE',
#    'contributor_employer': 'RETIRED',
# ...
#    'contributor_aggregate_ytd': 5400.0,
#    'contributor_city': 'SAINT JAMES',
#    'contributor_employer': 'RENAISSANCE TECHNOLOGIES',
#    'contributor_first_name': 'ROBERT',
#    'contributor_id': None,
#    'contributor_last_name': 'MERCER',
#    'contributor_middle_name': 'L.',
#    'contributor_name': 'MERCER, ROBERT L.',
#    'contributor_occupation': 'FINANCE',
#    'contributor_prefix': None,
#    'contributor_state': 'NY',
#    'contributor_street_1': '149 HARBOR RD',
#    'contributor_street_2': None,
#    'contributor_suffix': None,
#    'contributor_zip': '117801113',
#    'donor_committee_name': None,
#    'election_type': 'G2020',
#    'election_type_full': None,
#    'entity_type': 'IND',
#    'entity_type_desc': 'INDIVIDUAL',
#    'fec_election_type_desc': 'GENERAL',
#    'fec_election_year': '2020',
#    'file_number': 1322783,
#    'filing_form': 'F3',
#    'image_number': '201904079146047123',
#    'increased_limit': None,
#    'is_individual': True,
#    'line_number': '11AI',
#    'line_number_label': 'Contributions From Individuals/Persons Other Than Political Committees',
#    'link_id': 4040720191646004836,
#    'load_date': '2019-04-09T02:42:36.822000+00:00',
#    'memo_code': None,
#    'memo_code_full': None,
#    'memo_text': None,
#    'memoed_subtotal': False,
#    'national_committee_nonfederal_account': None,
#    'original_sub_id': None,
#    'pdf_url': 'http://docquery.fec.gov/cgi-bin/fecimg/?201904079146047123',
#    'receipt_type': '15',
#    'receipt_type_desc': 'CONTRIBUTION',
#    'receipt_type_full': None,
#    'recipient_committee_type': 'S',
#    'report_type': 'Q1',
#    'report_year': 2019,
#    'schedule_type': 'SA',
#    'schedule_type_full': 'ITEMIZED RECEIPTS',
#    'sub_id': '4040820191646013389',
#    'transaction_id': 'A560177DEA30A4A64A10',
#    'two_year_transaction_period': 2020,
#    'unused_contbr_id': None},
#   {'amendment_indicator': 'A',
#    'amendment_indicator_desc': 'ADD',
#    'back_reference_schedule_name': None,
#    'back_reference_transaction_id': None,
#    'candidate_first_name': None,
#    'candidate_id': None,
#    'candidate_last_name': None,
#    'candidate_middle_name': None,
#    'candidate_name': None,
#    'candidate_office': None,
#    'candidate_office_district': None,
#    'candidate_office_full': None,
#    'candidate_office_state': None,
#    'candidate_office_state_full': None,
#    'candidate_prefix': None,
#    'candidate_suffix': None,
#    'committee': {'candidate_ids': ['S6ME00159'],
#     'city': 'BANGOR',
#     'committee_id': 'C00314575',
#     'committee_type': 'S',
#     'committee_type_full': 'Senate',
#     'cycle': 2020,
#     'cycles': [1996,
#      1998,
#      2000,
#      2002,
#      2004,
#      2006,
#      2008,
#      2010,
#      2012,
#      2014,
#      2016,
#      2018,
#      2020],
#     'designation': 'P',
#     'designation_full': 'Principal campaign committee',
#     'filing_frequency': 'Q',
#     'name': 'COLLINS FOR SENATOR',
#     'organization_type': None,
#     'organization_type_full': None,
#     'party': 'REP',
#     'party_full': 'REPUBLICAN PARTY',
#     'state': 'ME',
#     'state_full': 'Maine',
#     'street_1': 'PO BOX 1096',
#     'street_2': None,
#     'treasurer_name': 'MCCANDLESS, ELIZABETH T.',
#     'zip': '04402'},
#    'committee_id': 'C00314575',
#    'committee_name': None,
#    'conduit_committee_city': None,
#    'conduit_committee_id': None,
#    'conduit_committee_name': None,
#    'conduit_committee_state': None,
#    'conduit_committee_street1': None,
#    'conduit_committee_street2': None,
#    'conduit_committee_zip': None,
#    'contribution_receipt_amount': 1000.0,
#    'contribution_receipt_date': '2019-02-02T00:00:00',
#    'contributor': None,
#    'contributor_aggregate_ytd': 2000.0,
#    'contributor_city': 'ALEXANDRIA',
#    'contributor_employer': 'THE DUBERSTEIN GROUP',
#    'contributor_first_name': 'DANIEL',
#    'contributor_id': None,
#    'contributor_last_name': 'MEYER',
#    'contributor_middle_name': 'P.',
#    'contributor_name': 'MEYER, DANIEL P.',
#    'contributor_occupation': 'SENIOR VICE PRESIDENT',
#    'contributor_prefix': None,
#    'contributor_state': 'VA',
#    'contributor_street_1': '3900 PICARDY CT',
#    'contributor_street_2': None,
#    'contributor_suffix': None,
#    'contributor_zip': '223092718',
#    'donor_committee_name': None,
#    'election_type': 'P2020',
#    'election_type_full': None,
#    'entity_type': 'IND',
#    'entity_type_desc': 'INDIVIDUAL',
#    'fec_election_type_desc': 'PRIMARY',
#    'fec_election_year': '2020',
#    'file_number': 1322783,
#    'filing_form': 'F3',
#    'image_number': '201904079146047124',
#    'increased_limit': None,
#    'is_individual': True,
#    'line_number': '11AI',
#    'line_number_label': 'Contributions From Individuals/Persons Other Than Political Committees',
#    'link_id': 4040720191646004836,
#    'load_date': '2019-04-09T02:42:36.822000+00:00',
#    'memo_code': None,
#    'memo_code_full': None,
#    'memo_text': None,
#    'memoed_subtotal': False,
#    'national_committee_nonfederal_account': None,
#    'original_sub_id': None,
#    'pdf_url': 'http://docquery.fec.gov/cgi-bin/fecimg/?201904079146047124',
#    'receipt_type': '15',
#    'receipt_type_desc': 'CONTRIBUTION',
#    'receipt_type_full': None,
#    'recipient_committee_type': 'S',
#    'report_type': 'Q1',
#    'report_year': 2019,
#    'schedule_type': 'SA',
#    'schedule_type_full': 'ITEMIZED RECEIPTS',
#    'sub_id': '4040820191646013390',
#    'transaction_id': 'A2B14CFA5C3B74025892',
#    'two_year_transaction_period': 2020,
#    'unused_contbr_id': None},
#   {'amendment_indicator': 'A',
#    'amendment_indicator_desc': 'ADD',
#    'back_reference_schedule_name': None,
#    'back_reference_transaction_id': None,
#    'candidate_first_name': None,
#    'candidate_id': None,
#    'candidate_last_name': None,
#    'candidate_middle_name': None,
#    'candidate_name': None,
#    'candidate_office': None,
#    'candidate_office_district': None,
#    'candidate_office_full': None,
#    'candidate_office_state': None,
#    'candidate_office_state_full': None,
#    'candidate_prefix': None,
#    'candidate_suffix': None,
#    'committee': {'candidate_ids': ['S6ME00159'],
#     'city': 'BANGOR',
#     'committee_id': 'C00314575',
#     'committee_type': 'S',
#     'committee_type_full': 'Senate',
#     'cycle': 2020,
#     'cycles': [1996,
#      1998,
#      2000,
#      2002,
#      2004,
#      2006,
#      2008,
#      2010,
#      2012,
#      2014,
#      2016,
#      2018,
#      2020],
#     'designation': 'P',
#     'designation_full': 'Principal campaign committee',
#     'filing_frequency': 'Q',
#     'name': 'COLLINS FOR SENATOR',
#     'organization_type': None,
#     'organization_type_full': None,
#     'party': 'REP',
#     'party_full': 'REPUBLICAN PARTY',
#     'state': 'ME',
#     'state_full': 'Maine',
#     'street_1': 'PO BOX 1096',
#     'street_2': None,
#     'treasurer_name': 'MCCANDLESS, ELIZABETH T.',
#     'zip': '04402'},
#    'committee_id': 'C00314575',
#    'committee_name': None,
#    'conduit_committee_city': None,
#    'conduit_committee_id': None,
#    'conduit_committee_name': None,
#    'conduit_committee_state': None,
#    'conduit_committee_street1': None,
#    'conduit_committee_street2': None,
#    'conduit_committee_zip': None,
#    'contribution_receipt_amount': 250.0,
#    'contribution_receipt_date': '2019-02-02T00:00:00',
#    'contributor': None,
#    'contributor_aggregate_ytd': 250.0,
#    'contributor_city': 'SUNRISE BEACH',
#    'contributor_employer': 'RETIRED',
#    'contributor_first_name': 'PALMER',
#    'contributor_id': None,
#    'contributor_last_name': 'MOE',
#    'contributor_middle_name': None,
#    'contributor_name': 'MOE, PALMER',
#    'contributor_occupation': 'RETIRED',
#    'contributor_prefix': None,
#    'contributor_state': 'TX',
#    'contributor_street_1': '319 GRANITE SHOALS LANE',
#    'contributor_street_2': None,
#    'contributor_suffix': None,
#    'contributor_zip': '786439377',
#    'donor_committee_name': None,
#    'election_type': 'P2020',
#    'election_type_full': None,
#    'entity_type': 'IND',
#    'entity_type_desc': 'INDIVIDUAL',
#    'fec_election_type_desc': 'PRIMARY',
#    'fec_election_year': '2020',
#    'file_number': 1322783,
#    'filing_form': 'F3',
#    'image_number': '201904079146047132',
#    'increased_limit': None,
#    'is_individual': True,
#    'line_number': '11AI',
#    'line_number_label': 'Contributions From Individuals/Persons Other Than Political Committees',
#    'link_id': 4040720191646004836,
#    'load_date': '2019-04-09T02:42:36.830000+00:00',
#    'memo_code': None,
#    'memo_code_full': None,
#    'memo_text': None,
#    'memoed_subtotal': False,
#    'national_committee_nonfederal_account': None,
#    'original_sub_id': None,
#    'pdf_url': 'http://docquery.fec.gov/cgi-bin/fecimg/?201904079146047132',
#    'receipt_type': '15',
#    'receipt_type_desc': 'CONTRIBUTION',
#    'receipt_type_full': None,
#    'recipient_committee_type': 'S',
#    'report_type': 'Q1',
#    'report_year': 2019,
#    'schedule_type': 'SA',
#    'schedule_type_full': 'ITEMIZED RECEIPTS',
#    'sub_id': '4040820191646013415',
#    'transaction_id': 'A8E7C2ABB59784D44BB5',
#    'two_year_transaction_period': 2020,
#    'unused_contbr_id': None},
#   {'amendment_indicator': 'A',
#    'amendment_indicator_desc': 'ADD',
#    'back_reference_schedule_name': None,
#    'back_reference_transaction_id': None,
#    'candidate_first_name': None,
#    'candidate_id': None,
#    'candidate_last_name': None,
#    'candidate_middle_name': None,
#    'candidate_name': None,
#    'candidate_office': None,
#    'candidate_office_district': None,
#    'candidate_office_full': None,
#    'candidate_office_state': None,
#    'candidate_office_state_full': None,
#    'candidate_prefix': None,
#    'candidate_suffix': None,
#    'committee': {'candidate_ids': ['S6ME00159'],
#     'city': 'BANGOR',
#     'committee_id': 'C00314575',
#     'committee_type': 'S',
#     'committee_type_full': 'Senate',
#     'cycle': 2020,
#     'cycles': [1996,
#      1998,
#      2000,
#      2002,
#      2004,
#      2006,
#      2008,
#      2010,
#      2012,
#      2014,
#      2016,
#      2018,
#      2020],
#     'designation': 'P',
#     'designation_full': 'Principal campaign committee',
#     'filing_frequency': 'Q',
#     'name': 'COLLINS FOR SENATOR',
#     'organization_type': None,
#     'organization_type_full': None,
#     'party': 'REP',
#     'party_full': 'REPUBLICAN PARTY',
#     'state': 'ME',
#     'state_full': 'Maine',
#     'street_1': 'PO BOX 1096',
#     'street_2': None,
#     'treasurer_name': 'MCCANDLESS, ELIZABETH T.',
#     'zip': '04402'},
#    'committee_id': 'C00314575',
#    'committee_name': None,
#    'conduit_committee_city': None,
#    'conduit_committee_id': None,
#    'conduit_committee_name': None,
#    'conduit_committee_state': None,
#    'conduit_committee_street1': None,
#    'conduit_committee_street2': None,
#    'conduit_committee_zip': None,
#    'contribution_receipt_amount': 2700.0,
#    'contribution_receipt_date': '2019-02-02T00:00:00',
#    'contributor': None,
#    'contributor_aggregate_ytd': 2700.0,
#    'contributor_city': 'HOUSTON',
#    'contributor_employer': 'SILVER EAGLE DISTRIBUTORS',
#    'contributor_first_name': 'JOHN',
#    'contributor_id': None,
#    'contributor_last_name': 'NAU',
#    'contributor_middle_name': 'L.',
#    'contributor_name': 'NAU, JOHN L. III',
#    'contributor_occupation': 'PRESIDENT AND C.E.O.',
#    'contributor_prefix': None,
#    'contributor_state': 'TX',
#    'contributor_street_1': 'PO BOX 130130',
#    'contributor_street_2': None,
#    'contributor_suffix': 'III',
#    'contributor_zip': '772190130',
#    'donor_committee_name': None,
#    'election_type': 'P2020',
#    'election_type_full': None,
#    'entity_type': 'IND',
#    'entity_type_desc': 'INDIVIDUAL',
#    'fec_election_type_desc': 'PRIMARY',
#    'fec_election_year': '2020',
#    'file_number': 1322783,
#    'filing_form': 'F3',
#    'image_number': '201904079146047137',
#    'increased_limit': None,
#    'is_individual': True,
#    'line_number': '11AI',
#    'line_number_label': 'Contributions From Individuals/Persons Other Than Political Committees',
#    'link_id': 4040720191646004836,
#    'load_date': '2019-04-09T02:42:36.833000+00:00',
#    'memo_code': None,
#    'memo_code_full': None,
#    'memo_text': None,
#    'memoed_subtotal': False,
#    'national_committee_nonfederal_account': None,
#    'original_sub_id': None,
#    'pdf_url': 'http://docquery.fec.gov/cgi-bin/fecimg/?201904079146047137',
#    'receipt_type': '15',
#    'receipt_type_desc': 'CONTRIBUTION',
#    'receipt_type_full': None,
#    'recipient_committee_type': 'S',
#    'report_type': 'Q1',
#    'report_year': 2019,
#    'schedule_type': 'SA',
#    'schedule_type_full': 'ITEMIZED RECEIPTS',
#    'sub_id': '4040820191646013430',
#    'transaction_id': 'ADE6B73A3853B4068ACB',
#    'two_year_transaction_period': 2020,
#    'unused_contbr_id': None},
#   {'amendment_indicator': 'A',
#    'amendment_indicator_desc': 'ADD',
#    'back_reference_schedule_name': None,
#    'back_reference_transaction_id': None,
#    'candidate_first_name': None,
#    'candidate_id': None,
#    'candidate_last_name': None,
#    'candidate_middle_name': None,
#    'candidate_name': None,
#    'candidate_office': None,
#    'candidate_office_district': None,
#    'candidate_office_full': None,
#    'candidate_office_state': None,
#    'candidate_office_state_full': None,
#    'candidate_prefix': None,
#    'candidate_suffix': None,
#    'committee': {'candidate_ids': ['S6ME00159'],
#     'city': 'BANGOR',
#     'committee_id': 'C00314575',
#     'committee_type': 'S',
#     'committee_type_full': 'Senate',
#     'cycle': 2020,
#     'cycles': [1996,
#      1998,
#      2000,
#      2002,
#      2004,
#      2006,
#      2008,
#      2010,
#      2012,
#      2014,
#      2016,
#      2018,
#      2020],
#     'designation': 'P',
#     'designation_full': 'Principal campaign committee',
#     'filing_frequency': 'Q',
#     'name': 'COLLINS FOR SENATOR',
#     'organization_type': None,
#     'organization_type_full': None,
#     'party': 'REP',
#     'party_full': 'REPUBLICAN PARTY',
#     'state': 'ME',
#     'state_full': 'Maine',
#     'street_1': 'PO BOX 1096',
#     'street_2': None,
#     'treasurer_name': 'MCCANDLESS, ELIZABETH T.',
#     'zip': '04402'},
#    'committee_id': 'C00314575',
#    'committee_name': None,
#    'conduit_committee_city': None,
#    'conduit_committee_id': None,
#    'conduit_committee_name': None,
#    'conduit_committee_state': None,
#    'conduit_committee_street1': None,
#    'conduit_committee_street2': None,
#    'conduit_committee_zip': None,
#    'contribution_receipt_amount': 2700.0,
#    'contribution_receipt_date': '2019-02-02T00:00:00',
#    'contributor': None,
#    'contributor_aggregate_ytd': 5400.0,
#    'contributor_city': 'SAN FRANCISCO',
#    'contributor_employer': 'OBERNDORF FOUNDATION',
#    'contributor_first_name': 'SUSAN',
#    'contributor_id': None,
#    'contributor_last_name': 'OBERNDORF',
#    'contributor_middle_name': 'C.',
#    'contributor_name': 'OBERNDORF, SUSAN C.',
#    'contributor_occupation': 'EXECUTIVE',
#    'contributor_prefix': None,
#    'contributor_state': 'CA',
#    'contributor_street_1': '615 FRONT STREET',
#    'contributor_street_2': None,
#    'contributor_suffix': None,
#    'contributor_zip': '941111913',
#    'donor_committee_name': None,
#    'election_type': 'G2020',
#    'election_type_full': None,
#    'entity_type': 'IND',
#    'entity_type_desc': 'INDIVIDUAL',
#    'fec_election_type_desc': 'GENERAL',
#    'fec_election_year': '2020',
#    'file_number': 1322783,
#    'filing_form': 'F3',
#    'image_number': '201904079146047142',
#    'increased_limit': None,
#    'is_individual': True,
#    'line_number': '11AI',
#    'line_number_label': 'Contributions From Individuals/Persons Other Than Political Committees',
#    'link_id': 4040720191646004836,
#    'load_date': '2019-04-09T02:42:36.838000+00:00',
#    'memo_code': None,
#    'memo_code_full': None,
#    'memo_text': None,
#    'memoed_subtotal': False,
#    'national_committee_nonfederal_account': None,
#    'original_sub_id': None,
#    'pdf_url': 'http://docquery.fec.gov/cgi-bin/fecimg/?201904079146047142',
#    'receipt_type': '15',
#    'receipt_type_desc': 'CONTRIBUTION',
#    'receipt_type_full': None,
#    'recipient_committee_type': 'S',
#    'report_type': 'Q1',
#    'report_year': 2019,
#    'schedule_type': 'SA',
#    'schedule_type_full': 'ITEMIZED RECEIPTS',
#    'sub_id': '4040820191646013446',
#    'transaction_id': 'ADFC01FA3F5A94C4FB23',
#    'two_year_transaction_period': 2020,
#    'unused_contbr_id': None}]}

# %%
# Out:
# 9

# %%
data = json_normalize(r)
r['results']
df = pd.DataFrame.from_dict(r['results'])
df
# Out:
#    amendment_indicator amendment_indicator_desc back_reference_schedule_name  \
# 0                    A                      ADD                         None
# 1                    A                      ADD                         None
# 2                    A                      ADD                         None
# 3                    A                      ADD                         None
# 4                    A                      ADD                         None
# 5                    A                      ADD                         None
# 6                    A                      ADD                         None
# 7                    A                      ADD                         None
# 8                    A                      ADD                         None
# 9                    A                      ADD                         None
# 10                   A                      ADD                         None
# 11                   A                      ADD                         None
# 12                   A                      ADD                         None
# 13                   A                      ADD                         None
# 14                   A                      ADD                         None
# 15                   A                      ADD                         None
# 16                   A                      ADD                         None
# 17                   A                      ADD                         None
# 18                   A                      ADD                         None
# 19                   A                      ADD                         None
# 20                   A                      ADD                         None
# 21                   A                      ADD                         None
# 22                   A                      ADD                         None
# 23                   A                      ADD                         None
# 24                   A                      ADD                         None
# 25                   A                      ADD                         None
# 26                   A                      ADD                         None
# 27                   A                      ADD                         None
# 28                   A                      ADD                         None
# 29                   A                      ADD                         None
# ..                 ...                      ...                          ...
# 70                   A                      ADD                         None
# 71                   A                      ADD                         None
# 72                   A                      ADD                         None
# 73                   A                      ADD                         None
# 74                   A                      ADD                         None
# 75                   A                      ADD                         None
# 76                   A                      ADD                         None
# 77                   A                      ADD                         None
# 78                   A                      ADD                         None
# 79                   A                      ADD                         None
# 80                   A                      ADD                         None
# 81                   A                      ADD                         None
# 82                   A                      ADD                         None
# 83                   A                      ADD                         None
# 84                   A                      ADD                         None
# 85                   A                      ADD                         None
# 86                   A                      ADD                         None
# 87                   A                      ADD                         None
# 88                   A                      ADD                         None
# 89                   A                      ADD                         None
# 90                   A                      ADD                         None
# 91                   A                      ADD                         None
# 92                   A                      ADD                         None
# 93                   A                      ADD                         None
# 94                   A                      ADD                         None
# 95                   A                      ADD                         None
# 96                   A                      ADD                         None
# 97                   A                      ADD                         None
# 98                   A                      ADD                         None
# 99                   A                      ADD                         None
#
#    back_reference_transaction_id candidate_first_name candidate_id  \
# 0                           None                 None         None
# 1                           None                 None         None
# 2                           None                 None         None
# 3                           None                 None         None
# 4                           None                 None         None
# 5                           None                 None         None
# 6                           None                 None         None
# 7                           None                 None         None
# 8                           None                 None         None
# 9                           None                 None         None
# 10                          None                 None         None
# 11                          None                 None         None
# 12                          None                 None         None
# 13                          None                 None         None
# 14                          None                 None         None
# 15                          None                 None         None
# 16                          None                 None         None
# 17                          None                 None         None
# 18                          None                 None         None
# 19                          None                 None         None
# 20                          None                 None         None
# 21                          None                 None         None
# 22                          None                 None         None
# 23                          None                 None         None
# 24                          None                 None         None
# 25                          None                 None         None
# 26                          None                 None         None
# 27                          None                 None         None
# 28                          None                 None         None
# 29                          None                 None         None
# ..                           ...                  ...          ...
# 70                          None                 None         None
# 71                          None                 None         None
# 72                          None                 None         None
# 73                          None                 None         None
# 74                          None                 None         None
# 75                          None                 None         None
# 76                          None                 None         None
# 77                          None                 None         None
# 78                          None                 None         None
# 79                          None                 None         None
# 80                          None                 None         None
# 81                          None                 None         None
# 82                          None                 None         None
# 83                          None                 None         None
# 84                          None                 None         None
# 85                          None                 None         None
# 86                          None                 None         None
# 87                          None                 None         None
# 88                          None                 None         None
# 89                          None                 None         None
# 90                          None                 None         None
# 91                          None                 None         None
# 92                          None                 None         None
# 93                          None                 None         None
# 94                          None                 None         None
# 95                          None                 None         None
# 96                          None                 None         None
# 97                          None                 None         None
# 98                          None                 None         None
# 99                          None                 None         None
#
#    candidate_last_name candidate_middle_name candidate_name candidate_office  \
# 0                 None                  None           None             None
# 1                 None                  None           None             None
# 2                 None                  None           None             None
# 3                 None                  None           None             None
# 4                 None                  None           None             None
# 5                 None                  None           None             None
# 6                 None                  None           None             None
# 7                 None                  None           None             None
# 8                 None                  None           None             None
# 9                 None                  None           None             None
# 10                None                  None           None             None
# 11                None                  None           None             None
# 12                None                  None           None             None
# 13                None                  None           None             None
# 14                None                  None           None             None
# 15                None                  None           None             None
# 16                None                  None           None             None
# 17                None                  None           None             None
# 18                None                  None           None             None
# 19                None                  None           None             None
# 20                None                  None           None             None
# 21                None                  None           None             None
# 22                None                  None           None             None
# 23                None                  None           None             None
# 24                None                  None           None             None
# 25                None                  None           None             None
# 26                None                  None           None             None
# 27                None                  None           None             None
# 28                None                  None           None             None
# 29                None                  None           None             None
# ..                 ...                   ...            ...              ...
# 70                None                  None           None             None
# 71                None                  None           None             None
# 72                None                  None           None             None
# 73                None                  None           None             None
# 74                None                  None           None             None
# 75                None                  None           None             None
# 76                None                  None           None             None
# 77                None                  None           None             None
# 78                None                  None           None             None
# 79                None                  None           None             None
# 80                None                  None           None             None
# 81                None                  None           None             None
# 82                None                  None           None             None
# 83                None                  None           None             None
# 84                None                  None           None             None
# 85                None                  None           None             None
# 86                None                  None           None             None
# 87                None                  None           None             None
# 88                None                  None           None             None
# 89                None                  None           None             None
# 90                None                  None           None             None
# 91                None                  None           None             None
# 92                None                  None           None             None
# 93                None                  None           None             None
# 94                None                  None           None             None
# 95                None                  None           None             None
# 96                None                  None           None             None
# 97                None                  None           None             None
# 98                None                  None           None             None
# 99                None                  None           None             None
#
#          ...        receipt_type_full recipient_committee_type report_type  \
# 0        ...                     None                        S          Q1
# 1        ...                     None                        S          Q1
# 2        ...                     None                        S          Q1
# 3        ...                     None                        S          Q1
# 4        ...                     None                        S          Q1
# 5        ...                     None                        S          Q1
# 6        ...                     None                        S          Q1
# 7        ...                     None                        S          Q1
# 8        ...                     None                        S          Q1
# 9        ...                     None                        S          Q1
# 10       ...                     None                        S          Q1
# 11       ...                     None                        S          Q1
# 12       ...                     None                        S          Q1
# 13       ...                     None                        S          Q1
# 14       ...                     None                        S          Q1
# 15       ...                     None                        S          Q1
# 16       ...                     None                        S          Q1
# 17       ...                     None                        S          Q1
# 18       ...                     None                        S          Q1
# 19       ...                     None                        S          Q1
# 20       ...                     None                        S          Q1
# 21       ...                     None                        S          Q1
# 22       ...                     None                        S          Q1
# 23       ...                     None                        S          Q1
# 24       ...                     None                        S          Q1
# 25       ...                     None                        S          Q1
# 26       ...                     None                        S          Q1
# 27       ...                     None                        S          Q1
# 28       ...                     None                        S          Q1
# 29       ...                     None                        S          Q1
# ..       ...                      ...                      ...         ...
# 70       ...                     None                        S          Q1
# 71       ...                     None                        S          Q1
# 72       ...                     None                        S          Q1
# 73       ...                     None                        S          Q1
# 74       ...                     None                        S          Q1
# 75       ...                     None                        S          Q1
# 76       ...                     None                        S          Q1
# 77       ...                     None                        S          Q1
# 78       ...                     None                        S          Q1
# 79       ...                     None                        S          Q1
# 80       ...                     None                        S          Q1
# 81       ...                     None                        S          Q1
# 82       ...                     None                        S          Q1
# 83       ...                     None                        S          Q1
# 84       ...                     None                        S          Q1
# 85       ...                     None                        S          Q1
# 86       ...                     None                        S          Q1
# 87       ...                     None                        S          Q1
# 88       ...                     None                        S          Q1
# 89       ...                     None                        S          Q1
# 90       ...                     None                        S          Q1
# 91       ...                     None                        S          Q1
# 92       ...                     None                        S          Q1
# 93       ...                     None                        S          Q1
# 94       ...                     None                        S          Q1
# 95       ...                     None                        S          Q1
# 96       ...                     None                        S          Q1
# 97       ...                     None                        S          Q1
# 98       ...                     None                        S          Q1
# 99       ...                     None                        S          Q1
#
#    report_year schedule_type schedule_type_full               sub_id  \
# 0         2019            SA  ITEMIZED RECEIPTS  4040820191646013039
# 1         2019            SA  ITEMIZED RECEIPTS  4040820191646013082
# 2         2019            SA  ITEMIZED RECEIPTS  4040820191646013115
# 3         2019            SA  ITEMIZED RECEIPTS  4040820191646013134
# 4         2019            SA  ITEMIZED RECEIPTS  4040820191646013157
# 5         2019            SA  ITEMIZED RECEIPTS  4040820191646013179
# 6         2019            SA  ITEMIZED RECEIPTS  4040820191646013225
# 7         2019            SA  ITEMIZED RECEIPTS  4040820191646013255
# 8         2019            SA  ITEMIZED RECEIPTS  4040820191646013279
# 9         2019            SA  ITEMIZED RECEIPTS  4040820191646013315
# 10        2019            SA  ITEMIZED RECEIPTS  4040820191646013336
# 11        2019            SA  ITEMIZED RECEIPTS  4040820191646013356
# 12        2019            SA  ITEMIZED RECEIPTS  4040820191646013361
# 13        2019            SA  ITEMIZED RECEIPTS  4040820191646013366
# 14        2019            SA  ITEMIZED RECEIPTS  4040820191646013398
# 15        2019            SA  ITEMIZED RECEIPTS  4040820191646013426
# 16        2019            SA  ITEMIZED RECEIPTS  4040820191646013516
# 17        2019            SA  ITEMIZED RECEIPTS  4040820191646013561
# 18        2019            SA  ITEMIZED RECEIPTS  4040820191646013654
# 19        2019            SA  ITEMIZED RECEIPTS  4040820191646013688
# 20        2019            SA  ITEMIZED RECEIPTS  4040820191646013711
# 21        2019            SA  ITEMIZED RECEIPTS  4040820191646013015
# 22        2019            SA  ITEMIZED RECEIPTS  4040820191646013078
# 23        2019            SA  ITEMIZED RECEIPTS  4040820191646013129
# 24        2019            SA  ITEMIZED RECEIPTS  4040820191646013260
# 25        2019            SA  ITEMIZED RECEIPTS  4040820191646013273
# 26        2019            SA  ITEMIZED RECEIPTS  4040820191646013305
# 27        2019            SA  ITEMIZED RECEIPTS  4040820191646013455
# 28        2019            SA  ITEMIZED RECEIPTS  4040820191646013495
# 29        2019            SA  ITEMIZED RECEIPTS  4040820191646013707
# ..         ...           ...                ...                  ...
# 70        2019            SA  ITEMIZED RECEIPTS  4040820191646013635
# 71        2019            SA  ITEMIZED RECEIPTS  4040820191646013636
# 72        2019            SA  ITEMIZED RECEIPTS  4040820191646013637
# 73        2019            SA  ITEMIZED RECEIPTS  4040820191646013638
# 74        2019            SA  ITEMIZED RECEIPTS  4040820191646012919
# 75        2019            SA  ITEMIZED RECEIPTS  4040820191646013009
# 76        2019            SA  ITEMIZED RECEIPTS  4040820191646013027
# 77        2019            SA  ITEMIZED RECEIPTS  4040820191646013028
# 78        2019            SA  ITEMIZED RECEIPTS  4040820191646013031
# 79        2019            SA  ITEMIZED RECEIPTS  4040820191646013047
# 80        2019            SA  ITEMIZED RECEIPTS  4040820191646013048
# 81        2019            SA  ITEMIZED RECEIPTS  4040820191646013049
# 82        2019            SA  ITEMIZED RECEIPTS  4040820191646013050
# 83        2019            SA  ITEMIZED RECEIPTS  4040820191646013051
# 84        2019            SA  ITEMIZED RECEIPTS  4040820191646013102
# 85        2019            SA  ITEMIZED RECEIPTS  4040820191646013103
# 86        2019            SA  ITEMIZED RECEIPTS  4040820191646013104
# 87        2019            SA  ITEMIZED RECEIPTS  4040820191646013105
# 88        2019            SA  ITEMIZED RECEIPTS  4040820191646013164
# 89        2019            SA  ITEMIZED RECEIPTS  4040820191646013171
# 90        2019            SA  ITEMIZED RECEIPTS  4040820191646013173
# 91        2019            SA  ITEMIZED RECEIPTS  4040820191646013359
# 92        2019            SA  ITEMIZED RECEIPTS  4040820191646013386
# 93        2019            SA  ITEMIZED RECEIPTS  4040820191646013387
# 94        2019            SA  ITEMIZED RECEIPTS  4040820191646013388
# 95        2019            SA  ITEMIZED RECEIPTS  4040820191646013389
# 96        2019            SA  ITEMIZED RECEIPTS  4040820191646013390
# 97        2019            SA  ITEMIZED RECEIPTS  4040820191646013415
# 98        2019            SA  ITEMIZED RECEIPTS  4040820191646013430
# 99        2019            SA  ITEMIZED RECEIPTS  4040820191646013446
#
#           transaction_id two_year_transaction_period unused_contbr_id
# 0   AC1C778FAA9F947FCB5B                        2020             None
# 1   AC89769045D39476184F                        2020             None
# 2   A280B235C4F5B43DDA6A                        2020             None
# 3   AFDAAA9D1244C4274AE0                        2020             None
# 4   A9789D8329FB84C3A976                        2020             None
# 5   AB9B3C7DCE9E748F6BC1                        2020             None
# 6   AADD9C48ECDD44E7DBC0                        2020             None
# 7   A6917801701764472B28                        2020             None
# 8   A73AF2BDC237D43DBB68                        2020             None
# 9   A0865815980C7485AA1A                        2020             None
# 10  A99470A6BF09641C0B17                        2020             None
# 11  A4F423F06190D4119A1D                        2020             None
# 12  A115F086262FC4A47991                        2020             None
# 13  ACF77730188AC4E48B5E                        2020             None
# 14  A81603E43589341CEA5E                        2020             None
# 15  AD380B9F8BC934514AC9                        2020             None
# 16  A472FDFAAF18845C09A5                        2020             None
# 17  A1F9056DE19B540699C8                        2020             None
# 18  A1F69340399D94355893                        2020             None
# 19  A115E071301F2489788D                        2020             None
# 20  AB07013254B1B4E5CA7F                        2020             None
# 21  AEC90140AC1EE4CBB8BF                        2020             None
# 22  AD320C0DB73D74538879                        2020             None
# 23  AF09B457E76014869B71                        2020             None
# 24  AA9F96879B8964522878                        2020             None
# 25  A17B20FEA67A2423BA91                        2020             None
# 26  AE9844634B38B4D219EB                        2020             None
# 27  A7955583AFE454368939                        2020             None
# 28  AD3FD8BAF3137456CA4A                        2020             None
# 29  AED456E796C664E5297B                        2020             None
# ..                   ...                         ...              ...
# 70  AC3A925FB7489471EBFB                        2020             None
# 71  AB7EE19EF83254C908CE                        2020             None
# 72  A86B72EA7E7EE431F9F5                        2020             None
# 73  A44AF6C7A85A54C3BB1E                        2020             None
# 74  AA9B5067434874C809CF                        2020             None
# 75  A713E694034294C3EA26                        2020             None
# 76  AD71C893A363840B68DA                        2020             None
# 77  AAC0FF923802F4F27BE8                        2020             None
# 78  A1D97F07556524F9E916                        2020             None
# 79  A4FEFCED4262345478C0                        2020             None
# 80  AE0746530934142FF86A                        2020             None
# 81  AE663F5D0133848DDB07                        2020             None
# 82  A9F8DD4FC057D4A0AB0E                        2020             None
# 83  AB086D51E1FBD429689B                        2020             None
# 84  AE0AEAF54399548C8986                        2020             None
# 85  AC07C30DD9043408083D                        2020             None
# 86  AC53633C3026D4874A65                        2020             None
# 87  ADF65194B90AD45EB93B                        2020             None
# 88  A7FA8F7CBBD67444396E                        2020             None
# 89  A63F67446A99A479FAAE                        2020             None
# 90  A57672D17D04044D08F3                        2020             None
# 91  ABBBB0BDF399D4A08A6B                        2020             None
# 92  ABE22EAB96F9946EF8C7                        2020             None
# 93  A88E42EED2E404465AD9                        2020             None
# 94  A381A347188454879898                        2020             None
# 95  A560177DEA30A4A64A10                        2020             None
# 96  A2B14CFA5C3B74025892                        2020             None
# 97  A8E7C2ABB59784D44BB5                        2020             None
# 98  ADE6B73A3853B4068ACB                        2020             None
# 99  ADFC01FA3F5A94C4FB23                        2020             None
#
# [100 rows x 79 columns]

# %%
#Write results to a CSV
cwd = os.getcwd()
df.to_csv(cwd+'/collins-itemized-receipts.csv')

# %%
#Template for paging through results

page = 1

def getNextPage(nextpage):
    global page
    page = page + 1
    print('PAGE ', page)
    headers = {"Authorization": "Bearer " + token}
    r = requests.get(nextpage, headers=headers)
    nextpage = r.json()['pagination']['next_link']
    records = r.json()['data']
    for user in records:
        s  = pd.Series(user,index=user.keys())
        global records_df
        records_df.loc[len(records_df)] = s
    records_df.to_csv('records.csv')
    if nextpage:
        getNextPage(nextpage)

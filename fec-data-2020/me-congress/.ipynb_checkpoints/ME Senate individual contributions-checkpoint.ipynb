# %%
import numpy as np
import pandas as pd
import requests
import config
import os
import json
from pandas.io.json import json_normalize
import time

##Schedule_a API guide: https://api.open.fec.gov/developers/#/receipts/get_schedules_schedule_a_˜

# %%
### MULTI-CANDIDATE SEARCH ###
#Set search for all 2020 (two-year transaction period) Maine Congressional candidates
cand_state = 'ME'
period='2020'
parameters = {'election_year':period
            ,'state':cand_state
            ,'api_key':config.api_key}
#To iterate over comm_ids
id=int(0)

#Requests candidate info
r_cands = requests.get('https://api.open.fec.gov/v1/candidates/search',params=parameters).json()

#Locates and sets Committee ID from 'principal_committees' sub-array
#Output list of IDs
comm_ids=json_normalize(data=r_cands['results'],record_path='principal_committees')['committee_id'].tolist()
comm_ids
# Out:
# ['C00715532',
#  'C00722108',
#  'C00713958',
#  'C00710087',
#  'C00314575',
#  'C00722454',
#  'C00709899',
#  'C00653816',
#  'C00703413',
#  'C00706739',
#  'C00683193',
#  'C00433391',
#  'C00723411',
#  'C00709279',
#  'C00712323',
#  'C00694364']

# %%
## INDIVIDUAL DONATIONS TO MAINE SENATE CAMPAIGNS ##
#Initialize dataframe collector for itemized contribs
cycle='2020'
dfs=[]
commid=0

#Initialize query dictionary
querydict = {'per_page':'100'
              ,'sort':'contribution_receipt_date'
              ,'api_key':config.api_key
              ,'is_individual':'true'
              ,'two_year_transaction_period':cycle
              ,'last_index':[]
              ,'last_contribution_receipt_date':[]
              ,'committee_id':comm_ids[commid]
             }

#Page through results for each committee id
for x in comm_ids:
    
    #Get first payload for next candidate
    r = requests.get('https://api.open.fec.gov/v1/schedules/schedule_a/',params=querydict).json()
    
    #For validation only
    print(querydict)
    
    #Last page variables
    while r['pagination']['last_indexes'] is not None:
        
        #Store results of payload
        df = json_normalize(r['results'])
        dfs.append(df)
        
        #For validation only
        print('page: '+str(commid)+','+str(r['pagination']['per_page'])+' records')
        
        #Assign last_index and date values, update querydict
        last_index=pd.to_numeric(r['pagination']['last_indexes']['last_index'])
        last_date=r['pagination']['last_indexes']['last_contribution_receipt_date']
        #Update dictionary with new indices
        querydict.update([('last_index',last_index)
                        ,('last_contribution_receipt_date',last_date)])

        #Get next payload
        r = requests.get('https://api.open.fec.gov/v1/schedules/schedule_a/',params=querydict).json()

    commid+=1
    
    #Update dictionary with candidate, reset last indices
    querydict.update([('committee_id',comm_ids[commid])])
# Out:
# {'per_page': '100', 'sort': 'contribution_receipt_date', 'api_key': 'egxSs7endLz5xMuoprm5zfVZCeoyeZbO5D6HFzJz', 'is_individual': 'true', 'two_year_transaction_period': '2020', 'last_index': [], 'last_contribution_receipt_date': [], 'committee_id': 'C00715532'}
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-68-8a0e448bbdf4> in <module>()
#      30
#      31     #Last page variables
# ---> 32     while r['pagination']['last_indexes'] is not None:
#      33
#      34         print('page: '+str(commid)+','+str(r['pagination']['per_page'])+' records')
#
# KeyError: 'pagination'

# %%
r
# Out:
# {'error': {'code': 'OVER_RATE_LIMIT',
#   'message': 'You have exceeded your rate limit of 40 calls per hour for the DEMO_KEY, 1000 calls per hour for a personal key, or 120 calls per minute for an upgraded key. You can either try again later, sign up for a personal key at https://api.data.gov/signup/, or email apiinfo@fec.gov to upgrade your key.'}}

# %%
querydict2 = {'per_page':'100'
              ,'sort':'contribution_receipt_date'
              ,'api_key':config.api_key
              ,'is_individual':'true'
              ,'two_year_transaction_period':cycle
              ,'last_index':[]
              ,'last_contribution_receipt_date':[]
              ,'committee_id':'C00709899'
             }

r2 = requests.get('https://api.open.fec.gov/v1/schedules/schedule_a/',params=querydict2).json()
r2
# Out:
# {'api_version': '1.0',
#  'pagination': {'count': 4723,
#   'last_indexes': {'last_contribution_receipt_date': '2019-06-24T00:00:00',
#    'last_index': '4090620191672335968'},
#   'pages': 48,
#   'per_page': 100},
#  'results': [{'amendment_indicator': 'N',
#    'amendment_indicator_desc': 'NO CHANGE',
#    'back_reference_schedule_name': 'SA11AI',
#    'back_reference_transaction_id': 'VVC97N5TZS1E',
#    'candidate_first_name': None,
#    'candidate_id': None,
#    'candidate_last_name': None,
#    'candidate_middle_name': None,
#    'candidate_name': None,
#    'candidate_office': None,
#    'candidate_office_district': None,
#    'candidate_office_full': None,
#    'candidate_office_state': None,
#    'candidate_office_state_full': None,
#    'candidate_prefix': None,
#    'candidate_suffix': None,
#    'committee': {'affiliated_committee_name': 'NONE',
#     'candidate_ids': ['S0ME00111'],
#     'city': 'SOUTH FREEPORT',
#     'committee_id': 'C00709899',
#     'committee_type': 'S',
#     'committee_type_full': 'Senate',
#     'cycle': 2020,
#     'cycles': [2020],
#     'designation': 'P',
#     'designation_full': 'Principal campaign committee',
#     'filing_frequency': 'Q',
#     'name': 'SARA GIDEON FOR MAINE',
#     'organization_type': None,
#     'organization_type_full': None,
#     'party': 'DEM',
#     'party_full': 'DEMOCRATIC PARTY',
#     'state': 'ME',
#     'state_full': 'Maine',
#     'street_1': 'PO BOX 812',
#     'street_2': None,
#     'treasurer_name': 'LUNN, LISA MS.',
#     'zip': '04078'},
#    'committee_id': 'C00709899',
#    'committee_name': None,
#    'conduit_committee_city': None,
#    'conduit_committee_id': None,
#    'conduit_committee_name': None,
#    'conduit_committee_state': None,
#    'conduit_committee_street1': None,
#    'conduit_committee_street2': None,
#    'conduit_committee_zip': None,
#    'contribution_receipt_amount': 1000.0,
#    'contribution_receipt_date': '2019-06-20T00:00:00',
#    'contributor': {'affiliated_committee_name': 'NONE',
#     'candidate_ids': [],
#     'city': 'SOMERVILLE',
#     'committee_id': 'C00401224',
#     'committee_type': 'W',
#     'committee_type_full': 'PAC with Non-Contribution Account - Qualified',
#     'cycle': 2020,
#     'cycles': [2004, 2006, 2008, 2010, 2012, 2014, 2016, 2018, 2020],
#     'designation': 'U',
#     'designation_full': 'Unauthorized',
#     'filing_frequency': 'Q',
#     'name': 'ACTBLUE',
#     'organization_type': None,
#     'organization_type_full': None,
#     'party': None,
#     'party_full': None,
#     'state': 'MA',
#     'state_full': 'Massachusetts',
#     'street_1': 'P.O. BOX 441146',
#     'street_2': None,
#     'treasurer_name': 'HILL, ERIN',
#     'zip': '02144'},
#    'contributor_aggregate_ytd': 1000.0,
#    'contributor_city': 'SARATOGA',
#    'contributor_employer': 'GRADIENT',
#    'contributor_first_name': 'TOM',
#    'contributor_id': 'C00401224',
#    'contributor_last_name': 'COSTELLO',
#    'contributor_middle_name': None,
#    'contributor_name': 'COSTELLO, TOM',
#    'contributor_occupation': 'MP',
#    'contributor_prefix': None,
#    'contributor_state': 'CA',
#    'contributor_street_1': '12441 PARKER RANCH RD',
#    'contributor_street_2': None,
#    'contributor_suffix': None,
#    'contributor_zip': '950706538',
#    'donor_committee_name': None,
#    'election_type': 'P2020',
#    'election_type_full': None,
#    'entity_type': 'IND',
#    'entity_type_desc': 'INDIVIDUAL',
#    'fec_election_type_desc': 'PRIMARY',
#    'fec_election_year': '2020',
#    'file_number': 1350784,
#    'filing_form': 'F3',
#    'image_number': '201909059163151590',
#    'increased_limit': None,
#    'is_individual': True,
#    'line_number': '11AI',
#    'line_number_label': 'Contributions From Individuals/Persons Other Than Political Committees',
#    'link_id': 4090520191672279062,
#    'load_date': '2019-09-07T02:49:13.347000+00:00',
#    'memo_code': None,
#    'memo_code_full': None,
#    'memo_text': '* EARMARKED CONTRIBUTION: SEE BELOW',
#    'memoed_subtotal': False,
#    'national_committee_nonfederal_account': None,
#    'original_sub_id': None,
#    'pdf_url': 'http://docquery.fec.gov/cgi-bin/fecimg/?201909059163151590',
#    'receipt_type': '15E',
#    'receipt_type_desc': 'EARMARKED CONTRIBUTION',
#    'receipt_type_full': None,
#    'recipient_committee_designation': 'P',
#    'recipient_committee_org_type': None,
#    'recipient_committee_type': 'S',
#    'report_type': 'Q2',
#    'report_year': 2019,
#    'schedule_type': 'SA',
#    'schedule_type_full': 'ITEMIZED RECEIPTS',
#    'sub_id': '4090620191672335182',
#    'transaction_id': 'VVC97N5TZS1',
#    'two_year_transaction_period': 2020,
#    'unused_contbr_id': 'C00401224'},
#   {'amendment_indicator': 'N',
#    'amendment_indicator_desc': 'NO CHANGE',
#    'back_reference_schedule_name': 'SA11AI',
#    'back_reference_transaction_id': 'VVC97N5XE52E',
#    'candidate_first_name': None,
#    'candidate_id': None,
#    'candidate_last_name': None,
#    'candidate_middle_name': None,
#    'candidate_name': None,
#    'candidate_office': None,
#    'candidate_office_district': None,
#    'candidate_office_full': None,
#    'candidate_office_state': None,
#    'candidate_office_state_full': None,
#    'candidate_prefix': None,
#    'candidate_suffix': None,
#    'committee': {'affiliated_committee_name': 'NONE',
#     'candidate_ids': ['S0ME00111'],
#     'city': 'SOUTH FREEPORT',
#     'committee_id': 'C00709899',
#     'committee_type': 'S',
#     'committee_type_full': 'Senate',
#     'cycle': 2020,
#     'cycles': [2020],
#     'designation': 'P',
#     'designation_full': 'Principal campaign committee',
#     'filing_frequency': 'Q',
#     'name': 'SARA GIDEON FOR MAINE',
#     'organization_type': None,
#     'organization_type_full': None,
#     'party': 'DEM',
#     'party_full': 'DEMOCRATIC PARTY',
#     'state': 'ME',
#     'state_full': 'Maine',
#     'street_1': 'PO BOX 812',
#     'street_2': None,
#     'treasurer_name': 'LUNN, LISA MS.',
#     'zip': '04078'},
#    'committee_id': 'C00709899',
#    'committee_name': None,
#    'conduit_committee_city': None,
#    'conduit_committee_id': None,
#    'conduit_committee_name': None,
#    'conduit_committee_state': None,
#    'conduit_committee_street1': None,
#    'conduit_committee_street2': None,
#    'conduit_committee_zip': None,
#    'contribution_receipt_amount': 2800.0,
#    'contribution_receipt_date': '2019-06-20T00:00:00',
#    'contributor': {'affiliated_committee_name': 'NONE',
#     'candidate_ids': [],
#     'city': 'SOMERVILLE',
#     'committee_id': 'C00401224',
#     'committee_type': 'W',
#     'committee_type_full': 'PAC with Non-Contribution Account - Qualified',
#     'cycle': 2020,
#     'cycles': [2004, 2006, 2008, 2010, 2012, 2014, 2016, 2018, 2020],
#     'designation': 'U',
#     'designation_full': 'Unauthorized',
#     'filing_frequency': 'Q',
#     'name': 'ACTBLUE',
#     'organization_type': None,
#     'organization_type_full': None,
#     'party': None,
#     'party_full': None,
#     'state': 'MA',
#     'state_full': 'Massachusetts',
#     'street_1': 'P.O. BOX 441146',
#     'street_2': None,
#     'treasurer_name': 'HILL, ERIN',
#     'zip': '02144'},
#    'contributor_aggregate_ytd': 2800.0,
#    'contributor_city': 'FALMOUTH',
#    'contributor_employer': 'SELF EMPLOYED',
#    'contributor_first_name': 'CHARLOTTE',
#    'contributor_id': 'C00401224',
#    'contributor_last_name': 'ASEN',
#    'contributor_middle_name': None,
#    'contributor_name': 'ASEN, CHARLOTTE',
#    'contributor_occupation': 'ARTIST',
#    'contributor_prefix': None,
#    'contributor_state': 'ME',
#    'contributor_street_1': '17 ASHWOOD LN',
#    'contributor_street_2': None,
#    'contributor_suffix': None,
#    'contributor_zip': '041051152',
#    'donor_committee_name': None,
#    'election_type': 'P2020',
#    'election_type_full': None,
#    'entity_type': 'IND',
#    'entity_type_desc': 'INDIVIDUAL',
#    'fec_election_type_desc': 'PRIMARY',
#    'fec_election_year': '2020',
#    'file_number': 1350784,
#    'filing_form': 'F3',
#    'image_number': '201909059163151607',
#    'increased_limit': None,
#    'is_individual': True,
#    'line_number': '11AI',
#    'line_number_label': 'Contributions From Individuals/Persons Other Than Political Committees',
#    'link_id': 4090520191672279062,
#    'load_date': '2019-09-07T02:49:13.355000+00:00',
#    'memo_code': None,
#    'memo_code_full': None,
#    'memo_text': '* EARMARKED CONTRIBUTION: SEE BELOW',
#    'memoed_subtotal': False,
#    'national_committee_nonfederal_account': None,
#    'original_sub_id': None,
#    'pdf_url': 'http://docquery.fec.gov/cgi-bin/fecimg/?201909059163151607',
#    'receipt_type': '15E',
#    'receipt_type_desc': 'EARMARKED CONTRIBUTION',
#    'receipt_type_full': None,
#    'recipient_committee_designation': 'P',
#    'recipient_committee_org_type': None,
#    'recipient_committee_type': 'S',
#    'report_type': 'Q2',
#    'report_year': 2019,
#    'schedule_type': 'SA',
#    'schedule_type_full': 'ITEMIZED RECEIPTS',
#    'sub_id': '4090620191672335284',
#    'transaction_id': 'VVC97N5XE52',
#    'two_year_transaction_period': 2020,
#    'unused_contbr_id': 'C00401224'},
#   {'amendment_indicator': 'N',
#    'amendment_indicator_desc': 'NO CHANGE',
#    'back_reference_schedule_name': 'SA11AI',
#    'back_reference_transaction_id': 'VVC97N5YPH2E',
#    'candidate_first_name': None,
#    'candidate_id': None,
#    'candidate_last_name': None,
#    'candidate_middle_name': None,
#    'candidate_name': None,
#    'candidate_office': None,
#    'candidate_office_district': None,
#    'candidate_office_full': None,
#    'candidate_office_state': None,
#    'candidate_office_state_full': None,
#    'candidate_prefix': None,
#    'candidate_suffix': None,
#    'committee': {'affiliated_committee_name': 'NONE',
#     'candidate_ids': ['S0ME00111'],
#     'city': 'SOUTH FREEPORT',
#     'committee_id': 'C00709899',
#     'committee_type': 'S',
#     'committee_type_full': 'Senate',
#     'cycle': 2020,
#     'cycles': [2020],
#     'designation': 'P',
#     'designation_full': 'Principal campaign committee',
#     'filing_frequency': 'Q',
#     'name': 'SARA GIDEON FOR MAINE',
#     'organization_type': None,
#     'organization_type_full': None,
#     'party': 'DEM',
#     'party_full': 'DEMOCRATIC PARTY',
#     'state': 'ME',
#     'state_full': 'Maine',
#     'street_1': 'PO BOX 812',
#     'street_2': None,
#     'treasurer_name': 'LUNN, LISA MS.',
#     'zip': '04078'},
#    'committee_id': 'C00709899',
#    'committee_name': None,
#    'conduit_committee_city': None,
#    'conduit_committee_id': None,
#    'conduit_committee_name': None,
#    'conduit_committee_state': None,
#    'conduit_committee_street1': None,
#    'conduit_committee_street2': None,
#    'conduit_committee_zip': None,
#    'contribution_receipt_amount': 2800.0,
#    'contribution_receipt_date': '2019-06-20T00:00:00',
#    'contributor': {'affiliated_committee_name': 'NONE',
#     'candidate_ids': [],
#     'city': 'SOMERVILLE',
#     'committee_id': 'C00401224',
#     'committee_type': 'W',
#     'committee_type_full': 'PAC with Non-Contribution Account - Qualified',
#     'cycle': 2020,
#     'cycles': [2004, 2006, 2008, 2010, 2012, 2014, 2016, 2018, 2020],
#     'designation': 'U',
#     'designation_full': 'Unauthorized',
#     'filing_frequency': 'Q',
#     'name': 'ACTBLUE',
#     'organization_type': None,
#     'organization_type_full': None,
#     'party': None,
#     'party_full': None,
#     'state': 'MA',
#     'state_full': 'Massachusetts',
#     'street_1': 'P.O. BOX 441146',
#     'street_2': None,
#     'treasurer_name': 'HILL, ERIN',
#     'zip': '02144'},
#    'contributor_aggregate_ytd': 2800.0,
#    'contributor_city': 'LOS ANGELES',
#    'contributor_employer': 'SELF EMPLOYED',
#    'contributor_first_name': 'TIMOTHY',
#    'contributor_id': 'C00401224',
#    'contributor_last_name': 'DISNEY',
#    'contributor_middle_name': None,
#    'contributor_name': 'DISNEY, TIMOTHY',
#    'contributor_occupation': 'WRITER',
#    'contributor_prefix': None,
#    'contributor_state': 'CA',
#    'contributor_street_1': '2673 ABERDEEN AVE',
#    'contributor_street_2': None,
#    'contributor_suffix': None,
#    'contributor_zip': '900271221',
#    'donor_committee_name': None,
#    'election_type': 'P2020',
#    'election_type_full': None,
#    'entity_type': 'IND',
#    'entity_type_desc': 'INDIVIDUAL',
#    'fec_election_type_desc': 'PRIMARY',
#    'fec_election_year': '2020',
#    'file_number': 1350784,
#    'filing_form': 'F3',
#    'image_number': '201909059163151622',
#    'increased_limit': None,
#    'is_individual': True,
#    'line_number': '11AI',
#    'line_number_label': 'Contributions From Individuals/Persons Other Than Political Committees',
#    'link_id': 4090520191672279062,
#    'load_date': '2019-09-07T02:49:13.364000+00:00',
#    'memo_code': None,
#    'memo_code_full': None,
#    'memo_text': '* EARMARKED CONTRIBUTION: SEE BELOW',
#    'memoed_subtotal': False,
#    'national_committee_nonfederal_account': None,
#    'original_sub_id': None,
#    'pdf_url': 'http://docquery.fec.gov/cgi-bin/fecimg/?201909059163151622',
#    'receipt_type': '15E',
#    'receipt_type_desc': 'EARMARKED CONTRIBUTION',
#    'receipt_type_full': None,
#    'recipient_committee_designation': 'P',
#    'recipient_committee_org_type': None,
#    'recipient_committee_type': 'S',
#    'report_type': 'Q2',
#    'report_year': 2019,
#    'schedule_type': 'SA',
#    'schedule_type_full': 'ITEMIZED RECEIPTS',
#    'sub_id': '4090620191672335374',
#    'transaction_id': 'VVC97N5YPH2',
#    'two_year_transaction_period': 2020,
#    'unused_contbr_id': 'C00401224'},
#   {'amendment_indicator': 'N',
#    'amendment_indicator_desc': 'NO CHANGE',
#    'back_reference_schedule_name': 'SA11AI',
#    'back_reference_transaction_id': 'VVC97N5W4R2E',
#    'candidate_first_name': None,
#    'candidate_id': None,
#    'candidate_last_name': None,
#    'candidate_middle_name': None,
#    'candidate_name': None,
#    'candidate_office': None,
#    'candidate_office_district': None,
#    'candidate_office_full': None,
#    'candidate_office_state': None,
#    'candidate_office_state_full': None,
#    'candidate_prefix': None,
#    'candidate_suffix': None,
#    'committee': {'affiliated_committee_name': 'NONE',
#     'candidate_ids': ['S0ME00111'],
#     'city': 'SOUTH FREEPORT',
#     'committee_id': 'C00709899',
#     'committee_type': 'S',
#     'committee_type_full': 'Senate',
#     'cycle': 2020,
#     'cycles': [2020],
#     'designation': 'P',
#     'designation_full': 'Principal campaign committee',
#     'filing_frequency': 'Q',
#     'name': 'SARA GIDEON FOR MAINE',
#     'organization_type': None,
#     'organization_type_full': None,
#     'party': 'DEM',
#     'party_full': 'DEMOCRATIC PARTY',
#     'state': 'ME',
#     'state_full': 'Maine',
#     'street_1': 'PO BOX 812',
#     'street_2': None,
#     'treasurer_name': 'LUNN, LISA MS.',
#     'zip': '04078'},
#    'committee_id': 'C00709899',
#    'committee_name': None,
#    'conduit_committee_city': None,
#    'conduit_committee_id': None,
#    'conduit_committee_name': None,
#    'conduit_committee_state': None,
#    'conduit_committee_street1': None,
#    'conduit_committee_street2': None,
#    'conduit_committee_zip': None,
#    'contribution_receipt_amount': 500.0,
#    'contribution_receipt_date': '2019-06-20T00:00:00',
#    'contributor': {'affiliated_committee_name': 'NONE',
#     'candidate_ids': [],
#     'city': 'SOMERVILLE',
#     'committee_id': 'C00401224',
#     'committee_type': 'W',
#     'committee_type_full': 'PAC with Non-Contribution Account - Qualified',
#     'cycle': 2020,
#     'cycles': [2004, 2006, 2008, 2010, 2012, 2014, 2016, 2018, 2020],
#     'designation': 'U',
#     'designation_full': 'Unauthorized',
#     'filing_frequency': 'Q',
#     'name': 'ACTBLUE',
#     'organization_type': None,
#     'organization_type_full': None,
#     'party': None,
#     'party_full': None,
#     'state': 'MA',
#     'state_full': 'Massachusetts',
#     'street_1': 'P.O. BOX 441146',
#     'street_2': None,
#     'treasurer_name': 'HILL, ERIN',
#     'zip': '02144'},
#    'contributor_aggregate_ytd': 500.0,
#    'contributor_city': 'BERKELEY',
#    'contributor_employer': 'LIEFF CABRASER',
#    'contributor_first_name': 'DONALD',
#    'contributor_id': 'C00401224',
#    'contributor_last_name': 'ARBITBLIT',
#    'contributor_middle_name': None,
#    'contributor_name': 'ARBITBLIT, DONALD',
#    'contributor_occupation': 'ATTORNEY',
#    'contributor_prefix': None,
#    'contributor_state': 'CA',
#    'contributor_street_1': '988 CRESTON RD',
#    'contributor_street_2': None,
#    'contributor_suffix': None,
#    'contributor_zip': '947081544',
#    'donor_committee_name': None,
#    'election_type': 'P2020',
#    'election_type_full': None,
#    'entity_type': 'IND',
#    'entity_type_desc': 'INDIVIDUAL',
#    'fec_election_type_desc': 'PRIMARY',
#    'fec_election_year': '2020',
#    'file_number': 1350784,
#    'filing_form': 'F3',
#    'image_number': '201909059163151628',
#    'increased_limit': None,
#    'is_individual': True,
#    'line_number': '11AI',
#    'line_number_label': 'Contributions From Individuals/Persons Other Than Political Committees',
#    'link_id': 4090520191672279062,
#    'load_date': '2019-09-07T02:49:13.367000+00:00',
#    'memo_code': None,
#    'memo_code_full': None,
#    'memo_text': '* EARMARKED CONTRIBUTION: SEE BELOW',
#    'memoed_subtotal': False,
#    'national_committee_nonfederal_account': None,
#    'original_sub_id': None,
#    'pdf_url': 'http://docquery.fec.gov/cgi-bin/fecimg/?201909059163151628',
#    'receipt_type': '15E',
#    'receipt_type_desc': 'EARMARKED CONTRIBUTION',
#    'receipt_type_full': None,
#    'recipient_committee_designation': 'P',
#    'recipient_committee_org_type': None,
#    'recipient_committee_type': 'S',
#    'report_type': 'Q2',
#    'report_year': 2019,
#    'schedule_type': 'SA',
#    'schedule_type_full': 'ITEMIZED RECEIPTS',
#    'sub_id': '4090620191672335414',
#    'transaction_id': 'VVC97N5W4R2',
#    'two_year_transaction_period': 2020,
#    'unused_contbr_id': 'C00401224'},
#   {'amendment_indicator': 'N',
#    'amendment_indicator_desc': 'NO CHANGE',
#    'back_reference_schedule_name': 'SA11AI',
#    'back_reference_transaction_id': 'VVC97N5TXC3E',
#    'candidate_first_name': None,
#    'candidate_id': None,
#    'candidate_last_name': None,
#    'candidate_middle_name': None,
#    'candidate_name': None,
#    'candidate_office': None,
#    'candidate_office_district': None,
#    'candidate_office_full': None,
#    'candidate_office_state': None,
#    'candidate_office_state_full': None,
#    'candidate_prefix': None,
#    'candidate_suffix': None,
#    'committee': {'affiliated_committee_name': 'NONE',
#     'candidate_ids': ['S0ME00111'],
#     'city': 'SOUTH FREEPORT',
#     'committee_id': 'C00709899',
#     'committee_type': 'S',
#     'committee_type_full': 'Senate',
#     'cycle': 2020,
#     'cycles': [2020],
#     'designation': 'P',
#     'designation_full': 'Principal campaign committee',
#     'filing_frequency': 'Q',
#     'name': 'SARA GIDEON FOR MAINE',
#     'organization_type': None,
#     'organization_type_full': None,
#     'party': 'DEM',
#     'party_full': 'DEMOCRATIC PARTY',
#     'state': 'ME',
#     'state_full': 'Maine',
#     'street_1': 'PO BOX 812',
#     'street_2': None,
#     'treasurer_name': 'LUNN, LISA MS.',
#     'zip': '04078'},
#    'committee_id': 'C00709899',
#    'committee_name': None,
#    'conduit_committee_city': None,
#    'conduit_committee_id': None,
#    'conduit_committee_name': None,
#    'conduit_committee_state': None,
#    'conduit_committee_street1': None,
#    'conduit_committee_street2': None,
#    'conduit_committee_zip': None,
#    'contribution_receipt_amount': 200.0,
#    'contribution_receipt_date': '2019-06-20T00:00:00',
#    'contributor': {'affiliated_committee_name': 'NONE',
#     'candidate_ids': [],
#     'city': 'SOMERVILLE',
#     'committee_id': 'C00401224',
#     'committee_type': 'W',
#     'committee_type_full': 'PAC with Non-Contribution Account - Qualified',
#     'cycle': 2020,
#     'cycles': [2004, 2006, 2008, 2010, 2012, 2014, 2016, 2018, 2020],
#     'designation': 'U',
#     'designation_full': 'Unauthorized',
#     'filing_frequency': 'Q',
#     'name': 'ACTBLUE',
#     'organization_type': None,
#     'organization_type_full': None,
#     'party': None,
#     'party_full': None,
#     'state': 'MA',
#     'state_full': 'Massachusetts',
#     'street_1': 'P.O. BOX 441146',
#     'street_2': None,
#     'treasurer_name': 'HILL, ERIN',
#     'zip': '02144'},
#    'contributor_aggregate_ytd': 203.0,
#    'contributor_city': 'PORTLAND',
#    'contributor_employer': 'HOUSE OF REPRESENTATIVES',
#    'contributor_first_name': 'JONATHAN',
#    'contributor_id': 'C00401224',
#    'contributor_last_name': 'ASEN',
#    'contributor_middle_name': None,
#    'contributor_name': 'ASEN, JONATHAN',
#    'contributor_occupation': 'CHIEF OF STAFF',
#    'contributor_prefix': None,
#    'contributor_state': 'ME',
#    'contributor_street_1': '8 GLENWOOD AVE',
#    'contributor_street_2': None,
#    'contributor_suffix': None,
#    'contributor_zip': '041033019',
#    'donor_committee_name': None,
#    'election_type': 'P2020',
#    'election_type_full': None,
#    'entity_type': 'IND',
#    'entity_type_desc': 'INDIVIDUAL',
#    'fec_election_type_desc': 'PRIMARY',
#    'fec_election_year': '2020',
#    'file_number': 1350784,
#    'filing_form': 'F3',
#    'image_number': '201909059163151654',
#    'increased_limit': None,
#    'is_individual': True,
#    'line_number': '11AI',
#    'line_number_label': 'Contributions From Individuals/Persons Other Than Political Committees',
#    'link_id': 4090520191672279062,
#    'load_date': '2019-09-07T02:49:13.381000+00:00',
#    'memo_code': None,
#    'memo_code_full': None,
#    'memo_text': '* EARMARKED CONTRIBUTION: SEE BELOW',
#    'memoed_subtotal': False,
#    'national_committee_nonfederal_account': None,
#    'original_sub_id': None,
#    'pdf_url': 'http://docquery.fec.gov/cgi-bin/fecimg/?201909059163151654',
#    'receipt_type': '15E',
#    'receipt_type_desc': 'EARMARKED CONTRIBUTION',
#    'receipt_type_full': None,
#    'recipient_committee_designation': 'P',
#    'recipient_committee_org_type': None,
#    'recipient_committee_type': 'S',
#    'report_type': 'Q2',
#    'report_year': 2019,
#    'schedule_type': 'SA',
#    'schedule_type_full': 'ITEMIZED RECEIPTS',
#    'sub_id': '4090620191672335570',
#    'transaction_id': 'VVC97N5TXC3',
#    'two_year_transaction_period': 2020,
#    'unused_contbr_id': 'C00401224'},
#   {'amendment_indicator': 'N',
#    'amendment_indicator_desc': 'NO CHANGE',
#    'back_reference_schedule_name': 'SA11AI',
#    'back_reference_transaction_id': 'VVC97N5XKH7E',
#    'candidate_first_name': None,
#    'candidate_id': None,
#    'candidate_last_name': None,
#    'candidate_middle_name': None,
#    'candidate_name': None,
#    'candidate_office': None,
#    'candidate_office_district': None,
#    'candidate_office_full': None,
#    'candidate_office_state': None,
#    'candidate_office_state_full': None,
#    'candidate_prefix': None,
#    'candidate_suffix': None,
#    'committee': {'affiliated_committee_name': 'NONE',
#     'candidate_ids': ['S0ME00111'],
#     'city': 'SOUTH FREEPORT',
#     'committee_id': 'C00709899',
#     'committee_type': 'S',
#     'committee_type_full': 'Senate',
#     'cycle': 2020,
#     'cycles': [2020],
#     'designation': 'P',
#     'designation_full': 'Principal campaign committee',
#     'filing_frequency': 'Q',
#     'name': 'SARA GIDEON FOR MAINE',
#     'organization_type': None,
#     'organization_type_full': None,
#     'party': 'DEM',
#     'party_full': 'DEMOCRATIC PARTY',
#     'state': 'ME',
#     'state_full': 'Maine',
#     'street_1': 'PO BOX 812',
#     'street_2': None,
#     'treasurer_name': 'LUNN, LISA MS.',
#     'zip': '04078'},
#    'committee_id': 'C00709899',
#    'committee_name': None,
#    'conduit_committee_city': None,
#    'conduit_committee_id': None,
#    'conduit_committee_name': None,
#    'conduit_committee_state': None,
#    'conduit_committee_street1': None,
#    'conduit_committee_street2': None,
#    'conduit_committee_zip': None,
#    'contribution_receipt_amount': 2800.0,
#    'contribution_receipt_date': '2019-06-20T00:00:00',
#    'contributor': {'affiliated_committee_name': 'NONE',
#     'candidate_ids': [],
#     'city': 'SOMERVILLE',
#     'committee_id': 'C00401224',
#     'committee_type': 'W',
#     'committee_type_full': 'PAC with Non-Contribution Account - Qualified',
#     'cycle': 2020,
#     'cycles': [2004, 2006, 2008, 2010, 2012, 2014, 2016, 2018, 2020],
#     'designation': 'U',
#     'designation_full': 'Unauthorized',
#     'filing_frequency': 'Q',
#     'name': 'ACTBLUE',
#     'organization_type': None,
#     'organization_type_full': None,
#     'party': None,
#     'party_full': None,
#     'state': 'MA',
#     'state_full': 'Massachusetts',
#     'street_1': 'P.O. BOX 441146',
#     'street_2': None,
#     'treasurer_name': 'HILL, ERIN',
#     'zip': '02144'},
#    'contributor_aggregate_ytd': 2800.0,
#    'contributor_city': 'FALMOUTH',
#    'contributor_employer': 'MITTEL ASEN, LLC',
#    'contributor_first_name': 'MICHAEL',
#    'contributor_id': 'C00401224',
#    'contributor_last_name': 'ASEN',
#    'contributor_middle_name': None,
#    'contributor_name': 'ASEN, MICHAEL',
#    'contributor_occupation': 'ATTORNEY',
#    'contributor_prefix': None,
#    'contributor_state': 'ME',
#    'contributor_street_1': '17 ASHWOOD LN',
#    'contributor_street_2': None,
#    'contributor_suffix': None,
#    'contributor_zip': '041051152',
#    'donor_committee_name': None,
#    'election_type': 'P2020',
#    'election_type_full': None,
#    'entity_type': 'IND',
#    'entity_type_desc': 'INDIVIDUAL',
#    'fec_election_type_desc': 'PRIMARY',
#    'fec_election_year': '2020',
#    'file_number': 1350784,
#    'filing_form': 'F3',
#    'image_number': '201909059163151815',
#    'increased_limit': None,
#    'is_individual': True,
#    'line_number': '11AI',
#    'line_number_label': 'Contributions From Individuals/Persons Other Than Political Committees',
#    'link_id': 4090520191672279062,
#    'load_date': '2019-09-07T02:49:18.773000+00:00',
#    'memo_code': None,
#    'memo_code_full': None,
#    'memo_text': '* EARMARKED CONTRIBUTION: SEE BELOW',
#    'memoed_subtotal': False,
#    'national_committee_nonfederal_account': None,
#    'original_sub_id': None,
#    'pdf_url': 'http://docquery.fec.gov/cgi-bin/fecimg/?201909059163151815',
#    'receipt_type': '15E',
#    'receipt_type_desc': 'EARMARKED CONTRIBUTION',
#    'receipt_type_full': None,
#    'recipient_committee_designation': 'P',
#    'recipient_committee_org_type': None,
#    'recipient_committee_type': 'S',
#    'report_type': 'Q2',
#    'report_year': 2019,
#    'schedule_type': 'SA',
#    'schedule_type_full': 'ITEMIZED RECEIPTS',
#    'sub_id': '4090620191672336535',
#    'transaction_id': 'VVC97N5XKH7',
#    'two_year_transaction_period': 2020,
#    'unused_contbr_id': 'C00401224'},
#   {'amendment_indicator': 'N',
#    'amendment_indicator_desc': 'NO CHANGE',
#    'back_reference_schedule_name': 'SA11AI',
#    'back_reference_transaction_id': 'VVC97N5X842E',
#    'candidate_first_name': None,
#    'candidate_id': None,
#    'candidate_last_name': None,
#    'candidate_middle_name': None,
#    'candidate_name': None,
#    'candidate_office': None,
#    'candidate_office_district': None,
#    'candidate_office_full': None,
#    'candidate_office_state': None,
#    'candidate_office_state_full': None,
#    'candidate_prefix': None,
#    'candidate_suffix': None,
#    'committee': {'affiliated_committee_name': 'NONE',
#     'candidate_ids': ['S0ME00111'],
#     'city': 'SOUTH FREEPORT',
#     'committee_id': 'C00709899',
#     'committee_type': 'S',
#     'committee_type_full': 'Senate',
#     'cycle': 2020,
#     'cycles': [2020],
#     'designation': 'P',
#     'designation_full': 'Principal campaign committee',
#     'filing_frequency': 'Q',
#     'name': 'SARA GIDEON FOR MAINE',
#     'organization_type': None,
#     'organization_type_full': None,
#     'party': 'DEM',
#     'party_full': 'DEMOCRATIC PARTY',
#     'state': 'ME',
#     'state_full': 'Maine',
#     'street_1': 'PO BOX 812',
#     'street_2': None,
#     'treasurer_name': 'LUNN, LISA MS.',
#     'zip': '04078'},
#    'committee_id': 'C00709899',
#    'committee_name': None,
#    'conduit_committee_city': None,
#    'conduit_committee_id': None,
#    'conduit_committee_name': None,
#    'conduit_committee_state': None,
#    'conduit_committee_street1': None,
#    'conduit_committee_street2': None,
#    'conduit_committee_zip': None,
#    'contribution_receipt_amount': 500.0,
#    'contribution_receipt_date': '2019-06-21T00:00:00',
#    'contributor': {'affiliated_committee_name': 'NONE',
#     'candidate_ids': [],
#     'city': 'SOMERVILLE',
#     'committee_id': 'C00401224',
#     'committee_type': 'W',
#     'committee_type_full': 'PAC with Non-Contribution Account - Qualified',
#     'cycle': 2020,
#     'cycles': [2004, 2006, 2008, 2010, 2012, 2014, 2016, 2018, 2020],
#     'designation': 'U',
#     'designation_full': 'Unauthorized',
#     'filing_frequency': 'Q',
#     'name': 'ACTBLUE',
#     'organization_type': None,
#     'organization_type_full': None,
#     'party': None,
#     'party_full': None,
#     'state': 'MA',
#     'state_full': 'Massachusetts',
#     'street_1': 'P.O. BOX 441146',
#     'street_2': None,
#     'treasurer_name': 'HILL, ERIN',
#     'zip': '02144'},
#    'contributor_aggregate_ytd': 500.0,
#    'contributor_city': 'DALLAS',
#    'contributor_employer': 'STANLEY IOLA, LLP',
#    'contributor_first_name': 'MARC',
#    'contributor_id': 'C00401224',
#    'contributor_last_name': 'STANLEY',
#    'contributor_middle_name': None,
#    'contributor_name': 'STANLEY, MARC',
#    'contributor_occupation': 'ATTORNEY',
#    'contributor_prefix': None,
#    'contributor_state': 'TX',
#    'contributor_street_1': '7403 MIDBURY DR',
#    'contributor_street_2': None,
#    'contributor_suffix': None,
#    'contributor_zip': '752303205',
#    'donor_committee_name': None,
#    'election_type': 'P2020',
#    'election_type_full': None,
#    'entity_type': 'IND',
#    'entity_type_desc': 'INDIVIDUAL',
#    'fec_election_type_desc': 'PRIMARY',
#    'fec_election_year': '2020',
#    'file_number': 1350784,
#    'filing_form': 'F3',
#    'image_number': '201909059163151605',
#    'increased_limit': None,
#    'is_individual': True,
#    'line_number': '11AI',
#    'line_number_label': 'Contributions From Individuals/Persons Other Than Political Committees',
#    'link_id': 4090520191672279062,
#    'load_date': '2019-09-07T02:49:13.355000+00:00',
#    'memo_code': None,
#    'memo_code_full': None,
#    'memo_text': '* EARMARKED CONTRIBUTION: SEE BELOW',
#    'memoed_subtotal': False,
#    'national_committee_nonfederal_account': None,
#    'original_sub_id': None,
#    'pdf_url': 'http://docquery.fec.gov/cgi-bin/fecimg/?201909059163151605',
#    'receipt_type': '15E',
#    'receipt_type_desc': 'EARMARKED CONTRIBUTION',
#    'receipt_type_full': None,
#    'recipient_committee_designation': 'P',
#    'recipient_committee_org_type': None,
#    'recipient_committee_type': 'S',
#    'report_type': 'Q2',
#    'report_year': 2019,
#    'schedule_type': 'SA',
#    'schedule_type_full': 'ITEMIZED RECEIPTS',
#    'sub_id': '4090620191672335276',
#    'transaction_id': 'VVC97N5X842',
#    'two_year_transaction_period': 2020,
#    'unused_contbr_id': 'C00401224'},
#   {'amendment_indicator': 'N',
#    'amendment_indicator_desc': 'NO CHANGE',
#    'back_reference_schedule_name': 'SA11AI',
#    'back_reference_transaction_id': 'VVC97N5XXF2E',
#    'candidate_first_name': None,
#    'candidate_id': None,
#    'candidate_last_name': None,
#    'candidate_middle_name': None,
#    'candidate_name': None,
#    'candidate_office': None,
#    'candidate_office_district': None,
#    'candidate_office_full': None,
#    'candidate_office_state': None,
#    'candidate_office_state_full': None,
#    'candidate_prefix': None,
#    'candidate_suffix': None,
#    'committee': {'affiliated_committee_name': 'NONE',
#     'candidate_ids': ['S0ME00111'],
#     'city': 'SOUTH FREEPORT',
#     'committee_id': 'C00709899',
#     'committee_type': 'S',
#     'committee_type_full': 'Senate',
#     'cycle': 2020,
#     'cycles': [2020],
#     'designation': 'P',
#     'designation_full': 'Principal campaign committee',
#     'filing_frequency': 'Q',
#     'name': 'SARA GIDEON FOR MAINE',
#     'organization_type': None,
#     'organization_type_full': None,
#     'party': 'DEM',
#     'party_full': 'DEMOCRATIC PARTY',
#     'state': 'ME',
#     'state_full': 'Maine',
#     'street_1': 'PO BOX 812',
#     'street_2': None,
#     'treasurer_name': 'LUNN, LISA MS.',
#     'zip': '04078'},
#    'committee_id': 'C00709899',
#    'committee_name': None,
#    'conduit_committee_city': None,
#    'conduit_committee_id': None,
#    'conduit_committee_name': None,
#    'conduit_committee_state': None,
#    'conduit_committee_street1': None,
#    'conduit_committee_street2': None,
#    'conduit_committee_zip': None,
#    'contribution_receipt_amount': 1000.0,
#    'contribution_receipt_date': '2019-06-21T00:00:00',
#    'contributor': {'affiliated_committee_name': 'NONE',
#     'candidate_ids': [],
#     'city': 'SOMERVILLE',
#     'committee_id': 'C00401224',
#     'committee_type': 'W',
#     'committee_type_full': 'PAC with Non-Contribution Account - Qualified',
#     'cycle': 2020,
#     'cycles': [2004, 2006, 2008, 2010, 2012, 2014, 2016, 2018, 2020],
#     'designation': 'U',
#     'designation_full': 'Unauthorized',
#     'filing_frequency': 'Q',
#     'name': 'ACTBLUE',
#     'organization_type': None,
#     'organization_type_full': None,
#     'party': None,
#     'party_full': None,
#     'state': 'MA',
#     'state_full': 'Massachusetts',
#     'street_1': 'P.O. BOX 441146',
#     'street_2': None,
#     'treasurer_name': 'HILL, ERIN',
#     'zip': '02144'},
#    'contributor_aggregate_ytd': 1000.0,
#    'contributor_city': 'MIAMI BEACH',
#    'contributor_employer': 'NOT EMPLOYED',
#    'contributor_first_name': 'MARY',
#    'contributor_id': 'C00401224',
#    'contributor_last_name': 'SULLIVAN',
#    'contributor_middle_name': 'PEACE',
#    'contributor_name': 'SULLIVAN, MARY PEACE',
#    'contributor_occupation': 'NOT EMPLOYED',
#    'contributor_prefix': None,
#    'contributor_state': 'FL',
#    'contributor_street_1': '300 S POINTE DR',
#    'contributor_street_2': 'APT 1401',
#    'contributor_suffix': None,
#    'contributor_zip': '331397304',
#    'donor_committee_name': None,
#    'election_type': 'P2020',
#    'election_type_full': None,
#    'entity_type': 'IND',
#    'entity_type_desc': 'INDIVIDUAL',
#    'fec_election_type_desc': 'PRIMARY',
#    'fec_election_year': '2020',
#    'file_number': 1350784,
#    'filing_form': 'F3',
#    'image_number': '201909059163151618',
#    'increased_limit': None,
#    'is_individual': True,
#    'line_number': '11AI',
#    'line_number_label': 'Contributions From Individuals/Persons Other Than Political Committees',
#    'link_id': 4090520191672279062,
#    'load_date': '2019-09-07T02:49:13.362000+00:00',
#    'memo_code': None,
#    'memo_code_full': None,
#    'memo_text': '* EARMARKED CONTRIBUTION: SEE BELOW',
#    'memoed_subtotal': False,
#    'national_committee_nonfederal_account': None,
#    'original_sub_id': None,
#    'pdf_url': 'http://docquery.fec.gov/cgi-bin/fecimg/?201909059163151618',
#    'receipt_type': '15E',
#    'receipt_type_desc': 'EARMARKED CONTRIBUTION',
#    'receipt_type_full': None,
#    'recipient_committee_designation': 'P',
#    'recipient_committee_org_type': None,
#    'recipient_committee_type': 'S',
#    'report_type': 'Q2',
#    'report_year': 2019,
#    'schedule_type': 'SA',
#    'schedule_type_full': 'ITEMIZED RECEIPTS',
#    'sub_id': '4090620191672335354',
#    'transaction_id': 'VVC97N5XXF2',
#    'two_year_transaction_period': 2020,
#    'unused_contbr_id': 'C00401224'},
#   {'amendment_indicator': 'N',
#    'amendment_indicator_desc': 'NO CHANGE',
#    'back_reference_schedule_name': 'SA11AI',
#    'back_reference_transaction_id': 'VVC97N5VQF3E',
#    'candidate_first_name': None,
#    'candidate_id': None,
#    'candidate_last_name': None,
#    'candidate_middle_name': None,
#    'candidate_name': None,
#    'candidate_office': None,
#    'candidate_office_district': None,
#    'candidate_office_full': None,
#    'candidate_office_state': None,
#    'candidate_office_state_full': None,
#    'candidate_prefix': None,
#    'candidate_suffix': None,
#    'committee': {'affiliated_committee_name': 'NONE',
#     'candidate_ids': ['S0ME00111'],
#     'city': 'SOUTH FREEPORT',
#     'committee_id': 'C00709899',
#     'committee_type': 'S',
#     'committee_type_full': 'Senate',
#     'cycle': 2020,
#     'cycles': [2020],
#     'designation': 'P',
#     'designation_full': 'Principal campaign committee',
#     'filing_frequency': 'Q',
#     'name': 'SARA GIDEON FOR MAINE',
#     'organization_type': None,
#     'organization_type_full': None,
#     'party': 'DEM',
#     'party_full': 'DEMOCRATIC PARTY',
#     'state': 'ME',
#     'state_full': 'Maine',
#     'street_1': 'PO BOX 812',
#     'street_2': None,
#     'treasurer_name': 'LUNN, LISA MS.',
#     'zip': '04078'},
#    'committee_id': 'C00709899',
#    'committee_name': None,
#    'conduit_committee_city': None,
#    'conduit_committee_id': None,
#    'conduit_committee_name': None,
#    'conduit_committee_state': None,
#    'conduit_committee_street1': None,
#    'conduit_committee_street2': None,
#    'conduit_committee_zip': None,
#    'contribution_receipt_amount': 2800.0,
#    'contribution_receipt_date': '2019-06-21T00:00:00',
#    'contributor': {'affiliated_committee_name': 'NONE',
#     'candidate_ids': [],
#     'city': 'SOMERVILLE',
#     'committee_id': 'C00401224',
#     'committee_type': 'W',
#     'committee_type_full': 'PAC with Non-Contribution Account - Qualified',
#     'cycle': 2020,
#     'cycles': [2004, 2006, 2008, 2010, 2012, 2014, 2016, 2018, 2020],
#     'designation': 'U',
#     'designation_full': 'Unauthorized',
#     'filing_frequency': 'Q',
#     'name': 'ACTBLUE',
#     'organization_type': None,
#     'organization_type_full': None,
#     'party': None,
#     'party_full': None,
#     'state': 'MA',
#     'state_full': 'Massachusetts',
#     'street_1': 'P.O. BOX 441146',
#     'street_2': None,
#     'treasurer_name': 'HILL, ERIN',
#     'zip': '02144'},
#    'contributor_aggregate_ytd': 5600.0,
#    'contributor_city': 'WESTBROOK',
#    'contributor_employer': 'MAINE STATE LEGISLATURE',
#    'contributor_first_name': 'ANDREW',
#    'contributor_id': 'C00401224',
#    'contributor_last_name': 'GATTINE',
#    'contributor_middle_name': None,
#    'contributor_name': 'GATTINE, ANDREW',
#    'contributor_occupation': 'STATE REPRESENTATIVE',
#    'contributor_prefix': None,
#    'contributor_state': 'ME',
#    'contributor_street_1': '529 STROUDWATER ST',
#    'contributor_street_2': None,
#    'contributor_suffix': None,
#    'contributor_zip': '040924070',
#    'donor_committee_name': None,
#    'election_type': 'P2020',
#    'election_type_full': None,
#    'entity_type': 'IND',
#    'entity_type_desc': 'INDIVIDUAL',
#    'fec_election_type_desc': 'PRIMARY',
#    'fec_election_year': '2020',
#    'file_number': 1350784,
#    'filing_form': 'F3',
#    'image_number': '201909059163151656',
#    'increased_limit': None,
#    'is_individual': True,
#    'line_number': '11AI',
#    'line_number_label': 'Contributions From Individuals/Persons Other Than Political Committees',
#    'link_id': 4090520191672279062,
#    'load_date': '2019-09-07T02:49:13.382000+00:00',
#    'memo_code': None,
#    'memo_code_full': None,
#    'memo_text': '* EARMARKED CONTRIBUTION: SEE BELOW',
#    'memoed_subtotal': False,
#    'national_committee_nonfederal_account': None,
#    'original_sub_id': None,
#    'pdf_url': 'http://docquery.fec.gov/cgi-bin/fecimg/?201909059163151656',
#    'receipt_type': '15E',
#    'receipt_type_desc': 'EARMARKED CONTRIBUTION',
#    'receipt_type_full': None,
#    'recipient_committee_designation': 'P',
#    'recipient_committee_org_type': None,
#    'recipient_committee_type': 'S',
#    'report_type': 'Q2',
#    'report_year': 2019,
#    'schedule_type': 'SA',
#    'schedule_type_full': 'ITEMIZED RECEIPTS',
#    'sub_id': '4090620191672335582',
#    'transaction_id': 'VVC97N5VQF3',
#    'two_year_transaction_period': 2020,
#    'unused_contbr_id': 'C00401224'},
#   {'amendment_indicator': 'N',
#    'amendment_indicator_desc': 'NO CHANGE',
#    'back_reference_schedule_name': 'SA11AI',
#    'back_reference_transaction_id': 'VVC97N5VQE6E',
#    'candidate_first_name': None,
#    'candidate_id': None,
#    'candidate_last_name': None,
#    'candidate_middle_name': None,
#    'candidate_name': None,
#    'candidate_office': None,
#    'candidate_office_district': None,
#    'candidate_office_full': None,
#    'candidate_office_state': None,
#    'candidate_office_state_full': None,
#    'candidate_prefix': None,
#    'candidate_suffix': None,
#    'committee': {'affiliated_committee_name': 'NONE',
#     'candidate_ids': ['S0ME00111'],
#     'city': 'SOUTH FREEPORT',
#     'committee_id': 'C00709899',
#     'committee_type': 'S',
#     'committee_type_full': 'Senate',
#     'cycle': 2020,
#     'cycles': [2020],
#     'designation': 'P',
#     'designation_full': 'Principal campaign committee',
#     'filing_frequency': 'Q',
#     'name': 'SARA GIDEON FOR MAINE',
#     'organization_type': None,
#     'organization_type_full': None,
#     'party': 'DEM',
#     'party_full': 'DEMOCRATIC PARTY',
#     'state': 'ME',
#     'state_full': 'Maine',
#     'street_1': 'PO BOX 812',
#     'street_2': None,
#     'treasurer_name': 'LUNN, LISA MS.',
#     'zip': '04078'},
#    'committee_id': 'C00709899',
#    'committee_name': None,
#    'conduit_committee_city': None,
#    'conduit_committee_id': None,
#    'conduit_committee_name': None,
#    'conduit_committee_state': None,
#    'conduit_committee_street1': None,
#    'conduit_committee_street2': None,
#    'conduit_committee_zip': None,
#    'contribution_receipt_amount': 2800.0,
#    'contribution_receipt_date': '2019-06-21T00:00:00',
#    'contributor': {'affiliated_committee_name': 'NONE',
#     'candidate_ids': [],
#     'city': 'SOMERVILLE',
#     'committee_id': 'C00401224',
#     'committee_type': 'W',
#     'committee_type_full': 'PAC with Non-Contribution Account - Qualified',
#     'cycle': 2020,
#     'cycles': [2004, 2006, 2008, 2010, 2012, 2014, 2016, 2018, 2020],
#     'designation': 'U',
#     'designation_full': 'Unauthorized',
#     'filing_frequency': 'Q',
#     'name': 'ACTBLUE',
#     'organization_type': None,
#     'organization_type_full': None,
#     'party': None,
#     'party_full': None,
#     'state': 'MA',
#     'state_full': 'Massachusetts',
#     'street_1': 'P.O. BOX 441146',
#     'street_2': None,
#     'treasurer_name': 'HILL, ERIN',
#     'zip': '02144'},
#    'contributor_aggregate_ytd': 5600.0,
#    'contributor_city': 'WESTBROOK',
#    'contributor_employer': 'MAINE STATE LEGISLATURE',
#    'contributor_first_name': 'ANDREW',
#    'contributor_id': 'C00401224',
#    'contributor_last_name': 'GATTINE',
#    'contributor_middle_name': None,
#    'contributor_name': 'GATTINE, ANDREW',
#    'contributor_occupation': 'STATE REPRESENTATIVE',
#    'contributor_prefix': None,
#    'contributor_state': 'ME',
#    'contributor_street_1': '529 STROUDWATER ST',
#    'contributor_street_2': None,
#    'contributor_suffix': None,
#    'contributor_zip': '040924070',
#    'donor_committee_name': None,
#    'election_type': 'G2020',
#    'election_type_full': None,
#    'entity_type': 'IND',
#    'entity_type_desc': 'INDIVIDUAL',
#    'fec_election_type_desc': 'GENERAL',
#    'fec_election_year': '2020',
#    'file_number': 1350784,
#    'filing_form': 'F3',
#    'image_number': '201909059163151772',
#    'increased_limit': None,
#    'is_individual': True,
#    'line_number': '11AI',
#    'line_number_label': 'Contributions From Individuals/Persons Other Than Political Committees',
#    'link_id': 4090520191672279062,
#    'load_date': '2019-09-07T02:49:13.443000+00:00',
#    'memo_code': None,
#    'memo_code_full': None,
#    'memo_text': '* EARMARKED CONTRIBUTION: SEE BELOW',
#    'memoed_subtotal': False,
#    'national_committee_nonfederal_account': None,
#    'original_sub_id': None,
#    'pdf_url': 'http://docquery.fec.gov/cgi-bin/fecimg/?201909059163151772',
#    'receipt_type': '15E',
#    'receipt_type_desc': 'EARMARKED CONTRIBUTION',
#    'receipt_type_full': None,
#    'recipient_committee_designation': 'P',
#    'recipient_committee_org_type': None,
#    'recipient_committee_type': 'S',
#    'report_type': 'Q2',
#    'report_year': 2019,
#    'schedule_type': 'SA',
#    'schedule_type_full': 'ITEMIZED RECEIPTS',
#    'sub_id': '4090620191672336277',
#    'transaction_id': 'VVC97N5VQE6',
#    'two_year_transaction_period': 2020,
#    'unused_contbr_id': 'C00401224'},
#   {'amendment_indicator': 'N',
#    'amendment_indicator_desc': 'NO CHANGE',
#    'back_reference_schedule_name': 'SA11AI',
#    'back_reference_transaction_id': 'VVC97N5X0T7E',
#    'candidate_first_name': None,
#    'candidate_id': None,
#    'candidate_last_name': None,
#    'candidate_middle_name': None,
#    'candidate_name': None,
#    'candidate_office': None,
#    'candidate_office_district': None,
#    'candidate_office_full': None,
#    'candidate_office_state': None,
#    'candidate_office_state_full': None,
#    'candidate_prefix': None,
#    'candidate_suffix': None,
#    'committee': {'affiliated_committee_name': 'NONE',
#     'candidate_ids': ['S0ME00111'],
#     'city': 'SOUTH FREEPORT',
#     'committee_id': 'C00709899',
#     'committee_type': 'S',
#     'committee_type_full': 'Senate',
#     'cycle': 2020,
#     'cycles': [2020],
#     'designation': 'P',
#     'designation_full': 'Principal campaign committee',
#     'filing_frequency': 'Q',
#     'name': 'SARA GIDEON FOR MAINE',
#     'organization_type': None,
#     'organization_type_full': None,
#     'party': 'DEM',
#     'party_full': 'DEMOCRATIC PARTY',
#     'state': 'ME',
#     'state_full': 'Maine',
#     'street_1': 'PO BOX 812',
#     'street_2': None,
#     'treasurer_name': 'LUNN, LISA MS.',
#     'zip': '04078'},
#    'committee_id': 'C00709899',
#    'committee_name': None,
#    'conduit_committee_city': None,
#    'conduit_committee_id': None,
#    'conduit_committee_name': None,
#    'conduit_committee_state': None,
#    'conduit_committee_street1': None,
#    'conduit_committee_street2': None,
#    'conduit_committee_zip': None,
#    'contribution_receipt_amount': 1000.0,
#    'contribution_receipt_date': '2019-06-21T00:00:00',
#    'contributor': {'affiliated_committee_name': 'NONE',
#     'candidate_ids': [],
#     'city': 'SOMERVILLE',
#     'committee_id': 'C00401224',
#     'committee_type': 'W',
#     'committee_type_full': 'PAC with Non-Contribution Account - Qualified',
#     'cycle': 2020,
#     'cycles': [2004, 2006, 2008, 2010, 2012, 2014, 2016, 2018, 2020],
#     'designation': 'U',
#     'designation_full': 'Unauthorized',
#     'filing_frequency': 'Q',
#     'name': 'ACTBLUE',
#     'organization_type': None,
#     'organization_type_full': None,
#     'party': None,
#     'party_full': None,
#     'state': 'MA',
#     'state_full': 'Massachusetts',
#     'street_1': 'P.O. BOX 441146',
#     'street_2': None,
#     'treasurer_name': 'HILL, ERIN',
#     'zip': '02144'},
#    'contributor_aggregate_ytd': 1000.0,
#    'contributor_city': 'MENLO PARK',
#    'contributor_employer': 'VOYANT',
#    'contributor_first_name': 'K.',
#    'contributor_id': 'C00401224',
#    'contributor_last_name': 'MACFARLANE',
#    'contributor_middle_name': 'A.',
#    'contributor_name': 'MACFARLANE, K. A.',
#    'contributor_occupation': 'CEO',
#    'contributor_prefix': None,
#    'contributor_state': 'CA',
#    'contributor_street_1': '325 SHARON PARK DR',
#    'contributor_street_2': 'UNIT 735',
#    'contributor_suffix': None,
#    'contributor_zip': '940256805',
#    'donor_committee_name': None,
#    'election_type': 'P2020',
#    'election_type_full': None,
#    'entity_type': 'IND',
#    'entity_type_desc': 'INDIVIDUAL',
#    'fec_election_type_desc': 'PRIMARY',
#    'fec_election_year': '2020',
#    'file_number': 1350784,
#    'filing_form': 'F3',
#    'image_number': '201909059163151829',
#    'increased_limit': None,
#    'is_individual': True,
#    'line_number': '11AI',
#    'line_number_label': 'Contributions From Individuals/Persons Other Than Political Committees',
#    'link_id': 4090520191672279062,
#    'load_date': '2019-09-07T02:49:18.779000+00:00',
#    'memo_code': None,
#    'memo_code_full': None,
#    'memo_text': '* EARMARKED CONTRIBUTION: SEE BELOW',
#    'memoed_subtotal': False,
#    'national_committee_nonfederal_account': None,
#    'original_sub_id': None,
#    'pdf_url': 'http://docquery.fec.gov/cgi-bin/fecimg/?201909059163151829',
#    'receipt_type': '15E',
#    'receipt_type_desc': 'EARMARKED CONTRIBUTION',
#    'receipt_type_full': None,
#    'recipient_committee_designation': 'P',
#    'recipient_committee_org_type': None,
#    'recipient_committee_type': 'S',
#    'report_type': 'Q2',
#    'report_year': 2019,
#    'schedule_type': 'SA',
#    'schedule_type_full': 'ITEMIZED RECEIPTS',
#    'sub_id': '4090620191672336619',
#    'transaction_id': 'VVC97N5X0T7',
#    'two_year_transaction_period': 2020,
#    'unused_contbr_id': 'C00401224'},
#   {'amendment_indicator': 'N',
#    'amendment_indicator_desc': 'NO CHANGE',
#    'back_reference_schedule_name': 'SA11AI',
#    'back_reference_transaction_id': 'VVC97N5Y748E',
#    'candidate_first_name': None,
#    'candidate_id': None,
#    'candidate_last_name': None,
#    'candidate_middle_name': None,
#    'candidate_name': None,
#    'candidate_office': None,
#    'candidate_office_district': None,
#    'candidate_office_full': None,
# ...
#     'zip': '04078'},
#    'committee_id': 'C00709899',
#    'committee_name': None,
#    'conduit_committee_city': None,
#    'conduit_committee_id': None,
#    'conduit_committee_name': None,
#    'conduit_committee_state': None,
#    'conduit_committee_street1': None,
#    'conduit_committee_street2': None,
#    'conduit_committee_zip': None,
#    'contribution_receipt_amount': 2000.0,
#    'contribution_receipt_date': '2019-06-24T00:00:00',
#    'contributor': {'affiliated_committee_name': 'NONE',
#     'candidate_ids': [],
#     'city': 'SOMERVILLE',
#     'committee_id': 'C00401224',
#     'committee_type': 'W',
#     'committee_type_full': 'PAC with Non-Contribution Account - Qualified',
#     'cycle': 2020,
#     'cycles': [2004, 2006, 2008, 2010, 2012, 2014, 2016, 2018, 2020],
#     'designation': 'U',
#     'designation_full': 'Unauthorized',
#     'filing_frequency': 'Q',
#     'name': 'ACTBLUE',
#     'organization_type': None,
#     'organization_type_full': None,
#     'party': None,
#     'party_full': None,
#     'state': 'MA',
#     'state_full': 'Massachusetts',
#     'street_1': 'P.O. BOX 441146',
#     'street_2': None,
#     'treasurer_name': 'HILL, ERIN',
#     'zip': '02144'},
#    'contributor_aggregate_ytd': 2000.0,
#    'contributor_city': 'PORTLAND',
#    'contributor_employer': 'NOT EMPLOYED',
#    'contributor_first_name': 'DANIEL',
#    'contributor_id': 'C00401224',
#    'contributor_last_name': 'AMORY',
#    'contributor_middle_name': None,
#    'contributor_name': 'AMORY, DANIEL',
#    'contributor_occupation': 'NOT EMPLOYED',
#    'contributor_prefix': None,
#    'contributor_state': 'ME',
#    'contributor_street_1': '188 PINE ST',
#    'contributor_street_2': None,
#    'contributor_suffix': None,
#    'contributor_zip': '041023513',
#    'donor_committee_name': None,
#    'election_type': 'P2020',
#    'election_type_full': None,
#    'entity_type': 'IND',
#    'entity_type_desc': 'INDIVIDUAL',
#    'fec_election_type_desc': 'PRIMARY',
#    'fec_election_year': '2020',
#    'file_number': 1350784,
#    'filing_form': 'F3',
#    'image_number': '201909059163151716',
#    'increased_limit': None,
#    'is_individual': True,
#    'line_number': '11AI',
#    'line_number_label': 'Contributions From Individuals/Persons Other Than Political Committees',
#    'link_id': 4090520191672279062,
#    'load_date': '2019-09-07T02:49:13.414000+00:00',
#    'memo_code': None,
#    'memo_code_full': None,
#    'memo_text': '* EARMARKED CONTRIBUTION: SEE BELOW',
#    'memoed_subtotal': False,
#    'national_committee_nonfederal_account': None,
#    'original_sub_id': None,
#    'pdf_url': 'http://docquery.fec.gov/cgi-bin/fecimg/?201909059163151716',
#    'receipt_type': '15E',
#    'receipt_type_desc': 'EARMARKED CONTRIBUTION',
#    'receipt_type_full': None,
#    'recipient_committee_designation': 'P',
#    'recipient_committee_org_type': None,
#    'recipient_committee_type': 'S',
#    'report_type': 'Q2',
#    'report_year': 2019,
#    'schedule_type': 'SA',
#    'schedule_type_full': 'ITEMIZED RECEIPTS',
#    'sub_id': '4090620191672335940',
#    'transaction_id': 'VVC97N5VAY4',
#    'two_year_transaction_period': 2020,
#    'unused_contbr_id': 'C00401224'},
#   {'amendment_indicator': 'N',
#    'amendment_indicator_desc': 'NO CHANGE',
#    'back_reference_schedule_name': 'SA11AI',
#    'back_reference_transaction_id': 'VVC97N5XNY4E',
#    'candidate_first_name': None,
#    'candidate_id': None,
#    'candidate_last_name': None,
#    'candidate_middle_name': None,
#    'candidate_name': None,
#    'candidate_office': None,
#    'candidate_office_district': None,
#    'candidate_office_full': None,
#    'candidate_office_state': None,
#    'candidate_office_state_full': None,
#    'candidate_prefix': None,
#    'candidate_suffix': None,
#    'committee': {'affiliated_committee_name': 'NONE',
#     'candidate_ids': ['S0ME00111'],
#     'city': 'SOUTH FREEPORT',
#     'committee_id': 'C00709899',
#     'committee_type': 'S',
#     'committee_type_full': 'Senate',
#     'cycle': 2020,
#     'cycles': [2020],
#     'designation': 'P',
#     'designation_full': 'Principal campaign committee',
#     'filing_frequency': 'Q',
#     'name': 'SARA GIDEON FOR MAINE',
#     'organization_type': None,
#     'organization_type_full': None,
#     'party': 'DEM',
#     'party_full': 'DEMOCRATIC PARTY',
#     'state': 'ME',
#     'state_full': 'Maine',
#     'street_1': 'PO BOX 812',
#     'street_2': None,
#     'treasurer_name': 'LUNN, LISA MS.',
#     'zip': '04078'},
#    'committee_id': 'C00709899',
#    'committee_name': None,
#    'conduit_committee_city': None,
#    'conduit_committee_id': None,
#    'conduit_committee_name': None,
#    'conduit_committee_state': None,
#    'conduit_committee_street1': None,
#    'conduit_committee_street2': None,
#    'conduit_committee_zip': None,
#    'contribution_receipt_amount': 2000.0,
#    'contribution_receipt_date': '2019-06-24T00:00:00',
#    'contributor': {'affiliated_committee_name': 'NONE',
#     'candidate_ids': [],
#     'city': 'SOMERVILLE',
#     'committee_id': 'C00401224',
#     'committee_type': 'W',
#     'committee_type_full': 'PAC with Non-Contribution Account - Qualified',
#     'cycle': 2020,
#     'cycles': [2004, 2006, 2008, 2010, 2012, 2014, 2016, 2018, 2020],
#     'designation': 'U',
#     'designation_full': 'Unauthorized',
#     'filing_frequency': 'Q',
#     'name': 'ACTBLUE',
#     'organization_type': None,
#     'organization_type_full': None,
#     'party': None,
#     'party_full': None,
#     'state': 'MA',
#     'state_full': 'Massachusetts',
#     'street_1': 'P.O. BOX 441146',
#     'street_2': None,
#     'treasurer_name': 'HILL, ERIN',
#     'zip': '02144'},
#    'contributor_aggregate_ytd': 2000.0,
#    'contributor_city': 'BOSTON',
#    'contributor_employer': 'NOT EMPLOYED',
#    'contributor_first_name': 'NICKI',
#    'contributor_id': 'C00401224',
#    'contributor_last_name': 'GAMBLE',
#    'contributor_middle_name': None,
#    'contributor_name': 'GAMBLE, NICKI',
#    'contributor_occupation': 'NOT EMPLOYED',
#    'contributor_prefix': None,
#    'contributor_state': 'MA',
#    'contributor_street_1': '100 BELVIDERE ST',
#    'contributor_street_2': None,
#    'contributor_suffix': None,
#    'contributor_zip': '021997622',
#    'donor_committee_name': None,
#    'election_type': 'P2020',
#    'election_type_full': None,
#    'entity_type': 'IND',
#    'entity_type_desc': 'INDIVIDUAL',
#    'fec_election_type_desc': 'PRIMARY',
#    'fec_election_year': '2020',
#    'file_number': 1350784,
#    'filing_form': 'F3',
#    'image_number': '201909059163151717',
#    'increased_limit': None,
#    'is_individual': True,
#    'line_number': '11AI',
#    'line_number_label': 'Contributions From Individuals/Persons Other Than Political Committees',
#    'link_id': 4090520191672279062,
#    'load_date': '2019-09-07T02:49:13.414000+00:00',
#    'memo_code': None,
#    'memo_code_full': None,
#    'memo_text': '* EARMARKED CONTRIBUTION: SEE BELOW',
#    'memoed_subtotal': False,
#    'national_committee_nonfederal_account': None,
#    'original_sub_id': None,
#    'pdf_url': 'http://docquery.fec.gov/cgi-bin/fecimg/?201909059163151717',
#    'receipt_type': '15E',
#    'receipt_type_desc': 'EARMARKED CONTRIBUTION',
#    'receipt_type_full': None,
#    'recipient_committee_designation': 'P',
#    'recipient_committee_org_type': None,
#    'recipient_committee_type': 'S',
#    'report_type': 'Q2',
#    'report_year': 2019,
#    'schedule_type': 'SA',
#    'schedule_type_full': 'ITEMIZED RECEIPTS',
#    'sub_id': '4090620191672335944',
#    'transaction_id': 'VVC97N5XNY4',
#    'two_year_transaction_period': 2020,
#    'unused_contbr_id': 'C00401224'},
#   {'amendment_indicator': 'N',
#    'amendment_indicator_desc': 'NO CHANGE',
#    'back_reference_schedule_name': 'SA11AI',
#    'back_reference_transaction_id': 'VVC97N5YN05E',
#    'candidate_first_name': None,
#    'candidate_id': None,
#    'candidate_last_name': None,
#    'candidate_middle_name': None,
#    'candidate_name': None,
#    'candidate_office': None,
#    'candidate_office_district': None,
#    'candidate_office_full': None,
#    'candidate_office_state': None,
#    'candidate_office_state_full': None,
#    'candidate_prefix': None,
#    'candidate_suffix': None,
#    'committee': {'affiliated_committee_name': 'NONE',
#     'candidate_ids': ['S0ME00111'],
#     'city': 'SOUTH FREEPORT',
#     'committee_id': 'C00709899',
#     'committee_type': 'S',
#     'committee_type_full': 'Senate',
#     'cycle': 2020,
#     'cycles': [2020],
#     'designation': 'P',
#     'designation_full': 'Principal campaign committee',
#     'filing_frequency': 'Q',
#     'name': 'SARA GIDEON FOR MAINE',
#     'organization_type': None,
#     'organization_type_full': None,
#     'party': 'DEM',
#     'party_full': 'DEMOCRATIC PARTY',
#     'state': 'ME',
#     'state_full': 'Maine',
#     'street_1': 'PO BOX 812',
#     'street_2': None,
#     'treasurer_name': 'LUNN, LISA MS.',
#     'zip': '04078'},
#    'committee_id': 'C00709899',
#    'committee_name': None,
#    'conduit_committee_city': None,
#    'conduit_committee_id': None,
#    'conduit_committee_name': None,
#    'conduit_committee_state': None,
#    'conduit_committee_street1': None,
#    'conduit_committee_street2': None,
#    'conduit_committee_zip': None,
#    'contribution_receipt_amount': 250.0,
#    'contribution_receipt_date': '2019-06-24T00:00:00',
#    'contributor': {'affiliated_committee_name': 'NONE',
#     'candidate_ids': [],
#     'city': 'SOMERVILLE',
#     'committee_id': 'C00401224',
#     'committee_type': 'W',
#     'committee_type_full': 'PAC with Non-Contribution Account - Qualified',
#     'cycle': 2020,
#     'cycles': [2004, 2006, 2008, 2010, 2012, 2014, 2016, 2018, 2020],
#     'designation': 'U',
#     'designation_full': 'Unauthorized',
#     'filing_frequency': 'Q',
#     'name': 'ACTBLUE',
#     'organization_type': None,
#     'organization_type_full': None,
#     'party': None,
#     'party_full': None,
#     'state': 'MA',
#     'state_full': 'Massachusetts',
#     'street_1': 'P.O. BOX 441146',
#     'street_2': None,
#     'treasurer_name': 'HILL, ERIN',
#     'zip': '02144'},
#    'contributor_aggregate_ytd': 250.0,
#    'contributor_city': 'CHICAGO',
#    'contributor_employer': 'SELF EMPLOYED',
#    'contributor_first_name': 'TIM',
#    'contributor_id': 'C00401224',
#    'contributor_last_name': 'FRIEDMAN',
#    'contributor_middle_name': None,
#    'contributor_name': 'FRIEDMAN, TIM',
#    'contributor_occupation': 'PRIVATE EQUITY INVESTOR',
#    'contributor_prefix': None,
#    'contributor_state': 'IL',
#    'contributor_street_1': '1925 N CLEVELAND AVE',
#    'contributor_street_2': None,
#    'contributor_suffix': None,
#    'contributor_zip': '606145215',
#    'donor_committee_name': None,
#    'election_type': 'P2020',
#    'election_type_full': None,
#    'entity_type': 'IND',
#    'entity_type_desc': 'INDIVIDUAL',
#    'fec_election_type_desc': 'PRIMARY',
#    'fec_election_year': '2020',
#    'file_number': 1350784,
#    'filing_form': 'F3',
#    'image_number': '201909059163151719',
#    'increased_limit': None,
#    'is_individual': True,
#    'line_number': '11AI',
#    'line_number_label': 'Contributions From Individuals/Persons Other Than Political Committees',
#    'link_id': 4090520191672279062,
#    'load_date': '2019-09-07T02:49:13.415000+00:00',
#    'memo_code': None,
#    'memo_code_full': None,
#    'memo_text': '* EARMARKED CONTRIBUTION: SEE BELOW',
#    'memoed_subtotal': False,
#    'national_committee_nonfederal_account': None,
#    'original_sub_id': None,
#    'pdf_url': 'http://docquery.fec.gov/cgi-bin/fecimg/?201909059163151719',
#    'receipt_type': '15E',
#    'receipt_type_desc': 'EARMARKED CONTRIBUTION',
#    'receipt_type_full': None,
#    'recipient_committee_designation': 'P',
#    'recipient_committee_org_type': None,
#    'recipient_committee_type': 'S',
#    'report_type': 'Q2',
#    'report_year': 2019,
#    'schedule_type': 'SA',
#    'schedule_type_full': 'ITEMIZED RECEIPTS',
#    'sub_id': '4090620191672335956',
#    'transaction_id': 'VVC97N5YN05',
#    'two_year_transaction_period': 2020,
#    'unused_contbr_id': 'C00401224'},
#   {'amendment_indicator': 'N',
#    'amendment_indicator_desc': 'NO CHANGE',
#    'back_reference_schedule_name': 'SA11AI',
#    'back_reference_transaction_id': 'VVC97N5WF15E',
#    'candidate_first_name': None,
#    'candidate_id': None,
#    'candidate_last_name': None,
#    'candidate_middle_name': None,
#    'candidate_name': None,
#    'candidate_office': None,
#    'candidate_office_district': None,
#    'candidate_office_full': None,
#    'candidate_office_state': None,
#    'candidate_office_state_full': None,
#    'candidate_prefix': None,
#    'candidate_suffix': None,
#    'committee': {'affiliated_committee_name': 'NONE',
#     'candidate_ids': ['S0ME00111'],
#     'city': 'SOUTH FREEPORT',
#     'committee_id': 'C00709899',
#     'committee_type': 'S',
#     'committee_type_full': 'Senate',
#     'cycle': 2020,
#     'cycles': [2020],
#     'designation': 'P',
#     'designation_full': 'Principal campaign committee',
#     'filing_frequency': 'Q',
#     'name': 'SARA GIDEON FOR MAINE',
#     'organization_type': None,
#     'organization_type_full': None,
#     'party': 'DEM',
#     'party_full': 'DEMOCRATIC PARTY',
#     'state': 'ME',
#     'state_full': 'Maine',
#     'street_1': 'PO BOX 812',
#     'street_2': None,
#     'treasurer_name': 'LUNN, LISA MS.',
#     'zip': '04078'},
#    'committee_id': 'C00709899',
#    'committee_name': None,
#    'conduit_committee_city': None,
#    'conduit_committee_id': None,
#    'conduit_committee_name': None,
#    'conduit_committee_state': None,
#    'conduit_committee_street1': None,
#    'conduit_committee_street2': None,
#    'conduit_committee_zip': None,
#    'contribution_receipt_amount': 2700.0,
#    'contribution_receipt_date': '2019-06-24T00:00:00',
#    'contributor': {'affiliated_committee_name': 'NONE',
#     'candidate_ids': [],
#     'city': 'SOMERVILLE',
#     'committee_id': 'C00401224',
#     'committee_type': 'W',
#     'committee_type_full': 'PAC with Non-Contribution Account - Qualified',
#     'cycle': 2020,
#     'cycles': [2004, 2006, 2008, 2010, 2012, 2014, 2016, 2018, 2020],
#     'designation': 'U',
#     'designation_full': 'Unauthorized',
#     'filing_frequency': 'Q',
#     'name': 'ACTBLUE',
#     'organization_type': None,
#     'organization_type_full': None,
#     'party': None,
#     'party_full': None,
#     'state': 'MA',
#     'state_full': 'Massachusetts',
#     'street_1': 'P.O. BOX 441146',
#     'street_2': None,
#     'treasurer_name': 'HILL, ERIN',
#     'zip': '02144'},
#    'contributor_aggregate_ytd': 2700.0,
#    'contributor_city': 'PORTLAND',
#    'contributor_employer': 'BERMAN & SIMMONS',
#    'contributor_first_name': 'JODI',
#    'contributor_id': 'C00401224',
#    'contributor_last_name': 'NOFSINGER',
#    'contributor_middle_name': None,
#    'contributor_name': 'NOFSINGER, JODI',
#    'contributor_occupation': 'ATTORNEY',
#    'contributor_prefix': None,
#    'contributor_state': 'ME',
#    'contributor_street_1': '15 MORSE ST',
#    'contributor_street_2': None,
#    'contributor_suffix': None,
#    'contributor_zip': '041035015',
#    'donor_committee_name': None,
#    'election_type': 'P2020',
#    'election_type_full': None,
#    'entity_type': 'IND',
#    'entity_type_desc': 'INDIVIDUAL',
#    'fec_election_type_desc': 'PRIMARY',
#    'fec_election_year': '2020',
#    'file_number': 1350784,
#    'filing_form': 'F3',
#    'image_number': '201909059163151721',
#    'increased_limit': None,
#    'is_individual': True,
#    'line_number': '11AI',
#    'line_number_label': 'Contributions From Individuals/Persons Other Than Political Committees',
#    'link_id': 4090520191672279062,
#    'load_date': '2019-09-07T02:49:13.417000+00:00',
#    'memo_code': None,
#    'memo_code_full': None,
#    'memo_text': '* EARMARKED CONTRIBUTION: SEE BELOW',
#    'memoed_subtotal': False,
#    'national_committee_nonfederal_account': None,
#    'original_sub_id': None,
#    'pdf_url': 'http://docquery.fec.gov/cgi-bin/fecimg/?201909059163151721',
#    'receipt_type': '15E',
#    'receipt_type_desc': 'EARMARKED CONTRIBUTION',
#    'receipt_type_full': None,
#    'recipient_committee_designation': 'P',
#    'recipient_committee_org_type': None,
#    'recipient_committee_type': 'S',
#    'report_type': 'Q2',
#    'report_year': 2019,
#    'schedule_type': 'SA',
#    'schedule_type_full': 'ITEMIZED RECEIPTS',
#    'sub_id': '4090620191672335968',
#    'transaction_id': 'VVC97N5WF15',
#    'two_year_transaction_period': 2020,
#    'unused_contbr_id': 'C00401224'}]}

# %%
alldf=pd.concat(dfs,sort=False,ignore_index=True)
alldf.to_csv('sample-dfs.csv')

# %%
# Concatenate all dfs
itemdf=pd.concat(dfs,sort=False,ignore_index=True)
itemdf=itemdf.drop_duplicates(subset='transaction_id')

# %%
#Write itemized individual results to local CSV
cwd = os.getcwd()
itemdf.to_csv(cwd+'/data/individual-senate-contributions.csv')

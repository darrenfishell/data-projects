# %%
import numpy as np
import pandas as pd
import requests
import config
import os
import json
from pandas.io.json import json_normalize
import pygsheets

##Schedule_a API guide: https://api.open.fec.gov/developers/#/receipts/get_schedules_schedule_a_

querydict = {'per_page':'20'
               ,'api_key':config.api_key
               ,'committee_id':'C00709899'
               ,'page':'1'
               ,'sort_nulls_last':'false'
               ,'sort':'-contribution_receipt_date'
               ,'sort_hide_null':'false'
                 }
r = requests.get('https://api.open.fec.gov/v1/schedules/schedule_a/efile/',params=querydict).json()
r
# Out:
# {'api_version': '1.0',
#  'pagination': {'count': 1176, 'page': 1, 'pages': 59, 'per_page': 20},
#  'results': [{'amendment_indicator': 'A',
#    'back_reference_schedule_name': 'SA11AI',
#    'back_reference_transaction_id': 'VVC97N903W0E',
#    'committee': {'candidate_ids': ['S0ME00111'],
#     'city': 'SOUTH FREEPORT',
#     'committee_id': 'C00709899',
#     'committee_type': 'S',
#     'committee_type_full': 'Senate',
#     'cycle': 2020,
#     'cycles': [2020],
#     'designation': 'P',
#     'designation_full': 'Principal campaign committee',
#     'filing_frequency': 'Q',
#     'name': 'SARA GIDEON FOR MAINE',
#     'organization_type': None,
#     'organization_type_full': None,
#     'party': 'DEM',
#     'party_full': 'DEMOCRATIC PARTY',
#     'state': 'ME',
#     'state_full': 'Maine',
#     'street_1': 'PO BOX 812',
#     'street_2': None,
#     'treasurer_name': 'LUNN, LISA',
#     'zip': '04078'},
#    'committee_id': 'C00709899',
#    'conduit_committee_city': None,
#    'conduit_committee_id': None,
#    'conduit_committee_name': None,
#    'conduit_committee_state': None,
#    'conduit_committee_street1': None,
#    'conduit_committee_street2': None,
#    'conduit_committee_zip': None,
#    'contribution_receipt_amount': 2800.0,
#    'contribution_receipt_date': '2019-07-29',
#    'contributor_aggregate_ytd': 5600.0,
#    'contributor_city': 'Cumberland Foreside',
#    'contributor_employer': 'Horizon Foundation',
#    'contributor_first_name': 'Alexander',
#    'contributor_last_name': 'Buck',
#    'contributor_middle_name': 'K.',
#    'contributor_name': 'Buck,  Alexander K. Jr.',
#    'contributor_occupation': 'President',
#    'contributor_prefix': None,
#    'contributor_state': 'ME',
#    'contributor_suffix': 'Jr.',
#    'contributor_zip': '041101436',
#    'cycle': 2019,
#    'entity_type': 'IND',
#    'fec_election_type_desc': 'GENERAL',
#    'file_number': 1340957,
#    'filing': {'amended_by': None,
#     'amendment_chain': [1340957],
#     'amendment_number': 0,
#     'amends_file': None,
#     'beginning_image_number': '201907159151132120',
#     'committee_id': 'C00709899',
#     'committee_name': 'SARA GIDEON FOR MAINE',
#     'coverage_end_date': '2019-06-30',
#     'coverage_start_date': '2019-06-20',
#     'csv_url': 'http://docquery.fec.gov/csv/957/1340957.csv',
#     'document_description': 'JULY QUARTERLY 2019',
#     'ending_image_number': '201907159151132518',
#     'fec_file_id': 'FEC-1340957',
#     'fec_url': 'http://docquery.fec.gov/dcdev/posted/1340957.fec',
#     'file_number': 1340957,
#     'filed_date': '2019-07-15',
#     'form_type': 'F3N',
#     'html_url': 'http://docquery.fec.gov/cgi-bin/forms/C00709899/1340957/',
#     'is_amended': False,
#     'load_timestamp': '2019-07-15T20:19:07+00:00',
#     'most_recent': True,
#     'most_recent_filing': 1340957,
#     'pdf_url': 'http://docquery.fec.gov/pdf/120/201907159151132120/201907159151132120.pdf',
#     'receipt_date': '2019-07-15T20:18:59+00:00'},
#    'image_number': '201907159151132158',
#    'line_number': '11AI',
#    'load_timestamp': '2019-07-15T20:19:08+00:00',
#    'memo_code': None,
#    'memo_text': '* Earmarked Contribution: See Below',
#    'pdf_url': 'http://docquery.fec.gov/cgi-bin/fecimg/?201907159151132158',
#    'pgo': 'G2020',
#    'related_line_number': 104,
#    'report_type': 'F3N',
#    'transaction_id': 'VVC97N903W0'},
#   {'amendment_indicator': 'A',
#    'back_reference_schedule_name': None,
#    'back_reference_transaction_id': None,
#    'committee': {'candidate_ids': ['S0ME00111'],
#     'city': 'SOUTH FREEPORT',
#     'committee_id': 'C00709899',
#     'committee_type': 'S',
#     'committee_type_full': 'Senate',
#     'cycle': 2020,
#     'cycles': [2020],
#     'designation': 'P',
#     'designation_full': 'Principal campaign committee',
#     'filing_frequency': 'Q',
#     'name': 'SARA GIDEON FOR MAINE',
#     'organization_type': None,
#     'organization_type_full': None,
#     'party': 'DEM',
#     'party_full': 'DEMOCRATIC PARTY',
#     'state': 'ME',
#     'state_full': 'Maine',
#     'street_1': 'PO BOX 812',
#     'street_2': None,
#     'treasurer_name': 'LUNN, LISA',
#     'zip': '04078'},
#    'committee_id': 'C00709899',
#    'conduit_committee_city': None,
#    'conduit_committee_id': 'C00401224',
#    'conduit_committee_name': 'ActBlue',
#    'conduit_committee_state': None,
#    'conduit_committee_street1': None,
#    'conduit_committee_street2': None,
#    'conduit_committee_zip': None,
#    'contribution_receipt_amount': 500.0,
#    'contribution_receipt_date': '2019-06-30',
#    'contributor_aggregate_ytd': 1016439.26,
#    'contributor_city': 'West Somerville',
#    'contributor_employer': None,
#    'contributor_first_name': None,
#    'contributor_last_name': 'ActBlue',
#    'contributor_middle_name': None,
#    'contributor_name': 'ActBlue,',
#    'contributor_occupation': 'Conduit total listed in Agg. field',
#    'contributor_prefix': None,
#    'contributor_state': 'MA',
#    'contributor_suffix': None,
#    'contributor_zip': '021440031',
#    'cycle': 2019,
#    'entity_type': 'PAC',
#    'fec_election_type_desc': 'PRIMARY',
#    'file_number': 1340957,
#    'filing': {'amended_by': None,
#     'amendment_chain': [1340957],
#     'amendment_number': 0,
#     'amends_file': None,
#     'beginning_image_number': '201907159151132120',
#     'committee_id': 'C00709899',
#     'committee_name': 'SARA GIDEON FOR MAINE',
#     'coverage_end_date': '2019-06-30',
#     'coverage_start_date': '2019-06-20',
#     'csv_url': 'http://docquery.fec.gov/csv/957/1340957.csv',
#     'document_description': 'JULY QUARTERLY 2019',
#     'ending_image_number': '201907159151132518',
#     'fec_file_id': 'FEC-1340957',
#     'fec_url': 'http://docquery.fec.gov/dcdev/posted/1340957.fec',
#     'file_number': 1340957,
#     'filed_date': '2019-07-15',
#     'form_type': 'F3N',
#     'html_url': 'http://docquery.fec.gov/cgi-bin/forms/C00709899/1340957/',
#     'is_amended': False,
#     'load_timestamp': '2019-07-15T20:19:07+00:00',
#     'most_recent': True,
#     'most_recent_filing': 1340957,
#     'pdf_url': 'http://docquery.fec.gov/pdf/120/201907159151132120/201907159151132120.pdf',
#     'receipt_date': '2019-07-15T20:18:59+00:00'},
#    'image_number': '201907159151132287',
#    'line_number': '11AI',
#    'load_timestamp': '2019-07-15T20:19:11+00:00',
#    'memo_code': 'X',
#    'memo_text': 'Note: Above Contribution earmarked through this organization.',
#    'pdf_url': 'http://docquery.fec.gov/cgi-bin/fecimg/?201907159151132287',
#    'pgo': 'P2020',
#    'related_line_number': 492,
#    'report_type': 'F3N',
#    'transaction_id': 'VVC97N6TM04E'},
#   {'amendment_indicator': 'A',
#    'back_reference_schedule_name': None,
#    'back_reference_transaction_id': None,
#    'committee': {'candidate_ids': ['S0ME00111'],
#     'city': 'SOUTH FREEPORT',
#     'committee_id': 'C00709899',
#     'committee_type': 'S',
#     'committee_type_full': 'Senate',
#     'cycle': 2020,
#     'cycles': [2020],
#     'designation': 'P',
#     'designation_full': 'Principal campaign committee',
#     'filing_frequency': 'Q',
#     'name': 'SARA GIDEON FOR MAINE',
#     'organization_type': None,
#     'organization_type_full': None,
#     'party': 'DEM',
#     'party_full': 'DEMOCRATIC PARTY',
#     'state': 'ME',
#     'state_full': 'Maine',
#     'street_1': 'PO BOX 812',
#     'street_2': None,
#     'treasurer_name': 'LUNN, LISA',
#     'zip': '04078'},
#    'committee_id': 'C00709899',
#    'conduit_committee_city': None,
#    'conduit_committee_id': 'C00401224',
#    'conduit_committee_name': 'ActBlue',
#    'conduit_committee_state': None,
#    'conduit_committee_street1': None,
#    'conduit_committee_street2': None,
#    'conduit_committee_zip': None,
#    'contribution_receipt_amount': 1000.0,
#    'contribution_receipt_date': '2019-06-30',
#    'contributor_aggregate_ytd': 1016439.26,
#    'contributor_city': 'West Somerville',
#    'contributor_employer': None,
#    'contributor_first_name': None,
#    'contributor_last_name': 'ActBlue',
#    'contributor_middle_name': None,
#    'contributor_name': 'ActBlue,',
#    'contributor_occupation': 'Conduit total listed in Agg. field',
#    'contributor_prefix': None,
#    'contributor_state': 'MA',
#    'contributor_suffix': None,
#    'contributor_zip': '021440031',
#    'cycle': 2019,
#    'entity_type': 'PAC',
#    'fec_election_type_desc': 'PRIMARY',
#    'file_number': 1340957,
#    'filing': {'amended_by': None,
#     'amendment_chain': [1340957],
#     'amendment_number': 0,
#     'amends_file': None,
#     'beginning_image_number': '201907159151132120',
#     'committee_id': 'C00709899',
#     'committee_name': 'SARA GIDEON FOR MAINE',
#     'coverage_end_date': '2019-06-30',
#     'coverage_start_date': '2019-06-20',
#     'csv_url': 'http://docquery.fec.gov/csv/957/1340957.csv',
#     'document_description': 'JULY QUARTERLY 2019',
#     'ending_image_number': '201907159151132518',
#     'fec_file_id': 'FEC-1340957',
#     'fec_url': 'http://docquery.fec.gov/dcdev/posted/1340957.fec',
#     'file_number': 1340957,
#     'filed_date': '2019-07-15',
#     'form_type': 'F3N',
#     'html_url': 'http://docquery.fec.gov/cgi-bin/forms/C00709899/1340957/',
#     'is_amended': False,
#     'load_timestamp': '2019-07-15T20:19:07+00:00',
#     'most_recent': True,
#     'most_recent_filing': 1340957,
#     'pdf_url': 'http://docquery.fec.gov/pdf/120/201907159151132120/201907159151132120.pdf',
#     'receipt_date': '2019-07-15T20:18:59+00:00'},
#    'image_number': '201907159151132306',
#    'line_number': '11AI',
#    'load_timestamp': '2019-07-15T20:19:12+00:00',
#    'memo_code': 'X',
#    'memo_text': 'Note: Above Contribution earmarked through this organization.',
#    'pdf_url': 'http://docquery.fec.gov/cgi-bin/fecimg/?201907159151132306',
#    'pgo': 'P2020',
#    'related_line_number': 550,
#    'report_type': 'F3N',
#    'transaction_id': 'VVC97N6S7G4E'},
#   {'amendment_indicator': 'A',
#    'back_reference_schedule_name': 'SA11AI',
#    'back_reference_transaction_id': 'VVC97N6VJG4E',
#    'committee': {'candidate_ids': ['S0ME00111'],
#     'city': 'SOUTH FREEPORT',
#     'committee_id': 'C00709899',
#     'committee_type': 'S',
#     'committee_type_full': 'Senate',
#     'cycle': 2020,
#     'cycles': [2020],
#     'designation': 'P',
#     'designation_full': 'Principal campaign committee',
#     'filing_frequency': 'Q',
#     'name': 'SARA GIDEON FOR MAINE',
#     'organization_type': None,
#     'organization_type_full': None,
#     'party': 'DEM',
#     'party_full': 'DEMOCRATIC PARTY',
#     'state': 'ME',
#     'state_full': 'Maine',
#     'street_1': 'PO BOX 812',
#     'street_2': None,
#     'treasurer_name': 'LUNN, LISA',
#     'zip': '04078'},
#    'committee_id': 'C00709899',
#    'conduit_committee_city': None,
#    'conduit_committee_id': None,
#    'conduit_committee_name': None,
#    'conduit_committee_state': None,
#    'conduit_committee_street1': None,
#    'conduit_committee_street2': None,
#    'conduit_committee_zip': None,
#    'contribution_receipt_amount': 500.0,
#    'contribution_receipt_date': '2019-06-30',
#    'contributor_aggregate_ytd': 500.0,
#    'contributor_city': 'Brookline',
#    'contributor_employer': 'Not Employed',
#    'contributor_first_name': 'Marilyn',
#    'contributor_last_name': 'Smith',
#    'contributor_middle_name': None,
#    'contributor_name': 'Smith,  Marilyn',
#    'contributor_occupation': 'Not Employed',
#    'contributor_prefix': None,
#    'contributor_state': 'MA',
#    'contributor_suffix': None,
#    'contributor_zip': '024457421',
#    'cycle': 2019,
#    'entity_type': 'IND',
#    'fec_election_type_desc': 'PRIMARY',
#    'file_number': 1340957,
#    'filing': {'amended_by': None,
#     'amendment_chain': [1340957],
#     'amendment_number': 0,
#     'amends_file': None,
#     'beginning_image_number': '201907159151132120',
#     'committee_id': 'C00709899',
#     'committee_name': 'SARA GIDEON FOR MAINE',
#     'coverage_end_date': '2019-06-30',
#     'coverage_start_date': '2019-06-20',
#     'csv_url': 'http://docquery.fec.gov/csv/957/1340957.csv',
#     'document_description': 'JULY QUARTERLY 2019',
#     'ending_image_number': '201907159151132518',
#     'fec_file_id': 'FEC-1340957',
#     'fec_url': 'http://docquery.fec.gov/dcdev/posted/1340957.fec',
#     'file_number': 1340957,
#     'filed_date': '2019-07-15',
#     'form_type': 'F3N',
#     'html_url': 'http://docquery.fec.gov/cgi-bin/forms/C00709899/1340957/',
#     'is_amended': False,
#     'load_timestamp': '2019-07-15T20:19:07+00:00',
#     'most_recent': True,
#     'most_recent_filing': 1340957,
#     'pdf_url': 'http://docquery.fec.gov/pdf/120/201907159151132120/201907159151132120.pdf',
#     'receipt_date': '2019-07-15T20:18:59+00:00'},
#    'image_number': '201907159151132307',
#    'line_number': '11AI',
#    'load_timestamp': '2019-07-15T20:19:12+00:00',
#    'memo_code': None,
#    'memo_text': '* Earmarked Contribution: See Below',
#    'pdf_url': 'http://docquery.fec.gov/cgi-bin/fecimg/?201907159151132307',
#    'pgo': 'P2020',
#    'related_line_number': 551,
#    'report_type': 'F3N',
#    'transaction_id': 'VVC97N6VJG4'},
#   {'amendment_indicator': 'A',
#    'back_reference_schedule_name': None,
#    'back_reference_transaction_id': None,
#    'committee': {'candidate_ids': ['S0ME00111'],
#     'city': 'SOUTH FREEPORT',
#     'committee_id': 'C00709899',
#     'committee_type': 'S',
#     'committee_type_full': 'Senate',
#     'cycle': 2020,
#     'cycles': [2020],
#     'designation': 'P',
#     'designation_full': 'Principal campaign committee',
#     'filing_frequency': 'Q',
#     'name': 'SARA GIDEON FOR MAINE',
#     'organization_type': None,
#     'organization_type_full': None,
#     'party': 'DEM',
#     'party_full': 'DEMOCRATIC PARTY',
#     'state': 'ME',
#     'state_full': 'Maine',
#     'street_1': 'PO BOX 812',
#     'street_2': None,
#     'treasurer_name': 'LUNN, LISA',
#     'zip': '04078'},
#    'committee_id': 'C00709899',
#    'conduit_committee_city': None,
#    'conduit_committee_id': 'C00401224',
#    'conduit_committee_name': 'ActBlue',
#    'conduit_committee_state': None,
#    'conduit_committee_street1': None,
#    'conduit_committee_street2': None,
#    'conduit_committee_zip': None,
#    'contribution_receipt_amount': 500.0,
#    'contribution_receipt_date': '2019-06-30',
#    'contributor_aggregate_ytd': 1016439.26,
#    'contributor_city': 'West Somerville',
#    'contributor_employer': None,
#    'contributor_first_name': None,
#    'contributor_last_name': 'ActBlue',
#    'contributor_middle_name': None,
#    'contributor_name': 'ActBlue,',
#    'contributor_occupation': 'Conduit total listed in Agg. field',
#    'contributor_prefix': None,
#    'contributor_state': 'MA',
#    'contributor_suffix': None,
#    'contributor_zip': '021440031',
#    'cycle': 2019,
#    'entity_type': 'PAC',
#    'fec_election_type_desc': 'PRIMARY',
#    'file_number': 1340957,
#    'filing': {'amended_by': None,
#     'amendment_chain': [1340957],
#     'amendment_number': 0,
#     'amends_file': None,
#     'beginning_image_number': '201907159151132120',
#     'committee_id': 'C00709899',
#     'committee_name': 'SARA GIDEON FOR MAINE',
#     'coverage_end_date': '2019-06-30',
#     'coverage_start_date': '2019-06-20',
#     'csv_url': 'http://docquery.fec.gov/csv/957/1340957.csv',
#     'document_description': 'JULY QUARTERLY 2019',
#     'ending_image_number': '201907159151132518',
#     'fec_file_id': 'FEC-1340957',
#     'fec_url': 'http://docquery.fec.gov/dcdev/posted/1340957.fec',
#     'file_number': 1340957,
#     'filed_date': '2019-07-15',
#     'form_type': 'F3N',
#     'html_url': 'http://docquery.fec.gov/cgi-bin/forms/C00709899/1340957/',
#     'is_amended': False,
#     'load_timestamp': '2019-07-15T20:19:07+00:00',
#     'most_recent': True,
#     'most_recent_filing': 1340957,
#     'pdf_url': 'http://docquery.fec.gov/pdf/120/201907159151132120/201907159151132120.pdf',
#     'receipt_date': '2019-07-15T20:18:59+00:00'},
#    'image_number': '201907159151132307',
#    'line_number': '11AI',
#    'load_timestamp': '2019-07-15T20:19:12+00:00',
#    'memo_code': 'X',
#    'memo_text': 'Note: Above Contribution earmarked through this organization.',
#    'pdf_url': 'http://docquery.fec.gov/cgi-bin/fecimg/?201907159151132307',
#    'pgo': 'P2020',
#    'related_line_number': 552,
#    'report_type': 'F3N',
#    'transaction_id': 'VVC97N6VJG4E'},
#   {'amendment_indicator': 'A',
#    'back_reference_schedule_name': None,
#    'back_reference_transaction_id': None,
#    'committee': {'candidate_ids': ['S0ME00111'],
#     'city': 'SOUTH FREEPORT',
#     'committee_id': 'C00709899',
#     'committee_type': 'S',
#     'committee_type_full': 'Senate',
#     'cycle': 2020,
#     'cycles': [2020],
#     'designation': 'P',
#     'designation_full': 'Principal campaign committee',
#     'filing_frequency': 'Q',
#     'name': 'SARA GIDEON FOR MAINE',
#     'organization_type': None,
#     'organization_type_full': None,
#     'party': 'DEM',
#     'party_full': 'DEMOCRATIC PARTY',
#     'state': 'ME',
#     'state_full': 'Maine',
#     'street_1': 'PO BOX 812',
#     'street_2': None,
#     'treasurer_name': 'LUNN, LISA',
#     'zip': '04078'},
#    'committee_id': 'C00709899',
#    'conduit_committee_city': None,
#    'conduit_committee_id': 'C00401224',
#    'conduit_committee_name': 'ActBlue',
#    'conduit_committee_state': None,
#    'conduit_committee_street1': None,
#    'conduit_committee_street2': None,
#    'conduit_committee_zip': None,
#    'contribution_receipt_amount': 2800.0,
#    'contribution_receipt_date': '2019-06-30',
#    'contributor_aggregate_ytd': 1016439.26,
#    'contributor_city': 'West Somerville',
#    'contributor_employer': None,
#    'contributor_first_name': None,
#    'contributor_last_name': 'ActBlue',
#    'contributor_middle_name': None,
#    'contributor_name': 'ActBlue,',
#    'contributor_occupation': 'Conduit total listed in Agg. field',
#    'contributor_prefix': None,
#    'contributor_state': 'MA',
#    'contributor_suffix': None,
#    'contributor_zip': '021440031',
#    'cycle': 2019,
#    'entity_type': 'PAC',
#    'fec_election_type_desc': 'GENERAL',
#    'file_number': 1340957,
#    'filing': {'amended_by': None,
#     'amendment_chain': [1340957],
#     'amendment_number': 0,
#     'amends_file': None,
#     'beginning_image_number': '201907159151132120',
#     'committee_id': 'C00709899',
#     'committee_name': 'SARA GIDEON FOR MAINE',
#     'coverage_end_date': '2019-06-30',
#     'coverage_start_date': '2019-06-20',
#     'csv_url': 'http://docquery.fec.gov/csv/957/1340957.csv',
#     'document_description': 'JULY QUARTERLY 2019',
#     'ending_image_number': '201907159151132518',
#     'fec_file_id': 'FEC-1340957',
#     'fec_url': 'http://docquery.fec.gov/dcdev/posted/1340957.fec',
#     'file_number': 1340957,
#     'filed_date': '2019-07-15',
#     'form_type': 'F3N',
#     'html_url': 'http://docquery.fec.gov/cgi-bin/forms/C00709899/1340957/',
#     'is_amended': False,
#     'load_timestamp': '2019-07-15T20:19:07+00:00',
#     'most_recent': True,
#     'most_recent_filing': 1340957,
#     'pdf_url': 'http://docquery.fec.gov/pdf/120/201907159151132120/201907159151132120.pdf',
#     'receipt_date': '2019-07-15T20:18:59+00:00'},
#    'image_number': '201907159151132331',
#    'line_number': '11AI',
#    'load_timestamp': '2019-07-15T20:19:12+00:00',
#    'memo_code': 'X',
#    'memo_text': 'Note: Above Contribution earmarked through this organization.',
#    'pdf_url': 'http://docquery.fec.gov/cgi-bin/fecimg/?201907159151132331',
#    'pgo': 'G2020',
#    'related_line_number': 625,
#    'report_type': 'F3N',
#    'transaction_id': 'VVC97N90435E'},
#   {'amendment_indicator': 'A',
#    'back_reference_schedule_name': None,
#    'back_reference_transaction_id': None,
#    'committee': {'candidate_ids': ['S0ME00111'],
#     'city': 'SOUTH FREEPORT',
#     'committee_id': 'C00709899',
#     'committee_type': 'S',
#     'committee_type_full': 'Senate',
#     'cycle': 2020,
#     'cycles': [2020],
#     'designation': 'P',
#     'designation_full': 'Principal campaign committee',
#     'filing_frequency': 'Q',
#     'name': 'SARA GIDEON FOR MAINE',
#     'organization_type': None,
#     'organization_type_full': None,
#     'party': 'DEM',
#     'party_full': 'DEMOCRATIC PARTY',
#     'state': 'ME',
#     'state_full': 'Maine',
#     'street_1': 'PO BOX 812',
#     'street_2': None,
#     'treasurer_name': 'LUNN, LISA',
#     'zip': '04078'},
#    'committee_id': 'C00709899',
#    'conduit_committee_city': None,
#    'conduit_committee_id': 'C00401224',
#    'conduit_committee_name': 'ActBlue',
#    'conduit_committee_state': None,
#    'conduit_committee_street1': None,
#    'conduit_committee_street2': None,
#    'conduit_committee_zip': None,
#    'contribution_receipt_amount': 2800.0,
#    'contribution_receipt_date': '2019-06-30',
#    'contributor_aggregate_ytd': 1016439.26,
#    'contributor_city': 'West Somerville',
#    'contributor_employer': None,
#    'contributor_first_name': None,
#    'contributor_last_name': 'ActBlue',
#    'contributor_middle_name': None,
#    'contributor_name': 'ActBlue,',
#    'contributor_occupation': 'Conduit total listed in Agg. field',
#    'contributor_prefix': None,
#    'contributor_state': 'MA',
#    'contributor_suffix': None,
#    'contributor_zip': '021440031',
#    'cycle': 2019,
#    'entity_type': 'PAC',
#    'fec_election_type_desc': 'PRIMARY',
#    'file_number': 1340957,
#    'filing': {'amended_by': None,
#     'amendment_chain': [1340957],
#     'amendment_number': 0,
#     'amends_file': None,
#     'beginning_image_number': '201907159151132120',
#     'committee_id': 'C00709899',
#     'committee_name': 'SARA GIDEON FOR MAINE',
#     'coverage_end_date': '2019-06-30',
#     'coverage_start_date': '2019-06-20',
#     'csv_url': 'http://docquery.fec.gov/csv/957/1340957.csv',
#     'document_description': 'JULY QUARTERLY 2019',
#     'ending_image_number': '201907159151132518',
#     'fec_file_id': 'FEC-1340957',
#     'fec_url': 'http://docquery.fec.gov/dcdev/posted/1340957.fec',
#     'file_number': 1340957,
#     'filed_date': '2019-07-15',
#     'form_type': 'F3N',
#     'html_url': 'http://docquery.fec.gov/cgi-bin/forms/C00709899/1340957/',
#     'is_amended': False,
#     'load_timestamp': '2019-07-15T20:19:07+00:00',
#     'most_recent': True,
#     'most_recent_filing': 1340957,
#     'pdf_url': 'http://docquery.fec.gov/pdf/120/201907159151132120/201907159151132120.pdf',
#     'receipt_date': '2019-07-15T20:18:59+00:00'},
#    'image_number': '201907159151132333',
#    'line_number': '11AI',
#    'load_timestamp': '2019-07-15T20:19:12+00:00',
#    'memo_code': 'X',
#    'memo_text': 'Note: Above Contribution earmarked through this organization.',
#    'pdf_url': 'http://docquery.fec.gov/cgi-bin/fecimg/?201907159151132333',
#    'pgo': 'P2020',
#    'related_line_number': 631,
#    'report_type': 'F3N',
#    'transaction_id': 'VVC97N6SS55E'},
#   {'amendment_indicator': 'A',
#    'back_reference_schedule_name': None,
#    'back_reference_transaction_id': None,
#    'committee': {'candidate_ids': ['S0ME00111'],
#     'city': 'SOUTH FREEPORT',
#     'committee_id': 'C00709899',
#     'committee_type': 'S',
#     'committee_type_full': 'Senate',
#     'cycle': 2020,
#     'cycles': [2020],
#     'designation': 'P',
#     'designation_full': 'Principal campaign committee',
#     'filing_frequency': 'Q',
#     'name': 'SARA GIDEON FOR MAINE',
#     'organization_type': None,
#     'organization_type_full': None,
#     'party': 'DEM',
#     'party_full': 'DEMOCRATIC PARTY',
#     'state': 'ME',
#     'state_full': 'Maine',
#     'street_1': 'PO BOX 812',
#     'street_2': None,
#     'treasurer_name': 'LUNN, LISA',
#     'zip': '04078'},
#    'committee_id': 'C00709899',
#    'conduit_committee_city': None,
#    'conduit_committee_id': None,
#    'conduit_committee_name': None,
#    'conduit_committee_state': None,
#    'conduit_committee_street1': None,
#    'conduit_committee_street2': None,
#    'conduit_committee_zip': None,
#    'contribution_receipt_amount': 500.0,
#    'contribution_receipt_date': '2019-06-30',
#    'contributor_aggregate_ytd': 500.0,
#    'contributor_city': 'Scarborough',
#    'contributor_employer': 'Not Employed',
#    'contributor_first_name': 'Rachel',
#    'contributor_last_name': 'Hendrickson',
#    'contributor_middle_name': None,
#    'contributor_name': 'Hendrickson,  Rachel',
#    'contributor_occupation': 'Not Employed',
#    'contributor_prefix': None,
#    'contributor_state': 'ME',
#    'contributor_suffix': None,
#    'contributor_zip': '040749800',
#    'cycle': 2019,
#    'entity_type': 'IND',
#    'fec_election_type_desc': 'PRIMARY',
#    'file_number': 1340957,
#    'filing': {'amended_by': None,
#     'amendment_chain': [1340957],
#     'amendment_number': 0,
#     'amends_file': None,
#     'beginning_image_number': '201907159151132120',
#     'committee_id': 'C00709899',
#     'committee_name': 'SARA GIDEON FOR MAINE',
#     'coverage_end_date': '2019-06-30',
#     'coverage_start_date': '2019-06-20',
#     'csv_url': 'http://docquery.fec.gov/csv/957/1340957.csv',
#     'document_description': 'JULY QUARTERLY 2019',
#     'ending_image_number': '201907159151132518',
#     'fec_file_id': 'FEC-1340957',
#     'fec_url': 'http://docquery.fec.gov/dcdev/posted/1340957.fec',
#     'file_number': 1340957,
#     'filed_date': '2019-07-15',
#     'form_type': 'F3N',
#     'html_url': 'http://docquery.fec.gov/cgi-bin/forms/C00709899/1340957/',
#     'is_amended': False,
#     'load_timestamp': '2019-07-15T20:19:07+00:00',
#     'most_recent': True,
#     'most_recent_filing': 1340957,
#     'pdf_url': 'http://docquery.fec.gov/pdf/120/201907159151132120/201907159151132120.pdf',
#     'receipt_date': '2019-07-15T20:18:59+00:00'},
#    'image_number': '201907159151132334',
#    'line_number': '11AI',
#    'load_timestamp': '2019-07-15T20:19:12+00:00',
#    'memo_code': None,
#    'memo_text': None,
#    'pdf_url': 'http://docquery.fec.gov/cgi-bin/fecimg/?201907159151132334',
#    'pgo': 'P2020',
#    'related_line_number': 632,
#    'report_type': 'F3N',
#    'transaction_id': 'VVC97N77655'},
#   {'amendment_indicator': 'A',
#    'back_reference_schedule_name': None,
#    'back_reference_transaction_id': None,
#    'committee': {'candidate_ids': ['S0ME00111'],
#     'city': 'SOUTH FREEPORT',
#     'committee_id': 'C00709899',
#     'committee_type': 'S',
#     'committee_type_full': 'Senate',
#     'cycle': 2020,
#     'cycles': [2020],
#     'designation': 'P',
#     'designation_full': 'Principal campaign committee',
#     'filing_frequency': 'Q',
#     'name': 'SARA GIDEON FOR MAINE',
#     'organization_type': None,
#     'organization_type_full': None,
#     'party': 'DEM',
#     'party_full': 'DEMOCRATIC PARTY',
#     'state': 'ME',
#     'state_full': 'Maine',
#     'street_1': 'PO BOX 812',
#     'street_2': None,
#     'treasurer_name': 'LUNN, LISA',
#     'zip': '04078'},
#    'committee_id': 'C00709899',
#    'conduit_committee_city': None,
#    'conduit_committee_id': 'C00401224',
#    'conduit_committee_name': 'ActBlue',
#    'conduit_committee_state': None,
#    'conduit_committee_street1': None,
#    'conduit_committee_street2': None,
#    'conduit_committee_zip': None,
#    'contribution_receipt_amount': 500.0,
#    'contribution_receipt_date': '2019-06-30',
#    'contributor_aggregate_ytd': 1016439.26,
#    'contributor_city': 'West Somerville',
#    'contributor_employer': None,
#    'contributor_first_name': None,
#    'contributor_last_name': 'ActBlue',
#    'contributor_middle_name': None,
#    'contributor_name': 'ActBlue,',
#    'contributor_occupation': 'Conduit total listed in Agg. field',
#    'contributor_prefix': None,
#    'contributor_state': 'MA',
#    'contributor_suffix': None,
#    'contributor_zip': '021440031',
#    'cycle': 2019,
#    'entity_type': 'PAC',
#    'fec_election_type_desc': 'PRIMARY',
#    'file_number': 1340957,
#    'filing': {'amended_by': None,
#     'amendment_chain': [1340957],
#     'amendment_number': 0,
#     'amends_file': None,
#     'beginning_image_number': '201907159151132120',
#     'committee_id': 'C00709899',
#     'committee_name': 'SARA GIDEON FOR MAINE',
#     'coverage_end_date': '2019-06-30',
#     'coverage_start_date': '2019-06-20',
#     'csv_url': 'http://docquery.fec.gov/csv/957/1340957.csv',
#     'document_description': 'JULY QUARTERLY 2019',
#     'ending_image_number': '201907159151132518',
#     'fec_file_id': 'FEC-1340957',
#     'fec_url': 'http://docquery.fec.gov/dcdev/posted/1340957.fec',
#     'file_number': 1340957,
#     'filed_date': '2019-07-15',
#     'form_type': 'F3N',
#     'html_url': 'http://docquery.fec.gov/cgi-bin/forms/C00709899/1340957/',
#     'is_amended': False,
#     'load_timestamp': '2019-07-15T20:19:07+00:00',
#     'most_recent': True,
#     'most_recent_filing': 1340957,
#     'pdf_url': 'http://docquery.fec.gov/pdf/120/201907159151132120/201907159151132120.pdf',
#     'receipt_date': '2019-07-15T20:18:59+00:00'},
#    'image_number': '201907159151132363',
#    'line_number': '11AI',
#    'load_timestamp': '2019-07-15T20:19:13+00:00',
#    'memo_code': 'X',
#    'memo_text': 'Note: Above Contribution earmarked through this organization.',
#    'pdf_url': 'http://docquery.fec.gov/cgi-bin/fecimg/?201907159151132363',
#    'pgo': 'P2020',
#    'related_line_number': 720,
#    'report_type': 'F3N',
#    'transaction_id': 'VVC97N6XMY5E'},
#   {'amendment_indicator': 'A',
#    'back_reference_schedule_name': None,
#    'back_reference_transaction_id': None,
#    'committee': {'candidate_ids': ['S0ME00111'],
#     'city': 'SOUTH FREEPORT',
#     'committee_id': 'C00709899',
#     'committee_type': 'S',
#     'committee_type_full': 'Senate',
#     'cycle': 2020,
#     'cycles': [2020],
#     'designation': 'P',
#     'designation_full': 'Principal campaign committee',
#     'filing_frequency': 'Q',
#     'name': 'SARA GIDEON FOR MAINE',
#     'organization_type': None,
#     'organization_type_full': None,
#     'party': 'DEM',
#     'party_full': 'DEMOCRATIC PARTY',
#     'state': 'ME',
#     'state_full': 'Maine',
#     'street_1': 'PO BOX 812',
#     'street_2': None,
#     'treasurer_name': 'LUNN, LISA',
#     'zip': '04078'},
#    'committee_id': 'C00709899',
#    'conduit_committee_city': None,
#    'conduit_committee_id': None,
#    'conduit_committee_name': None,
#    'conduit_committee_state': None,
#    'conduit_committee_street1': None,
#    'conduit_committee_street2': None,
#    'conduit_committee_zip': None,
#    'contribution_receipt_amount': 350.0,
#    'contribution_receipt_date': '2019-06-30',
#    'contributor_aggregate_ytd': 350.0,
#    'contributor_city': 'New York',
#    'contributor_employer': 'NYC Health + Hospitals',
#    'contributor_first_name': 'Helen',
#    'contributor_last_name': 'Bredt Stevens',
#    'contributor_middle_name': None,
#    'contributor_name': 'Bredt Stevens,  Helen',
#    'contributor_occupation': 'Psychiatry & Behavioral Health',
#    'contributor_prefix': None,
#    'contributor_state': 'NY',
#    'contributor_suffix': None,
#    'contributor_zip': '100169196',
#    'cycle': 2019,
#    'entity_type': 'IND',
#    'fec_election_type_desc': 'PRIMARY',
#    'file_number': 1340957,
#    'filing': {'amended_by': None,
#     'amendment_chain': [1340957],
#     'amendment_number': 0,
#     'amends_file': None,
#     'beginning_image_number': '201907159151132120',
#     'committee_id': 'C00709899',
#     'committee_name': 'SARA GIDEON FOR MAINE',
#     'coverage_end_date': '2019-06-30',
#     'coverage_start_date': '2019-06-20',
#     'csv_url': 'http://docquery.fec.gov/csv/957/1340957.csv',
#     'document_description': 'JULY QUARTERLY 2019',
#     'ending_image_number': '201907159151132518',
#     'fec_file_id': 'FEC-1340957',
#     'fec_url': 'http://docquery.fec.gov/dcdev/posted/1340957.fec',
#     'file_number': 1340957,
#     'filed_date': '2019-07-15',
#     'form_type': 'F3N',
#     'html_url': 'http://docquery.fec.gov/cgi-bin/forms/C00709899/1340957/',
#     'is_amended': False,
#     'load_timestamp': '2019-07-15T20:19:07+00:00',
#     'most_recent': True,
#     'most_recent_filing': 1340957,
#     'pdf_url': 'http://docquery.fec.gov/pdf/120/201907159151132120/201907159151132120.pdf',
#     'receipt_date': '2019-07-15T20:18:59+00:00'},
#    'image_number': '201907159151132364',
#    'line_number': '11AI',
#    'load_timestamp': '2019-07-15T20:19:13+00:00',
#    'memo_code': None,
#    'memo_text': None,
#    'pdf_url': 'http://docquery.fec.gov/cgi-bin/fecimg/?201907159151132364',
#    'pgo': 'P2020',
#    'related_line_number': 723,
#    'report_type': 'F3N',
#    'transaction_id': 'VVC97N77606'},
#   {'amendment_indicator': 'A',
#    'back_reference_schedule_name': None,
#    'back_reference_transaction_id': None,
#    'committee': {'candidate_ids': ['S0ME00111'],
#     'city': 'SOUTH FREEPORT',
#     'committee_id': 'C00709899',
#     'committee_type': 'S',
#     'committee_type_full': 'Senate',
#     'cycle': 2020,
#     'cycles': [2020],
#     'designation': 'P',
#     'designation_full': 'Principal campaign committee',
#     'filing_frequency': 'Q',
#     'name': 'SARA GIDEON FOR MAINE',
#     'organization_type': None,
#     'organization_type_full': None,
#     'party': 'DEM',
#     'party_full': 'DEMOCRATIC PARTY',
#     'state': 'ME',
#     'state_full': 'Maine',
#     'street_1': 'PO BOX 812',
#     'street_2': None,
#     'treasurer_name': 'LUNN, LISA',
#     'zip': '04078'},
#    'committee_id': 'C00709899',
#    'conduit_committee_city': None,
#    'conduit_committee_id': 'C00401224',
#    'conduit_committee_name': 'ActBlue',
#    'conduit_committee_state': None,
#    'conduit_committee_street1': None,
#    'conduit_committee_street2': None,
#    'conduit_committee_zip': None,
#    'contribution_receipt_amount': 2800.0,
#    'contribution_receipt_date': '2019-06-30',
#    'contributor_aggregate_ytd': 1016439.26,
#    'contributor_city': 'West Somerville',
#    'contributor_employer': None,
#    'contributor_first_name': None,
#    'contributor_last_name': 'ActBlue',
#    'contributor_middle_name': None,
#    'contributor_name': 'ActBlue,',
#    'contributor_occupation': 'Conduit total listed in Agg. field',
#    'contributor_prefix': None,
#    'contributor_state': 'MA',
#    'contributor_suffix': None,
#    'contributor_zip': '021440031',
#    'cycle': 2019,
#    'entity_type': 'PAC',
#    'fec_election_type_desc': 'GENERAL',
#    'file_number': 1340957,
#    'filing': {'amended_by': None,
#     'amendment_chain': [1340957],
#     'amendment_number': 0,
#     'amends_file': None,
#     'beginning_image_number': '201907159151132120',
#     'committee_id': 'C00709899',
#     'committee_name': 'SARA GIDEON FOR MAINE',
#     'coverage_end_date': '2019-06-30',
#     'coverage_start_date': '2019-06-20',
#     'csv_url': 'http://docquery.fec.gov/csv/957/1340957.csv',
#     'document_description': 'JULY QUARTERLY 2019',
#     'ending_image_number': '201907159151132518',
#     'fec_file_id': 'FEC-1340957',
#     'fec_url': 'http://docquery.fec.gov/dcdev/posted/1340957.fec',
#     'file_number': 1340957,
#     'filed_date': '2019-07-15',
#     'form_type': 'F3N',
#     'html_url': 'http://docquery.fec.gov/cgi-bin/forms/C00709899/1340957/',
#     'is_amended': False,
#     'load_timestamp': '2019-07-15T20:19:07+00:00',
#     'most_recent': True,
#     'most_recent_filing': 1340957,
#     'pdf_url': 'http://docquery.fec.gov/pdf/120/201907159151132120/201907159151132120.pdf',
#     'receipt_date': '2019-07-15T20:18:59+00:00'},
#    'image_number': '201907159151132396',
#    'line_number': '11AI',
#    'load_timestamp': '2019-07-15T20:19:14+00:00',
#    'memo_code': 'X',
#    'memo_text': 'Note: Above Contribution earmarked through this organization.',
#    'pdf_url': 'http://docquery.fec.gov/cgi-bin/fecimg/?201907159151132396',
#    'pgo': 'G2020',
#    'related_line_number': 820,
#    'report_type': 'F3N',
#    'transaction_id': 'VVC97N903Y6E'},
#   {'amendment_indicator': 'A',
#    'back_reference_schedule_name': None,
#    'back_reference_transaction_id': None,
#    'committee': {'candidate_ids': ['S0ME00111'],
#     'city': 'SOUTH FREEPORT',
#     'committee_id': 'C00709899',
#     'committee_type': 'S',
#     'committee_type_full': 'Senate',
#     'cycle': 2020,
#     'cycles': [2020],
#     'designation': 'P',
#     'designation_full': 'Principal campaign committee',
#     'filing_frequency': 'Q',
#     'name': 'SARA GIDEON FOR MAINE',
#     'organization_type': None,
#     'organization_type_full': None,
#     'party': 'DEM',
#     'party_full': 'DEMOCRATIC PARTY',
#     'state': 'ME',
#     'state_full': 'Maine',
#     'street_1': 'PO BOX 812',
#     'street_2': None,
#     'treasurer_name': 'LUNN, LISA',
#     'zip': '04078'},
#    'committee_id': 'C00709899',
#    'conduit_committee_city': None,
#    'conduit_committee_id': 'C00401224',
#    'conduit_committee_name': 'ActBlue',
#    'conduit_committee_state': None,
#    'conduit_committee_street1': None,
#    'conduit_committee_street2': None,
#    'conduit_committee_zip': None,
#    'contribution_receipt_amount': 2800.0,
#    'contribution_receipt_date': '2019-06-30',
#    'contributor_aggregate_ytd': 1016439.26,
#    'contributor_city': 'West Somerville',
#    'contributor_employer': None,
#    'contributor_first_name': None,
#    'contributor_last_name': 'ActBlue',
#    'contributor_middle_name': None,
#    'contributor_name': 'ActBlue,',
#    'contributor_occupation': 'Conduit total listed in Agg. field',
#    'contributor_prefix': None,
#    'contributor_state': 'MA',
#    'contributor_suffix': None,
#    'contributor_zip': '021440031',
#    'cycle': 2019,
#    'entity_type': 'PAC',
#    'fec_election_type_desc': 'PRIMARY',
#    'file_number': 1340957,
#    'filing': {'amended_by': None,
#     'amendment_chain': [1340957],
#     'amendment_number': 0,
#     'amends_file': None,
#     'beginning_image_number': '201907159151132120',
#     'committee_id': 'C00709899',
#     'committee_name': 'SARA GIDEON FOR MAINE',
#     'coverage_end_date': '2019-06-30',
#     'coverage_start_date': '2019-06-20',
#     'csv_url': 'http://docquery.fec.gov/csv/957/1340957.csv',
#     'document_description': 'JULY QUARTERLY 2019',
#     'ending_image_number': '201907159151132518',
#     'fec_file_id': 'FEC-1340957',
#     'fec_url': 'http://docquery.fec.gov/dcdev/posted/1340957.fec',
#     'file_number': 1340957,
#     'filed_date': '2019-07-15',
#     'form_type': 'F3N',
#     'html_url': 'http://docquery.fec.gov/cgi-bin/forms/C00709899/1340957/',
#     'is_amended': False,
#     'load_timestamp': '2019-07-15T20:19:07+00:00',
#     'most_recent': True,
#     'most_recent_filing': 1340957,
#     'pdf_url': 'http://docquery.fec.gov/pdf/120/201907159151132120/201907159151132120.pdf',
#     'receipt_date': '2019-07-15T20:18:59+00:00'},
#    'image_number': '201907159151132398',
#    'line_number': '11AI',
#    'load_timestamp': '2019-07-15T20:19:14+00:00',
#    'memo_code': 'X',
#    'memo_text': 'Note: Above Contribution earmarked through this organization.',
#    'pdf_url': 'http://docquery.fec.gov/cgi-bin/fecimg/?201907159151132398',
#    'pgo': 'P2020',
#    'related_line_number': 824,
#    'report_type': 'F3N',
#    'transaction_id': 'VVC97N6S9Z6E'},
#   {'amendment_indicator': 'A',
#    'back_reference_schedule_name': None,
#    'back_reference_transaction_id': None,
#    'committee': {'candidate_ids': ['S0ME00111'],
#     'city': 'SOUTH FREEPORT',
#     'committee_id': 'C00709899',
#     'committee_type': 'S',
#     'committee_type_full': 'Senate',
#     'cycle': 2020,
#     'cycles': [2020],
#     'designation': 'P',
#     'designation_full': 'Principal campaign committee',
#     'filing_frequency': 'Q',
#     'name': 'SARA GIDEON FOR MAINE',
#     'organization_type': None,
#     'organization_type_full': None,
#     'party': 'DEM',
#     'party_full': 'DEMOCRATIC PARTY',
#     'state': 'ME',
#     'state_full': 'Maine',
#     'street_1': 'PO BOX 812',
#     'street_2': None,
#     'treasurer_name': 'LUNN, LISA',
#     'zip': '04078'},
#    'committee_id': 'C00709899',
#    'conduit_committee_city': None,
#    'conduit_committee_id': 'C00401224',
#    'conduit_committee_name': 'ActBlue',
#    'conduit_committee_state': None,
#    'conduit_committee_street1': None,
#    'conduit_committee_street2': None,
#    'conduit_committee_zip': None,
#    'contribution_receipt_amount': 500.0,
#    'contribution_receipt_date': '2019-06-30',
#    'contributor_aggregate_ytd': 1016439.26,
#    'contributor_city': 'West Somerville',
#    'contributor_employer': None,
#    'contributor_first_name': None,
#    'contributor_last_name': 'ActBlue',
#    'contributor_middle_name': None,
#    'contributor_name': 'ActBlue,',
#    'contributor_occupation': 'Conduit total listed in Agg. field',
#    'contributor_prefix': None,
#    'contributor_state': 'MA',
#    'contributor_suffix': None,
#    'contributor_zip': '021440031',
#    'cycle': 2019,
#    'entity_type': 'PAC',
#    'fec_election_type_desc': 'PRIMARY',
#    'file_number': 1340957,
#    'filing': {'amended_by': None,
#     'amendment_chain': [1340957],
#     'amendment_number': 0,
#     'amends_file': None,
#     'beginning_image_number': '201907159151132120',
#     'committee_id': 'C00709899',
#     'committee_name': 'SARA GIDEON FOR MAINE',
#     'coverage_end_date': '2019-06-30',
#     'coverage_start_date': '2019-06-20',
#     'csv_url': 'http://docquery.fec.gov/csv/957/1340957.csv',
#     'document_description': 'JULY QUARTERLY 2019',
#     'ending_image_number': '201907159151132518',
#     'fec_file_id': 'FEC-1340957',
#     'fec_url': 'http://docquery.fec.gov/dcdev/posted/1340957.fec',
#     'file_number': 1340957,
#     'filed_date': '2019-07-15',
#     'form_type': 'F3N',
#     'html_url': 'http://docquery.fec.gov/cgi-bin/forms/C00709899/1340957/',
#     'is_amended': False,
#     'load_timestamp': '2019-07-15T20:19:07+00:00',
#     'most_recent': True,
#     'most_recent_filing': 1340957,
#     'pdf_url': 'http://docquery.fec.gov/pdf/120/201907159151132120/201907159151132120.pdf',
#     'receipt_date': '2019-07-15T20:18:59+00:00'},
#    'image_number': '201907159151132479',
#    'line_number': '11AI',
#    'load_timestamp': '2019-07-15T20:19:15+00:00',
#    'memo_code': 'X',
#    'memo_text': 'Note: Above Contribution earmarked through this organization.',
#    'pdf_url': 'http://docquery.fec.gov/cgi-bin/fecimg/?201907159151132479',
#    'pgo': 'P2020',
#    'related_line_number': 1069,
#    'report_type': 'F3N',
#    'transaction_id': 'VVC97N6XN19E'},
#   {'amendment_indicator': 'A',
#    'back_reference_schedule_name': None,
#    'back_reference_transaction_id': None,
#    'committee': {'candidate_ids': ['S0ME00111'],
#     'city': 'SOUTH FREEPORT',
#     'committee_id': 'C00709899',
#     'committee_type': 'S',
#     'committee_type_full': 'Senate',
#     'cycle': 2020,
#     'cycles': [2020],
#     'designation': 'P',
#     'designation_full': 'Principal campaign committee',
#     'filing_frequency': 'Q',
#     'name': 'SARA GIDEON FOR MAINE',
#     'organization_type': None,
#     'organization_type_full': None,
#     'party': 'DEM',
#     'party_full': 'DEMOCRATIC PARTY',
#     'state': 'ME',
#     'state_full': 'Maine',
#     'street_1': 'PO BOX 812',
#     'street_2': None,
#     'treasurer_name': 'LUNN, LISA',
#     'zip': '04078'},
#    'committee_id': 'C00709899',
#    'conduit_committee_city': None,
#    'conduit_committee_id': 'C00401224',
#    'conduit_committee_name': 'ActBlue',
#    'conduit_committee_state': None,
#    'conduit_committee_street1': None,
#    'conduit_committee_street2': None,
#    'conduit_committee_zip': None,
#    'contribution_receipt_amount': 2400.0,
#    'contribution_receipt_date': '2019-06-30',
#    'contributor_aggregate_ytd': 1016439.26,
#    'contributor_city': 'West Somerville',
#    'contributor_employer': None,
#    'contributor_first_name': None,
#    'contributor_last_name': 'ActBlue',
#    'contributor_middle_name': None,
#    'contributor_name': 'ActBlue,',
#    'contributor_occupation': 'Conduit total listed in Agg. field',
#    'contributor_prefix': None,
#    'contributor_state': 'MA',
#    'contributor_suffix': None,
#    'contributor_zip': '021440031',
#    'cycle': 2019,
#    'entity_type': 'PAC',
#    'fec_election_type_desc': 'GENERAL',
#    'file_number': 1340957,
#    'filing': {'amended_by': None,
#     'amendment_chain': [1340957],
#     'amendment_number': 0,
#     'amends_file': None,
#     'beginning_image_number': '201907159151132120',
#     'committee_id': 'C00709899',
#     'committee_name': 'SARA GIDEON FOR MAINE',
#     'coverage_end_date': '2019-06-30',
#     'coverage_start_date': '2019-06-20',
#     'csv_url': 'http://docquery.fec.gov/csv/957/1340957.csv',
#     'document_description': 'JULY QUARTERLY 2019',
#     'ending_image_number': '201907159151132518',
#     'fec_file_id': 'FEC-1340957',
#     'fec_url': 'http://docquery.fec.gov/dcdev/posted/1340957.fec',
#     'file_number': 1340957,
#     'filed_date': '2019-07-15',
#     'form_type': 'F3N',
#     'html_url': 'http://docquery.fec.gov/cgi-bin/forms/C00709899/1340957/',
#     'is_amended': False,
#     'load_timestamp': '2019-07-15T20:19:07+00:00',
#     'most_recent': True,
#     'most_recent_filing': 1340957,
#     'pdf_url': 'http://docquery.fec.gov/pdf/120/201907159151132120/201907159151132120.pdf',
#     'receipt_date': '2019-07-15T20:18:59+00:00'},
#    'image_number': '201907159151132480',
#    'line_number': '11AI',
#    'load_timestamp': '2019-07-15T20:19:16+00:00',
#    'memo_code': 'X',
#    'memo_text': 'Note: Above Contribution earmarked through this organization.',
#    'pdf_url': 'http://docquery.fec.gov/cgi-bin/fecimg/?201907159151132480',
#    'pgo': 'G2020',
#    'related_line_number': 1071,
#    'report_type': 'F3N',
#    'transaction_id': 'VVC97N90419E'},
#   {'amendment_indicator': 'A',
#    'back_reference_schedule_name': None,
#    'back_reference_transaction_id': None,
#    'committee': {'candidate_ids': ['S0ME00111'],
#     'city': 'SOUTH FREEPORT',
#     'committee_id': 'C00709899',
#     'committee_type': 'S',
#     'committee_type_full': 'Senate',
#     'cycle': 2020,
#     'cycles': [2020],
#     'designation': 'P',
#     'designation_full': 'Principal campaign committee',
#     'filing_frequency': 'Q',
#     'name': 'SARA GIDEON FOR MAINE',
#     'organization_type': None,
#     'organization_type_full': None,
#     'party': 'DEM',
#     'party_full': 'DEMOCRATIC PARTY',
#     'state': 'ME',
#     'state_full': 'Maine',
#     'street_1': 'PO BOX 812',
#     'street_2': None,
#     'treasurer_name': 'LUNN, LISA',
#     'zip': '04078'},
#    'committee_id': 'C00709899',
#    'conduit_committee_city': None,
#    'conduit_committee_id': None,
#    'conduit_committee_name': None,
#    'conduit_committee_state': None,
#    'conduit_committee_street1': None,
#    'conduit_committee_street2': None,
#    'conduit_committee_zip': None,
#    'contribution_receipt_amount': 2600.0,
#    'contribution_receipt_date': '2019-06-30',
#    'contributor_aggregate_ytd': 2600.0,
#    'contributor_city': 'Freeport',
#    'contributor_employer': 'Not Employed',
#    'contributor_first_name': 'Jane',
#    'contributor_last_name': 'Bradley',
#    'contributor_middle_name': None,
#    'contributor_name': 'Bradley,  Jane',
#    'contributor_occupation': 'Retired',
#    'contributor_prefix': None,
#    'contributor_state': 'ME',
#    'contributor_suffix': None,
#    'contributor_zip': '040326512',
#    'cycle': 2019,
#    'entity_type': 'IND',
#    'fec_election_type_desc': 'PRIMARY',
#    'file_number': 1340957,
#    'filing': {'amended_by': None,
#     'amendment_chain': [1340957],
#     'amendment_number': 0,
#     'amends_file': None,
#     'beginning_image_number': '201907159151132120',
#     'committee_id': 'C00709899',
#     'committee_name': 'SARA GIDEON FOR MAINE',
#     'coverage_end_date': '2019-06-30',
#     'coverage_start_date': '2019-06-20',
#     'csv_url': 'http://docquery.fec.gov/csv/957/1340957.csv',
#     'document_description': 'JULY QUARTERLY 2019',
#     'ending_image_number': '201907159151132518',
#     'fec_file_id': 'FEC-1340957',
#     'fec_url': 'http://docquery.fec.gov/dcdev/posted/1340957.fec',
#     'file_number': 1340957,
#     'filed_date': '2019-07-15',
#     'form_type': 'F3N',
#     'html_url': 'http://docquery.fec.gov/cgi-bin/forms/C00709899/1340957/',
#     'is_amended': False,
#     'load_timestamp': '2019-07-15T20:19:07+00:00',
#     'most_recent': True,
#     'most_recent_filing': 1340957,
#     'pdf_url': 'http://docquery.fec.gov/pdf/120/201907159151132120/201907159151132120.pdf',
#     'receipt_date': '2019-07-15T20:18:59+00:00'},
#    'image_number': '201907159151132481',
#    'line_number': '11AI',
#    'load_timestamp': '2019-07-15T20:19:16+00:00',
#    'memo_code': None,
#    'memo_text': None,
#    'pdf_url': 'http://docquery.fec.gov/cgi-bin/fecimg/?201907159151132481',
#    'pgo': 'P2020',
#    'related_line_number': 1074,
#    'report_type': 'F3N',
#    'transaction_id': 'VVC97N77639'},
#   {'amendment_indicator': 'A',
#    'back_reference_schedule_name': None,
#    'back_reference_transaction_id': None,
#    'committee': {'candidate_ids': ['S0ME00111'],
#     'city': 'SOUTH FREEPORT',
#     'committee_id': 'C00709899',
#     'committee_type': 'S',
#     'committee_type_full': 'Senate',
#     'cycle': 2020,
#     'cycles': [2020],
#     'designation': 'P',
#     'designation_full': 'Principal campaign committee',
#     'filing_frequency': 'Q',
#     'name': 'SARA GIDEON FOR MAINE',
#     'organization_type': None,
#     'organization_type_full': None,
#     'party': 'DEM',
#     'party_full': 'DEMOCRATIC PARTY',
#     'state': 'ME',
#     'state_full': 'Maine',
#     'street_1': 'PO BOX 812',
#     'street_2': None,
#     'treasurer_name': 'LUNN, LISA',
#     'zip': '04078'},
#    'committee_id': 'C00709899',
#    'conduit_committee_city': None,
#    'conduit_committee_id': 'C00401224',
#    'conduit_committee_name': 'ActBlue',
#    'conduit_committee_state': None,
#    'conduit_committee_street1': None,
#    'conduit_committee_street2': None,
#    'conduit_committee_zip': None,
#    'contribution_receipt_amount': 1000.0,
#    'contribution_receipt_date': '2019-06-30',
#    'contributor_aggregate_ytd': 1016439.26,
#    'contributor_city': 'West Somerville',
#    'contributor_employer': None,
#    'contributor_first_name': None,
#    'contributor_last_name': 'ActBlue',
#    'contributor_middle_name': None,
#    'contributor_name': 'ActBlue,',
#    'contributor_occupation': 'Conduit total listed in Agg. field',
#    'contributor_prefix': None,
#    'contributor_state': 'MA',
#    'contributor_suffix': None,
#    'contributor_zip': '021440031',
#    'cycle': 2019,
#    'entity_type': 'PAC',
#    'fec_election_type_desc': 'PRIMARY',
#    'file_number': 1340957,
#    'filing': {'amended_by': None,
#     'amendment_chain': [1340957],
#     'amendment_number': 0,
#     'amends_file': None,
#     'beginning_image_number': '201907159151132120',
#     'committee_id': 'C00709899',
#     'committee_name': 'SARA GIDEON FOR MAINE',
#     'coverage_end_date': '2019-06-30',
#     'coverage_start_date': '2019-06-20',
#     'csv_url': 'http://docquery.fec.gov/csv/957/1340957.csv',
#     'document_description': 'JULY QUARTERLY 2019',
#     'ending_image_number': '201907159151132518',
#     'fec_file_id': 'FEC-1340957',
#     'fec_url': 'http://docquery.fec.gov/dcdev/posted/1340957.fec',
#     'file_number': 1340957,
#     'filed_date': '2019-07-15',
#     'form_type': 'F3N',
#     'html_url': 'http://docquery.fec.gov/cgi-bin/forms/C00709899/1340957/',
#     'is_amended': False,
#     'load_timestamp': '2019-07-15T20:19:07+00:00',
#     'most_recent': True,
#     'most_recent_filing': 1340957,
#     'pdf_url': 'http://docquery.fec.gov/pdf/120/201907159151132120/201907159151132120.pdf',
#     'receipt_date': '2019-07-15T20:18:59+00:00'},
#    'image_number': '201907159151132167',
#    'line_number': '11AI',
#    'load_timestamp': '2019-07-15T20:19:08+00:00',
#    'memo_code': 'X',
#    'memo_text': 'Note: Above Contribution earmarked through this organization.',
#    'pdf_url': 'http://docquery.fec.gov/cgi-bin/fecimg/?201907159151132167',
#    'pgo': 'P2020',
#    'related_line_number': 131,
#    'report_type': 'F3N',
#    'transaction_id': 'VVC97N6V441E'},
#   {'amendment_indicator': 'A',
#    'back_reference_schedule_name': None,
#    'back_reference_transaction_id': None,
#    'committee': {'candidate_ids': ['S0ME00111'],
#     'city': 'SOUTH FREEPORT',
#     'committee_id': 'C00709899',
#     'committee_type': 'S',
#     'committee_type_full': 'Senate',
#     'cycle': 2020,
#     'cycles': [2020],
#     'designation': 'P',
#     'designation_full': 'Principal campaign committee',
#     'filing_frequency': 'Q',
#     'name': 'SARA GIDEON FOR MAINE',
#     'organization_type': None,
#     'organization_type_full': None,
#     'party': 'DEM',
#     'party_full': 'DEMOCRATIC PARTY',
#     'state': 'ME',
#     'state_full': 'Maine',
#     'street_1': 'PO BOX 812',
#     'street_2': None,
#     'treasurer_name': 'LUNN, LISA',
#     'zip': '04078'},
#    'committee_id': 'C00709899',
#    'conduit_committee_city': None,
#    'conduit_committee_id': 'C00401224',
#    'conduit_committee_name': 'ActBlue',
#    'conduit_committee_state': None,
#    'conduit_committee_street1': None,
#    'conduit_committee_street2': None,
#    'conduit_committee_zip': None,
#    'contribution_receipt_amount': 2800.0,
#    'contribution_receipt_date': '2019-06-30',
#    'contributor_aggregate_ytd': 1016439.26,
#    'contributor_city': 'West Somerville',
#    'contributor_employer': None,
#    'contributor_first_name': None,
#    'contributor_last_name': 'ActBlue',
#    'contributor_middle_name': None,
#    'contributor_name': 'ActBlue,',
#    'contributor_occupation': 'Conduit total listed in Agg. field',
#    'contributor_prefix': None,
#    'contributor_state': 'MA',
#    'contributor_suffix': None,
#    'contributor_zip': '021440031',
#    'cycle': 2019,
#    'entity_type': 'PAC',
#    'fec_election_type_desc': 'PRIMARY',
#    'file_number': 1340957,
#    'filing': {'amended_by': None,
#     'amendment_chain': [1340957],
#     'amendment_number': 0,
#     'amends_file': None,
#     'beginning_image_number': '201907159151132120',
#     'committee_id': 'C00709899',
#     'committee_name': 'SARA GIDEON FOR MAINE',
#     'coverage_end_date': '2019-06-30',
#     'coverage_start_date': '2019-06-20',
#     'csv_url': 'http://docquery.fec.gov/csv/957/1340957.csv',
#     'document_description': 'JULY QUARTERLY 2019',
#     'ending_image_number': '201907159151132518',
#     'fec_file_id': 'FEC-1340957',
#     'fec_url': 'http://docquery.fec.gov/dcdev/posted/1340957.fec',
#     'file_number': 1340957,
#     'filed_date': '2019-07-15',
#     'form_type': 'F3N',
#     'html_url': 'http://docquery.fec.gov/cgi-bin/forms/C00709899/1340957/',
#     'is_amended': False,
#     'load_timestamp': '2019-07-15T20:19:07+00:00',
#     'most_recent': True,
#     'most_recent_filing': 1340957,
#     'pdf_url': 'http://docquery.fec.gov/pdf/120/201907159151132120/201907159151132120.pdf',
#     'receipt_date': '2019-07-15T20:18:59+00:00'},
#    'image_number': '201907159151132310',
#    'line_number': '11AI',
#    'load_timestamp': '2019-07-15T20:19:12+00:00',
#    'memo_code': 'X',
#    'memo_text': 'Note: Above Contribution earmarked through this organization.',
#    'pdf_url': 'http://docquery.fec.gov/cgi-bin/fecimg/?201907159151132310',
#    'pgo': 'P2020',
#    'related_line_number': 560,
#    'report_type': 'F3N',
#    'transaction_id': 'VVC97N6VBJ4E'},
#   {'amendment_indicator': 'A',
#    'back_reference_schedule_name': None,
#    'back_reference_transaction_id': None,
#    'committee': {'candidate_ids': ['S0ME00111'],
#     'city': 'SOUTH FREEPORT',
#     'committee_id': 'C00709899',
#     'committee_type': 'S',
#     'committee_type_full': 'Senate',
#     'cycle': 2020,
#     'cycles': [2020],
#     'designation': 'P',
#     'designation_full': 'Principal campaign committee',
#     'filing_frequency': 'Q',
#     'name': 'SARA GIDEON FOR MAINE',
#     'organization_type': None,
#     'organization_type_full': None,
#     'party': 'DEM',
#     'party_full': 'DEMOCRATIC PARTY',
#     'state': 'ME',
#     'state_full': 'Maine',
#     'street_1': 'PO BOX 812',
#     'street_2': None,
#     'treasurer_name': 'LUNN, LISA',
#     'zip': '04078'},
#    'committee_id': 'C00709899',
#    'conduit_committee_city': None,
#    'conduit_committee_id': 'C00401224',
#    'conduit_committee_name': 'ActBlue',
#    'conduit_committee_state': None,
#    'conduit_committee_street1': None,
#    'conduit_committee_street2': None,
#    'conduit_committee_zip': None,
#    'contribution_receipt_amount': 250.0,
#    'contribution_receipt_date': '2019-06-30',
#    'contributor_aggregate_ytd': 1016439.26,
#    'contributor_city': 'West Somerville',
#    'contributor_employer': None,
#    'contributor_first_name': None,
#    'contributor_last_name': 'ActBlue',
#    'contributor_middle_name': None,
#    'contributor_name': 'ActBlue,',
#    'contributor_occupation': 'Conduit total listed in Agg. field',
#    'contributor_prefix': None,
#    'contributor_state': 'MA',
#    'contributor_suffix': None,
#    'contributor_zip': '021440031',
#    'cycle': 2019,
#    'entity_type': 'PAC',
#    'fec_election_type_desc': 'PRIMARY',
#    'file_number': 1340957,
#    'filing': {'amended_by': None,
#     'amendment_chain': [1340957],
#     'amendment_number': 0,
#     'amends_file': None,
#     'beginning_image_number': '201907159151132120',
#     'committee_id': 'C00709899',
#     'committee_name': 'SARA GIDEON FOR MAINE',
#     'coverage_end_date': '2019-06-30',
#     'coverage_start_date': '2019-06-20',
#     'csv_url': 'http://docquery.fec.gov/csv/957/1340957.csv',
#     'document_description': 'JULY QUARTERLY 2019',
#     'ending_image_number': '201907159151132518',
#     'fec_file_id': 'FEC-1340957',
#     'fec_url': 'http://docquery.fec.gov/dcdev/posted/1340957.fec',
#     'file_number': 1340957,
#     'filed_date': '2019-07-15',
#     'form_type': 'F3N',
#     'html_url': 'http://docquery.fec.gov/cgi-bin/forms/C00709899/1340957/',
#     'is_amended': False,
#     'load_timestamp': '2019-07-15T20:19:07+00:00',
#     'most_recent': True,
#     'most_recent_filing': 1340957,
#     'pdf_url': 'http://docquery.fec.gov/pdf/120/201907159151132120/201907159151132120.pdf',
#     'receipt_date': '2019-07-15T20:18:59+00:00'},
#    'image_number': '201907159151132311',
#    'line_number': '11AI',
#    'load_timestamp': '2019-07-15T20:19:12+00:00',
#    'memo_code': 'X',
#    'memo_text': 'Note: Above Contribution earmarked through this organization.',
#    'pdf_url': 'http://docquery.fec.gov/cgi-bin/fecimg/?201907159151132311',
#    'pgo': 'P2020',
#    'related_line_number': 564,
#    'report_type': 'F3N',
#    'transaction_id': 'VVC97N6YRK4E'},
#   {'amendment_indicator': 'A',
#    'back_reference_schedule_name': 'SA11AI',
#    'back_reference_transaction_id': 'VVC97N6SMM4E',
#    'committee': {'candidate_ids': ['S0ME00111'],
#     'city': 'SOUTH FREEPORT',
#     'committee_id': 'C00709899',
#     'committee_type': 'S',
#     'committee_type_full': 'Senate',
#     'cycle': 2020,
#     'cycles': [2020],
#     'designation': 'P',
#     'designation_full': 'Principal campaign committee',
#     'filing_frequency': 'Q',
#     'name': 'SARA GIDEON FOR MAINE',
#     'organization_type': None,
#     'organization_type_full': None,
#     'party': 'DEM',
#     'party_full': 'DEMOCRATIC PARTY',
#     'state': 'ME',
#     'state_full': 'Maine',
#     'street_1': 'PO BOX 812',
#     'street_2': None,
#     'treasurer_name': 'LUNN, LISA',
#     'zip': '04078'},
#    'committee_id': 'C00709899',
#    'conduit_committee_city': None,
#    'conduit_committee_id': None,
#    'conduit_committee_name': None,
#    'conduit_committee_state': None,
#    'conduit_committee_street1': None,
#    'conduit_committee_street2': None,
#    'conduit_committee_zip': None,
#    'contribution_receipt_amount': 2800.0,
#    'contribution_receipt_date': '2019-06-30',
#    'contributor_aggregate_ytd': 2800.0,
#    'contributor_city': 'Portsmouth',
#    'contributor_employer': 'State of New Hampshire',
#    'contributor_first_name': 'Martha',
#    'contributor_last_name': 'Fuller Clark',
#    'contributor_middle_name': None,
#    'contributor_name': 'Fuller Clark,  Martha',
#    'contributor_occupation': 'Senator',
#    'contributor_prefix': None,
#    'contributor_state': 'NH',
#    'contributor_suffix': None,
#    'contributor_zip': '038014306',
#    'cycle': 2019,
#    'entity_type': 'IND',
#    'fec_election_type_desc': 'PRIMARY',
#    'file_number': 1340957,
#    'filing': {'amended_by': None,
#     'amendment_chain': [1340957],
#     'amendment_number': 0,
#     'amends_file': None,
#     'beginning_image_number': '201907159151132120',
#     'committee_id': 'C00709899',
#     'committee_name': 'SARA GIDEON FOR MAINE',
#     'coverage_end_date': '2019-06-30',
#     'coverage_start_date': '2019-06-20',
#     'csv_url': 'http://docquery.fec.gov/csv/957/1340957.csv',
#     'document_description': 'JULY QUARTERLY 2019',
#     'ending_image_number': '201907159151132518',
#     'fec_file_id': 'FEC-1340957',
#     'fec_url': 'http://docquery.fec.gov/dcdev/posted/1340957.fec',
#     'file_number': 1340957,
#     'filed_date': '2019-07-15',
#     'form_type': 'F3N',
#     'html_url': 'http://docquery.fec.gov/cgi-bin/forms/C00709899/1340957/',
#     'is_amended': False,
#     'load_timestamp': '2019-07-15T20:19:07+00:00',
#     'most_recent': True,
#     'most_recent_filing': 1340957,
#     'pdf_url': 'http://docquery.fec.gov/pdf/120/201907159151132120/201907159151132120.pdf',
#     'receipt_date': '2019-07-15T20:18:59+00:00'},
#    'image_number': '201907159151132311',
#    'line_number': '11AI',
#    'load_timestamp': '2019-07-15T20:19:12+00:00',
#    'memo_code': None,
#    'memo_text': '* Earmarked Contribution: See Below',
#    'pdf_url': 'http://docquery.fec.gov/cgi-bin/fecimg/?201907159151132311',
#    'pgo': 'P2020',
#    'related_line_number': 565,
#    'report_type': 'F3N',
#    'transaction_id': 'VVC97N6SMM4'},
#   {'amendment_indicator': 'A',
#    'back_reference_schedule_name': None,
#    'back_reference_transaction_id': None,
#    'committee': {'candidate_ids': ['S0ME00111'],
#     'city': 'SOUTH FREEPORT',
#     'committee_id': 'C00709899',
#     'committee_type': 'S',
#     'committee_type_full': 'Senate',
#     'cycle': 2020,
#     'cycles': [2020],
#     'designation': 'P',
#     'designation_full': 'Principal campaign committee',
#     'filing_frequency': 'Q',
#     'name': 'SARA GIDEON FOR MAINE',
#     'organization_type': None,
#     'organization_type_full': None,
#     'party': 'DEM',
#     'party_full': 'DEMOCRATIC PARTY',
#     'state': 'ME',
#     'state_full': 'Maine',
#     'street_1': 'PO BOX 812',
#     'street_2': None,
#     'treasurer_name': 'LUNN, LISA',
#     'zip': '04078'},
#    'committee_id': 'C00709899',
#    'conduit_committee_city': None,
#    'conduit_committee_id': 'C00401224',
#    'conduit_committee_name': 'ActBlue',
#    'conduit_committee_state': None,
#    'conduit_committee_street1': None,
#    'conduit_committee_street2': None,
#    'conduit_committee_zip': None,
#    'contribution_receipt_amount': 2800.0,
#    'contribution_receipt_date': '2019-06-30',
#    'contributor_aggregate_ytd': 1016439.26,
#    'contributor_city': 'West Somerville',
#    'contributor_employer': None,
#    'contributor_first_name': None,
#    'contributor_last_name': 'ActBlue',
#    'contributor_middle_name': None,
#    'contributor_name': 'ActBlue,',
#    'contributor_occupation': 'Conduit total listed in Agg. field',
#    'contributor_prefix': None,
#    'contributor_state': 'MA',
#    'contributor_suffix': None,
#    'contributor_zip': '021440031',
#    'cycle': 2019,
#    'entity_type': 'PAC',
#    'fec_election_type_desc': 'PRIMARY',
#    'file_number': 1340957,
#    'filing': {'amended_by': None,
#     'amendment_chain': [1340957],
#     'amendment_number': 0,
#     'amends_file': None,
#     'beginning_image_number': '201907159151132120',
#     'committee_id': 'C00709899',
#     'committee_name': 'SARA GIDEON FOR MAINE',
#     'coverage_end_date': '2019-06-30',
#     'coverage_start_date': '2019-06-20',
#     'csv_url': 'http://docquery.fec.gov/csv/957/1340957.csv',
#     'document_description': 'JULY QUARTERLY 2019',
#     'ending_image_number': '201907159151132518',
#     'fec_file_id': 'FEC-1340957',
#     'fec_url': 'http://docquery.fec.gov/dcdev/posted/1340957.fec',
#     'file_number': 1340957,
#     'filed_date': '2019-07-15',
#     'form_type': 'F3N',
#     'html_url': 'http://docquery.fec.gov/cgi-bin/forms/C00709899/1340957/',
#     'is_amended': False,
#     'load_timestamp': '2019-07-15T20:19:07+00:00',
#     'most_recent': True,
#     'most_recent_filing': 1340957,
#     'pdf_url': 'http://docquery.fec.gov/pdf/120/201907159151132120/201907159151132120.pdf',
#     'receipt_date': '2019-07-15T20:18:59+00:00'},
#    'image_number': '201907159151132312',
#    'line_number': '11AI',
#    'load_timestamp': '2019-07-15T20:19:12+00:00',
#    'memo_code': 'X',
#    'memo_text': 'Note: Above Contribution earmarked through this organization.',
#    'pdf_url': 'http://docquery.fec.gov/cgi-bin/fecimg/?201907159151132312',
#    'pgo': 'P2020',
#    'related_line_number': 566,
#    'report_type': 'F3N',
#    'transaction_id': 'VVC97N6SMM4E'}]}
